# %%
import iris
from warnings import warn
from iris.exceptions import ConstraintMismatchError

# %%
hfradar = dict(longbay="http://129.252.139.124/thredds/dodsC/longbay.nc",
               savannah="http://129.252.139.124/thredds/dodsC/savannah.nc",
               miami_wera="http://129.252.139.124/thredds/dodsC/miami_wera.nc",
               tampa_codar="http://129.252.139.124/thredds/dodsC/tampa_codar.nc",
               tampa_wera="http://129.252.139.124/thredds/dodsC/tampa_wera.nc")

# %%
for region in hfradar.keys():
    try:
        cube = iris.load_cube(hfradar[region])
    except (ConstraintMismatchError, ValueError, TypeError) as e:
        warn("Unable to load %s. %s\n" % (region, e))
# Out:
# /home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1147: UserWarning: Ignoring netCDF variable 'time_string' invalid units 'string YYYY-MM-DD hh:mm:ss UTC'
#   warnings.warn(msg.format(msg_name, msg_units))
# -c:5: UserWarning: Unable to load savannah. Not implemented for this type
#
# -c:5: UserWarning: Unable to load longbay. Not implemented for this type
# -c:5: UserWarning: Unable to load tampa_codar. '_FillValue' is not a permitted attribute
#
# -c:5: UserWarning: Unable to load miami_wera. '_FillValue' is not a permitted attribute
# -c:5: UserWarning: Unable to load tampa_wera. Not implemented for this type

# %%
from tempfile import NamedTemporaryFile
from sh import ncdump, ncgen, cfchecker

def call_cf_checker(url):
    cdl = ncdump('-h', url)
    if cdl.exit_code == 0:
        with NamedTemporaryFile(suffix='.cdl') as cdl_file:
            cdl_file.write(cdl.stdout)
            cdl_file.flush()
            with NamedTemporaryFile(suffix='.nc') as nc_file:
                out = ncgen('-x', cdl_file.name, o=nc_file.name, _ok_code=1)
                if out.exit_code == 0:
                    out = cfchecker(nc_file.name, _ok_code=1)
    return cdl, out

# %%
for region in hfradar.keys():
    url = hfradar[region]
    cdl, out = call_cf_checker(url)
    print(url)
    print('CF Checker:\n%s\nCF Error:\n%s\nCDL:\n%s\n' % (out.stdout, out.stderr, cdl))
# Out:
# http://129.252.139.124/thredds/dodsC/savannah.nc
# CF Checker:
#
# CHECKING NetCDF FILE: /tmp/tmpxiyOEZ.nc
# =====================
# Using CF Checker Version 2.0.2
# Using Standard Name Table Version 23 (2013-03-23:T12:30:00Z)
# Using Area Type Table Version 1 (5 December 2008)
#
#
# COULD NOT OPEN FILE, PLEASE CHECK THAT NETCDF IS FORMATTED CORRECTLY.
#
# ERRORS detected: 1
#
# CF Error:
# Traceback (most recent call last):
#   File "/home/filipe/anaconda/envs/ioos/bin/cfchecks", line 9, in <module>
#     load_entry_point('cfchecker==2.0.3', 'console_scripts', 'cfchecks')()
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cfchecker/__init__.py", line 12, in cfchecks_main
#     rc = inst.checker(file)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cfchecker/cfchecks.py", line 303, in checker
#     self.f=cdms.open(file,"r")
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/dataset.py", line 191, in openDataset
#     file = CdmsFile(path,mode)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/dataset.py", line 908, in __init__
#     gridkey, lat, lon = var.generateGridkey(self._convention_, self.variables)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/avariable.py", line 158, in generateGridkey
#     raise CDMSError, "Axis %s is both a latitude and longitude axis! Check standard_name and/or axis attributes."%lat.id
# cdms2.error.CDMSError: Axis lon is both a latitude and longitude axis! Check standard_name and/or axis attributes.
#
# CDL:
# netcdf savannah {
# dimensions:
# 	lat = 150 ;
# 	lon = 150 ;
# 	maxStrlen64 = 64 ;
# 	time = 1403 ;
# 	time_string = 20 ;
# 	z = 1 ;
# variables:
# 	float lat(lat) ;
# 		lat:long_name = "Latitude in decimal degrees" ;
# 		lat:standard_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 		lat:reference = "geographical coordinates" ;
# 		lat:valid_range = -180.f, 180.f ;
# 	float lon(lon) ;
# 		lon:long_name = "Longitude in decimal degrees" ;
# 		lon:standard_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "Y" ;
# 		lon:reference = "geographical coordinates" ;
# 		lon:valid_range = -180.f, 180.f ;
# 	float z(z) ;
# 		z:long_name = "Height" ;
# 		z:standard_name = "height" ;
# 		z:units = "m" ;
# 		z:axis = "Z" ;
# 		z:reference = "mean seal level (MSL)" ;
# 		z:positive = "up" ;
# 	char time_string(time, time_string) ;
# 		time_string:long_name = "Sample Time String UTC" ;
# 		time_string:standard_name = "datetime UTC" ;
# 		time_string:units = "string YYYY-MM-DD hh:mm:ss UTC" ;
# 		time_string:c_format = "%4d-%2d-%2d %2d:%2d:%2d" ;
# 		time_string:_DODS_strlen = 20 ;
# 		time_string:_DODS_dimName = "time_string" ;
# 	char time(time, maxStrlen64) ;
# 		time:_CoordinateAxisType = "Time" ;
# 		time:long_name = "time coordinate" ;
# 		time:standard_name = "time" ;
# 	float eastward_current(time, lon, lat) ;
# 		eastward_current:long_name = "eastward surface_current" ;
# 		eastward_current:standard_name = "eastward_current" ;
# 		eastward_current:units = "cm/s" ;
# 		eastward_current:valid_min = -300.f ;
# 		eastward_current:valid_max = 300.f ;
# 		eastward_current:_FillValue = -999.9f ;
# 	float northward_current(time, lon, lat) ;
# 		northward_current:long_name = "northward surface current" ;
# 		northward_current:standard_name = "northward_current" ;
# 		northward_current:units = "cm/s" ;
# 		northward_current:valid_min = -300.f ;
# 		northward_current:valid_max = 300.f ;
# 		northward_current:_FillValue = -999.9f ;
# 	float eastward_current_accuracy(time, lon, lat) ;
# 		eastward_current_accuracy:long_name = "accuracy of eastward surface current" ;
# 		eastward_current_accuracy:standard_name = "eastward_current_accuracy" ;
# 		eastward_current_accuracy:units = "cm/s" ;
# 		eastward_current_accuracy:valid_min = -300.f ;
# 		eastward_current_accuracy:valid_max = 300.f ;
# 		eastward_current_accuracy:_FillValue = -999.9f ;
# 	float northward_current_accuracy(time, lon, lat) ;
# 		northward_current_accuracy:long_name = "accuracy of northward surface current" ;
# 		northward_current_accuracy:standard_name = "northward_current_accuracy" ;
# 		northward_current_accuracy:units = "cm/s" ;
# 		northward_current_accuracy:valid_min = -300.f ;
# 		northward_current_accuracy:valid_max = 300.f ;
# 		northward_current_accuracy:_FillValue = -999.9f ;
#
# // global attributes:
# 		:title = "Hourly Surface Currents from WERA" ;
# 		:summary = "near real-time HF Radar surface current measurements reported from a combination of land stations at St. Catherine\'s Island, GA and Jeckyll Island, GA" ;
# 		:creator_name = "Dr. Dana K. Savidge" ;
# 		:creator_url = "http://www.skio.usg.edu/?p=research/phy/sabsoon/wera/wera" ;
# 		:institution = "Skidaway Institute of Oceanography" ;
# 		:publisher = "SECOORA" ;
# 		:publisher_url = "http://secoora.org" ;
# 		:publisher_dods_url = "http://trident.baruch.sc.edu/netcdf_latest/wera" ;
# 		:publisher_email = "jeremy.cothran@gmail.com" ;
# 		:Convention = "CF-1.0" ;
# 		:format_category_code = "fixed-map" ;
# 		:platform_code = "savannah" ;
# 		:package_code = "wera_hf_radar" ;
# }
#
#
# http://129.252.139.124/thredds/dodsC/longbay.nc
# CF Checker:
#
# CHECKING NetCDF FILE: /tmp/tmpoon_oJ.nc
# =====================
# Using CF Checker Version 2.0.2
# Using Standard Name Table Version 23 (2013-03-23:T12:30:00Z)
# Using Area Type Table Version 1 (5 December 2008)
#
#
# COULD NOT OPEN FILE, PLEASE CHECK THAT NETCDF IS FORMATTED CORRECTLY.
#
# ERRORS detected: 1
#
# CF Error:
# Traceback (most recent call last):
#   File "/home/filipe/anaconda/envs/ioos/bin/cfchecks", line 9, in <module>
#     load_entry_point('cfchecker==2.0.3', 'console_scripts', 'cfchecks')()
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cfchecker/__init__.py", line 12, in cfchecks_main
#     rc = inst.checker(file)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cfchecker/cfchecks.py", line 303, in checker
#     self.f=cdms.open(file,"r")
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/dataset.py", line 191, in openDataset
#     file = CdmsFile(path,mode)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/dataset.py", line 908, in __init__
#     gridkey, lat, lon = var.generateGridkey(self._convention_, self.variables)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/avariable.py", line 158, in generateGridkey
#     raise CDMSError, "Axis %s is both a latitude and longitude axis! Check standard_name and/or axis attributes."%lat.id
# cdms2.error.CDMSError: Axis lon is both a latitude and longitude axis! Check standard_name and/or axis attributes.
#
# CDL:
# netcdf longbay {
# dimensions:
# 	lat = 150 ;
# 	lon = 150 ;
# 	maxStrlen64 = 64 ;
# 	time = 1415 ;
# 	time_string = 20 ;
# 	z = 1 ;
# variables:
# 	float lat(lat) ;
# 		lat:long_name = "Latitude in decimal degrees" ;
# 		lat:standard_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 		lat:reference = "geographical coordinates" ;
# 		lat:valid_range = -180.f, 180.f ;
# 	float lon(lon) ;
# 		lon:long_name = "Longitude in decimal degrees" ;
# 		lon:standard_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "Y" ;
# 		lon:reference = "geographical coordinates" ;
# 		lon:valid_range = -180.f, 180.f ;
# 	float z(z) ;
# 		z:long_name = "Height" ;
# 		z:standard_name = "height" ;
# 		z:units = "m" ;
# 		z:axis = "Z" ;
# 		z:reference = "mean seal level (MSL)" ;
# 		z:positive = "up" ;
# 	char time_string(time, time_string) ;
# 		time_string:long_name = "Sample Time String UTC" ;
# 		time_string:standard_name = "datetime UTC" ;
# 		time_string:units = "string YYYY-MM-DD hh:mm:ss UTC" ;
# 		time_string:c_format = "%4d-%2d-%2d %2d:%2d:%2d" ;
# 		time_string:_DODS_strlen = 20 ;
# 		time_string:_DODS_dimName = "time_string" ;
# 	char time(time, maxStrlen64) ;
# 		time:_CoordinateAxisType = "Time" ;
# 		time:long_name = "time coordinate" ;
# 		time:standard_name = "time" ;
# 	float eastward_current(time, lon, lat) ;
# 		eastward_current:long_name = "eastward surface_current" ;
# 		eastward_current:standard_name = "eastward_current" ;
# 		eastward_current:units = "cm/s" ;
# 		eastward_current:valid_min = -300.f ;
# 		eastward_current:valid_max = 300.f ;
# 		eastward_current:_FillValue = -999.9f ;
# 	float northward_current(time, lon, lat) ;
# 		northward_current:long_name = "northward surface current" ;
# 		northward_current:standard_name = "northward_current" ;
# 		northward_current:units = "cm/s" ;
# 		northward_current:valid_min = -300.f ;
# 		northward_current:valid_max = 300.f ;
# 		northward_current:_FillValue = -999.9f ;
# 	float eastward_current_accuracy(time, lon, lat) ;
# 		eastward_current_accuracy:long_name = "accuracy of eastward surface current" ;
# 		eastward_current_accuracy:standard_name = "eastward_current_accuracy" ;
# 		eastward_current_accuracy:units = "cm/s" ;
# 		eastward_current_accuracy:valid_min = -300.f ;
# 		eastward_current_accuracy:valid_max = 300.f ;
# 		eastward_current_accuracy:_FillValue = -999.9f ;
# 	float northward_current_accuracy(time, lon, lat) ;
# 		northward_current_accuracy:long_name = "accuracy of northward surface current" ;
# 		northward_current_accuracy:standard_name = "northward_current_accuracy" ;
# 		northward_current_accuracy:units = "cm/s" ;
# 		northward_current_accuracy:valid_min = -300.f ;
# 		northward_current_accuracy:valid_max = 300.f ;
# 		northward_current_accuracy:_FillValue = -999.9f ;
#
# // global attributes:
# 		:title = "Hourly Surface Currents from WERA" ;
# 		:summary = "near real-time HF Radar surface current measurements reported from a combination of land stations at Georgetown, SC and Ft. Caswell, NC" ;
# 		:creator_name = "Dr. George Voulgaris" ;
# 		:creator_url = "http://www.geol.sc.edu/gvoulgar/cpsdlab.html" ;
# 		:institution = "University of South Carolina" ;
# 		:publisher = "SECOORA" ;
# 		:publisher_url = "http://secoora.org" ;
# 		:publisher_dods_url = "http://trident.baruch.sc.edu/netcdf_latest/wera" ;
# 		:publisher_email = "jeremy.cothran@gmail.com" ;
# 		:Convention = "CF-1.0" ;
# 		:format_category_code = "fixed-map" ;
# 		:platform_code = "longbay" ;
# 		:package_code = "wera_hf_radar" ;
# }
#
#
# http://129.252.139.124/thredds/dodsC/tampa_codar.nc
# CF Checker:
#
# CF Error:
# ncgen: /tmp/tmpu6MHqd.cdl line 79: syntax error, unexpected _FILLVALUE, expecting IDENT or _FORMAT
#
# CDL:
# netcdf tampa_codar {
# dimensions:
# 	lat = 33 ;
# 	lon = 44 ;
# 	maxStrlen64 = 64 ;
# 	time = 681 ;
# 	time_string = 20 ;
# 	z = 1 ;
# variables:
# 	float lat(lat) ;
# 		lat:long_name = "Latitude in decimal degrees" ;
# 		lat:standard_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 		lat:reference = "geographical coordinates" ;
# 		lat:valid_range = -180.f, 180.f ;
# 	float lon(lon) ;
# 		lon:long_name = "Longitude in decimal degrees" ;
# 		lon:standard_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "Y" ;
# 		lon:reference = "geographical coordinates" ;
# 		lon:valid_range = -180.f, 180.f ;
# 	float z(z) ;
# 		z:long_name = "Height" ;
# 		z:standard_name = "height" ;
# 		z:units = "m" ;
# 		z:axis = "Z" ;
# 		z:reference = "mean seal level (MSL)" ;
# 		z:positive = "up" ;
# 	char time_string(time, time_string) ;
# 		time_string:long_name = "Sample Time String UTC" ;
# 		time_string:standard_name = "datetime UTC" ;
# 		time_string:units = "string YYYY-MM-DD hh:mm:ss UTC" ;
# 		time_string:c_format = "%4d-%2d-%2d %2d:%2d:%2d" ;
# 		time_string:_DODS_strlen = 20 ;
# 		time_string:_DODS_dimName = "time_string" ;
# 	char time(time, maxStrlen64) ;
# 		time:_CoordinateAxisType = "Time" ;
# 		time:long_name = "time coordinate" ;
# 		time:standard_name = "time" ;
# 	float eastward_current(time, lon, lat) ;
# 		eastward_current:long_name = "eastward surface_current" ;
# 		eastward_current:standard_name = "eastward_current" ;
# 		eastward_current:units = "cm/s" ;
# 		eastward_current:valid_min = -300.f ;
# 		eastward_current:valid_max = 300.f ;
# 	float northward_current(time, lon, lat) ;
# 		northward_current:long_name = "northward surface current" ;
# 		northward_current:standard_name = "northward_current" ;
# 		northward_current:units = "cm/s" ;
# 		northward_current:valid_min = -300.f ;
# 		northward_current:valid_max = 300.f ;
# 	float eastward_current_accuracy(time, lon, lat) ;
# 		eastward_current_accuracy:long_name = "accuracy of eastward surface current" ;
# 		eastward_current_accuracy:standard_name = "eastward_current_accuracy" ;
# 		eastward_current_accuracy:units = "cm/s" ;
# 		eastward_current_accuracy:valid_min = -300.f ;
# 		eastward_current_accuracy:valid_max = 300.f ;
# 	float northward_current_accuracy(time, lon, lat) ;
# 		northward_current_accuracy:long_name = "accuracy of northward surface current" ;
# 		northward_current_accuracy:standard_name = "northward_current_accuracy" ;
# 		northward_current_accuracy:units = "cm/s" ;
# 		northward_current_accuracy:valid_min = -300.f ;
# 		northward_current_accuracy:valid_max = 300.f ;
#
# // global attributes:
# 		:title = "Hourly Surface Currents from CODAR" ;
# 		:summary = "near real-time HF Radar surface current measurements reported from a combination of land stations at Redington Shores, Fort DeSoto and Naples, FL" ;
# 		:creator_name = "Dr. Robert H. Weisberg" ;
# 		:creator_url = "http://ocgweb.marine.usf.edu/hfradar/codar_current_map.html" ;
# 		:institution = "University of South Florida" ;
# 		:publisher = "SECOORA" ;
# 		:publisher_url = "http://secoora.org" ;
# 		:publisher_dods_url = "http://trident.baruch.sc.edu/thredds/catalog_hfradar.html?dataset=hfradar_wfs" ;
# 		:publisher_email = "jeremy.cothran@gmail.com" ;
# 		:Convention = "CF-1.0" ;
# 		:format_category_code = "fixed-map" ;
# 		:_FillValue = -999.9f ;
# 		:platform_code = "tampa" ;
# 		:package_code = "hf_radar" ;
# }
#
#
# http://129.252.139.124/thredds/dodsC/miami_wera.nc
# CF Checker:
#
# CF Error:
# ncgen: /tmp/tmpt5XAkV.cdl line 77: syntax error, unexpected _FILLVALUE, expecting IDENT or _FORMAT
#
# CDL:
# netcdf miami_wera {
# dimensions:
# 	lat = 23 ;
# 	lon = 22 ;
# 	maxStrlen64 = 64 ;
# 	time = 584 ;
# 	time_string = 20 ;
# 	z = 1 ;
# variables:
# 	float lat(lat) ;
# 		lat:long_name = "Latitude in decimal degrees" ;
# 		lat:standard_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 		lat:reference = "geographical coordinates" ;
# 		lat:valid_range = -180.f, 180.f ;
# 	float lon(lon) ;
# 		lon:long_name = "Longitude in decimal degrees" ;
# 		lon:standard_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "Y" ;
# 		lon:reference = "geographical coordinates" ;
# 		lon:valid_range = -180.f, 180.f ;
# 	float z(z) ;
# 		z:long_name = "Height" ;
# 		z:standard_name = "height" ;
# 		z:units = "m" ;
# 		z:axis = "Z" ;
# 		z:reference = "mean sea level (MSL)" ;
# 		z:positive = "up" ;
# 	char time_string(time, time_string) ;
# 		time_string:long_name = "Sample Time String UTC" ;
# 		time_string:standard_name = "datetime UTC" ;
# 		time_string:units = "string YYYY-MM-DD hh:mm:ss UTC" ;
# 		time_string:c_format = "%4d-%2d-%2d %2d:%2d:%2d" ;
# 		time_string:_DODS_strlen = 20 ;
# 		time_string:_DODS_dimName = "time_string" ;
# 	char time(time, maxStrlen64) ;
# 		time:_CoordinateAxisType = "Time" ;
# 		time:long_name = "time coordinate" ;
# 		time:standard_name = "time" ;
# 	float eastward_current(time, lon, lat) ;
# 		eastward_current:long_name = "eastward surface_current" ;
# 		eastward_current:standard_name = "eastward_current" ;
# 		eastward_current:units = "cm/s" ;
# 		eastward_current:valid_min = -300.f ;
# 		eastward_current:valid_max = 300.f ;
# 	float northward_current(time, lon, lat) ;
# 		northward_current:long_name = "northward surface current" ;
# 		northward_current:standard_name = "northward_current" ;
# 		northward_current:units = "cm/s" ;
# 		northward_current:valid_min = -300.f ;
# 		northward_current:valid_max = 300.f ;
# 	float eastward_current_accuracy(time, lon, lat) ;
# 		eastward_current_accuracy:long_name = "accuracy of eastward surface current" ;
# 		eastward_current_accuracy:standard_name = "surface current accuracy u" ;
# 		eastward_current_accuracy:units = "cm/s" ;
# 		eastward_current_accuracy:valid_min = -300.f ;
# 		eastward_current_accuracy:valid_max = 300.f ;
# 	float northward_current_accuracy(time, lon, lat) ;
# 		northward_current_accuracy:long_name = "accuracy of northward surface current" ;
# 		northward_current_accuracy:standard_name = "surface current accuracy v" ;
# 		northward_current_accuracy:units = "cm/s" ;
# 		northward_current_accuracy:valid_min = -300.f ;
# 		northward_current_accuracy:valid_max = 300.f ;
#
# // global attributes:
# 		:title = "Hourly Surface Currents from WERA" ;
# 		:institution = "Rosenstiel School for Marine and Atmospheric Sciences - University of Miami" ;
# 		:institution_code = "umiami" ;
# 		:institution_url = "http://iwave.rsmas.miami.edu/wera" ;
# 		:institution_dods_url = "http://hfrnet-dp.rsmas.miami.edu/cgi-bin/nph-dods/wera" ;
# 		:contact = "nshay@rsmas.miami.edu" ;
# 		:Convention = "CF-1.0" ;
# 		:format_category_code = "fixed-map" ;
# 		:data_in_average = "20141631530_efsn.cur_asc (20141631530_stf.RAD and 20141631520_vir.RAD); 20141631520_efsn.cur_asc (20141631520_vir.RAD and 20141631510_stf.RAD); 20141631510_efsn.cur_asc (20141631510_stf.RAD and 20141631500_vir.RAD); 20141631500_efsn.cur_asc (20141631500_vir.RAD and 20141631450_stf.RAD); 20141631450_efsn.cur_asc (20141631450_stf.RAD and 20141631440_vir.RAD); 20141631440_efsn.cur_asc (20141631440_vir.RAD and 20141631430_stf.RAD); " ;
# 		:_FillValue = -999.9f ;
# 		:platform_code = "um_weranet" ;
# 		:package_code = "wera_hf_radar" ;
# }
#
#
# http://129.252.139.124/thredds/dodsC/tampa_wera.nc
# CF Checker:
#
# CHECKING NetCDF FILE: /tmp/tmpXGX3Xm.nc
# =====================
# Using CF Checker Version 2.0.2
# Using Standard Name Table Version 23 (2013-03-23:T12:30:00Z)
# Using Area Type Table Version 1 (5 December 2008)
#
#
# COULD NOT OPEN FILE, PLEASE CHECK THAT NETCDF IS FORMATTED CORRECTLY.
#
# ERRORS detected: 1
#
# CF Error:
# Traceback (most recent call last):
#   File "/home/filipe/anaconda/envs/ioos/bin/cfchecks", line 9, in <module>
#     load_entry_point('cfchecker==2.0.3', 'console_scripts', 'cfchecks')()
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cfchecker/__init__.py", line 12, in cfchecks_main
#     rc = inst.checker(file)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cfchecker/cfchecks.py", line 303, in checker
#     self.f=cdms.open(file,"r")
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/dataset.py", line 191, in openDataset
#     file = CdmsFile(path,mode)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/dataset.py", line 908, in __init__
#     gridkey, lat, lon = var.generateGridkey(self._convention_, self.variables)
#   File "/home/filipe/anaconda/envs/ioos/lib/python2.7/site-packages/cdms2/avariable.py", line 158, in generateGridkey
#     raise CDMSError, "Axis %s is both a latitude and longitude axis! Check standard_name and/or axis attributes."%lat.id
# cdms2.error.CDMSError: Axis lon is both a latitude and longitude axis! Check standard_name and/or axis attributes.
#
# CDL:
# netcdf tampa_wera {
# dimensions:
# 	lat = 250 ;
# 	lon = 250 ;
# 	maxStrlen64 = 64 ;
# 	time = 1844 ;
# 	time_string = 20 ;
# 	z = 1 ;
# variables:
# 	float lat(lat) ;
# 		lat:long_name = "Latitude in decimal degrees" ;
# 		lat:standard_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 		lat:reference = "geographical coordinates" ;
# 		lat:valid_range = -180.f, 180.f ;
# 	float lon(lon) ;
# 		lon:long_name = "Longitude in decimal degrees" ;
# 		lon:standard_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "Y" ;
# 		lon:reference = "geographical coordinates" ;
# 		lon:valid_range = -180.f, 180.f ;
# 	float z(z) ;
# 		z:long_name = "Height" ;
# 		z:standard_name = "height" ;
# 		z:units = "m" ;
# 		z:axis = "Z" ;
# 		z:reference = "mean seal level (MSL)" ;
# 		z:positive = "up" ;
# 	char time_string(time, time_string) ;
# 		time_string:long_name = "Sample Time String UTC" ;
# 		time_string:standard_name = "datetime UTC" ;
# 		time_string:units = "string YYYY-MM-DD hh:mm:ss UTC" ;
# 		time_string:c_format = "%4d-%2d-%2d %2d:%2d:%2d" ;
# 		time_string:_DODS_strlen = 20 ;
# 		time_string:_DODS_dimName = "time_string" ;
# 	char time(time, maxStrlen64) ;
# 		time:_CoordinateAxisType = "Time" ;
# 		time:long_name = "time coordinate" ;
# 		time:standard_name = "time" ;
# 	float eastward_current(time, lon, lat) ;
# 		eastward_current:long_name = "eastward surface_current" ;
# 		eastward_current:standard_name = "eastward_current" ;
# 		eastward_current:units = "cm/s" ;
# 		eastward_current:valid_min = -300.f ;
# 		eastward_current:valid_max = 300.f ;
# 		eastward_current:_FillValue = -999.9f ;
# 	float northward_current(time, lon, lat) ;
# 		northward_current:long_name = "northward surface current" ;
# 		northward_current:standard_name = "northward_current" ;
# 		northward_current:units = "cm/s" ;
# 		northward_current:valid_min = -300.f ;
# 		northward_current:valid_max = 300.f ;
# 		northward_current:_FillValue = -999.9f ;
# 	float eastward_current_accuracy(time, lon, lat) ;
# 		eastward_current_accuracy:long_name = "accuracy of eastward surface current" ;
# 		eastward_current_accuracy:standard_name = "eastward_current_accuracy" ;
# 		eastward_current_accuracy:units = "cm/s" ;
# 		eastward_current_accuracy:valid_min = -300.f ;
# 		eastward_current_accuracy:valid_max = 300.f ;
# 		eastward_current_accuracy:_FillValue = -999.9f ;
# 	float northward_current_accuracy(time, lon, lat) ;
# 		northward_current_accuracy:long_name = "accuracy of northward surface current" ;
# 		northward_current_accuracy:standard_name = "northward_current_accuracy" ;
# 		northward_current_accuracy:units = "cm/s" ;
# 		northward_current_accuracy:valid_min = -300.f ;
# 		northward_current_accuracy:valid_max = 300.f ;
# 		northward_current_accuracy:_FillValue = -999.9f ;
#
# // global attributes:
# 		:title = "Hourly Surface Currents from WERA" ;
# 		:summary = "near real-time HF Radar surface current measurements reported from a combination of land stations at Fort DeSoto, FL and Venice, FL" ;
# 		:creator_name = "Dr. Robert H. Weisberg" ;
# 		:creator_url = "http://ocgweb.marine.usf.edu/hfradar/wera_current_map.html" ;
# 		:institution = "University of South Florida" ;
# 		:publisher = "SECOORA" ;
# 		:publisher_url = "http://secoora.org" ;
# 		:publisher_dods_url = "http://trident.baruch.sc.edu/thredds/catalog_hfradar.html?dataset=hfradar_usf" ;
# 		:publisher_email = "jeremy.cothran@gmail.com" ;
# 		:Convention = "CF-1.0" ;
# 		:format_category_code = "fixed-map" ;
# 		:platform_code = "usf" ;
# 		:package_code = "wera_hf_radar" ;
# }
