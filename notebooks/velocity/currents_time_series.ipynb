# %%
# %matplotlib inline

import iris
import pyoos
import owslib

import time
start_time = time.time()

# %%
import os
import sys
root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(root)

from utilities import css_styles
style = '../../style.css'
css_styles(style)


dow = {d: i for i, d in
       enumerate('Mon,Tue,Wed,Thu,Fri,Sat,Sun'.split(','))}


def next_dow(date, day):
    while date.weekday() != day:
        date += timedelta(days=1)
    return date

# %% [markdown]
# ### SECOORA Currents notebook
# Based on IOOS system-test [notebook](http://nbviewer.ipython.org/github/ioos/system-test/blob/master/Theme_2_Extreme_Events/Scenario_2A/ModelDataCompare_Currents/Model_Obs_Compare_Currents.ipynb).

# %%
import pytz
from datetime import datetime, timedelta

# Choose the date range.
if False:
    kw = dict(hour=12, minute=0, second=0, microsecond=0)
    stop = next_dow(datetime.utcnow(), dow['Fri']).replace(**kw)
else:
    stop = datetime(2014, 10, 10, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = stop - timedelta(hours=7)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# %%
directory = '{:%Y-%m-%d}'.format(stop)

if not os.path.exists(directory):
    os.makedirs(directory)

# %%
import logging as log
reload(log)

fmt = '{:*^64}'.format
log.captureWarnings(True)
LOG_FILENAME = 'log'
LOG_FILENAME = os.path.join(directory, LOG_FILENAME)
log.basicConfig(filename=LOG_FILENAME,
                filemode='w',
                format='%(asctime)s %(levelname)s: %(message)s',
                datefmt='%I:%M:%S',
                level=log.INFO,
                stream=None)

log.info(fmt(' Run information '))
log.info('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
log.info('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
log.info('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
log.info('Bounding box: {0:3.2f}, {1:3.2f},'
         '{2:3.2f}, {3:3.2f}'.format(*bbox))
log.info(fmt(' Software version '))
log.info('Iris version: {}'.format(iris.__version__))
log.info('owslib version: {}'.format(owslib.__version__))
log.info('pyoos version: {}'.format(pyoos.__version__))

# %%
from owslib import fes
from utilities import fes_date_filter, CF_names

name_list = CF_names['currents']

begin, end = fes_date_filter(start, stop)

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')


or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw) for
                  val in name_list])

not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])


filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls
dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW URLs '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' DAP URLs '))
for url in dap_urls:
    log.info('{}.html'.format(url))

log.info(fmt(' SOS URLs '))
for url in sos_urls:
    log.info('{}'.format(url))

# %% [markdown]
# <div class="success"><strong>Get list of stations</strong>
# - we get a list of the available stations from COOPS/NDBC</div>

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

sos_name = 'Currents'

sos = CoopsSos()
sos.end_time = stop
sos.start_time = start
sos.variables = [sos_name]
sos.server.identification.title

ofrs = sos.server.offerings
title = sos.server.identification.title

log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pyoos.collectors.ndbc.ndbc_sos import NdbcSos

ndbc = NdbcSos()

ndbc.end_time = stop
ndbc.start_time = start
ndbc.variables = [sos_name]
ndbc.server.identification.title

ofrs = sos.server.offerings
title = sos.server.identification.title

log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request, get_coops_longname, to_html

params = dict(bin='1',
              observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:CurrentsActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
log.info('sos_request: {}'.format(url))

obs_sos = read_csv(url)
obs_sos.drop_duplicates(subset='station_id', inplace=True)

# Clean the dataframe.
drop = ['bin (count)',
        'orientation',
        'bin_size (m)',
        'number_of_bins',
        'bin_distance (m)',
        'processing_level',
        'sensor_depth (m)',
        'sampling_rate (Hz)',
        'first_bin_center (m)',
        'reporting_interval (s)',
        'sea_water_speed (cm/s)',
        'sea_water_temperature (C)',
        'platform_roll_angle (degree)',
        'platform_orientation (degree)',
        'platform_pitch_angle (degree)',
        'direction_of_sea_water_velocity (degree)']

rename = {'sensor_id': 'sensor',
          'station_id': 'station',
          'latitude (degree)': 'lat',
          'longitude (degree)': 'lon'}

obs_sos.drop(drop, axis=1, inplace=True)
obs_sos.rename(columns=rename, inplace=True)

obs_sos['sensor'] = [s.split(':')[-1] for s in obs_sos['sensor']]
obs_sos['station'] = [s.split(':')[-1] for s in obs_sos['station']]
obs_sos['name'] = [get_coops_longname(s) for s in obs_sos['station']]

obs_sos.set_index('name', inplace=True)
to_html(obs_sos, style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Old Port Tampa</th>
#       <td> t02010</td>
#       <td> Workhorse-ADCP-457</td>
#       <td> 27.8629</td>
#       <td>-82.5537</td>
#       <td> 2014-10-10T05:00:00Z</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from utilities import get_ndbc_longname

params = dict(offering='urn:ioos:network:noaa.nws.ndbc:all',
              observedProperty=sos_name,
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox))

uri = 'http://sdf.ndbc.noaa.gov/sos/server.php'
url = sos_request(uri, **params)
log.info('sos_request: {}'.format(url))

obs_ndbc = read_csv(url)
obs_ndbc.drop_duplicates(subset='station_id', inplace=True)

# Clean the dataframe.
drop = ['depth (m)',
        'bin (count)',
        'pct_bad (%)',
        'quality_flags',
        'pct_rejected (%)',
        'pct_good_3_beam (%)',
        'pct_good_4_beam (%)',
        'error_velocity (cm/s)',
        'sea_water_speed (cm/s)',
        'sea_water_temperature (C)',
        'platform_roll_angle (degree)',
        'echo_intensity_beam1 (count)',
        'echo_intensity_beam2 (count)',
        'echo_intensity_beam3 (count)',
        'echo_intensity_beam4 (count)',
        'platform_pitch_angle (degree)',
        'platform_orientation (degree)',
        'upward_sea_water_velocity (cm/s)',
        'correlation_magnitude_beam1 (count)',
        'correlation_magnitude_beam2 (count)',
        'correlation_magnitude_beam3 (count)',
        'correlation_magnitude_beam4 (count)',
        'direction_of_sea_water_velocity (degree)']

rename = {'sensor_id': 'sensor',
          'station_id': 'station',
          'latitude (degree)': 'lat',
          'longitude (degree)': 'lon'}

obs_ndbc.drop(drop, axis=1, inplace=True)
obs_ndbc.rename(columns=rename, inplace=True)

obs_ndbc['sensor'] = [s.split(':')[-1] for s in obs_ndbc['sensor']]
obs_ndbc['station'] = [s.split(':')[-1] for s in obs_ndbc['station']]
obs_ndbc['name'] = [get_ndbc_longname(s) for s in obs_ndbc['station']]

obs_ndbc.set_index('name', inplace=True)
to_html(obs_ndbc, style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Grays Reef</th>
#       <td> 41008</td>
#       <td> adcp0</td>
#       <td> 31.400</td>
#       <td>-80.870</td>
#       <td> 2012-02-20T10:50:00Z</td>
#     </tr>
#     <tr>
#       <th>St. Augustine</th>
#       <td> 41012</td>
#       <td> adcp0</td>
#       <td> 30.040</td>
#       <td>-80.550</td>
#       <td> 2013-10-16T01:50:00Z</td>
#     </tr>
#     <tr>
#       <th>Frying Pan Shoals</th>
#       <td> 41013</td>
#       <td> pscm0</td>
#       <td> 33.440</td>
#       <td>-77.740</td>
#       <td> 2008-10-02T19:50:00Z</td>
#     </tr>
#     <tr>
#       <th>Sunset Nearshore (Sun 2)</th>
#       <td> 41024</td>
#       <td> adcp0</td>
#       <td> 33.850</td>
#       <td>-78.480</td>
#       <td> 2008-04-27T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>Capers Nearshore (Cap 2)</th>
#       <td> 41029</td>
#       <td> adcp0</td>
#       <td> 32.810</td>
#       <td>-79.630</td>
#       <td> 2008-07-24T18:00:00Z</td>
#     </tr>
#     <tr>
#       <th>Capers Mid-Shelf (Cap 3)</th>
#       <td> 41030</td>
#       <td> adcp0</td>
#       <td> 32.520</td>
#       <td>-79.340</td>
#       <td> 2008-02-04T08:00:00Z</td>
#     </tr>
#     <tr>
#       <th>Fripp Nearshore (Frp 2)</th>
#       <td> 41033</td>
#       <td> adcp0</td>
#       <td> 32.280</td>
#       <td>-80.410</td>
#       <td> 2008-07-24T18:00:00Z</td>
#     </tr>
#     <tr>
#       <th>Onslow Bay Inner</th>
#       <td> 41035</td>
#       <td> pscm0</td>
#       <td> 34.480</td>
#       <td>-77.280</td>
#       <td> 2009-07-25T22:50:00Z</td>
#     </tr>
#     <tr>
#       <th>Onslow Bay Outer</th>
#       <td> 41036</td>
#       <td> adcp0</td>
#       <td> 34.210</td>
#       <td>-76.950</td>
#       <td> 2008-07-24T19:00:00Z</td>
#     </tr>
#     <tr>
#       <th>Ilm2</th>
#       <td> 41038</td>
#       <td> adcp0</td>
#       <td> 34.140</td>
#       <td>-77.710</td>
#       <td> 2008-05-20T09:00:00Z</td>
#     </tr>
#     <tr>
#       <th>East Gulf</th>
#       <td> 42003</td>
#       <td> adcp0</td>
#       <td> 25.740</td>
#       <td>-85.730</td>
#       <td> 2011-05-20T07:50:00Z</td>
#     </tr>
#     <tr>
#       <th>C10</th>
#       <td> 42013</td>
#       <td> adcp0</td>
#       <td> 27.169</td>
#       <td>-82.926</td>
#       <td> 2013-08-18T06:00:00Z</td>
#     </tr>
#     <tr>
#       <th>C14</th>
#       <td> 42021</td>
#       <td> adcp0</td>
#       <td> 28.311</td>
#       <td>-83.306</td>
#       <td> 2010-07-13T04:00:00Z</td>
#     </tr>
#     <tr>
#       <th>C16</th>
#       <td> 42024</td>
#       <td> adcp0</td>
#       <td> 27.464</td>
#       <td>-84.219</td>
#       <td> 2009-07-21T02:00:00Z</td>
#     </tr>
#     <tr>
#       <th>West Tampa</th>
#       <td> 42036</td>
#       <td> pscm0</td>
#       <td> 28.500</td>
#       <td>-84.520</td>
#       <td> 2012-06-26T11:50:00Z</td>
#     </tr>
#     <tr>
#       <th>Offshore Sand Key</th>
#       <td> 42080</td>
#       <td> adcp0</td>
#       <td> 24.390</td>
#       <td>-81.950</td>
#       <td> 2009-09-12T02:06:00Z</td>
#     </tr>
#     <tr>
#       <th>Virginia Beach 64 Nm East Of Virginia Beach</th>
#       <td> 44014</td>
#       <td> adcp0</td>
#       <td> 36.610</td>
#       <td>-74.840</td>
#       <td> 2008-07-24T19:00:00Z</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
import numpy as np
from pandas import Panel, DataFrame


def df2xt(df):
    """Enter a coops2df `currents` and return a distance by time df."""
    num_bins = np.unique(df['number_of_bins'])
    if num_bins.size == 1:
        num_bins = num_bins[0]
    else:
        raise ValueError('Expect unique num_bins.  Got {!r}'.format(num_bins))
    depths = df['bin_distance (m)'].iloc[:num_bins].values
    times = df.index.values.reshape(-1, num_bins)[:, 0]
    kw = dict(index=times, columns=depths)
    ang = df['direction_of_sea_water_velocity (degree)']
    spd = df['sea_water_speed (cm/s)']
    tmp = df['sea_water_temperature (C)']
    panel = dict(ang=DataFrame(ang.reshape(-1, num_bins), **kw),
                 spd=DataFrame(spd.reshape(-1, num_bins), **kw),
                 tmp=DataFrame(tmp.reshape(-1, num_bins), **kw))
    panel = Panel.fromDict(panel)
    panel.name = df.name
    return panel

# %%
import iris
from utilities import coops2df

iris.FUTURE.netcdf_promote = True

bad_sos_data = []
obs_sos_data = dict()
for station in obs_sos.station:
    try:
        df = coops2df(sos, station)
        p = df2xt(df)
        # p = p.swapaxes(0, 1).swapaxes(1, 2).to_frame()
        obs_sos_data.update({station: p})
    except Exception as e:
        bad_sos_data.append(station)
        name = get_coops_longname(station)
        log.warning("[%s] %s:\n%s" % (station, name, e))

# %% [markdown]
# <div class="error"><strong>Test: </strong>
# The following cells are just to check if the data makes sense.
# It will be removed from future versions of this notebook!</div>

# %%
from utilities import ndbc2df

bad_ndbc_data = []
obs_ndbc_data = dict()

for station_name, obs in obs_ndbc.iterrows():
    try:
        station = obs['station']
        df = ndbc2df(ndbc, station)
        obs_ndbc_data.update({station: df})
    except Exception as e:
        bad_ndbc_data.append(station)
        # name = get_ndbc_longname(station)
        # log.warning("[%s] %s:\n%s" % (station, name, e))
        log.warning("[%s]:\n%s" % (station, e))

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

depth = -p['spd'].columns.values
index = p['spd'].index.to_pydatetime()

fig, ax = plt.subplots(figsize=(7, 2.75))
cs = ax.pcolormesh(index, depth, p['spd'].values.T, cmap=plt.cm.RdBu_r)
_ = ax.set_title(p.name)
fig.tight_layout()

# %%
import mpl_toolkits.axisartist as AA
from mpl_toolkits.axes_grid1 import host_subplot

fig = plt.figure(figsize=(7, 2.75))
ax0 = host_subplot(111, axes_class=AA.Axes)
ax1 = ax0.twinx()
ax2 = ax0.twinx()

offset = 60
new_fixed_axis = ax2.get_grid_helper().new_fixed_axis
ax2.axis["right"] = new_fixed_axis(loc="right", axes=ax2,
                                   offset=(offset, 0))

ax2.axis["right"].toggle(all=True)

# Only plot the first bin.
kw = dict(linewidth=1.0, zorder=1)

p0, = ax0.plot(index, p['spd'].icol(0), color='blue', **kw)
ax0.set_ylabel('Current Speed (cm/s)')
ax0.axis["left"].label.set_color(p0.get_color())

color = 'green'
p1, = ax1.plot(index, p['ang'].icol(0), color=color, **kw)
ax1.set_ylabel('Current Direction (degrees)')
ax1.axis["right"].label.set_color(p1.get_color())

color = 'red'
p2, = ax2.plot(index, p['tmp'].icol(0), color=color, **kw)
ax2.set_ylabel('sea_water_temperature (C)')
ax2.axis["right"].label.set_color(p2.get_color())

ax0.grid(False)

# %%
import folium
from utilities import get_coordinates, inline_map

lon_center, lat_center = np.array(bbox).reshape(2, 2).mean(axis=0)
currents = folium.Map(location=[lat_center, lon_center], zoom_start=5)

# Create the map and add the bounding box line.
kw = dict(line_color='#FF0000', line_weight=2)
currents.line(get_coordinates(bbox), **kw)

# SOS
for station in obs_sos_data.keys():
    obs = obs_sos[obs_sos['station'] == station]
    popup = '<b>SOS:</b> {}'
    popup = popup.format(station)
    kw = dict(popup=popup, marker_color="green", marker_icon="ok")
    currents.simple_marker(location=[obs['lat'].values[0],
                                     obs['lon'].values[0]], **kw)

for station in bad_sos_data:
    obs = obs_sos[obs_sos['station'] == station]
    popup = '<b>SOS:</b> {}'
    popup = popup.format(station)
    kw = dict(popup=popup, marker_color="red", marker_icon="remove-sign")
    currents.simple_marker(location=[obs['lat'].values[0],
                                     obs['lon'].values[0]], **kw)

# NDBC
for station in obs_ndbc_data.keys():
    obs = obs_ndbc[obs_ndbc['station'] == station]
    popup = '<b>NDBC:</b> {}'
    popup = popup.format(station)
    kw = dict(popup=popup, marker_color="blue", marker_icon="ok")
    currents.simple_marker(location=[obs['lat'].values[0],
                                     obs['lon'].values[0]], **kw)

for station in bad_ndbc_data:
    obs = obs_ndbc[obs_ndbc['station'] == station]
    popup = '<b>NDBC:</b> {}'
    popup = popup.format(station)
    kw = dict(popup=popup, marker_color="blue", marker_icon="question-sign")
    currents.simple_marker(location=[obs['lat'].values[0],
                                     obs['lon'].values[0]], **kw)

currents.create_map(path='currents.html')
currents.render_iframe = True
inline_map(currents)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;http://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_3e39f1d7a9124d7bb514c4ee7b18ba55&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_3e39f1d7a9124d7bb514c4ee7b18ba55', {
#                                        center:[30.475, -81.05],
#                                        zoom: 5,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'green',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([27.8629,
# 							-82.5537],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<b>SOS:</b> t02010&quot;);
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([31.4,
# 							-80.87],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<b>NDBC:</b> 41008&quot;);
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([30.04,
# 							-80.55],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<b>NDBC:</b> 41012&quot;);
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([33.44,
# 							-77.74],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<b>NDBC:</b> 41013&quot;);
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([33.85,
# 							-78.48],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<b>NDBC:</b> 41024&quot;);
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([32.81,
# 							-79.63],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<b>NDBC:</b> 41029&quot;);
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([32.52,
# 							-79.34],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<b>NDBC:</b> 41030&quot;);
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([32.28,
# 							-80.41],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;<b>NDBC:</b> 41033&quot;);
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([34.48,
# 							-77.28],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;<b>NDBC:</b> 41035&quot;);
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([34.21,
# 							-76.95],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;<b>NDBC:</b> 41036&quot;);
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([34.14,
# 							-77.71],
# 							{'icon':marker_11_icon}
# 							);
#       marker_11.bindPopup(&quot;<b>NDBC:</b> 41038&quot;);
#       map.addLayer(marker_11)
#
#       var marker_12_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_12 = L.marker([25.74,
# 							-85.73],
# 							{'icon':marker_12_icon}
# 							);
#       marker_12.bindPopup(&quot;<b>NDBC:</b> 42003&quot;);
#       map.addLayer(marker_12)
#
#       var marker_13_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_13 = L.marker([27.169,
# 							-82.926],
# 							{'icon':marker_13_icon}
# 							);
#       marker_13.bindPopup(&quot;<b>NDBC:</b> 42013&quot;);
#       map.addLayer(marker_13)
#
#       var marker_14_icon = L.AwesomeMarkers.icon({ icon: 'question-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_14 = L.marker([28.311,
# 							-83.306],
# 							{'icon':marker_14_icon}
# 							);
#       marker_14.bindPopup(&quot;<b>NDBC:</b> 42021&quot;);

# %%
elapsed = time.time() - start_time
log.info(elapsed)
log.info('EOF')

# %%
with open(LOG_FILENAME) as f:
    print(f.read())
# Out:
# 02:22:01 INFO: *********************** Run information ************************
# 02:22:01 INFO: Run date: 2014-10-16 17:22:01
# 02:22:01 INFO: Download start: 2014-10-10 05:00:00
# 02:22:01 INFO: Download stop: 2014-10-10 12:00:00
# 02:22:01 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 02:22:01 INFO: *********************** Software version ***********************
# 02:22:01 INFO: Iris version: 1.8.0-DEV
# 02:22:01 INFO: owslib version: 0.8-dev
# 02:22:01 INFO: pyoos version: 0.6.2
# 02:22:08 INFO: ********************* Catalog information **********************
# 02:22:11 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 02:22:11 INFO: CSW version: 2.0.2
# 02:22:11 INFO: Number of datasets available: 14
# 02:22:11 INFO: *************************** CSW URLs ***************************
# 02:22:11 INFO: Near-Real Time Surface Ocean Velocity, U.S. East and Gulf Coast, 6 km Resolution (GNOME)
# 02:22:11 INFO: Near-Real Time Surface Ocean Velocity, U.S. East
# and Gulf Coast, 6 km Resolution
# 02:22:11 INFO: Near-Real Time Surface Ocean Velocity, U.S. East and Gulf Coast, 1 km Resolution (GNOME)
# 02:22:11 INFO: Near-Real Time Surface Ocean Velocity, U.S. East
# and Gulf Coast, 1 km Resolution
# 02:22:11 INFO: Near-Real Time Surface Ocean Velocity, U.S. East and Gulf Coast, 2 km Resolution (GNOME)
# 02:22:11 INFO: Near-Real Time Surface Ocean Velocity, U.S. East
# and Gulf Coast, 2 km Resolution
# 02:22:11 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 02:22:11 INFO: ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# 02:22:11 INFO: Surface CUrrents from a Diagnostic model (SCUD): Pacific
# 02:22:11 INFO: Barotropic Tide Model for the Pacific Basin
# 02:22:11 INFO: TBOFS - Tampa Bay Operational Forecast System - NOAA CO-OPS - POM
# 02:22:11 INFO: HYbrid Coordinate Ocean Model (HYCOM): Global
# 02:22:11 INFO: CBOFS - Chesapeake Bay Operational Forecast System - NOAA CO-OPS - POM
# 02:22:11 INFO: NECOFS GOM3 (FVCOM) - Northeast US - Latest Forecast
# 02:22:11 INFO: *************************** DAP URLs ***************************
# 02:22:11 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 02:22:11 INFO: http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/1km/hourly/GNOME.html
# 02:22:11 INFO: http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/1km/hourly/RTV.html
# 02:22:11 INFO: http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/2km/hourly/GNOME.html
# 02:22:11 INFO: http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/2km/hourly/RTV.html
# 02:22:11 INFO: http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/6km/hourly/GNOME.html
# 02:22:11 INFO: http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/6km/hourly/RTV.html
# 02:22:11 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac.html
# 02:22:11 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 02:22:11 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/scud/pac.html
# 02:22:11 INFO: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd.html
# 02:22:11 INFO: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd.html
# 02:22:11 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd.html
# 02:22:11 INFO: http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_GOM3_FORECAST.nc.html
# 02:22:11 INFO: *************************** SOS URLs ***************************
# 02:22:18 INFO: ********************* Collector offerings **********************
# 02:22:21 INFO: NOAA.NOS.CO-OPS SOS: 1027 offerings
# 02:23:01 INFO: ********************* Collector offerings **********************
# 02:23:01 INFO: NOAA.NOS.CO-OPS SOS: 1027 offerings
# 02:23:02 INFO: sos_request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?bin=1&eventTime=2014-10-10T05%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3ACurrentsActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=Currents
# 02:23:06 INFO: sos_request: http://sdf.ndbc.noaa.gov/sos/server.php?service=SOS&offering=urn%3Aioos%3Anetwork%3Anoaa.nws.ndbc%3Aall&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=Currents
# 02:23:40 WARNING: [41008]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:24:05 WARNING: [41012]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:24:06 WARNING: [41013]:
# Cannot find data at 'http://dods.ndbc.noaa.gov/thredds/dodsC/data/adcp/41013/'
# 02:24:13 WARNING: [41024]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:24:20 WARNING: [41029]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:24:24 WARNING: [41030]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:24:29 WARNING: [41033]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:24:39 WARNING: [41035]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:24:57 WARNING: [41036]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:25:02 WARNING: [41038]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:25:04 WARNING: [42003]:
# Cannot find data at 'http://dods.ndbc.noaa.gov/thredds/dodsC/data/adcp/42003/'
# 02:25:23 WARNING: [42013]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:25:30 WARNING: [42021]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:25:36 WARNING: [42024]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:25:45 WARNING: [42036]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:25:53 WARNING: [42080]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:26:05 WARNING: [44014]:
# No data within time range datetime.datetime(2014, 10, 10, 5, 0, tzinfo=<UTC>) and datetime.datetime(2014, 10, 10, 12, 0, tzinfo=<UTC>)
# 02:26:45 INFO: 294.576848984
# 02:26:45 INFO: EOF
