# %%
import iris
import pyoos
import owslib

import time
start_time = time.time()

# %%
import os
import sys
root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(root)

# %% [markdown]
# ### SECOORA inundation notebook
# Based on IOOS system-test [notebook](http://nbviewer.ipython.org/github/ioos/system-test/blob/master/Theme_2_Extreme_Events/Scenario_2A/ModelDataCompare_Inundation/Water_Level_Signell.ipynb).

# %%
import pytz
from datetime import datetime, timedelta

# Choose the date range.
stop = datetime(2014, 7, 7, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = stop - timedelta(days=7)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# %%
print('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
print('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
print('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
print('Bounding box: {0:3.2f}, {1:3.2f},'
      '{2:3.2f}, {3:3.2f}'.format(*bbox))
print('Iris version: {}'.format(iris.__version__))
print('owslib version: {}'.format(owslib.__version__))
print('pyoos version: {}'.format(pyoos.__version__))
# Out:
# Run date: 2014-09-26 17:28:36
# Download start: 2014-06-30 12:00:00
# Download stop: 2014-07-07 12:00:00
# Bounding box: -87.40, 24.25,-74.70, 36.70
# Iris version: 1.8.0-DEV
# owslib version: 0.8.8
# pyoos version: 0.6.2

# %%
from owslib import fes
from utilities import fes_date_filter

# CF-names to look for (Sea Surface Height).
name_list = ['water level',
             'sea_surface_height',
             'sea_surface_elevation',
             'sea_surface_height_above_geoid',
             'sea_surface_height_above_sea_level',
             'water_surface_height_above_reference_datum',
             'sea_surface_height_above_reference_ellipsoid']

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

print("CSW version: {}".format(csw.version))
print("Number of datasets available: {}".format('\n'.join(csw.records.keys())))
# Out:
# CSW version: 2.0.2
# Number of datasets available: FVCOM-Nowcast-Agg
# WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# coawst_4/use/fmrc/coawst_4_use_best.ncd
# CDIP_Archive/156p1/156p1_d07.nc
# CDIP_Archive/185p1/185p1_d02.nc
# CDIP_Archive/142p1/142p1_d14.nc
# CDIP_Archive/029p1/029p1_d19.nc
# CDIP_Archive/168p1/168p1_d05.nc
# CDIP_Archive/142p1/142p1_historic.nc
# CDIP_Archive/203p1/203p1_d01.nc
# CDIP_Archive/043p1/043p1_d16.nc
# CDIP_Archive/067p1/067p1_d22.nc
# CDIP_Archive/100p1/100p1_d13.nc
# CDIP_Archive/093p1/093p1_d40.nc
# CDIP_Archive/191p1/191p1_d12.nc
# CDIP_Archive/098p1/098p1_historic.nc
# CDIP_Archive/100p1/100p1_historic.nc
# roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# tide_pac
# CDIP_Archive/067p1/067p1_historic.nc
# cwwcNDBCMet
# CDIP_Archive/029p1/029p1_historic.nc
# hycom_global
# Aquarius_V3_SSS_Daily
# Aquarius_V3_SSS_Monthly
# Aquarius_V3_SSS_Weekly
# Aquarius_V3_scat_wind_speed_Daily
# Aquarius_V3_scat_wind_speed_Monthly
# Aquarius_V3_scat_wind_speed_Weekly
# estofs/atlantic
# necofs_gom3_wave
# CDIP_Archive/190p1/190p1_historic.nc
# CDIP_Archive/190p1/190p1_d02.nc

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

for rec, item in csw.records.items():
    print('CSW: {}'.format(item.title))

for url in dap_urls:
    print('DAP: {}.html'.format(url))

for url in sos_urls:
    print('SOS: {}'.format(url))
# Out:
# CSW: USF FVCOM - Nowcast Aggregation
# CSW: ROMS/TOMS 3.0 - New Floria Shelf Application
# CSW: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# CSW: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY CANYON OUTER, CA from 2013/07/11 17:00:00 to 2014/07/01 20:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY BAY WEST, CA from 2013/06/19 18:00:00 to 2014/07/01 14:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SAN FRANCISCO BAR, CA from 2013/06/19 22:00:00 to 2014/07/24 14:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near POINT REYES, CA from 2013/10/16 21:00:00 to 2014/09/05 11:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near HUMBOLDT BAY NORTH SPIT, CA from 2013/08/26 19:00:00 to 2014/07/24 03:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near SAN FRANCISCO BAR, CA from 2007/07/25 to 2014/07/24.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SANTA CRUZ BASIN, CA from 2013/07/09 15:00:00 to 2014/07/14 16:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near CAMP PENDLETON NEARSHORE, CA from 2014/04/24 22:00:00 to 2014/06/06 16:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SAN NICOLAS ISLAND, CA from 2013/04/19 17:00:00 to 2014/06/08 21:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near TORREY PINES OUTER, CA from 2014/06/10 21:00:00 to 2014/06/12 15:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MISSION BAY OFFSHORE, CA from 2014/04/28 21:00:00 to 2014/06/24 09:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near POINT LOMA SOUTH, CA from 2013/08/12 20:00:00 to 2014/09/10 07:59:59.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near MOKAPU POINT, HI from 2000/08/09 to 2014/09/10.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near TORREY PINES OUTER, CA from 2001/01/30 to 2014/06/06.
# CSW: ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# CSW: Barotropic Tide Model for the Pacific Basin
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near SAN NICOLAS ISLAND, CA from 1991/09/10 to 2014/06/08.
# CSW: NDBC Standard Meteorological Buoy Data
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near POINT REYES, CA from 1996/12/06 to 2014/09/05.
# CSW: HYbrid Coordinate Ocean Model (HYCOM): Global
# CSW: Aquarius Level 3 Sea Surface Salinity Standard Mapped Image Daily Data V3.0
# CSW: Aquarius Level 3 Sea Surface Salinity Standard Mapped Image Monthly Data V3.0
# CSW: Aquarius Level 3 Sea Surface Salinity Standard Mapped Image Weekly Data V3.0
# CSW: Aquarius Level 3 Wind Speed Standard Mapped Image Daily Data V3.0
# CSW: Aquarius Level 3 Wind Speed Standard Mapped Image Monthly Data V3.0
# CSW: Aquarius Level 3 Wind Speed Standard Mapped Image Weely Data V3.0
# CSW: ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC
# CSW: NECOFS GOM3 Wave - Northeast US - Latest Forecast
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near NEW RIVER INLET, NC from 2012/04/14 to 2014/07/11.
# CSW: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near NEW RIVER INLET, NC from 2014/03/09 19:00:00 to 2014/07/11 23:59:59.
# DAP: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# DAP: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd.html
# DAP: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic.html
# DAP: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# DAP: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# DAP: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac.html
# DAP: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# DAP: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd.html
# DAP: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Daily.nc.html
# DAP: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Monthly.nc.html
# DAP: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Weekly.nc.html
# DAP: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Daily.nc.html
# DAP: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Monthly.nc.html
# DAP: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Weekly.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc.html
# DAP: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc.html
# DAP: http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_WAVE_FORECAST.nc.html
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d19.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d16.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d22.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d40.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/098p1/098p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/156p1/156p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/168p1/168p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/185p1/185p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/190p1/190p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/190p1/190p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# SOS: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/203p1/203p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()
sos_name = 'water_surface_height_above_reference_datum'

datum = 'NAVD'
collector.set_datum(datum)
collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
print('{}: {} offerings'.format(title, len(ofrs)))
# Out:
# NOAA.NOS.CO-OPS SOS: 1026 offerings

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

print('sos_request: {}'.format(url))
# Out:
# sos_request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-06-30T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AWaterLevelActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=water_surface_height_above_reference_datum

# %% [markdown]
# #### Clean the dataframe (visualization purpose only)

# %%
from utilities import get_coops_longname, to_html

columns = {'datum_id': 'datum',
           'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': 'ssh above datum'}

observations.rename(columns=columns, inplace=True)

observations['datum'] = [s.split(':')[-1] for s in observations['datum']]
observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>ssh above datum</th>
#       <th>datum</th>
#       <th>height</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td> 8651370</td>
#       <td> A1</td>
#       <td> 36.1833</td>
#       <td>-75.7467</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.761</td>
#       <td> MLLW</td>
#       <td> 5.663</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td> 8652587</td>
#       <td> A1</td>
#       <td> 35.7950</td>
#       <td>-75.5483</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.242</td>
#       <td> MLLW</td>
#       <td> 0.788</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td> 8656483</td>
#       <td> A1</td>
#       <td> 34.7200</td>
#       <td>-76.6700</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.703</td>
#       <td> MLLW</td>
#       <td> 0.562</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td> 8658120</td>
#       <td> A1</td>
#       <td> 34.2267</td>
#       <td>-77.9533</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.391</td>
#       <td> MLLW</td>
#       <td> 0.747</td>
#     </tr>
#     <tr>
#       <th>Wrightsville Beach, NC</th>
#       <td> 8658163</td>
#       <td> A1</td>
#       <td> 34.2133</td>
#       <td>-77.7867</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.958</td>
#       <td> MLLW</td>
#       <td> 5.793</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Generate a uniform 6-min time base for model/data comparison

# %%
import iris
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
print('Downloading observation to file {}.'.format(fname))
data = dict()
bad_datum = []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'water_surface_height_above_reference_datum (m)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_datum.append(station)
        name = get_coops_longname(station)
        print("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad vertical datum stations.
pattern = '|'.join(bad_datum)
if pattern:
    non_navd = observations.station.str.contains(pattern)
    bad_datum = observations[non_navd]
    observations = observations[~non_navd]

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         datum=datum,
                         url=url))

save_timeseries(obs_data, outfile=fname, **kw)

to_html(obs_data.head())
# Out:
# Downloading observation to file 2014-07-07-OBS_DATA.nc.
# [8656483] Beaufort, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# [8658120] Wilmington, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# [8726520] St Petersburg, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# [8726607] Old Port Tampa, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# [8729210] Panama City Beach, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8662245</th>
#       <th>8665530</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720219</th>
#       <th>8720226</th>
#       <th>8720357</th>
#       <th>8720503</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8727520</th>
#       <th>8728690</th>
#       <th>8729108</th>
#       <th>8729840</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-06-30 12:00:00</th>
#       <td> 0.094</td>
#       <td> 0.027</td>
#       <td> 0.186</td>
#       <td> 0.220</td>
#       <td> 0.104</td>
#       <td> 0.299</td>
#       <td>-0.044</td>
#       <td> 0.023</td>
#       <td>-0.145</td>
#       <td>-0.074</td>
#       <td> 0.079</td>
#       <td> 0.124</td>
#       <td> 0.240</td>
#       <td>-0.056</td>
#       <td>-0.142</td>
#       <td>-0.161</td>
#       <td>-0.221</td>
#       <td>-0.216</td>
#       <td>-0.028</td>
#       <td>-0.102</td>
#       <td>-0.097</td>
#       <td> 0.122</td>
#       <td> 0.064</td>
#       <td> 0.122</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:06:00</th>
#       <td> 0.133</td>
#       <td> 0.036</td>
#       <td> 0.219</td>
#       <td> 0.249</td>
#       <td> 0.125</td>
#       <td> 0.325</td>
#       <td>-0.002</td>
#       <td> 0.046</td>
#       <td>-0.124</td>
#       <td>-0.071</td>
#       <td> 0.078</td>
#       <td> 0.120</td>
#       <td> 0.232</td>
#       <td>-0.060</td>
#       <td>-0.124</td>
#       <td>-0.166</td>
#       <td>-0.213</td>
#       <td>-0.239</td>
#       <td>-0.029</td>
#       <td>-0.098</td>
#       <td>-0.116</td>
#       <td> 0.123</td>
#       <td> 0.069</td>
#       <td> 0.122</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:12:00</th>
#       <td> 0.150</td>
#       <td> 0.042</td>
#       <td> 0.224</td>
#       <td> 0.263</td>
#       <td> 0.145</td>
#       <td> 0.352</td>
#       <td> 0.028</td>
#       <td> 0.071</td>
#       <td>-0.105</td>
#       <td>-0.061</td>
#       <td> 0.077</td>
#       <td> 0.116</td>
#       <td> 0.225</td>
#       <td>-0.010</td>
#       <td>-0.107</td>
#       <td>-0.169</td>
#       <td>-0.204</td>
#       <td>-0.225</td>
#       <td>-0.030</td>
#       <td>-0.100</td>
#       <td>-0.137</td>
#       <td> 0.130</td>
#       <td> 0.073</td>
#       <td> 0.125</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:18:00</th>
#       <td> 0.161</td>
#       <td> 0.050</td>
#       <td> 0.249</td>
#       <td> 0.301</td>
#       <td> 0.165</td>
#       <td> 0.379</td>
#       <td> 0.063</td>
#       <td> 0.100</td>
#       <td>-0.083</td>
#       <td>-0.055</td>
#       <td> 0.077</td>
#       <td> 0.110</td>
#       <td> 0.217</td>
#       <td>-0.026</td>
#       <td>-0.087</td>
#       <td>-0.173</td>
#       <td>-0.192</td>
#       <td>-0.249</td>
#       <td>-0.031</td>
#       <td>-0.102</td>
#       <td>-0.157</td>
#       <td> 0.133</td>
#       <td> 0.070</td>
#       <td> 0.132</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:24:00</th>
#       <td> 0.206</td>
#       <td> 0.059</td>
#       <td> 0.273</td>
#       <td> 0.323</td>
#       <td> 0.182</td>
#       <td> 0.402</td>
#       <td> 0.096</td>
#       <td> 0.126</td>
#       <td>-0.058</td>
#       <td>-0.046</td>
#       <td> 0.077</td>
#       <td> 0.110</td>
#       <td> 0.209</td>
#       <td>-0.055</td>
#       <td>-0.077</td>
#       <td>-0.176</td>
#       <td>-0.183</td>
#       <td>-0.228</td>
#       <td>-0.033</td>
#       <td>-0.105</td>
#       <td>-0.170</td>
#       <td> 0.131</td>
#       <td> 0.077</td>
#       <td> 0.140</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Loop discovered models and save the nearest time-series

# %%
import numpy as np
from iris.pandas import as_series
from iris.exceptions import (CoordinateNotFoundError, MergeError)

from utilities import (standardize_fill_value, plt_grid, get_cube,
                       get_model_name, make_tree, get_nearest_water,
                       add_station, ensure_timeseries)

for k, url in enumerate(dap_urls):
    print('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
    if 'NECOFS' in url:  # FIXME: NECOFS has cartesian coordinates.
        continue
    try:
        cube = get_cube(url, name_list=name_list, bbox=bbox,
                        time=(start, stop), units=iris.unit.Unit('meters'))
        if cube.ndim == 1:  # We Need a better way to identify model data.
            print('url {} is probably a timeSeries!'.format(url))
            continue
    except (RuntimeError, ValueError, MergeError) as e:
        print('Cannot get cube for: {}\n{}'.format(url, e))
        continue

    mod_name, model_full_name = get_model_name(cube, url)

    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    print('Downloading model series to file {}.'.format(fname))
    try:  # Make tree.
        tree, lon, lat = make_tree(cube)
        fig, ax = plt_grid(lon, lat)
    except CoordinateNotFoundError as e:
        print('Cannot make KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in observations.iterrows():
        a = obs_data[obs['station']]
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        # RuntimeError may occurs, but you should run it again!
        except ValueError as e:
            print(e)
            continue
        if not series:
            status = "Found Land"
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Found Water"
            ax.plot(lon[idx], lat[idx], 'g.')

        print('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = standardize_fill_value(cube)
            cube = add_station(cube, station)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            print(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    size = len(raw_series)
    ax.set_title('{}: Points found {}'.format(mod_name, size))
    ax.plot(observations.lon, observations.lat, 'ro',
            zorder=1, label='Observation', alpha=0.25)
    ax.set_extent([bbox[0], bbox[2], bbox[1], bbox[3]])

    print('[{}]: {}'.format(mod_name, url))
# Out:
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'lat' referenced by variable u'hc': Dimensions (u'node',) do not span (u'nele',)
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'lon' referenced by variable u'hc': Dimensions (u'node',) do not span (u'nele',)
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'siglay' referenced by variable u'u': Dimensions (u'siglay', u'node') do not span (u'time', u'siglay', u'nele')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'siglay' referenced by variable u'v': Dimensions (u'siglay', u'node') do not span (u'time', u'siglay', u'nele')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1337: UserWarning: Failed to create 'time' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'time' auxiliary coordinate instead.
#   error=e_msg))
# [Reading url 1/33]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'Itime2' invalid units 'msecs since 00:00:00'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'salinity' invalid units 'psu'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'v' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'v' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'u' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'u' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1291: UserWarning: Gracefully filling 'time' dimension coordinate masked points
#   warnings.warn(msg.format(str(cf_coord_var.cf_name)))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'Cs_r' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 's_rho' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'Cs_w' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 's_w' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'salt' invalid units 'PSU'
#   warnings.warn(msg.format(msg_name, msg_units))
# [Reading url 2/33]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# Downloading model series to file 2014-07-07-USF.nc.
# No data found for (-75.7467,36.1833) using max_dist=0.04.
# No data found for (-75.5483,35.795) using max_dist=0.04.
# No data found for (-77.7867,34.2133) using max_dist=0.04.
# No data found for (-78.9183,33.655) using max_dist=0.04.
# No data found for (-79.1867,33.3517) using max_dist=0.04.
# No data found for (-79.925,32.7817) using max_dist=0.04.
# No data found for (-81.465,30.6717) using max_dist=0.04.
# No data found for (-81.43,30.3967) using max_dist=0.04.
# No data found for (-81.5583,30.3867) using max_dist=0.04.
# No data found for (-81.6583,30.32) using max_dist=0.04.
# No data found for (-81.6917,30.1917) using max_dist=0.04.
# No data found for (-81.6283,29.9783) using max_dist=0.04.
# No data found for (-81.5483,29.8017) using max_dist=0.04.
# No data found for (-80.5931,28.4158) using max_dist=0.04.
# No data found for (-80.0333,26.6117) using max_dist=0.04.
# No data found for (-81.105,24.7117) using max_dist=0.04.
# No data found for (-81.8079,24.5557) using max_dist=0.04.
# [Found Water] Naples, FL
# [Found Water] Fort Myers, FL
# [Found Water] Port Manatee, FL
# [Found Water] Cedar Key, FL
# [Found Water] Apalachicola, FL
# [Found Water] Panama City, FL
# No data found for (-87.2112,30.4044) using max_dist=0.04.
# [USF]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nbdv' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'neta' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'ibtypee' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# [Reading url 3/33]: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# Downloading model series to file 2014-07-07-ESTOFS.nc.
# [Found Water] Duck, NC
# [Found Water] Oregon Inlet Marina, NC
# [Found Water] Wrightsville Beach, NC
# [Found Water] Springmaid Pier, SC
# [Found Water] Oyster Landing (N Inlet Estuary), SC
# No data found for (-79.925,32.7817) using max_dist=0.04.
# [Found Water] Fernandina Beach, FL
# [Found Water] Mayport (Bar Pilots Dock), FL
# No data found for (-81.5583,30.3867) using max_dist=0.04.
# No data found for (-81.6583,30.32) using max_dist=0.04.
# No data found for (-81.6917,30.1917) using max_dist=0.04.
# No data found for (-81.6283,29.9783) using max_dist=0.04.
# No data found for (-81.5483,29.8017) using max_dist=0.04.
# [Found Water] Trident Pier, FL
# [Found Water] Lake Worth Pier, FL
# [Found Water] Vaca Key, FL
# [Found Water] Key West, FL
# [Found Water] Naples, FL
# No data found for (-81.8712,26.6477) using max_dist=0.04.
# [Found Water] Port Manatee, FL
# [Found Water] Cedar Key, FL
# [Found Water] Apalachicola, FL
# No data found for (-85.6669,30.1523) using max_dist=0.04.
# No data found for (-87.2112,30.4044) using max_dist=0.04.
# [ESTOFS]: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
#
# [Reading url 4/33]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# Downloading model series to file 2014-07-07-COAWST_4.nc.
# [Found Land] Duck, NC
# [Found Water] Oregon Inlet Marina, NC
# [Found Water] Wrightsville Beach, NC
# [Found Water] Springmaid Pier, SC
# [Found Land] Oyster Landing (N Inlet Estuary), SC
# [Found Land] Charleston, SC
# [Found Land] Fernandina Beach, FL
# [Found Land] Mayport (Bar Pilots Dock), FL
# [Found Land] Dames Point, FL
# [Found Land] Southbank Riverwalk, St Johns River, FL
# [Found Land] I-295 Bridge, St Johns River, FL
# [Found Land] Red Bay Point, St Johns River, FL
# [Found Land] Racy Point, St Johns River, FL
# [Found Land] Trident Pier, FL
# [Found Water] Lake Worth Pier, FL
# [Found Land] Vaca Key, FL
# [Found Water] Key West, FL
# [Found Land] Naples, FL
# [Found Land] Fort Myers, FL
# [Found Land] Port Manatee, FL
# [Found Water] Cedar Key, FL
# [Found Water] Apalachicola, FL
# [Found Water] Panama City, FL
# [Found Water] Pensacola, FL
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nvell' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'ibtype' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nbvv' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nvel' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nvdll' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'chlorophyll' invalid units 'milligrams_chlorophyll meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'phytoplankton' invalid units 'millimole_nitrogen meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'NO3' invalid units 'millimole_N03 meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
# [COAWST_4]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
#
# [Reading url 5/33]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# Downloading model series to file 2014-07-07-SABGOM.nc.
# [Found Water] Duck, NC
# [Found Land] Oregon Inlet Marina, NC
# [Found Water] Wrightsville Beach, NC
# [Found Water] Springmaid Pier, SC
# [Found Land] Oyster Landing (N Inlet Estuary), SC
# [Found Land] Charleston, SC
# [Found Land] Fernandina Beach, FL
# [Found Land] Mayport (Bar Pilots Dock), FL
# [Found Land] Dames Point, FL
# [Found Land] Southbank Riverwalk, St Johns River, FL
# [Found Land] I-295 Bridge, St Johns River, FL
# [Found Land] Red Bay Point, St Johns River, FL
# [Found Land] Racy Point, St Johns River, FL
# [Found Land] Trident Pier, FL
# [Found Land] Lake Worth Pier, FL
# [Found Land] Vaca Key, FL
# [Found Water] Key West, FL
# [Found Land] Naples, FL
# [Found Land] Fort Myers, FL
# [Found Land] Port Manatee, FL
# [Found Water] Cedar Key, FL
# [Found Land] Apalachicola, FL
# [Found Land] Panama City, FL
# [Found Land] Pensacola, FL
# [SABGOM]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
#
# [Reading url 6/33]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# Cannot get cube for: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# NetCDF: I/O failure
#
# [Reading url 7/33]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# Downloading model series to file 2014-07-07-HYCOM.nc.
# [Found Land] Duck, NC
# [Found Water] Oregon Inlet Marina, NC
# [Found Water] Wrightsville Beach, NC
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'zooplankton' invalid units 'millimole_nitrogen meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'NH4' invalid units 'millimole_NH4 meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
# Exception
# No data found for (-78.9183,33.655) using max_dist=0.04.
# [Found Land] Oyster Landing (N Inlet Estuary), SC
# [Found Land] Charleston, SC
# [Found Land] Fernandina Beach, FL
# [Found Land] Mayport (Bar Pilots Dock), FL
# [Found Land] Dames Point, FL
# [Found Land] Southbank Riverwalk, St Johns River, FL
# [Found Land] I-295 Bridge, St Johns River, FL
# [Found Land] Red Bay Point, St Johns River, FL
# No data found for (-81.5483,29.8017) using max_dist=0.04.
# [Found Land] Trident Pier, FL
# [Found Water] Lake Worth Pier, FL
# [Found Land] Vaca Key, FL
# [Found Land] Key West, FL
# No data found for (-81.8075,26.1317) using max_dist=0.04.
# [Found Land] Fort Myers, FL
# [Found Land] Port Manatee, FL
# [Found Land] Cedar Key, FL
# [Found Land] Apalachicola, FL
# [Found Land] Panama City, FL
# [Found Land] Pensacola, FL
# [HYCOM]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
#
# [Reading url 8/33]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# Downloading model series to file 2014-07-07-ESPRESSO.nc.
# [Found Land] Duck, NC
# [Found Water] Oregon Inlet Marina, NC
# No data found for (-77.7867,34.2133) using max_dist=0.04.
# No data found for (-78.9183,33.655) using max_dist=0.04.
# No data found for (-79.1867,33.3517) using max_dist=0.04.
# No data found for (-79.925,32.7817) using max_dist=0.04.
# No data found for (-81.465,30.6717) using max_dist=0.04.
# No data found for (-81.43,30.3967) using max_dist=0.04.
# No data found for (-81.5583,30.3867) using max_dist=0.04.
# No data found for (-81.6583,30.32) using max_dist=0.04.
# No data found for (-81.6917,30.1917) using max_dist=0.04.
# No data found for (-81.6283,29.9783) using max_dist=0.04.
# No data found for (-81.5483,29.8017) using max_dist=0.04.
# No data found for (-80.5931,28.4158) using max_dist=0.04.
# No data found for (-80.0333,26.6117) using max_dist=0.04.
# No data found for (-81.105,24.7117) using max_dist=0.04.
# No data found for (-81.8079,24.5557) using max_dist=0.04.
# No data found for (-81.8075,26.1317) using max_dist=0.04.
# No data found for (-81.8712,26.6477) using max_dist=0.04.
# No data found for (-82.5621,27.6387) using max_dist=0.04.
# No data found for (-83.0317,29.135) using max_dist=0.04.
# No data found for (-84.9817,29.7267) using max_dist=0.04.
# No data found for (-85.6669,30.1523) using max_dist=0.04.
# No data found for (-87.2112,30.4044) using max_dist=0.04.
# [ESPRESSO]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
#
# [Reading url 9/33]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Daily.nc
# Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Daily.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 10/33]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Monthly.nc
# Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Monthly.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 11/33]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Weekly.nc
# Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Weekly.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 12/33]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Daily.nc
# Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Daily.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 13/33]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Monthly.nc
# Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Monthly.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 14/33]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Weekly.nc
# Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Weekly.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 15/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 16/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 17/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 18/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
# AttributeError: "'CFReader' object has no attribute '_dataset'" in <bound method CFReader.__del__ of CFReader('http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac')> ignored
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1337: UserWarning: Failed to create 'waveTime' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'waveTime' auxiliary coordinate instead.
#   error=e_msg))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1337: UserWarning: Failed to create 'sstTime' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'sstTime' auxiliary coordinate instead.
#   error=e_msg))
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1337: UserWarning: Failed to create 'dwrTime' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'dwrTime' auxiliary coordinate instead.
#   error=e_msg))
# [Reading url 19/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 20/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 21/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 22/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 23/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 24/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 25/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 26/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 27/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 28/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 29/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 30/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 31/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 32/33]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc
# Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc
# Cube does not contain ['water level', 'sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
#
# [Reading url 33/33]: http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_WAVE_FORECAST.nc

# %% [markdown]
# #### Load saved files and interpolate to the observations time interval

# %%
from glob import glob
from operator import itemgetter

from pandas import Panel
from utilities import nc2df

fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
OBS_DATA = nc2df(fname)
index = OBS_DATA.index

dfs = dict(OBS_DATA=OBS_DATA)
for fname in glob("*.nc"):
    if 'OBS_DATA' in fname:
        continue
    else:
        model = fname.split('.')[0].split('-')[-1]
        df = nc2df(fname)
        kw = dict(method='time', limit=30)
        df = df.reindex(index).interpolate(**kw).ix[index]
        dfs.update({model: df})

dfs = Panel.fromDict(dfs).swapaxes(0, 2)

# Clusters.
big_list = []
for fname in glob("*.nc"):
    if 'OBS_DATA' in fname:
        continue
    nc = iris.load_cube(fname)
    model = fname.split('-')[-1].split('.')[0]
    lons = nc.coord(axis='X').points
    lats = nc.coord(axis='Y').points
    stations = nc.coord('station name').points
    models = [model]*lons.size
    lista = zip(models, lons.tolist(), lats.tolist(), stations.tolist())
    big_list.extend(lista)

big_list.sort(key=itemgetter(3))
df = DataFrame(big_list, columns=['name', 'lon', 'lat', 'station'])
df.set_index('station', drop=True, inplace=True)
groups = df.groupby(df.index)

# %%
import folium
import vincent
from utilities import get_coordinates, inline_map

lon_center, lat_center = np.array(bbox).reshape(2, 2).mean(axis=0)
inundation_map = folium.Map(width=750, height=500,
                            location=[lat_center, lon_center], zoom_start=5)

# Create the map and add the bounding box line.
kw = dict(line_color='#FF0000', line_weight=2)
inundation_map.line(get_coordinates(bbox), **kw)

# Clusters.
for station, info in groups:
    station = get_coops_longname(station)
    for lat, lon, name in zip(info.lat, info.lon, info.name):
        location = lat, lon
        popup = '<b>{}</b>\n{}'.format(station, name)
        inundation_map.simple_marker(location=location, popup=popup,
                                     clustered_marker=True)

# Model and observations.
for station in dfs:
    sta_name = get_coops_longname(station)
    df = dfs[station].dropna(axis=1, how='all')
    # FIXME: This is bad!  But I cannot represent NaN with Vega!
    df.fillna(value='null', inplace=True)
    vis = vincent.Line(df, width=500, height=150)
    vis.axis_titles(x='Time', y='Sea surface height (m)')
    vis.legend(title=sta_name)
    vis.name = sta_name
    json = 'station_{}.json'.format(station)
    vis.to_json(json)
    obs = observations[observations['station'] == station].squeeze()
    popup = (vis, json)
    if (df.columns == 'OBS_DATA').all():
        kw = dict(popup=popup, marker_color="blue", marker_icon="ok")
    else:
        if 'SABGOM' in df.columns:
            kw = dict(popup=popup, marker_color="green", marker_icon="ok-sign")
        else:
            kw = dict(popup=popup, marker_color="green", marker_icon="ok")
    inundation_map.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# Bad datum.
if isinstance(bad_datum, DataFrame):
    for station, obs in bad_datum.iterrows():
        popup = '<b>Station:</b> {}<br><b>Datum:</b> {}<br>'
        popup = popup.format(station, obs['datum'])
        kw = dict(popup=popup, marker_color="red", marker_icon="question-sign")
        inundation_map.simple_marker(location=[obs['lat'], obs['lon']], **kw)

inundation_map.create_map(path='inundation_map.html')
inline_map(inundation_map)
# Out:
# -c:26: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;http://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#    <script src=&quot;http://d3js.org/d3.v3.min.js&quot; charset=&quot;utf-8&quot;></script>
#    <script src=&quot;http://trifacta.github.io/vega/vega.js&quot;></script>
#    <script src=&quot;https://code.jquery.com/jquery-2.1.0.min.js&quot;></script>
#
#    <style>
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_250c7fd99b9241b29394ed1802627be4&quot; style=&quot;width: 750px; height: 500px&quot;></div>
#
#    <script>
#
#       function parse(spec, div) {
#
#     vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });
#
# }
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_250c7fd99b9241b29394ed1802627be4', {
#                                        center:[30.475, -81.05],
#                                        zoom: 5,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([36.219991,
# 							-75.733948],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<b>Duck, NC</b>\nESTOFS&quot;);
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([36.1640944084,
# 							-75.7135500943],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<b>Duck, NC</b>\nSABGOM&quot;);
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([35.817473,
# 							-75.549107],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<b>Oregon Inlet Marina, NC</b>\nESTOFS&quot;);
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([35.8112,
# 							-75.51997],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<b>Oregon Inlet Marina, NC</b>\nHYCOM&quot;);
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([35.781312092,
# 							-75.5609029744],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<b>Oregon Inlet Marina, NC</b>\nESPRESSO&quot;);
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([35.7756363682,
# 							-75.5801504748],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<b>Oregon Inlet Marina, NC</b>\nCOAWST_4&quot;);
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([34.182089,
# 							-77.810371],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<b>Wrightsville Beach, NC</b>\nESTOFS&quot;);
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([34.239,
# 							-77.75997],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;<b>Wrightsville Beach, NC</b>\nHYCOM&quot;);
#       clusteredmarkers.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([34.2153474741,
# 							-77.7892059433],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;<b>Wrightsville Beach, NC</b>\nSABGOM&quot;);
#       clusteredmarkers.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([34.2170718628,
# 							-77.7778646689],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;<b>Wrightsville Beach, NC</b>\nCOAWST_4&quot;);
#       clusteredmarkers.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([33.628791,
# 							-78.945853],
# 							{'icon':marker_11_icon}
# 							);
#       marker_11.bindPopup(&quot;<b>Springmaid Pier, SC</b>\nESTOFS&quot;);
#       clusteredmarkers.addLayer(marker_11)
#
#       var marker_12_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_12 = L.marker([33.6369096117,
# 							-78.9333300342],
# 							{'icon':marker_12_icon}
# 							);
#       marker_12.bindPopup(&quot;<b>Springmaid Pier, SC</b>\nSABGOM&quot;);

# %%
elapsed = time.time() - start_time
print('{:.2f} minutes'.format(elapsed/60.))
# Out:
# 35.06 minutes
