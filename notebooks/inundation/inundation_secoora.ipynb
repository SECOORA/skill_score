# %%
# Standard Library.
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime, timedelta

# Scientific stack.
import iris
iris.FUTURE.netcdf_promote = True
import folium
import numpy as np
import matplotlib.pyplot as plt

from pandas import DataFrame, read_csv, concat

# Custom IOOS/ASA modules (available at PyPI).
from owslib import fes
from owslib.csw import CatalogueServiceWeb
from pyoos.collectors.coops.coops_sos import CoopsSos

# Local imports
from utilities import (dateRange, get_coops_longname, coops2df,
                       service_urls, inline_map, get_coordinates,
                       get_cube, make_tree, get_nearest_water)

# %%
now = datetime.utcnow()

start = now - timedelta(days=3)
stop = now + timedelta(days=3)

start_date = start.strftime('%Y-%m-%d %H:00')
stop_date = stop.strftime('%Y-%m-%d %H:00')

jd_start = datetime.strptime(start_date, '%Y-%m-%d %H:%M')
jd_stop = datetime.strptime(stop_date, '%Y-%m-%d %H:%M')

print('%s to %s' % (start_date, stop_date))
# Out:
# 2014-06-20 17:00 to 2014-06-26 17:00

# %%
name_list = ['water level',
             'sea_surface_height',
             'sea_surface_elevation',
             'sea_surface_height_above_geoid',
             'sea_surface_height_above_sea_level',
             'water_surface_height_above_reference_datum',
             'sea_surface_height_above_reference_ellipsoid']

bounding_box_type = "box"
bounding_box = [[-87.4, 24.25],
                [-74.7, 36.70]]  # SECOORA: NC, SC GA, FL

box = []
box.append(bounding_box[0][0])
box.append(bounding_box[0][1])
box.append(bounding_box[1][0])
box.append(bounding_box[1][1])

start, stop = dateRange(start_date, stop_date)
bbox = fes.BBox(box)

or_filt = fes.Or([fes.PropertyIsLike(propertyname='apiso:AnyText',
                                     literal=('*%s*' % val),
                                     escapeChar='\\',
                                     wildCard='*',
                                     singleChar='?') for val in name_list])

val = 'Averages'
not_filt = fes.Not([fes.PropertyIsLike(propertyname='apiso:AnyText',
                                       literal=('*%s*' % val),
                                       escapeChar='\\',
                                       wildCard='*',
                                       singleChar='?')])

filter_list = [fes.And([bbox, start, stop, or_filt, not_filt])]

# %%
endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

if True:
    print("CSW version: %s" % csw.version)
    print("Number of datasets available: %s" % len(csw.records.keys()))
# Out:
# CSW version: 2.0.2
# Number of datasets available: 11

# %%
dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

if True:
    print("CSW:")
    for rec, item in csw.records.items():
        print(item.title)
    print("\nDAP:")
    print("\n".join(dap_urls))
    print("\nSOS:")
    print("\n".join(sos_urls))
# Out:
# CSW:
# ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# Barotropic Tide Model for the Pacific Basin
# TBOFS - Tampa Bay Operational Forecast System - NOAA CO-OPS - POM
# NDBC Standard Meteorological Buoy Data
# HYbrid Coordinate Ocean Model (HYCOM): Global
# CBOFS - Chesapeake Bay Operational Forecast System - NOAA CO-OPS - POM
# ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC
# NECOFS GOM3 (FVCOM) - Northeast US - Latest Forecast
# NECOFS GOM3 Wave - Northeast US - Latest Forecast
#
# DAP:
# http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd
# http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd
# http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_GOM3_FORECAST.nc
# http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_WAVE_FORECAST.nc
#
# SOS:

# %% [markdown]
# # The datum should be NAVD! But all the data found find are MLLW.

# %%
sos_name = 'water_surface_height_above_reference_datum'

collector = CoopsSos()

collector.set_datum('MLLW')
collector.server.identification.title
collector.start_time = jd_start
collector.end_time = jd_stop
collector.variables = [sos_name]

ofrs = collector.server.offerings
if False:
    print(len(ofrs))

# %%
iso_start = jd_start.strftime('%Y-%m-%dT%H:%M:%SZ')
iso_stop = jd_stop.strftime('%Y-%m-%dT%H:%M:%SZ')
box_str = ','.join(str(e) for e in box)

print("Date: %s to %s" % (iso_start, iso_stop))
print("Lat/Lon Box: %s" % box_str)
# Out:
# Date: 2014-06-20T17:00:00Z to 2014-06-26T17:00:00Z
# Lat/Lon Box: -87.4,24.25,-74.7,36.7

# %%
url = ('http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?'
       'service=SOS&request=GetObservation&version=1.0.0&'
       'observedProperty=%s&offering=urn:ioos:network:NOAA.NOS.CO-OPS:'
       'WaterLevelActive&featureOfInterest=BBOX:%s&responseFormat='
       'text/csv&eventTime=%s' % (sos_name, box_str, iso_start))

observations = read_csv(url)
if True:
    print(url)
# Out:
# http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetObservation&version=1.0.0&observedProperty=water_surface_height_above_reference_datum&offering=urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive&featureOfInterest=BBOX:-87.4,24.25,-74.7,36.7&responseFormat=text/csv&eventTime=2014-06-20T17:00:00Z

# %%
# Clean the dataframe.
columns = {'station_id': 'station',
           'sensor_id': 'sensor',
           'datum_id': 'datum',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': 'ssh above datum'}

observations.rename(columns=columns, inplace=True)

observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['datum'] = [s.split(':')[-1] for s in observations['datum']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)

# %%
observations.head()
# Out:
#                            station sensor      lat      lon  \
# name
# Duck, NC                   8651370     A1  36.1833 -75.7467
# Oregon Inlet Marina, NC    8652587     A1  35.7950 -75.5483
# USCG Station Hatteras, NC  8654467     A1  35.2086 -75.7042
# Beaufort, NC               8656483     A1  34.7200 -76.6700
# Wilmington, NC             8658120     A1  34.2267 -77.9533
#
#                                       date_time  ssh above datum datum  height
# name
# Duck, NC                   2014-06-20T17:00:00Z            1.139  MLLW   5.663
# Oregon Inlet Marina, NC    2014-06-20T17:00:00Z            0.376  MLLW   0.788
# USCG Station Hatteras, NC  2014-06-20T17:00:00Z            0.272  MLLW   8.345
# Beaufort, NC               2014-06-20T17:00:00Z            0.841  MLLW   0.562
# Wilmington, NC             2014-06-20T17:00:00Z            0.470  MLLW   0.747

# %% [markdown]
# Generate a uniform 6-min time base for model/data comparison:

# %%
data = dict()

for s in observations.station:
    b = coops2df(collector, s, sos_name)
    b = b['water_surface_height_above_reference_datum (m)']
    data.update({s: b})

obs_data = DataFrame.from_dict(data)

# %%
obs_data.head()
# Out:
#                      8651370  8652587  8654467  8656483  8658120  8658163  \
# date_time
# 2014-06-20 17:00:00    1.139    0.376    0.272    0.841    0.470    1.163
# 2014-06-20 17:06:00    1.160    0.386    0.266    0.875    0.519    1.186
# 2014-06-20 17:12:00    1.151    0.391    0.264    0.899    0.565    1.196
# 2014-06-20 17:18:00    1.154    0.398    0.261    0.914    0.612    1.225
# 2014-06-20 17:24:00    1.187    0.404    0.266    0.925    0.656    1.262
#
#                      8661070  8662245  8665530  8670870   ...     8726384  \
# date_time                                                 ...
# 2014-06-20 17:00:00    1.380    0.936    1.296    1.590   ...       0.362
# 2014-06-20 17:06:00    1.423    0.962    1.333    1.646   ...       0.351
# 2014-06-20 17:12:00    1.435    0.986    1.367    1.701   ...       0.340
# 2014-06-20 17:18:00    1.458    1.012    1.399    1.755   ...       0.332
# 2014-06-20 17:24:00    1.489    1.037    1.429    1.799   ...       0.321
#
#                      8726520  8726607  8726667  8726724  8727520  8728690  \
# date_time
# 2014-06-20 17:00:00    0.443    0.513    0.530    0.262    0.521    0.440
# 2014-06-20 17:06:00    0.434    0.502    0.520    0.273    0.502    0.435
# 2014-06-20 17:12:00    0.425    0.495    0.508    0.275    0.486    0.424
# 2014-06-20 17:18:00    0.409    0.475    0.497    0.277    0.470    0.416
# 2014-06-20 17:24:00    0.397    0.463    0.490    0.295    0.451    0.407
#
#                      8729108  8729210  8729840
# date_time
# 2014-06-20 17:00:00    0.313    0.272    0.321
# 2014-06-20 17:06:00    0.312    0.267    0.318
# 2014-06-20 17:12:00    0.310    0.268    0.314
# 2014-06-20 17:18:00    0.308    0.273    0.313
# 2014-06-20 17:24:00    0.303    0.269    0.312
#
# [5 rows x 34 columns]

# %%
m = folium.Map(location=[np.mean(bounding_box, axis=0)[1],
                         np.mean(bounding_box, axis=0)[0]],
               zoom_start=5)

# Create the map and add the bounding box line.
m.line(get_coordinates(bounding_box, bounding_box_type),
       line_color='#FF0000', line_weight=2)

for station, row in observations.iterrows():
    if row['datum'] == 'NAVD':
        html = '<b>Station:</b><br>%s<br><b>Long Name:</b><br>%s'
        popup_string = html % (station, row['name'])
        m.circle_marker(location=[row['lat'], row['lon']], popup=popup_string,
                        fill_color='#ff0000', radius=1e4, line_color='#ff0000')
    else:
        html = '<b>%s</b><br><b>Station:</b><br>%s<br><b>Long Name:</b><br>%s'
        popup_string = html % (row['datum'], station, row.name)
        m.simple_marker(location=[row['lat'], row['lon']], popup=popup_string)

inline_map(m)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.js&quot;></script>
#
#
#
#
#
#
#
#    <style>
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_354d147ac72a4481ac8578e18db5e94a&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var map = L.map('folium_354d147ac72a4481ac8578e18db5e94a').setView([30.475, -81.05], 5);
#
#       L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       }).addTo(map);
#
#
#       var marker_1 = L.marker([36.1833, -75.7467]);
#       marker_1.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Duck, NC<br><b>Long Name:</b><br>Duck, NC&quot;);
#       map.addLayer(marker_1)
#
#       var marker_2 = L.marker([35.795, -75.5483]);
#       marker_2.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Oregon Inlet Marina, NC<br><b>Long Name:</b><br>Oregon Inlet Marina, NC&quot;);
#       map.addLayer(marker_2)
#
#       var marker_3 = L.marker([35.2086, -75.7042]);
#       marker_3.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>USCG Station Hatteras, NC<br><b>Long Name:</b><br>USCG Station Hatteras, NC&quot;);
#       map.addLayer(marker_3)
#
#       var marker_4 = L.marker([34.72, -76.67]);
#       marker_4.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Beaufort, NC<br><b>Long Name:</b><br>Beaufort, NC&quot;);
#       map.addLayer(marker_4)
#
#       var marker_5 = L.marker([34.2267, -77.9533]);
#       marker_5.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Wilmington, NC<br><b>Long Name:</b><br>Wilmington, NC&quot;);
#       map.addLayer(marker_5)
#
#       var marker_6 = L.marker([34.2133, -77.7867]);
#       marker_6.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Wrightsville Beach, NC<br><b>Long Name:</b><br>Wrightsville Beach, NC&quot;);
#       map.addLayer(marker_6)
#
#       var marker_7 = L.marker([33.655, -78.9183]);
#       marker_7.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Springmaid Pier, SC<br><b>Long Name:</b><br>Springmaid Pier, SC&quot;);
#       map.addLayer(marker_7)
#
#       var marker_8 = L.marker([33.3517, -79.1867]);
#       marker_8.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Oyster Landing (N Inlet Estuary), SC<br><b>Long Name:</b><br>Oyster Landing (N Inlet Estuary), SC&quot;);
#       map.addLayer(marker_8)
#
#       var marker_9 = L.marker([32.7817, -79.925]);
#       marker_9.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Charleston, SC<br><b>Long Name:</b><br>Charleston, SC&quot;);
#       map.addLayer(marker_9)
#
#       var marker_10 = L.marker([32.0333, -80.9017]);
#       marker_10.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Fort Pulaski, GA<br><b>Long Name:</b><br>Fort Pulaski, GA&quot;);
#       map.addLayer(marker_10)
#
#       var marker_11 = L.marker([30.6717, -81.465]);
#       marker_11.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Fernandina Beach, FL<br><b>Long Name:</b><br>Fernandina Beach, FL&quot;);
#       map.addLayer(marker_11)
#
#       var marker_12 = L.marker([30.3967, -81.43]);
#       marker_12.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Mayport (Bar Pilots Dock), FL<br><b>Long Name:</b><br>Mayport (Bar Pilots Dock), FL&quot;);
#       map.addLayer(marker_12)
#
#       var marker_13 = L.marker([30.3867, -81.5583]);
#       marker_13.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Dames Point, FL<br><b>Long Name:</b><br>Dames Point, FL&quot;);
#       map.addLayer(marker_13)
#
#       var marker_14 = L.marker([30.32, -81.6583]);
#       marker_14.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Southbank Riverwalk, St Johns River, FL<br><b>Long Name:</b><br>Southbank Riverwalk, St Johns River, FL&quot;);
#       map.addLayer(marker_14)
#
#       var marker_15 = L.marker([30.1917, -81.6917]);
#       marker_15.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>I-295 Bridge, St Johns River, FL<br><b>Long Name:</b><br>I-295 Bridge, St Johns River, FL&quot;);
#       map.addLayer(marker_15)
#
#       var marker_16 = L.marker([29.9783, -81.6283]);
#       marker_16.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Red Bay Point, St Johns River, FL<br><b>Long Name:</b><br>Red Bay Point, St Johns River, FL&quot;);
#       map.addLayer(marker_16)
#
#       var marker_17 = L.marker([29.8017, -81.5483]);
#       marker_17.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Racy Point, St Johns River, FL<br><b>Long Name:</b><br>Racy Point, St Johns River, FL&quot;);
#       map.addLayer(marker_17)
#
#       var marker_18 = L.marker([28.4158, -80.5931]);
#       marker_18.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Trident Pier, FL<br><b>Long Name:</b><br>Trident Pier, FL&quot;);
#       map.addLayer(marker_18)
#
#       var marker_19 = L.marker([26.6117, -80.0333]);
#       marker_19.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Lake Worth Pier, FL<br><b>Long Name:</b><br>Lake Worth Pier, FL&quot;);
#       map.addLayer(marker_19)
#
#       var marker_20 = L.marker([25.7314, -80.1618]);
#       marker_20.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Virginia Key, FL<br><b>Long Name:</b><br>Virginia Key, FL&quot;);
#       map.addLayer(marker_20)
#
#       var marker_21 = L.marker([24.7117, -81.105]);
#       marker_21.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Vaca Key, FL<br><b>Long Name:</b><br>Vaca Key, FL&quot;);
#       map.addLayer(marker_21)
#
#       var marker_22 = L.marker([24.5557, -81.8079]);
#       marker_22.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Key West, FL<br><b>Long Name:</b><br>Key West, FL&quot;);
#       map.addLayer(marker_22)
#
#       var marker_23 = L.marker([26.1317, -81.8075]);
#       marker_23.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Naples, FL<br><b>Long Name:</b><br>Naples, FL&quot;);
#       map.addLayer(marker_23)
#
#       var marker_24 = L.marker([26.6477, -81.8712]);
#       marker_24.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Fort Myers, FL<br><b>Long Name:</b><br>Fort Myers, FL&quot;);
#       map.addLayer(marker_24)
#
#       var marker_25 = L.marker([27.6387, -82.5621]);
#       marker_25.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Port Manatee, FL<br><b>Long Name:</b><br>Port Manatee, FL&quot;);
#       map.addLayer(marker_25)
#
#       var marker_26 = L.marker([27.7606, -82.6269]);
#       marker_26.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>St Petersburg, FL<br><b>Long Name:</b><br>St Petersburg, FL&quot;);
#       map.addLayer(marker_26)
#
#       var marker_27 = L.marker([27.8578, -82.5527]);
#       marker_27.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Old Port Tampa, FL<br><b>Long Name:</b><br>Old Port Tampa, FL&quot;);
#       map.addLayer(marker_27)
#
#       var marker_28 = L.marker([27.9133, -82.425]);
#       marker_28.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Mckay Bay Entrance, FL<br><b>Long Name:</b><br>Mckay Bay Entrance, FL&quot;);
#       map.addLayer(marker_28)
#
#       var marker_29 = L.marker([27.9783, -82.8317]);
#       marker_29.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Clearwater Beach, FL<br><b>Long Name:</b><br>Clearwater Beach, FL&quot;);
#       map.addLayer(marker_29)
#
#       var marker_30 = L.marker([29.135, -83.0317]);
#       marker_30.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Cedar Key, FL<br><b>Long Name:</b><br>Cedar Key, FL&quot;);
#       map.addLayer(marker_30)
#
#       var marker_31 = L.marker([29.7267, -84.9817]);
#       marker_31.bindPopup(&quot;<b>MLLW</b><br><b>Station:</b><br>Apalachicola, FL<br><b>Long Name:</b

# %% [markdown]
# ### Get model output from OPeNDAP URLS

# %%
name_in_list = lambda cube: cube.standard_name in name_list
constraint = iris.Constraint(cube_func=name_in_list)

# %%
# Use only data where the standard deviation of the time series exceeds 0.01 m
# (1 cm) this eliminates flat line model time series that come from land
# points that should have had missing values.
min_var = 0.01

# Use only data within 0.04 degrees (about 4 km).
max_dist = 0.04

# %%
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER


def plt_grid(lon, lat, i, j):
    fig, ax = plt.subplots(figsize=(6, 6),
                           subplot_kw=dict(projection=ccrs.PlateCarree()))
    ax.coastlines('10m', color='k', zorder=3)
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                      linewidth=1.5, color='gray', alpha=0.5, linestyle='--')
    gl.xlabels_top = gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    if (lon.ndim == 1) and (lon.size != lat.size):
        lon, lat = np.meshgrid(lon, lat)
    ax.plot(lon, lat, '.', color='gray', alpha=0.25, zorder=0,
            label='Model')
    ax.plot(observations.lon, observations.lat, 'ro', zorder=1,
            label='Observation')
    if cube.ndim == 3:
        ax.plot(lon[i, j], lat[i, j], 'g.', zorder=2, label='Model@Obs')
    else:
        ax.plot(lon[i], lat[i], 'g.', label='Model@Obs')
    ax.set_title(mod_name)
    return fig, ax

# %%
url = dap_urls[0]  # Plotting SABGOM only for now to avoid a big output.

cube = get_cube(url, constraint, jd_start, jd_stop)
# Cube metadata.
mod_name = cube.attributes['title']
lat = cube.coord(axis='Y').points
lon = cube.coord(axis='X').points
print('%s:\n%s\n' % (mod_name, url))
# Find the closest non-land point from a structured grid model.
tree, lon, lat = make_tree(cube)

for station, obs in observations.iterrows():
    try:
        data = get_nearest_water(cube, tree, obs.lon, obs.lat,
                                 shape=lon.shape, k=100)
        a = obs_data[obs.station]
        data.name = mod_name
        df = concat([a, data], axis=1).sort_index().interpolate().ix[a.index]
        ax = df.plot(legend=False)
        patches, labels = ax.get_legend_handles_labels()
        ax.legend(patches, labels, bbox_to_anchor=(1.5, 1.15),
                  ncol=3, fancybox=True, shadow=True)
    except ValueError as e:
        print(e)  # TODO: Output station object with name instead of position.
# Out:
# ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico:
# http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
#
# No data found at -75.5483,35.795 using min_var=0.01.
# No data found at -76.67,34.72 using min_var=0.01.
# No data found at -77.9533,34.2267 using min_var=0.01.
# No data found at -79.1867,33.3517 using min_var=0.01.
# No data found at -79.925,32.7817 using min_var=0.01.
# No data found at -80.9017,32.0333 using min_var=0.01.
# No data found at -81.465,30.6717 using min_var=0.01.
# No data found at -81.43,30.3967 using min_var=0.01.
# No data found at -81.5583,30.3867 using min_var=0.01.
# No data found at -81.6583,30.32 using min_var=0.01.
# No data found at -81.6917,30.1917 using min_var=0.01.
# No data found at -81.6283,29.9783 using min_var=0.01.
# No data found at -81.5483,29.8017 using min_var=0.01.
# No data found at -81.8075,26.1317 using min_var=0.01.
# No data found at -81.8712,26.6477 using min_var=0.01.
# No data found at -84.9817,29.7267 using min_var=0.01.
# No data found at -85.6669,30.1523 using min_var=0.01.
# No data found at -87.2112,30.4044 using min_var=0.01.
