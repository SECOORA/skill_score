# %%
import sys
sys.path.append("..")

# Standard Library.
from warnings import warn
from datetime import datetime, timedelta

# Scientific stack.
import iris
iris.FUTURE.netcdf_promote = True
import folium
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, Point, LineString
from pandas import DataFrame, date_range, read_csv, concat
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

# Custom IOOS/ASA modules (available at PyPI).
from owslib import fes
from owslib.csw import CatalogueServiceWeb
from pyoos.collectors.coops.coops_sos import CoopsSos

# Local imports
from utilities import name_list, sos_name
from utilities import (find_timevar, find_ij, nearxy,
                       dateRange, get_coops_longname, coops2df, 
                       mod_df, service_urls, inline_map, get_coordinates, get_nearest)

# %%
now = datetime.utcnow()

start = now - timedelta(days=3)
stop = now + timedelta(days=3)

start_date = start.strftime('%Y-%m-%d %H:00')
stop_date = stop.strftime('%Y-%m-%d %H:00')
time_date_range = [start_date, stop_date]

jd_start = datetime.strptime(start_date, '%Y-%m-%d %H:%M')
jd_stop = datetime.strptime(stop_date, '%Y-%m-%d %H:%M')

print('%s to %s' % (start_date, stop_date))
# Out:
# 2014-06-13 18:00 to 2014-06-19 18:00

# %%
bounding_box_type = "box"
bounding_box = [[-87.4, 24.25],
                [-74.7, 36.70]]  # SECOORA: NC, SC GA, FL

box = []
box.append(bounding_box[0][0])
box.append(bounding_box[0][1])
box.append(bounding_box[1][0])
box.append(bounding_box[1][1])

start, stop = dateRange(start_date, stop_date)
bbox = fes.BBox(box)

or_filt = fes.Or([fes.PropertyIsLike(propertyname='apiso:AnyText',
                                     literal=('*%s*' % val),
                                     escapeChar='\\',
                                     wildCard='*',
                                     singleChar='?') for val in name_list])

val = 'Averages'
not_filt = fes.Not([fes.PropertyIsLike(propertyname='apiso:AnyText',
                                       literal=('*%s*' % val),
                                       escapeChar='\\',
                                       wildCard='*',
                                       singleChar='?')])

filter_list = [fes.And([bbox, start, stop, or_filt, not_filt])]

# %%
CSW = {'NGDC Geoportal':
       'http://www.ngdc.noaa.gov/geoportal/csw',
       'USGS WHSC Geoportal':
       'http://geoport.whoi.edu/geoportal/csw',
       'NODC Geoportal: granule level':
       'http://www.nodc.noaa.gov/geoportal/csw',
       'NODC Geoportal: collection level':
       'http://data.nodc.noaa.gov/geoportal/csw',
       'NRCAN CUSTOM':
       'http://geodiscover.cgdi.ca/wes/serviceManagerCSW/csw',
       'USGS Woods Hole GI_CAT':
       'http://geoport.whoi.edu/gi-cat/services/cswiso',
       'USGS CIDA Geonetwork':
       'http://cida.usgs.gov/gdp/geonetwork/srv/en/csw',
       'USGS Coastal and Marine Program':
       'http://cmgds.marine.usgs.gov/geonetwork/srv/en/csw',
       'USGS Woods Hole Geoportal':
       'http://geoport.whoi.edu/geoportal/csw',
       'CKAN testing site for new Data.gov':
       'http://geo.gov.ckan.org/csw',
       'EPA':
       'https://edg.epa.gov/metadata/csw',
       'CWIC':
       'http://cwic.csiss.gmu.edu/cwicv1/discovery'}

endpoint = CSW['NGDC Geoportal']
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

if True:
    print("CSW version: %s" % csw.version)
    print("Number of datasets available: %s" % len(csw.records.keys()))
# Out:
# CSW version: 2.0.2
# Number of datasets available: 10

# %%
dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

if True:
    print("CSW:")
    for rec, item in csw.records.items():
        print(item.title)
    print("\nDAP:")
    print("\n".join(dap_urls))
    print("\nSOS:")
    print("\n".join(sos_urls))
# Out:
# CSW:
# COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# Barotropic Tide Model for the Pacific Basin
# TBOFS - Tampa Bay Operational Forecast System - NOAA CO-OPS - POM
# NDBC Standard Meteorological Buoy Data
# HYbrid Coordinate Ocean Model (HYCOM): Global
# CBOFS - Chesapeake Bay Operational Forecast System - NOAA CO-OPS - POM
# ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC
# NECOFS GOM3 (FVCOM) - Northeast US - Latest Forecast
# NECOFS GOM3 Wave - Northeast US - Latest Forecast
#
# DAP:
# http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd
# http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd
# http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_GOM3_FORECAST.nc
# http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_WAVE_FORECAST.nc
#
# SOS:

# %% [markdown]
# # The datum should be NAVD! But all the data found find are MLLW.

# %%
collector = CoopsSos()

collector.set_datum('MLLW')
collector.server.identification.title
collector.start_time = jd_start
collector.end_time = jd_stop
collector.variables = [sos_name]

ofrs = collector.server.offerings
if False:
    print(len(ofrs))

# %%
iso_start = jd_start.strftime('%Y-%m-%dT%H:%M:%SZ')
iso_stop = jd_stop.strftime('%Y-%m-%dT%H:%M:%SZ')
box_str = ','.join(str(e) for e in box)

print("Date: %s to %s" % (iso_start, iso_stop))
print("Lat/Lon Box: %s" % box_str)
# Out:
# Date: 2014-06-13T18:00:00Z to 2014-06-19T18:00:00Z
# Lat/Lon Box: -87.4,24.25,-74.7,36.7

# %%
url = ('http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?'
       'service=SOS&request=GetObservation&version=1.0.0&'
       'observedProperty=%s&offering=urn:ioos:network:NOAA.NOS.CO-OPS:'
       'WaterLevelActive&featureOfInterest=BBOX:%s&responseFormat='
       'text/csv&eventTime=%s' % (sos_name, box_str, iso_start))

observations = read_csv(url)
if True:
    print(url)
# Out:
# http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetObservation&version=1.0.0&observedProperty=water_surface_height_above_reference_datum&offering=urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive&featureOfInterest=BBOX:-87.4,24.25,-74.7,36.7&responseFormat=text/csv&eventTime=2014-06-13T18:00:00Z

# %%
# Clean the dataframe.
columns = {'station_id': 'station',
           'sensor_id': 'sensor',
           'datum_id': 'datum',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': 'ssh above datum'}

observations.rename(columns=columns, inplace=True)

observations['station'] = [sta.split(':')[-1] for sta in observations['station']]
observations['sensor'] = [sta.split(':')[-1] for sta in observations['sensor']]
observations['datum'] = [sta.split(':')[-1] for sta in observations['datum']]
observations['name'] = [get_coops_longname(sta) for sta in observations['station']]

observations.set_index('name', inplace=True)

# %%
observations.head()
# Out:
#                            station sensor      lat      lon  \
# name
# Duck, NC                   8651370     A1  36.1833 -75.7467
# Oregon Inlet Marina, NC    8652587     A1  35.7950 -75.5483
# USCG Station Hatteras, NC  8654467     A1  35.2086 -75.7042
# Beaufort, NC               8656483     A1  34.7200 -76.6700
# Wilmington, NC             8658120     A1  34.2267 -77.9533
#
#                                       date_time  ssh above datum datum  height
# name
# Duck, NC                   2014-06-13T18:00:00Z            0.091  MLLW   5.663
# Oregon Inlet Marina, NC    2014-06-13T18:00:00Z            0.258  MLLW   0.788
# USCG Station Hatteras, NC  2014-06-13T18:00:00Z            0.142  MLLW   8.345
# Beaufort, NC               2014-06-13T18:00:00Z            0.044  MLLW   0.562
# Wilmington, NC             2014-06-13T18:00:00Z            0.603  MLLW   0.747

# %% [markdown]
# Generate a uniform 6-min time base for model/data comparison:

# %%
data = dict()

for sta in observations.station:
    b = coops2df(collector, sta, sos_name)['water_surface_height_above_reference_datum (m)']
    data.update({sta: b})

obs_data = DataFrame.from_dict(data)

# %%
obs_data.head()
# Out:
#                      8651370  8652587  8654467  8656483  8658120  8658163  \
# date_time
# 2014-06-13 18:00:00    0.091    0.258    0.142    0.044    0.603   -0.096
# 2014-06-13 18:06:00    0.098    0.259    0.128    0.029    0.579   -0.105
# 2014-06-13 18:12:00    0.115    0.260    0.121    0.018    0.555   -0.130
# 2014-06-13 18:18:00    0.108    0.256    0.106    0.015    0.531   -0.122
# 2014-06-13 18:24:00    0.119    0.252    0.098    0.013    0.502   -0.113
#
#                      8661070  8662245  8665530  8670870   ...     8726384  \
# date_time                                                 ...
# 2014-06-13 18:00:00   -0.089    0.182   -0.097   -0.046   ...       0.928
# 2014-06-13 18:06:00   -0.079    0.143   -0.119   -0.084   ...       0.925
# 2014-06-13 18:12:00   -0.093    0.108   -0.136   -0.114   ...       0.922
# 2014-06-13 18:18:00   -0.084    0.074   -0.153   -0.159   ...       0.912
# 2014-06-13 18:24:00   -0.093    0.040   -0.167   -0.177   ...       0.903
#
#                      8726520  8726607  8726667  8726724  8727520  8728690  \
# date_time
# 2014-06-13 18:00:00    1.010    1.079    1.119    0.976    1.573    0.646
# 2014-06-13 18:06:00    1.004    1.081    1.118    0.974    1.578    0.655
# 2014-06-13 18:12:00    1.001    1.083    1.113    0.959    1.590    0.658
# 2014-06-13 18:18:00    0.989    1.081    1.114    0.934    1.583    0.668
# 2014-06-13 18:24:00    0.982    1.075    1.115    0.885    1.573    0.677
#
#                      8729108  8729210  8729840
# date_time
# 2014-06-13 18:00:00    0.608    0.477    0.569
# 2014-06-13 18:06:00    0.607    0.445    0.571
# 2014-06-13 18:12:00    0.595    0.456    0.581
# 2014-06-13 18:18:00    0.588    0.437    0.582
# 2014-06-13 18:24:00    0.576    0.430    0.580
#
# [5 rows x 34 columns]

# %%
m = folium.Map(location=[np.mean(bounding_box, axis=0)[1],
                         np.mean(bounding_box, axis=0)[0]],
               zoom_start=5)

# Create the map and add the bounding box line.
m.line(get_coordinates(bounding_box, bounding_box_type),
       line_color='#FF0000', line_weight=2)

for station, row in observations.iterrows():
    if row['datum'] == 'NADV':
        popup_string = '<b>Station:</b><br>%s<br><b>Long Name:</b><br>%s' % (station, row['name'])
        m.simple_marker(location=[row['lat'], row['lon']], popup=popup_string)
    else:
        popup_string = '<b>Not NAVD</b><br><b>Station:</b><br>%s<br><b>Long Name:</b><br>%s' % (station, row.name)
        m.circle_marker(location=[row['lat'], row['lon']], popup=popup_string,
                        fill_color='#ff0000', radius=10000, line_color='#ff0000')
if False:
    for model, row in models.iterrows():
        popup_string = '<b>Station:</b><br>%s<br><b>Long Name:</b><br>%s' % (station, row['name'])
        m.simple_marker(location=[row['lat'], row['lon']], popup=popup_string)

inline_map(m)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.js&quot;></script>
#
#
#
#
#
#
#
#    <style>
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_7cf37b9e030e44a6b94f2b3172c132fa&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var map = L.map('folium_7cf37b9e030e44a6b94f2b3172c132fa').setView([30.475, -81.05], 5);
#
#       L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       }).addTo(map);
#
#
#       var circle_1 = L.circle([36.1833, -75.7467], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_1.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Duck, NC<br><b>Long Name:</b><br>Duck, NC&quot;);
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([35.795, -75.5483], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_2.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Oregon Inlet Marina, NC<br><b>Long Name:</b><br>Oregon Inlet Marina, NC&quot;);
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([35.2086, -75.7042], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_3.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>USCG Station Hatteras, NC<br><b>Long Name:</b><br>USCG Station Hatteras, NC&quot;);
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([34.72, -76.67], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_4.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Beaufort, NC<br><b>Long Name:</b><br>Beaufort, NC&quot;);
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([34.2267, -77.9533], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_5.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Wilmington, NC<br><b>Long Name:</b><br>Wilmington, NC&quot;);
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([34.2133, -77.7867], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_6.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Wrightsville Beach, NC<br><b>Long Name:</b><br>Wrightsville Beach, NC&quot;);
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([33.655, -78.9183], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_7.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Springmaid Pier, SC<br><b>Long Name:</b><br>Springmaid Pier, SC&quot;);
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([33.3517, -79.1867], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_8.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Oyster Landing (N Inlet Estuary), SC<br><b>Long Name:</b><br>Oyster Landing (N Inlet Estuary), SC&quot;);
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([32.7817, -79.925], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_9.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Charleston, SC<br><b>Long Name:</b><br>Charleston, SC&quot;);
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([32.0333, -80.9017], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_10.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Fort Pulaski, GA<br><b>Long Name:</b><br>Fort Pulaski, GA&quot;);
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([30.6717, -81.465], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_11.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Fernandina Beach, FL<br><b>Long Name:</b><br>Fernandina Beach, FL&quot;);
#       map.addLayer(circle_11)
#
#       var circle_12 = L.circle([30.3967, -81.43], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_12.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Mayport (Bar Pilots Dock), FL<br><b>Long Name:</b><br>Mayport (Bar Pilots Dock), FL&quot;);
#       map.addLayer(circle_12)
#
#       var circle_13 = L.circle([30.3867, -81.5583], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_13.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Dames Point, FL<br><b>Long Name:</b><br>Dames Point, FL&quot;);
#       map.addLayer(circle_13)
#
#       var circle_14 = L.circle([30.32, -81.6583], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_14.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Southbank Riverwalk, St Johns River, FL<br><b>Long Name:</b><br>Southbank Riverwalk, St Johns River, FL&quot;);
#       map.addLayer(circle_14)
#
#       var circle_15 = L.circle([30.1917, -81.6917], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_15.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>I-295 Bridge, St Johns River, FL<br><b>Long Name:</b><br>I-295 Bridge, St Johns River, FL&quot;);
#       map.addLayer(circle_15)
#
#       var circle_16 = L.circle([29.9783, -81.6283], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_16.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Red Bay Point, St Johns River, FL<br><b>Long Name:</b><br>Red Bay Point, St Johns River, FL&quot;);
#       map.addLayer(circle_16)
#
#       var circle_17 = L.circle([29.8017, -81.5483], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_17.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Racy Point, St Joh

# %% [markdown]
# ### Get model output from OPeNDAP URLS

# %%
print('\n'.join(name_list))

name_in_list = lambda cube: cube.standard_name in name_list
constraint = iris.Constraint(cube_func=name_in_list)
# Out:
# water level
# sea_surface_height
# sea_surface_elevation
# sea_surface_height_above_geoid
# sea_surface_height_above_sea_level
# water_surface_height_above_reference_datum
# sea_surface_height_above_reference_ellipsoid

# %%
# Use only data where the standard deviation of the time series exceeds 0.01 m
# (1 cm) this eliminates flat line model time series that come from land
# points that should have had missing values.
min_var = 0.01

# Use only data within 0.04 degrees (about 4 km).
max_dist = 0.04

# %%
def get_cube(url, constraint):
    cube = iris.load_cube(url, constraint)
    # Convert to units of meters:
    # cube.convert_units('m')  # TODO: Isn't working for unstructured data.
    mod_name = cube.attributes['title']
    timevar = find_timevar(cube)
    lat = cube.coord(axis='Y').points
    lon = cube.coord(axis='X').points
    start = timevar.units.date2num(jd_start)
    istart = timevar.nearest_neighbour_index(start)
    stop = timevar.units.date2num(jd_stop)
    istop = timevar.nearest_neighbour_index(stop)
    return cube, timevar, lon, lat, istart, istop, mod_name

# %%
url = dap_urls[0]
packed = get_cube(url, constraint)
cube, timevar, lon, lat, istart, istop, mod_name = packed
print(mod_name, url)

dist, i, j = get_nearest(cube, observations.lon, observations.lat)
for x in zip(cube.coord(axis='X').points[i, j], cube.coord(axis='Y').points[i, j], observations.lon, observations.lat):
    print(x)
# Out:
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'v' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'v' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'u' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'u' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1290: UserWarning: Gracefully filling 'time' dimension coordinate masked points
#   warnings.warn(msg.format(str(cf_coord_var.cf_name)))
# ('COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)', 'http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd')
# (-75.744684136366772, 36.159598275993766, -75.746700000000004, 36.183300000000003)
# (-75.534674051091301, 35.79570444958722, -75.548299999999998, 35.795000000000002)
# (-75.710330393822133, 35.196194639440023, -75.7042, 35.208599999999997)
# (-76.686880152731248, 34.699290366319651, -76.670000000000002, 34.719999999999999)
# (-77.937859119051467, 34.211797800844693, -77.953299999999999, 34.226700000000001)
# (-77.777864668884447, 34.217071862758758, -77.786699999999996, 34.213299999999997)
# (-78.93609529595534, 33.639602989155357, -78.918300000000002, 33.655000000000001)
# (-79.183233028452946, 33.333683666422424, -79.186700000000002, 33.351700000000001)
# (-79.930157605033003, 32.806425485989976, -79.924999999999997, 32.781700000000001)
# (-80.901936039723807, 32.047761828083857, -80.901700000000005, 32.033299999999997)
# (-81.451168125007285, 30.685804816502294, -81.465000000000003, 30.671700000000001)
# (-81.422867011243056, 30.369161255617996, -81.430000000000007, 30.396699999999999)
# (-81.537464143395098, 30.38405811255781, -81.558300000000003, 30.386700000000001)
# (-81.67363111668493, 30.32351288101458, -81.658299999999997, 30.32)
# (-81.671356827108809, 30.192777972914627, -81.691699999999997, 30.191700000000001)
# (-81.621406766482409, 29.951473663071681, -81.628299999999996, 29.978300000000001)
# (-81.549905600284546, 29.785635797947975, -81.548299999999998, 29.8017)
# (-80.58919676268394, 28.435049193382245, -80.593100000000007, 28.415800000000001)
# (-80.031801174816678, 26.640526259707894, -80.033299999999997, 26.611699999999999)
# (-80.174268502708017, 25.718018617278538, -80.161799999999999, 25.731400000000001)
# (-81.089726784229697, 24.709769529223909, -81.105000000000004, 24.7117)
# (-81.839577231747271, 24.569649975963202, -81.807900000000004, 24.555700000000002)
# (-81.801651241227702, 26.108578150684096, -81.807500000000005, 26.131699999999999)
# (-81.880962015979193, 26.66790350188047, -81.871200000000002, 26.6477)
# (-82.561609526765295, 27.618421648623418, -82.562100000000001, 27.6387)
# (-82.633335519758788, 27.784551788581435, -82.626900000000006, 27.7606)
# (-82.56659526913127, 27.880459777001143, -82.552700000000002, 27.857800000000001)
# (-82.430621896693239, 27.941256689651702, -82.424999999999997, 27.9133)
# (-82.819631582419674, 27.965543604249213, -82.831699999999998, 27.978300000000001)
# (-83.047124032784666, 29.118834495178053, -83.031700000000001, 29.135000000000002)
# (-84.980874914936692, 29.712400134656448, -84.981700000000004, 29.726700000000001)
# (-85.653461968753689, 30.141326360735597, -85.666899999999998, 30.1523)
# (-85.907199824913647, 30.227322193716667, -85.878299999999996, 30.2133)
# (-87.21690021948406, 30.375871710948555, -87.211200000000005, 30.404399999999999)

# %%
if istart != istop:  # Only proceed if we have data in the range requested.
    nsta = len(observations.lon)
    if len(cube.shape) == 3:
        print('[Structured grid model]: %s' % url)
        data = cube[0, ...].data
        # Find the closest non-land point from a structured grid model.
        if len(lon.shape) == 1:
            lon, lat = np.meshgrid(lon, lat)
        j, i, d = find_ij(lon, lat, data, observations.lon,
                          observations.lat)
        for n in range(nsta):
            # Only use if model cell is within 0.1 degree of requested
            # location.
            if d[n] <= max_dist:
                arr = cube[istart:istop, j[n], i[n]].data
                if arr.std() >= min_var:
                    print(observations.ix[n])
    elif len(cube.shape) == 1:
        print('[Data]:', url)
# Out:
# [Structured grid model]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# station                         8652587
# sensor                               A1
# lat                              35.795
# lon                            -75.5483
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.258
# datum                              MLLW
# height                            0.788
# Name: Oregon Inlet Marina, NC, dtype: object
# station                         8654467
# sensor                               A1
# lat                             35.2086
# lon                            -75.7042
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.142
# datum                              MLLW
# height                            8.345
# Name: USCG Station Hatteras, NC, dtype: object
# station                         8656483
# sensor                               A1
# lat                               34.72
# lon                              -76.67
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.044
# datum                              MLLW
# height                            0.562
# Name: Beaufort, NC, dtype: object
# station                         8658163
# sensor                               A1
# lat                             34.2133
# lon                            -77.7867
# date_time          2014-06-13T18:00:00Z
# ssh above datum                  -0.096
# datum                              MLLW
# height                            5.793
# Name: Wrightsville Beach, NC, dtype: object
# station                         8661070
# sensor                               A1
# lat                              33.655
# lon                            -78.9183
# date_time          2014-06-13T18:00:00Z
# ssh above datum                  -0.089
# datum                              MLLW
# height                            8.928
# Name: Springmaid Pier, SC, dtype: object
# station                         8722670
# sensor                               A1
# lat                             26.6117
# lon                            -80.0333
# date_time          2014-06-13T18:00:00Z
# ssh above datum                  -0.165
# datum                              MLLW
# height                            9.142
# Name: Lake Worth Pier, FL, dtype: object
# station                         8724580
# sensor                               A1
# lat                             24.5557
# lon                            -81.8079
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.225
# datum                              MLLW
# height                             1.39
# Name: Key West, FL, dtype: object
# station                         8726607
# sensor                               A1
# lat                             27.8578
# lon                            -82.5527
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   1.079
# datum                              MLLW
# height                            8.621
# Name: Old Port Tampa, FL, dtype: object
# station                         8727520
# sensor                               A1
# lat                              29.135
# lon                            -83.0317
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   1.573
# datum                              MLLW
# height                             0.55
# Name: Cedar Key, FL, dtype: object
# station                         8728690
# sensor                               A1
# lat                             29.7267
# lon                            -84.9817
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.646
# datum                              MLLW
# height                            1.307
# Name: Apalachicola, FL, dtype: object
# station                         8729108
# sensor                               A1
# lat                             30.1523
# lon                            -85.6669
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.608
# datum                              MLLW
# height                            1.019
# Name: Panama City, FL, dtype: object
# station                         8729210
# sensor                               A1
# lat                             30.2133
# lon                            -85.8783
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.477
# datum                              MLLW
# height                            8.236
# Name: Panama City Beach, FL, dtype: object
# station                         8729840
# sensor                               A1
# lat                             30.4044
# lon                            -87.2112
# date_time          2014-06-13T18:00:00Z
# ssh above datum                   0.569
# datum                              MLLW
# height                            2.569
# Name: Pensacola, FL, dtype: object
