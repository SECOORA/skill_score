# %%
# Standard Library.
from warnings import warn
from datetime import datetime, timedelta

# Scientific stack.
import iris
iris.FUTURE.netcdf_promote = True
import folium
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

from shapely.geometry import Polygon, Point, LineString
from pandas import DataFrame, date_range, read_csv, concat

from iris.unit import Unit
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

# Custom IOOS/ASA modules (available at PyPI).
from owslib import fes
from owslib.csw import CatalogueServiceWeb
from pyoos.collectors.coops.coops_sos import CoopsSos

# Local imports
from utilities import (find_timevar, dateRange, get_coops_longname, coops2df, 
                       mod_df, service_urls, inline_map, get_coordinates, get_nearest)

# %%
now = datetime.utcnow()

start = now - timedelta(days=3)
stop = now + timedelta(days=3)

start_date = start.strftime('%Y-%m-%d %H:00')
stop_date = stop.strftime('%Y-%m-%d %H:00')

jd_start = datetime.strptime(start_date, '%Y-%m-%d %H:%M')
jd_stop = datetime.strptime(stop_date, '%Y-%m-%d %H:%M')

print('%s to %s' % (start_date, stop_date))
# Out:
# 2014-06-19 15:00 to 2014-06-25 15:00

# %%
name_list = ['water level',
             'sea_surface_height',
             'sea_surface_elevation',
             'sea_surface_height_above_geoid',
             'sea_surface_height_above_sea_level',
             'water_surface_height_above_reference_datum',
             'sea_surface_height_above_reference_ellipsoid']

bounding_box_type = "box"
bounding_box = [[-87.4, 24.25],
                [-74.7, 36.70]]  # SECOORA: NC, SC GA, FL

box = []
box.append(bounding_box[0][0])
box.append(bounding_box[0][1])
box.append(bounding_box[1][0])
box.append(bounding_box[1][1])

start, stop = dateRange(start_date, stop_date)
bbox = fes.BBox(box)

or_filt = fes.Or([fes.PropertyIsLike(propertyname='apiso:AnyText',
                                     literal=('*%s*' % val),
                                     escapeChar='\\',
                                     wildCard='*',
                                     singleChar='?') for val in name_list])

val = 'Averages'
not_filt = fes.Not([fes.PropertyIsLike(propertyname='apiso:AnyText',
                                       literal=('*%s*' % val),
                                       escapeChar='\\',
                                       wildCard='*',
                                       singleChar='?')])

filter_list = [fes.And([bbox, start, stop, or_filt, not_filt])]

# %%
endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

if True:
    print("CSW version: %s" % csw.version)
    print("Number of datasets available: %s" % len(csw.records.keys()))
# Out:
# CSW version: 2.0.2
# Number of datasets available: 11

# %%
dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

if True:
    print("CSW:")
    for rec, item in csw.records.items():
        print(item.title)
    print("\nDAP:")
    print("\n".join(dap_urls))
    print("\nSOS:")
    print("\n".join(sos_urls))
# Out:
# CSW:
# ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# Barotropic Tide Model for the Pacific Basin
# TBOFS - Tampa Bay Operational Forecast System - NOAA CO-OPS - POM
# NDBC Standard Meteorological Buoy Data
# HYbrid Coordinate Ocean Model (HYCOM): Global
# CBOFS - Chesapeake Bay Operational Forecast System - NOAA CO-OPS - POM
# ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC
# NECOFS GOM3 (FVCOM) - Northeast US - Latest Forecast
# NECOFS GOM3 Wave - Northeast US - Latest Forecast
#
# DAP:
# http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd
# http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd
# http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_GOM3_FORECAST.nc
# http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_WAVE_FORECAST.nc
#
# SOS:

# %% [markdown]
# # The datum should be NAVD! But all the data found find are MLLW.

# %%
sos_name = 'water_surface_height_above_reference_datum'

collector = CoopsSos()

collector.set_datum('MLLW')
collector.server.identification.title
collector.start_time = jd_start
collector.end_time = jd_stop
collector.variables = [sos_name]

ofrs = collector.server.offerings
if False:
    print(len(ofrs))

# %%
iso_start = jd_start.strftime('%Y-%m-%dT%H:%M:%SZ')
iso_stop = jd_stop.strftime('%Y-%m-%dT%H:%M:%SZ')
box_str = ','.join(str(e) for e in box)

print("Date: %s to %s" % (iso_start, iso_stop))
print("Lat/Lon Box: %s" % box_str)
# Out:
# Date: 2014-06-19T15:00:00Z to 2014-06-25T15:00:00Z
# Lat/Lon Box: -87.4,24.25,-74.7,36.7

# %%
url = ('http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?'
       'service=SOS&request=GetObservation&version=1.0.0&'
       'observedProperty=%s&offering=urn:ioos:network:NOAA.NOS.CO-OPS:'
       'WaterLevelActive&featureOfInterest=BBOX:%s&responseFormat='
       'text/csv&eventTime=%s' % (sos_name, box_str, iso_start))

observations = read_csv(url)
if True:
    print(url)
# Out:
# http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetObservation&version=1.0.0&observedProperty=water_surface_height_above_reference_datum&offering=urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive&featureOfInterest=BBOX:-87.4,24.25,-74.7,36.7&responseFormat=text/csv&eventTime=2014-06-19T15:00:00Z

# %%
# Clean the dataframe.
columns = {'station_id': 'station',
           'sensor_id': 'sensor',
           'datum_id': 'datum',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': 'ssh above datum'}

observations.rename(columns=columns, inplace=True)

observations['station'] = [sta.split(':')[-1] for sta in observations['station']]
observations['sensor'] = [sta.split(':')[-1] for sta in observations['sensor']]
observations['datum'] = [sta.split(':')[-1] for sta in observations['datum']]
observations['name'] = [get_coops_longname(sta) for sta in observations['station']]

observations.set_index('name', inplace=True)

# %%
observations.head()
# Out:
#                            station sensor      lat      lon  \
# name
# Duck, NC                   8651370     A1  36.1833 -75.7467
# Oregon Inlet Marina, NC    8652587     A1  35.7950 -75.5483
# USCG Station Hatteras, NC  8654467     A1  35.2086 -75.7042
# Beaufort, NC               8656483     A1  34.7200 -76.6700
# Wilmington, NC             8658120     A1  34.2267 -77.9533
#
#                                       date_time  ssh above datum datum  height
# name
# Duck, NC                   2014-06-19T15:00:00Z            0.729  MLLW   5.663
# Oregon Inlet Marina, NC    2014-06-19T15:00:00Z            0.328  MLLW   0.788
# USCG Station Hatteras, NC  2014-06-19T15:00:00Z            0.231  MLLW   8.345
# Beaufort, NC               2014-06-19T15:00:00Z            0.573  MLLW   0.562
# Wilmington, NC             2014-06-19T15:00:00Z            0.003  MLLW   0.747

# %% [markdown]
# Generate a uniform 6-min time base for model/data comparison:

# %%
data = dict()

for sta in observations.station:
    b = coops2df(collector, sta, sos_name)['water_surface_height_above_reference_datum (m)']
    data.update({sta: b})

obs_data = DataFrame.from_dict(data)

# %%
obs_data.head()
# Out:
#                      8651370  8652587  8654467  8656483  8658120  8658163  \
# date_time
# 2014-06-19 15:00:00    0.729    0.328    0.231    0.573    0.003    0.800
# 2014-06-19 15:06:00    0.762    0.337    0.235    0.607    0.035    0.833
# 2014-06-19 15:12:00    0.747    0.345    0.244    0.630    0.056    0.845
# 2014-06-19 15:18:00    0.804    0.361    0.257    0.643    0.099    0.862
# 2014-06-19 15:24:00    0.875    0.375    0.268    0.657    0.144    0.883
#
#                      8661070  8662245  8665530  8670870   ...     8726384  \
# date_time                                                 ...
# 2014-06-19 15:00:00    0.947    0.602    0.902    1.001   ...       0.527
# 2014-06-19 15:06:00    0.996    0.637    0.950    1.052   ...       0.518
# 2014-06-19 15:12:00    1.054    0.673    0.994    1.123   ...       0.510
# 2014-06-19 15:18:00    1.075    0.706    1.046    1.191   ...       0.503
# 2014-06-19 15:24:00    1.126    0.740    1.085    1.255   ...       0.492
#
#                      8726520  8726607  8726667  8726724  8727520  8728690  \
# date_time
# 2014-06-19 15:00:00    0.584    0.657    0.624    0.452    0.809    0.587
# 2014-06-19 15:06:00    0.579    0.649    0.606    0.440    0.787    0.582
# 2014-06-19 15:12:00    0.571    0.640    0.590    0.438    0.767    0.574
# 2014-06-19 15:18:00    0.564    0.632    0.573    0.422    0.748    0.569
# 2014-06-19 15:24:00    0.556    0.622    0.571    0.421    0.733    0.564
#
#                      8729108  8729210  8729840
# date_time
# 2014-06-19 15:00:00    0.387    0.350    0.368
# 2014-06-19 15:06:00    0.387    0.350    0.363
# 2014-06-19 15:12:00    0.386    0.348    0.362
# 2014-06-19 15:18:00    0.386    0.360    0.360
# 2014-06-19 15:24:00    0.383    0.355    0.360
#
# [5 rows x 34 columns]

# %%
m = folium.Map(location=[np.mean(bounding_box, axis=0)[1],
                         np.mean(bounding_box, axis=0)[0]],
               zoom_start=5)

# Create the map and add the bounding box line.
m.line(get_coordinates(bounding_box, bounding_box_type),
       line_color='#FF0000', line_weight=2)

for station, row in observations.iterrows():
    if row['datum'] == 'NADV':
        popup_string = '<b>Station:</b><br>%s<br><b>Long Name:</b><br>%s' % (station, row['name'])
        m.simple_marker(location=[row['lat'], row['lon']], popup=popup_string)
    else:
        popup_string = '<b>Not NAVD</b><br><b>Station:</b><br>%s<br><b>Long Name:</b><br>%s' % (station, row.name)
        m.circle_marker(location=[row['lat'], row['lon']], popup=popup_string,
                        fill_color='#ff0000', radius=10000, line_color='#ff0000')
if False:
    for model, row in models.iterrows():
        popup_string = '<b>Station:</b><br>%s<br><b>Long Name:</b><br>%s' % (station, row['name'])
        m.simple_marker(location=[row['lat'], row['lon']], popup=popup_string)

inline_map(m)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.js&quot;></script>
#
#
#
#
#
#
#
#    <style>
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_b9b43427eb9a46b196ba2cfe96a452d7&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var map = L.map('folium_b9b43427eb9a46b196ba2cfe96a452d7').setView([30.475, -81.05], 5);
#
#       L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       }).addTo(map);
#
#
#       var circle_1 = L.circle([36.1833, -75.7467], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_1.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Duck, NC<br><b>Long Name:</b><br>Duck, NC&quot;);
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([35.795, -75.5483], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_2.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Oregon Inlet Marina, NC<br><b>Long Name:</b><br>Oregon Inlet Marina, NC&quot;);
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([35.2086, -75.7042], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_3.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>USCG Station Hatteras, NC<br><b>Long Name:</b><br>USCG Station Hatteras, NC&quot;);
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([34.72, -76.67], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_4.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Beaufort, NC<br><b>Long Name:</b><br>Beaufort, NC&quot;);
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([34.2267, -77.9533], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_5.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Wilmington, NC<br><b>Long Name:</b><br>Wilmington, NC&quot;);
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([34.2133, -77.7867], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_6.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Wrightsville Beach, NC<br><b>Long Name:</b><br>Wrightsville Beach, NC&quot;);
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([33.655, -78.9183], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_7.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Springmaid Pier, SC<br><b>Long Name:</b><br>Springmaid Pier, SC&quot;);
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([33.3517, -79.1867], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_8.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Oyster Landing (N Inlet Estuary), SC<br><b>Long Name:</b><br>Oyster Landing (N Inlet Estuary), SC&quot;);
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([32.7817, -79.925], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_9.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Charleston, SC<br><b>Long Name:</b><br>Charleston, SC&quot;);
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([32.0333, -80.9017], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_10.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Fort Pulaski, GA<br><b>Long Name:</b><br>Fort Pulaski, GA&quot;);
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([30.6717, -81.465], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_11.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Fernandina Beach, FL<br><b>Long Name:</b><br>Fernandina Beach, FL&quot;);
#       map.addLayer(circle_11)
#
#       var circle_12 = L.circle([30.3967, -81.43], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_12.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Mayport (Bar Pilots Dock), FL<br><b>Long Name:</b><br>Mayport (Bar Pilots Dock), FL&quot;);
#       map.addLayer(circle_12)
#
#       var circle_13 = L.circle([30.3867, -81.5583], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_13.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Dames Point, FL<br><b>Long Name:</b><br>Dames Point, FL&quot;);
#       map.addLayer(circle_13)
#
#       var circle_14 = L.circle([30.32, -81.6583], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_14.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Southbank Riverwalk, St Johns River, FL<br><b>Long Name:</b><br>Southbank Riverwalk, St Johns River, FL&quot;);
#       map.addLayer(circle_14)
#
#       var circle_15 = L.circle([30.1917, -81.6917], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_15.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>I-295 Bridge, St Johns River, FL<br><b>Long Name:</b><br>I-295 Bridge, St Johns River, FL&quot;);
#       map.addLayer(circle_15)
#
#       var circle_16 = L.circle([29.9783, -81.6283], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_16.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Red Bay Point, St Johns River, FL<br><b>Long Name:</b><br>Red Bay Point, St Johns River, FL&quot;);
#       map.addLayer(circle_16)
#
#       var circle_17 = L.circle([29.8017, -81.5483], 10000, {
#                             color: '#ff0000',
#                             fillColor: '#ff0000',
#                             fillOpacity: 0.6
#                             });
#       circle_17.bindPopup(&quot;<b>Not NAVD</b><br><b>Station:</b><br>Racy Point, St Joh

# %% [markdown]
# ### Get model output from OPeNDAP URLS

# %%
name_in_list = lambda cube: cube.standard_name in name_list
constraint = iris.Constraint(cube_func=name_in_list)

# %%
# Use only data where the standard deviation of the time series exceeds 0.01 m
# (1 cm) this eliminates flat line model time series that come from land
# points that should have had missing values.
min_var = 0.01

# Use only data within 0.04 degrees (about 4 km).
max_dist = 0.04

# %%
def get_cube(url, constraint):
    cube = iris.load_cube(url, constraint)
    if not cube.units == Unit('meters'):
        # TODO: Isn't working for unstructured data.
        cube.convert_units('m')
    mod_name = cube.attributes['title']
    timevar = find_timevar(cube)
    lat = cube.coord(axis='Y').points
    lon = cube.coord(axis='X').points
    start = timevar.units.date2num(jd_start)
    istart = timevar.nearest_neighbour_index(start)
    stop = timevar.units.date2num(jd_stop)
    istop = timevar.nearest_neighbour_index(stop)
    return cube, timevar, lon, lat, istart, istop, mod_name

# %%
import cartopy.crs as ccrs
import iris.quickplot as qplt

from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

def plt_grid(lon, lat):
    fig, ax = plt.subplots(figsize=(6, 6),
                           subplot_kw=dict(projection=ccrs.PlateCarree()))
    ax.coastlines('10m', color='k', zorder=3)
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                      linewidth=1.5, color='gray', alpha=0.5, linestyle='--')
    gl.xlabels_top = gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    if (lon.ndim == 1) and (lon.size != lat.size):
        lon, lat = np.meshgrid(lon, lat)
    ax.plot(lon, lat, '.', color='gray', alpha=0.25, zorder=0, label='Model')
    ax.plot(observations.lon, observations.lat, 'ro', zorder=1, label='Observation')
    if cube.ndim == 3:
        ax.plot(lon[i, j], lat[i, j], 'g.', zorder=2, label='Model@Obs')
    else:
        ax.plot(lon[i], lat[i], 'g.', label='Model@Obs')
    ax.set_title(mod_name)
    return fig, ax

# %%
import warnings
warnings.filterwarnings("ignore")

for url in dap_urls:
    try:
        packed = get_cube(url, constraint)
        cube, timevar, lon, lat, istart, istop, mod_name = packed
        print('%s:\n%s\n' % (mod_name, url))
        dist, i, j = get_nearest(cube, observations.lon, observations.lat)
        fig, ax = plt_grid(lon, lat)
    except CoordinateNotFoundError as e:
        print(e)
# Out:
# ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico:
# http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
#
# COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental):
# http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best):
# http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# Barotropic Tide Model for the Pacific Basin:
# http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# TBOFS - Tampa Bay Operational Forecast System - NOAA CO-OPS - POM:
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd
# HYbrid Coordinate Ocean Model (HYCOM): Global:
# http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# CBOFS - Chesapeake Bay Operational Forecast System - NOAA CO-OPS - POM:
# http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd
# ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC:
# http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# NECOFS GOM3 (FVCOM) - Northeast US - Latest Forecast:
# http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_GOM3_FORECAST.nc
# 'Expected to find exactly 1  coordinate, but found none.'
