# %% [markdown]
# <img style='float: left' width="150px" src="http://secoora.org/sites/default/files/secoora_logo.png">
# <br><br>
# ## [SECOORA Notebook 1](http://secoora.org/)
#
# ### Fetch Sea Surface Height time-series data
#
# This notebook fetches weekly time-series of all the SECOORA observations and
# models available in the **NGDC** and **SECOORA THREDDS** catalogs.

# %%
import time

start_time = time.time()

# %% [markdown]
# ### Save configuration

# %%
import os
try:
    import cPickle as pickle
except ImportError:
    import pickle

import iris
from datetime import datetime
from utilities import CF_names, fetch_range, start_log

# 1-week start of data.
kw = dict(start=datetime(2014, 7, 1, 12), days=6)
start, stop = fetch_range(**kw)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names.
sos_name = 'water_surface_height_above_reference_datum'
name_list = CF_names[sos_name]

# Units.
units = iris.unit.Unit('meters')

# Logging.
run_name = '{:%Y-%m-%d}'.format(stop)
log = start_log(start, stop, bbox)

# SECOORA models.
secoora_models = ['SABGOM', 'USEAST',
                  'USF_ROMS', 'USF_SWAN', 'USF_FVCOM']

# Config.
fname = os.path.join(run_name, 'config.pkl')
config = dict(start=start,
              stop=stop,
              bbox=bbox,
              name_list=name_list,
              units=units,
              run_name=run_name,
              secoora_models=secoora_models)

with open(fname,'wb') as f:
    pickle.dump(config, f)

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exclude ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

fmt = '{:*^64}'.format
log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %%
from utilities import is_station

# Filter out some station endpoints.
non_stations = []
for url in dap_urls:
    try:
        if not is_station(url):
            non_stations.append(url)
    except RuntimeError as e:
        log.warn("Could not access URL {}. {!r}".format(url, e))

dap_urls = non_stations

log.info(fmt(' Filtered DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %% [markdown]
# ### Add SECOORA models and observations

# %%
from utilities import titles, fix_url

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the NGDC csw'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# NOTE: USEAST is not archived at the moment!
# https://github.com/ioos/secoora/issues/173
dap_urls = [fix_url(start, url) if
            'SABGOM' in url else url for url in dap_urls]

# %%
import warnings
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

from utilities import (TimeoutException, secoora_buoys,
                       quick_load_cubes, proc_cube)

urls = list(secoora_buoys())
buoys = dict()
if not urls:
    raise ValueError("Did not find any SECOORA buoys!")

for url in urls:
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")  # Suppress iris warnings.
            kw = dict(bbox=bbox, time=(start, stop), units=units)
            cubes = quick_load_cubes(url, name_list)
            cubes = [proc_cube(cube, **kw) for cube in cubes]
        buoy = url.split('/')[-1].split('.nc')[0]
        if len(cubes) == 1:
            buoys.update({buoy: cubes[0]})
        else:
            #[buoys.update({'{}_{}'.format(buoy, k): cube}) for
            # k, cube in list(enumerate(cubes))]
            # FIXME: For now I am choosing the first sensor.
            buoys.update({buoy: cubes[0]})
    except (RuntimeError, ValueError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()

datum = 'NAVD'
collector.set_datum(datum)

collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# ### Clean the DataFrame

# %%
from utilities import get_coops_metadata, to_html

columns = {'datum_id': 'datum',
           'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': sos_name}

observations.rename(columns=columns, inplace=True)

observations['datum'] = [s.split(':')[-1] for s in observations['datum']]

observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_metadata(s)[0] for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>water_surface_height_above_reference_datum</th>
#       <th>datum</th>
#       <th>height</th>
#       <th>sigma</th>
#       <th>quality_flags</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>8651370</td>
#       <td>A1</td>
#       <td>36.1831</td>
#       <td>-75.7467</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.535</td>
#       <td>MLLW</td>
#       <td>5.663</td>
#       <td>0.125</td>
#       <td>0;0;0;0</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>8652587</td>
#       <td>A1</td>
#       <td>35.7942</td>
#       <td>-75.5481</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.219</td>
#       <td>MLLW</td>
#       <td>0.788</td>
#       <td>0.001</td>
#       <td>0;0;0;0</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td>8654467</td>
#       <td>A1</td>
#       <td>35.2086</td>
#       <td>-75.7042</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.179</td>
#       <td>MLLW</td>
#       <td>8.345</td>
#       <td>0.001</td>
#       <td>0;0;0;0</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td>8656483</td>
#       <td>A1</td>
#       <td>34.7200</td>
#       <td>-76.6700</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.552</td>
#       <td>MLLW</td>
#       <td>0.562</td>
#       <td>0.002</td>
#       <td>0;0;0;0</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td>8658120</td>
#       <td>A1</td>
#       <td>34.2267</td>
#       <td>-77.9533</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.183</td>
#       <td>MLLW</td>
#       <td>0.747</td>
#       <td>0.006</td>
#       <td>0;0;0;0</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from pandas import DataFrame
from utilities import secoora2df

if buoys:
    secoora_observations = secoora2df(buoys, sos_name)
    to_html(secoora_observations.head())
else:
    secoora_observations = DataFrame()

# %%
from pandas import concat


all_obs = concat([observations, secoora_observations], axis=0)
to_html(concat([all_obs.head(2), all_obs.tail(2)]))
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date_time</th>
#       <th>datum</th>
#       <th>height</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>quality_flags</th>
#       <th>sensor</th>
#       <th>sigma</th>
#       <th>station</th>
#       <th>water_surface_height_above_reference_datum</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>MLLW</td>
#       <td>5.663</td>
#       <td>36.183100</td>
#       <td>-75.746700</td>
#       <td>0;0;0;0</td>
#       <td>A1</td>
#       <td>0.125</td>
#       <td>8651370</td>
#       <td>0.535000</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>MLLW</td>
#       <td>0.788</td>
#       <td>35.794200</td>
#       <td>-75.548100</td>
#       <td>0;0;0;0</td>
#       <td>A1</td>
#       <td>0.001</td>
#       <td>8652587</td>
#       <td>0.219000</td>
#     </tr>
#     <tr>
#       <th>Binney Dock station</th>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>27.467546</td>
#       <td>-80.300850</td>
#       <td>NaN</td>
#       <td>NA</td>
#       <td>NaN</td>
#       <td>fldep.binneydock.</td>
#       <td>-0.215533</td>
#     </tr>
#     <tr>
#       <th>Gordon River Inlet station</th>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>26.093140</td>
#       <td>-81.798141</td>
#       <td>NaN</td>
#       <td>NA</td>
#       <td>NaN</td>
#       <td>fldep.gordonriverinlet.</td>
#       <td>-0.054746</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Uniform 6-min time base for model/data comparison

# %%
from owslib.ows import ExceptionReport
from utilities import pyoos2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
outfile = '{}-OBS_DATA.nc'.format(run_name)
outfile = os.path.join(run_name, outfile)

log.info(fmt(' Downloading to file {} '.format(outfile)))
data, bad_station = dict(), []
col = 'water_surface_height_above_reference_datum (m)'
for station in observations.index:
    station_code = observations['station'][station]
    try:
        df = pyoos2df(collector, station_code, df_name=station)
        data.update({station_code: df[col]})
    except ExceptionReport as e:
        bad_station.append(station_code)
        log.warning("[{}] {}:\n{}".format(station_code, station, e))
obs_data = DataFrame.from_dict(data)

# %% [markdown]
# ### Split good and bad vertical datum stations.

# %%
pattern = '|'.join(bad_station)
if pattern:
    all_obs['bad_station'] = all_obs.station.str.contains(pattern)
    observations = observations[~observations.station.str.contains(pattern)]
else:
    all_obs['bad_station'] = ~all_obs.station.str.contains(pattern)

# Save updated `all_obs.csv`.
fname = '{}-all_obs.csv'.format(run_name)
fname = os.path.join(run_name, fname)
all_obs.to_csv(fname)

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         datum=datum,
                         url=url))

save_timeseries(obs_data, outfile=outfile,
                standard_name=sos_name, **kw)

to_html(obs_data.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8662245</th>
#       <th>8665530</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720219</th>
#       <th>8720226</th>
#       <th>8720357</th>
#       <th>8720503</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723214</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8727520</th>
#       <th>8728690</th>
#       <th>8729108</th>
#       <th>8729840</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-07-01 12:00:00</th>
#       <td>-0.132</td>
#       <td>0.004</td>
#       <td>0.018</td>
#       <td>-0.041</td>
#       <td>-0.122</td>
#       <td>0.018</td>
#       <td>-0.376</td>
#       <td>-0.262</td>
#       <td>-0.320</td>
#       <td>-0.133</td>
#       <td>0.071</td>
#       <td>0.126</td>
#       <td>0.242</td>
#       <td>-0.160</td>
#       <td>-0.126</td>
#       <td>-0.290</td>
#       <td>-0.099</td>
#       <td>-0.220</td>
#       <td>-0.127</td>
#       <td>-0.005</td>
#       <td>-0.057</td>
#       <td>0.067</td>
#       <td>0.131</td>
#       <td>0.044</td>
#       <td>0.106</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:06:00</th>
#       <td>-0.102</td>
#       <td>0.007</td>
#       <td>0.044</td>
#       <td>-0.003</td>
#       <td>-0.096</td>
#       <td>0.049</td>
#       <td>-0.347</td>
#       <td>-0.228</td>
#       <td>-0.313</td>
#       <td>-0.132</td>
#       <td>0.068</td>
#       <td>0.120</td>
#       <td>0.236</td>
#       <td>-0.144</td>
#       <td>-0.111</td>
#       <td>-0.290</td>
#       <td>-0.103</td>
#       <td>-0.218</td>
#       <td>-0.138</td>
#       <td>-0.002</td>
#       <td>-0.057</td>
#       <td>0.051</td>
#       <td>0.146</td>
#       <td>0.055</td>
#       <td>0.113</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:12:00</th>
#       <td>-0.073</td>
#       <td>0.010</td>
#       <td>0.067</td>
#       <td>0.024</td>
#       <td>-0.070</td>
#       <td>0.083</td>
#       <td>-0.312</td>
#       <td>-0.203</td>
#       <td>-0.304</td>
#       <td>-0.130</td>
#       <td>0.067</td>
#       <td>0.117</td>
#       <td>0.229</td>
#       <td>-0.121</td>
#       <td>-0.076</td>
#       <td>-0.280</td>
#       <td>-0.108</td>
#       <td>-0.218</td>
#       <td>-0.165</td>
#       <td>0.000</td>
#       <td>-0.054</td>
#       <td>0.029</td>
#       <td>0.157</td>
#       <td>0.055</td>
#       <td>0.121</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:18:00</th>
#       <td>-0.068</td>
#       <td>0.016</td>
#       <td>0.092</td>
#       <td>0.051</td>
#       <td>-0.045</td>
#       <td>0.118</td>
#       <td>-0.278</td>
#       <td>-0.185</td>
#       <td>-0.293</td>
#       <td>-0.128</td>
#       <td>0.063</td>
#       <td>0.109</td>
#       <td>0.221</td>
#       <td>-0.130</td>
#       <td>-0.067</td>
#       <td>-0.263</td>
#       <td>-0.112</td>
#       <td>-0.218</td>
#       <td>-0.161</td>
#       <td>0.001</td>
#       <td>-0.055</td>
#       <td>0.007</td>
#       <td>0.165</td>
#       <td>0.054</td>
#       <td>0.121</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:24:00</th>
#       <td>-0.013</td>
#       <td>0.021</td>
#       <td>0.091</td>
#       <td>0.085</td>
#       <td>-0.019</td>
#       <td>0.153</td>
#       <td>-0.243</td>
#       <td>-0.161</td>
#       <td>-0.281</td>
#       <td>-0.125</td>
#       <td>0.066</td>
#       <td>0.108</td>
#       <td>0.213</td>
#       <td>-0.092</td>
#       <td>-0.048</td>
#       <td>-0.244</td>
#       <td>-0.115</td>
#       <td>-0.206</td>
#       <td>-0.167</td>
#       <td>0.002</td>
#       <td>-0.058</td>
#       <td>-0.010</td>
#       <td>0.165</td>
#       <td>0.053</td>
#       <td>0.123</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### SECOORA Observations

# %%
import numpy as np
from pandas import DataFrame

def extract_series(cube, station):
    time = cube.coord(axis='T')
    date_time = time.units.num2date(cube.coord(axis='T').points)
    data = cube.data
    return DataFrame(data, columns=[station], index=date_time)


if buoys:
    secoora_obs_data = []
    for station, cube in list(buoys.items()):
        df = extract_series(cube, station)
        secoora_obs_data.append(df)
    # Some series have duplicated times!
    kw = dict(subset='index', take_last=True)
    secoora_obs_data = [obs.reset_index().drop_duplicates(**kw).set_index('index') for
                        obs in secoora_obs_data]
    secoora_obs_data = concat(secoora_obs_data, axis=1)
else:
    secoora_obs_data = DataFrame()

# %% [markdown]
# ### These buoys need some QA/QC before saving

# %%
from utilities.qaqc import filter_spikes, threshold_series

if buoys:
    secoora_obs_data.apply(threshold_series, args=(0, 40))
    secoora_obs_data.apply(filter_spikes)

    # Interpolate to the same index as SOS.
    index = obs_data.index
    kw = dict(method='time', limit=30)
    secoora_obs_data = secoora_obs_data.reindex(index).interpolate(**kw).ix[index]

    log.info(fmt(' SECOORA Observations '))
    fname = '{}-SECOORA_OBS_DATA.nc'.format(run_name)
    fname = os.path.join(run_name, fname)

    log.info(fmt(' Downloading to file {} '.format(fname)))

    url = "http://129.252.139.124/thredds/catalog_platforms.html"
    comment = "Several stations {}".format(url)
    kw = dict(longitude=secoora_observations.lon,
              latitude=secoora_observations.lat,
              station_attr=dict(cf_role="timeseries_id"),
              cube_attr=dict(featureType='timeSeries',
                             Conventions='CF-1.6',
                             standard_name_vocabulary='CF-1.6',
                             cdm_data_type="Station",
                             comment=comment,
                             url=url))

    save_timeseries(secoora_obs_data, outfile=fname,
                    standard_name=sos_name, **kw)

    to_html(secoora_obs_data.head())

# %% [markdown]
# ### Loop discovered models and save the nearest time-series

# %%
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                             MergeError)

from utilities import time_limit, get_model_name, is_model, get_surface

log.info(fmt(' Models '))
cubes = dict()

with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # Suppress iris warnings.
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                cube = quick_load_cubes(url, name_list, callback=None, strict=True)
                if is_model(cube):
                    cube = proc_cube(cube, bbox=bbox, time=(start, stop), units=units)
                else:
                    log.warning("[Not model data]: {}".format(url))
                    continue
                cube = get_surface(cube)
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
        except (TimeoutException, RuntimeError, ValueError,
                ConstraintMismatchError, CoordinateNotFoundError,
                IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))
# Out:
# Exception AttributeError: "'CFReader' object has no attribute '_dataset'" in <bound method CFReader.__del__ of CFReader('http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd')> ignored

# %%
from iris.pandas import as_series

from utilities import (make_tree, get_nearest_water,
                       add_station, ensure_timeseries)

for mod_name, cube in cubes.items():
    fname = '{}-{}.nc'.format(run_name, mod_name)
    fname = os.path.join(run_name, fname)
    log.info(fmt(' Saving to file {} '.format(fname)))
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot create KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in all_obs.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            status = "No Data"
            log.info('[{}] {}'.format(status, obs.name))
            continue
        except RuntimeError as e:
            status = "Failed"
            log.info('[{}] {}. ({})'.format(status, obs.name, e.message))
            continue
        if not series:
            status = "Land   "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water  "

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = add_station(cube, station)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info(fmt('Finished processing {}\n'.format(mod_name)))

# %%
from utilities import nbviewer_link, make_qr

make_qr(nbviewer_link('00-fetch_data.ipynb'))

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

with open('{}/log.txt'.format(run_name)) as f:
    print(f.read())
# Out:
# 02:54:08 INFO: ************Saving data inside directory 2014-07-07*************
# 02:54:08 INFO: *********************** Run information ************************
# 02:54:08 INFO: Run date: 2015-11-25 17:54:08
# 02:54:08 INFO: Download start: 2014-07-01 12:00:00
# 02:54:08 INFO: Download stop: 2014-07-07 12:00:00
# 02:54:08 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 02:54:08 INFO: *********************** Software version ***********************
# 02:54:08 INFO: Iris version: 1.8.1
# 02:54:08 INFO: owslib version: 0.10.0
# 02:54:08 INFO: pyoos version: 0.6.2
# 02:54:15 INFO: ********************* Catalog information **********************
# 02:54:15 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 02:54:15 INFO: CSW version: 2.0.2
# 02:54:15 INFO: Number of datasets available: 22
# 02:54:15 INFO: ***************************** CSW ******************************
# 02:54:15 INFO: USF FVCOM - Nowcast Aggregation
# 02:54:15 INFO: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# 02:54:15 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 02:54:15 INFO: ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History
# 02:54:15 INFO: NOAA.NOS.CO-OPS SOS
# 02:54:15 INFO: HYbrid Coordinate Ocean Model (HYCOM): Global
# 02:54:15 INFO: ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC
# 02:54:15 INFO: fldep.bingslanding.
# 02:54:15 INFO: fldep.binneydock.
# 02:54:15 INFO: fldep.gordonriverinlet.
# 02:54:15 INFO: fldep.melbourne.
# 02:54:15 INFO: fldep.naplesbay.
# 02:54:15 INFO: fldep.poncedeleonsouth.
# 02:54:15 INFO: fldep.redbaypoint.
# 02:54:15 INFO: fldep.stlucieinlet.
# 02:54:15 INFO: fldep.tolomatoriver.
# 02:54:15 INFO: fldep.verobeach.
# 02:54:15 INFO: usf.apk.ngwlms
# 02:54:15 INFO: usf.bcp.ngwlms
# 02:54:15 INFO: usf.fhp.ngwlms
# 02:54:15 INFO: usf.shp.ngwlms
# 02:54:15 INFO: usf.tas.ngwlms
# 02:54:15 INFO: ***************************** SOS ******************************
# 02:54:15 INFO: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetCapabilities&acceptVersions=1.0.0
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.bingslanding..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.binneydock..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.gordonriverinlet..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.melbourne..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.naplesbay..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.poncedeleonsouth..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.redbaypoint..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.stlucieinlet..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.tolomatoriver..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/fldep.verobeach..nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/usf.apk.ngwlms.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/usf.bcp.ngwlms.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/usf.fhp.ngwlms.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/usf.shp.ngwlms.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: http://tds.secoora.org/thredds/sos/usf.tas.ngwlms.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 02:54:15 INFO: ***************************** DAP ******************************
# 02:54:15 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# 02:54:15 INFO: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic.html
# 02:54:15 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 02:54:15 INFO: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# 02:54:15 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 02:54:15 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his/ESPRESSO_Real-Time_v2_History_Best.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.bingslanding..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.binneydock..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.gordonriverinlet..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.melbourne..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.naplesbay..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.poncedeleonsouth..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.redbaypoint..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.stlucieinlet..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.tolomatoriver..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/fldep.verobeach..nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/usf.apk.ngwlms.nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/usf.bcp.ngwlms.nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/usf.fhp.ngwlms.nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/usf.shp.ngwlms.nc.html
# 02:54:15 INFO: http://tds.secoora.org/thredds/dodsC/usf.tas.ngwlms.nc.html
# 02:55:38 INFO: ************************* Filtered DAP *************************
# 02:55:38 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# 02:55:38 INFO: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic.html
# 02:55:38 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 02:55:38 INFO: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# 02:55:38 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 02:55:38 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his/ESPRESSO_Real-Time_v2_History_Best.html
# 02:55:38 WARNING: USEAST not in the NGDC csw
# 02:55:38 WARNING: USF_ROMS not in the NGDC csw
# 02:55:38 WARNING: USF_SWAN not in the NGDC csw
# 02:55:46 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fit.sispnj.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/fit.sispnj.met.nc.
# 02:55:58 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.imet.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c10.imet.nc.
# 02:56:06 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc.
# 02:56:26 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc.
# 02:56:48 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc.
# 02:56:54 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc.
# 02:57:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc.
# 02:57:09 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc.
# 02:57:12 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc.
# 02:57:17 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc.
# 02:57:20 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc.
# 02:57:25 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc.
# 02:57:29 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc.
# 02:57:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.sun2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/carocoops.sun2.buoy.nc.
# 02:57:41 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.frp2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/carocoops.frp2.buoy.nc.
# 02:57:48 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.cap2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/carocoops.cap2.buoy.nc.
# 02:57:56 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm3.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.ilm3.buoy.nc.
# 02:58:07 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.ilm2.buoy.nc.
# 02:58:10 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc.
# 02:58:15 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc.
# 02:58:22 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.gulfofmexico.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.gulfofmexico.wq.nc.
# 02:58:30 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.shellpoint.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.shellpoint.wq.nc.
# 02:58:38 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.redfishpass.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.redfishpass.wq.nc.
# 02:58:45 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.tarponbay.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.tarponbay.wq.nc.
# 02:58:51 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.fortmyers.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.fortmyers.wq.nc.
# 02:59:16 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc
# istart must be different from istop! Got istart 43 and  istop 43
# 03:00:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.2ndave.pier.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/lbhmc.2ndave.pier.nc.
# 03:00:49 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.cherrygrove.pier.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/lbhmc.cherrygrove.pier.nc.
# 03:00:59 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.apachepier.pier.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/lbhmc.apachepier.pier.nc.
# 03:01:06 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wiwf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.wiwf1.met.nc.
# 03:01:15 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lbrf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lbrf1.met.nc.
# 03:01:23 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bobf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bobf1.met.nc.
# 03:01:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.trrf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.trrf1.met.nc.
# 03:01:43 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wwef1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.wwef1.met.nc.
# 03:01:51 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lrif1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lrif1.met.nc.
# 03:01:57 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bwsf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bwsf1.met.nc.
# 03:02:04 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.pkyf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.pkyf1.met.nc.
# 03:02:12 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lmdf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lmdf1.met.nc.
# 03:02:19 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.cnbf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.cnbf1.met.nc.
# 03:02:27 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.hcef1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.hcef1.met.nc.
# 03:02:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.jkyf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.jkyf1.met.nc.
# 03:02:43 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wrbf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.wrbf1.met.nc.
# 03:02:50 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.gbif1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.gbif1.met.nc.
# 03:03:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc.
# 03:03:08 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bdvf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bdvf1.met.nc.
# 03:03:17 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lrkf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lrkf1.met.nc.
# 03:03:24 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bnkf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bnkf1.met.nc.
# 03:03:31 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.gbtf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.gbtf1.met.nc.
# 03:03:38 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.tcvf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.tcvf1.met.nc.
# 03:03:48 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.canf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.canf1.met.nc.
# 03:03:57 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lbsf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lbsf1.met.nc.
# 03:04:10 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.mukf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.mukf1.met.nc.
# 03:04:21 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.dkkf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.dkkf1.met.nc.
# 03:04:31 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.cwaf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.cwaf1.met.nc.
# 03:04:55 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fau.lobo.1.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/fau.lobo.1.nc.
# 03:05:07 INFO: ********************* Collector offerings **********************
# 03:05:07 INFO: NOAA.NOS.CO-OPS SOS: 1055 offerings
# 03:05:09 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-07-01T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AWaterLevelActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=water_surface_height_above_reference_datum
# 03:07:10 INFO: ************************* Observations *************************
# 03:07:10 INFO: **** Downloading to file 2014-07-07/2014-07-07-OBS_DATA.nc *****
# 03:07:13 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/utilities/secoora.py:694: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   df = df.drop_duplicates(cols='date_time').set_index('date_time')
#
# 03:07:16 WARNING: [8654467] USCG Station Hatteras, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:07:16 WARNING: [8656483] Beaufort, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:07:17 WARNING: [8658120] Wilmington, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:08:07 WARNING: [8726520] St Petersburg, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:08:07 WARNING: [8726607] Old Port Tampa, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:08:16 WARNING: [8729210] Panama City Beach, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:08:20 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/iris/fileformats/netcdf.py:1783: UserWarning: NetCDF default saving behaviour currently assigns the outermost dimensions to unlimited. This behaviour is to be deprecated, in favour of no automatic assignment. To switch to the new behaviour, set iris.FUTURE.netcdf_no_unlimited to True.
#   warnings.warn(msg)
#
# 03:08:20 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#
# 03:08:20 INFO: ********************* SECOORA Observations *********************
# 03:08:20 INFO:  Downloading to file 2014-07-07/2014-07-07-SECOORA_OBS_DATA.nc *
# 03:08:20 INFO: **************************** Models ****************************
# 03:08:20 INFO:
# [Reading url 1/9]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:08:41 INFO:
# [Reading url 2/9]: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# 03:09:38 INFO:
# [Reading url 3/9]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 03:10:26 INFO:
# [Reading url 4/9]: http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 03:10:27 WARNING: Cannot get cube for: http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# NetCDF: file not found
# 03:10:27 INFO:
# [Reading url 5/9]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 03:10:32 INFO:
# [Reading url 6/9]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his/ESPRESSO_Real-Time_v2_History_Best
# 03:10:47 INFO:
# [Reading url 7/9]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 03:11:17 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 03:11:17 INFO:
# [Reading url 8/9]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 03:11:30 INFO:
# [Reading url 9/9]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:11:33 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd.
# 03:11:33 INFO: ******** Saving to file 2014-07-07/2014-07-07-ESTOFS.nc ********
# 03:11:37 INFO: [Water  ] Duck, NC
# 03:11:41 INFO: [Water  ] Oregon Inlet Marina, NC
# 03:11:45 INFO: [Water  ] USCG Station Hatteras, NC
# 03:11:49 INFO: [Water  ] Beaufort, NC
# 03:11:49 INFO: [No Data] Wilmington, NC
# 03:11:53 INFO: [Water  ] Wrightsville Beach, NC
# 03:11:57 INFO: [Water  ] Springmaid Pier, SC
# 03:12:01 INFO: [Water  ] Oyster Landing (N Inlet Estuary), SC
# 03:12:01 INFO: [No Data] Charleston, SC
# 03:12:04 INFO: [Water  ] Fernandina Beach, FL
# 03:12:07 INFO: [Water  ] Mayport (Bar Pilots Dock), FL
# 03:12:07 INFO: [No Data] Dames Point, FL
# 03:12:07 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:12:07 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 03:12:07 INFO: [No Data] Red Bay Point, St Johns River, FL
# 03:12:07 INFO: [No Data] Racy Point, St Johns River, FL
# 03:12:10 INFO: [Water  ] Trident Pier, FL
# 03:12:14 INFO: [Water  ] Lake Worth Pier, FL
# 03:12:17 INFO: [Water  ] Virginia Key, FL
# 03:12:20 INFO: [Water  ] Vaca Key, FL
# 03:12:24 INFO: [Water  ] Key West, FL
# 03:12:27 INFO: [Water  ] Naples, FL
# 03:12:27 INFO: [No Data] Fort Myers, FL
# 03:12:31 INFO: [Water  ] Port Manatee, FL
# 03:12:34 INFO: [Water  ] St Petersburg, FL
# 03:12:37 INFO: [Water  ] Old Port Tampa, FL
# 03:12:40 INFO: [Water  ] Cedar Key, FL
# 03:12:44 INFO: [Water  ] Apalachicola, FL
# 03:12:44 INFO: [No Data] Panama City, FL
# 03:12:47 INFO: [Water  ] Panama City Beach, FL
# 03:12:47 INFO: [No Data] Pensacola, FL
# 03:12:51 INFO: [Water  ] Tolomato River station
# 03:12:53 INFO: [Water  ] Fred Howard Park
# 03:12:55 INFO: [Water  ] usf_tas_ngwlms
# 03:12:58 INFO: [Water  ] Big Carlos Pass
# 03:13:01 INFO: [Water  ] Shell Point
# 03:13:04 INFO: [Water  ] St Lucie Inlet station
# 03:13:06 INFO: [Water  ] Naples Bay station
# 03:13:10 INFO: [Water  ] Vero Beach station
# 03:13:12 INFO: [Water  ] Ponce De Leon South station
# 03:13:14 INFO: [Water  ] Melbourne station
# 03:13:17 INFO: [Water  ] Aripeka
# 03:13:20 INFO: [Water  ] Bing's Landing station
# 03:13:23 INFO: [Water  ] Binney Dock station
# 03:13:26 INFO: [Water  ] Gordon River Inlet station
# 03:13:26 INFO: Finished processing ESTOFS
#
# 03:13:26 INFO: ******** Saving to file 2014-07-07/2014-07-07-HYCOM.nc *********
# 03:13:46 INFO: [Land   ] Duck, NC
# 03:13:51 INFO: [Water  ] Oregon Inlet Marina, NC
# 03:14:00 INFO: [Land   ] USCG Station Hatteras, NC
# 03:14:11 INFO: [Land   ] Beaufort, NC
# 03:14:17 INFO: [Land   ] Wilmington, NC
# 03:14:22 INFO: [Water  ] Wrightsville Beach, NC
# 03:14:22 INFO: [No Data] Springmaid Pier, SC
# 03:14:29 INFO: [Land   ] Oyster Landing (N Inlet Estuary), SC
# 03:14:36 INFO: [Land   ] Charleston, SC
# 03:14:41 INFO: [Land   ] Fernandina Beach, FL
# 03:14:47 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 03:14:52 INFO: [Land   ] Dames Point, FL
# 03:14:56 INFO: [Land   ] Southbank Riverwalk, St Johns River, FL
# 03:15:01 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 03:15:05 INFO: [Land   ] Red Bay Point, St Johns River, FL
# 03:15:05 INFO: [No Data] Racy Point, St Johns River, FL
# 03:15:14 INFO: [Land   ] Trident Pier, FL
# 03:15:20 INFO: [Water  ] Lake Worth Pier, FL
# 03:15:24 INFO: [Land   ] Virginia Key, FL
# 03:15:30 INFO: [Land   ] Vaca Key, FL
# 03:15:40 INFO: [Land   ] Key West, FL
# 03:15:40 INFO: [No Data] Naples, FL
# 03:15:52 INFO: [Land   ] Fort Myers, FL
# 03:16:07 INFO: [Land   ] Port Manatee, FL
# 03:16:29 INFO: [Land   ] St Petersburg, FL
# 03:19:09 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/ipykernel/__main__.py:28: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#
# 03:19:09 INFO: [Failed] Old Port Tampa, FL. (NetCDF: DAP server error)
# 03:19:10 INFO: [Failed] Cedar Key, FL. (NetCDF: DAP server error)
# 03:19:11 INFO: [Failed] Apalachicola, FL. (NetCDF: DAP server error)
# 03:19:12 INFO: [Failed] Panama City, FL. (NetCDF: DAP server error)
# 03:19:12 INFO: [No Data] Panama City Beach, FL
# 03:19:12 INFO: [Failed] Pensacola, FL. (NetCDF: DAP server error)
# 03:19:13 INFO: [Failed] Tolomato River station. (NetCDF: DAP server error)
# 03:19:14 INFO: [Failed] Fred Howard Park. (NetCDF: DAP server error)
# 03:19:15 INFO: [Failed] usf_tas_ngwlms. (NetCDF: DAP server error)
# 03:19:15 INFO: [No Data] Big Carlos Pass
# 03:19:16 INFO: [Failed] Shell Point. (NetCDF: DAP server error)
# 03:19:16 INFO: [Failed] St Lucie Inlet station. (NetCDF: DAP server error)
# 03:19:17 INFO: [Failed] Naples Bay station. (NetCDF: DAP server error)
# 03:19:18 INFO: [Failed] Vero Beach station. (NetCDF: DAP server error)
# 03:19:19 INFO: [Failed] Ponce De Leon South station. (NetCDF: DAP server error)
# 03:19:20 INFO: [Failed] Melbourne station. (NetCDF: DAP server error)
# 03:19:20 INFO: [Failed] Aripeka. (NetCDF: DAP server error)
# 03:19:21 INFO: [Failed] Bing's Landing station. (NetCDF: DAP server error)
# 03:19:22 INFO: [Failed] Binney Dock station. (NetCDF: DAP server error)
# 03:19:23 INFO: [Failed] Gordon River Inlet station. (NetCDF: DAP server error)
# 03:19:23 INFO: Finished processing HYCOM
#
# 03:19:23 INFO: ******* Saving to file 2014-07-07/2014-07-07-USF_ROMS.nc *******
# 03:19:23 INFO: [No Data] Duck, NC
# 03:19:23 INFO: [No Data] Oregon Inlet Marina, NC
# 03:19:23 INFO: [No Data] USCG Station Hatteras, NC
# 03:19:23 INFO: [No Data] Beaufort, NC
# 03:19:23 INFO: [No Data] Wilmington, NC
# 03:19:23 INFO: [No Data] Wrightsville Beach, NC
# 03:19:23 INFO: [No Data] Springmaid Pier, SC
# 03:19:23 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 03:19:23 INFO: [No Data] Charleston, SC
# 03:19:23 INFO: [No Data] Fernandina Beach, FL
# 03:19:23 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 03:19:23 INFO: [No Data] Dames Point, FL
# 03:19:23 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:19:23 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 03:19:23 INFO: [No Data] Red Bay Point, St Johns River, FL
# 03:19:23 INFO: [No Data] Racy Point, St Johns River, FL
# 03:19:23 INFO: [No Data] Trident Pier, FL
# 03:19:23 INFO: [No Data] Lake Worth Pier, FL
# 03:19:23 INFO: [No Data] Virginia Key, FL
# 03:19:29 INFO: [Water  ] Vaca Key, FL
# 03:19:29 INFO: [No Data] Key West, FL
# 03:19:32 INFO: [Water  ] Naples, FL
# 03:19:36 INFO: [Water  ] Fort Myers, FL
# 03:19:38 INFO: [Water  ] Port Manatee, FL
# 03:19:41 INFO: [Water  ] St Petersburg, FL
# 03:19:44 INFO: [Water  ] Old Port Tampa, FL
# 03:19:47 INFO: [Water  ] Cedar Key, FL
# 03:19:51 INFO: [Water  ] Apalachicola, FL
# 03:19:53 INFO: [Water  ] Panama City, FL
# 03:19:56 INFO: [Water  ] Panama City Beach, FL
# 03:19:56 INFO: [No Data] Pensacola, FL
# 03:19:56 INFO: [No Data] Tolomato River station
# 03:20:00 INFO: [Water  ] Fred Howard Park
# 03:20:04 INFO: [Water  ] usf_tas_ngwlms
# 03:20:08 INFO: [Water  ] Big Carlos Pass
# 03:20:12 INFO: [Water  ] Shell Point
# 03:20:12 INFO: [No Data] St Lucie Inlet station
# 03:20:17 INFO: [Water  ] Naples Bay station
# 03:20:17 INFO: [No Data] Vero Beach station
# 03:20:17 INFO: [No Data] Ponce De Leon South station
# 03:20:17 INFO: [No Data] Melbourne station
# 03:20:21 INFO: [Water  ] Aripeka
# 03:20:21 INFO: [No Data] Bing's Landing station
# 03:20:21 INFO: [No Data] Binney Dock station
# 03:20:24 INFO: [Water  ] Gordon River Inlet station
# 03:21:17 INFO: Finished processing USF_ROMS
#
# 03:21:17 INFO: ****** Saving to file 2014-07-07/2014-07-07-USF_FVCOM.nc *******
# 03:21:17 INFO: [No Data] Duck, NC
# 03:21:17 INFO: [No Data] Oregon Inlet Marina, NC
# 03:21:17 INFO: [No Data] USCG Station Hatteras, NC
# 03:21:17 INFO: [No Data] Beaufort, NC
# 03:21:17 INFO: [No Data] Wilmington, NC
# 03:21:17 INFO: [No Data] Wrightsville Beach, NC
# 03:21:17 INFO: [No Data] Springmaid Pier, SC
# 03:21:17 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 03:21:17 INFO: [No Data] Charleston, SC
# 03:21:17 INFO: [No Data] Fernandina Beach, FL
# 03:21:17 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 03:21:17 INFO: [No Data] Dames Point, FL
# 03:21:17 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:21:17 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 03:21:17 INFO: [No Data] Red Bay Point, St Johns River, FL
# 03:21:17 INFO: [No Data] Racy Point, St Johns River, FL
# 03:21:17 INFO: [No Data] Trident Pier, FL
# 03:21:17 INFO: [No Data] Lake Worth Pier, FL
# 03:21:17 INFO: [No Data] Virginia Key, FL
# 03:21:24 INFO: [Water  ] Vaca Key, FL
# 03:21:31 INFO: [Water  ] Key West, FL
# 03:21:38 INFO: [Water  ] Naples, FL
# 03:21:45 INFO: [Water  ] Fort Myers, FL
# 03:21:52 INFO: [Water  ] Port Manatee, FL
# 03:22:00 INFO: [Water  ] St Petersburg, FL
# 03:22:06 INFO: [Water  ] Old Port Tampa, FL
# 03:22:14 INFO: [Water  ] Cedar Key, FL
# 03:22:21 INFO: [Water  ] Apalachicola, FL
# 03:22:21 INFO: [No Data] Panama City, FL
# 03:22:24 INFO: [Water  ] Panama City Beach, FL
# 03:22:24 INFO: [No Data] Pensacola, FL
# 03:22:24 INFO: [No Data] Tolomato River station
# 03:22:31 INFO: [Water  ] Fred Howard Park
# 03:22:35 INFO: [Water  ] usf_tas_ngwlms
# 03:22:42 INFO: [Water  ] Big Carlos Pass
# 03:22:49 INFO: [Water  ] Shell Point
# 03:22:49 INFO: [No Data] St Lucie Inlet station
# 03:22:50 INFO: [Water  ] Naples Bay station
# 03:22:50 INFO: [No Data] Vero Beach station
# 03:22:50 INFO: [No Data] Ponce De Leon South station
# 03:22:50 INFO: [No Data] Melbourne station
# 03:22:52 INFO: [Water  ] Aripeka
# 03:22:52 INFO: [No Data] Bing's Landing station
# 03:22:52 INFO: [No Data] Binney Dock station
# 03:22:54 INFO: [Water  ] Gordon River Inlet station
# 03:22:54 INFO: Finished processing USF_FVCOM
#
# 03:22:54 INFO: ******* Saving to file 2014-07-07/2014-07-07-COAWST_4.nc *******
# 03:23:10 INFO: [Land   ] Duck, NC
# 03:23:15 INFO: [Water  ] Oregon Inlet Marina, NC
# 03:23:21 INFO: [Water  ] USCG Station Hatteras, NC
# 03:23:27 INFO: [Water  ] Beaufort, NC
# 03:23:35 INFO: [Land   ] Wilmington, NC
# 03:23:41 INFO: [Water  ] Wrightsville Beach, NC
# 03:23:48 INFO: [Water  ] Springmaid Pier, SC
# 03:23:56 INFO: [Land   ] Oyster Landing (N Inlet Estuary), SC
# 03:24:07 INFO: [Water  ] Charleston, SC
# 03:24:19 INFO: [Land   ] Fernandina Beach, FL
# 03:24:32 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 03:24:46 INFO: [Land   ] Dames Point, FL
# 03:24:58 INFO: [Land   ] Southbank Riverwalk, St Johns River, FL
# 03:25:10 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 03:25:22 INFO: [Land   ] Red Bay Point, St Johns River, FL
# 03:25:28 INFO: [Land   ] Racy Point, St Johns River, FL
# 03:25:33 INFO: [Land   ] Trident Pier, FL
# 03:25:39 INFO: [Water  ] Lake Worth Pier, FL
# 03:25:52 INFO: [Water  ] Virginia Key, FL
# 03:26:06 INFO: [Land   ] Vaca Key, FL
# 03:26:13 INFO: [Water  ] Key West, FL
# 03:26:28 INFO: [Water  ] Naples, FL
# 03:26:41 INFO: [Land   ] Fort Myers, FL
# 03:26:48 INFO: [Land   ] Port Manatee, FL
# 03:27:01 INFO: [Water  ] St Petersburg, FL
# 03:27:07 INFO: [Water  ] Old Port Tampa, FL
# 03:27:12 INFO: [Water  ] Cedar Key, FL
# 03:27:18 INFO: [Water  ] Apalachicola, FL
# 03:27:24 INFO: [Water  ] Panama City, FL
# 03:27:31 INFO: [Water  ] Panama City Beach, FL
# 03:27:38 INFO: [Water  ] Pensacola, FL
# 03:27:43 INFO: [Land   ] Tolomato River station
# 03:27:49 INFO: [Land   ] Fred Howard Park
# 03:28:02 INFO: [Land   ] usf_tas_ngwlms
# 03:28:08 INFO: [Water  ] Big Carlos Pass
# 03:28:19 INFO: [Water  ] Shell Point
# 03:28:26 INFO: [Water  ] St Lucie Inlet station
# 03:28:40 INFO: [Land   ] Naples Bay station
# 03:28:46 INFO: [Water  ] Vero Beach station
# 03:28:53 INFO: [Water  ] Ponce De Leon South station
# 03:28:59 INFO: [Land   ] Melbourne station
# 03:29:15 INFO: [Water  ] Aripeka
# 03:29:23 INFO: [Land   ] Bing's Landing station
# 03:29:30 INFO: [Water  ] Binney Dock station
# 03:29:36 INFO: [Land   ] Gordon River Inlet station
# 03:32:01 INFO: Finished processing COAWST_4
#
# 03:32:01 INFO: **** Saving to file 2014-07-07/2014-07-07-ROMS_ESPRESSO.nc *****
# 03:32:08 INFO: [Land   ] Duck, NC
# 03:32:12 INFO: [Water  ] Oregon Inlet Marina, NC
# 03:32:17 INFO: [Land   ] USCG Station Hatteras, NC
# 03:32:21 INFO: [Water  ] Beaufort, NC
# 03:32:21 INFO: [No Data] Wilmington, NC
# 03:32:21 INFO: [No Data] Wrightsville Beach, NC
# 03:32:21 INFO: [No Data] Springmaid Pier, SC
# 03:32:21 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 03:32:21 INFO: [No Data] Charleston, SC
# 03:32:21 INFO: [No Data] Fernandina Beach, FL
# 03:32:21 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 03:32:21 INFO: [No Data] Dames Point, FL
# 03:32:21 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:32:21 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 03:32:21 INFO: [No Data] Red Bay Point, St Johns River, FL
# 03:32:21 INFO: [No Data] Racy Point, St Johns River, FL
# 03:32:21 INFO: [No Data] Trident Pier, FL
# 03:32:21 INFO: [No Data] Lake Worth Pier, FL
# 03:32:21 INFO: [No Data] Virginia Key, FL
# 03:32:21 INFO: [No Data] Vaca Key, FL
# 03:32:21 INFO: [No Data] Key West, FL
# 03:32:21 INFO: [No Data] Naples, FL
# 03:32:21 INFO: [No Data] Fort Myers, FL
# 03:32:21 INFO: [No Data] Port Manatee, FL
# 03:32:21 INFO: [No Data] St Petersburg, FL
# 03:32:21 INFO: [No Data] Old Port Tampa, FL
# 03:32:21 INFO: [No Data] Cedar Key, FL
# 03:32:21 INFO: [No Data] Apalachicola, FL
# 03:32:21 INFO: [No Data] Panama City, FL
# 03:32:21 INFO: [No Data] Panama City Beach, FL
# 03:32:21 INFO: [No Data] Pensacola, FL
# 03:32:21 INFO: [No Data] Tolomato River station
# 03:32:21 INFO: [No Data] Fred Howard Park
# 03:32:21 INFO: [No Data] usf_tas_ngwlms
# 03:32:21 INFO: [No Data] Big Carlos Pass
# 03:32:21 INFO: [No Data] Shell Point
# 03:32:21 INFO: [No Data] St Lucie Inlet station
# 03:32:21 INFO: [No Data] Naples Bay station
# 03:32:21 INFO: [No Data] Vero Beach station
# 03:32:21 INFO: [No Data] Ponce De Leon South station
# 03:32:21 INFO: [No Data] Melbourne station
# 03:32:21 INFO: [No Data] Aripeka
# 03:32:21 INFO: [No Data] Bing's Landing station
# 03:32:21 INFO: [No Data] Binney Dock station
# 03:32:21 INFO: [No Data] Gordon River Inlet station
# 03:32:28 INFO: Finished processing ROMS_ESPRESSO
#
# 03:32:29 INFO: 38.38 minutes
# 03:32:29 INFO: EOF
