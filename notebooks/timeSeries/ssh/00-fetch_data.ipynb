# %% [markdown]
# <img style='float: left' width="150px" src="http://secoora.org/sites/default/files/secoora_logo.png">
# <br><br>
# ## [SECOORA Notebook 1](http://secoora.org/)
#
# ### Fetch Sea Surface Height time-series data
#
# This notebook fetches weekly time-series of all the SECOORA observations and
# models available in the **NGDC** and **SECOORA THREDDS** catalogs.

# %%
import time

start_time = time.time()

# %% [markdown]
# ### Save configuration

# %%
import os
try:
    import cPickle as pickle
except ImportError:
    import pickle

import iris
from datetime import datetime
from utilities import CF_names, fetch_range, start_log

# 1-week start of data.
kw = dict(start=datetime(2014, 7, 1, 12), days=6)
start, stop = fetch_range(**kw)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names.
sos_name = 'water_surface_height_above_reference_datum'
name_list = CF_names[sos_name]

# Units.
units = iris.unit.Unit('meters')

# Logging.
run_name = '{:%Y-%m-%d}'.format(stop)
log = start_log(start, stop, bbox)

# SECOORA models.
secoora_models = ['SABGOM', 'USEAST',
                  'USF_ROMS', 'USF_SWAN', 'USF_FVCOM']

# Config.
fname = os.path.join(run_name, 'config.pkl')
config = dict(start=start,
              stop=stop,
              bbox=bbox,
              name_list=name_list,
              units=units,
              run_name=run_name,
              secoora_models=secoora_models)

with open(fname,'wb') as f:
    pickle.dump(config, f)

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exclude ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

fmt = '{:*^64}'.format
log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %%
from utilities import is_station

# Filter out some station endpoints.
non_stations = []
for url in dap_urls:
    try:
        if not is_station(url):
            non_stations.append(url)
    except RuntimeError as e:
        log.warn("Could not access URL {}. {!r}".format(url, e))

dap_urls = non_stations

log.info(fmt(' Filtered DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %% [markdown]
# ### Add SECOORA models and observations

# %%
from utilities import titles, fix_url

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the NGDC csw'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# NOTE: USEAST is not archived at the moment!
# https://github.com/ioos/secoora/issues/173
dap_urls = [fix_url(start, url) if
            'SABGOM' in url else url for url in dap_urls]

# %%
import warnings
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

from utilities import (TimeoutException, secoora_buoys,
                       quick_load_cubes, proc_cube)

urls = list(secoora_buoys())
buoys = dict()
if not urls:
    raise ValueError("Did not find any SECOORA buoys!")

for url in urls:
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")  # Suppress iris warnings.
            kw = dict(bbox=bbox, time=(start, stop), units=units)
            cubes = quick_load_cubes(url, name_list)
            cubes = [proc_cube(cube, **kw) for cube in cubes]
        buoy = url.split('/')[-1].split('.nc')[0]
        if len(cubes) == 1:
            buoys.update({buoy: cubes[0]})
        else:
            #[buoys.update({'{}_{}'.format(buoy, k): cube}) for
            # k, cube in list(enumerate(cubes))]
            # FIXME: For now I am choosing the first sensor.
            buoys.update({buoy: cubes[0]})
    except (RuntimeError, ValueError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()

datum = 'NAVD'
collector.set_datum(datum)

collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# ### Clean the DataFrame

# %%
from utilities import get_coops_metadata, to_html

columns = {'datum_id': 'datum',
           'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': sos_name}

observations.rename(columns=columns, inplace=True)

observations['datum'] = [s.split(':')[-1] for s in observations['datum']]

observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_metadata(s)[0] for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>water_surface_height_above_reference_datum</th>
#       <th>datum</th>
#       <th>height</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>8651370</td>
#       <td>A1</td>
#       <td>36.1833</td>
#       <td>-75.7467</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.535</td>
#       <td>MLLW</td>
#       <td>5.663</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>8652587</td>
#       <td>A1</td>
#       <td>35.7950</td>
#       <td>-75.5483</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.212</td>
#       <td>MLLW</td>
#       <td>0.788</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td>8654467</td>
#       <td>A1</td>
#       <td>35.2086</td>
#       <td>-75.7042</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.179</td>
#       <td>MLLW</td>
#       <td>8.345</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td>8656483</td>
#       <td>A1</td>
#       <td>34.7200</td>
#       <td>-76.6700</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.552</td>
#       <td>MLLW</td>
#       <td>0.562</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td>8658120</td>
#       <td>A1</td>
#       <td>34.2267</td>
#       <td>-77.9533</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>0.183</td>
#       <td>MLLW</td>
#       <td>0.747</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from pandas import DataFrame
from utilities import secoora2df

if buoys:
    secoora_observations = secoora2df(buoys, sos_name)
    to_html(secoora_observations.head())
else:
    secoora_observations = DataFrame()

# %%
from pandas import concat


all_obs = concat([observations, secoora_observations], axis=0)
to_html(concat([all_obs.head(2), all_obs.tail(2)]))
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date_time</th>
#       <th>datum</th>
#       <th>height</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>sensor</th>
#       <th>station</th>
#       <th>water_surface_height_above_reference_datum</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>MLLW</td>
#       <td>5.663</td>
#       <td>36.183300</td>
#       <td>-75.746700</td>
#       <td>A1</td>
#       <td>8651370</td>
#       <td>0.535000</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>MLLW</td>
#       <td>0.788</td>
#       <td>35.795000</td>
#       <td>-75.548300</td>
#       <td>A1</td>
#       <td>8652587</td>
#       <td>0.212000</td>
#     </tr>
#     <tr>
#       <th>Binney Dock station</th>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>27.467546</td>
#       <td>-80.300850</td>
#       <td>NA</td>
#       <td>fldep.binneydock.</td>
#       <td>-0.215533</td>
#     </tr>
#     <tr>
#       <th>Gordon River Inlet station</th>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>26.093140</td>
#       <td>-81.798141</td>
#       <td>NA</td>
#       <td>fldep.gordonriverinlet.</td>
#       <td>-0.054746</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Uniform 6-min time base for model/data comparison

# %%
from owslib.ows import ExceptionReport
from utilities import pyoos2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
outfile = '{}-OBS_DATA.nc'.format(run_name)
outfile = os.path.join(run_name, outfile)

log.info(fmt(' Downloading to file {} '.format(outfile)))
data, bad_station = dict(), []
col = 'water_surface_height_above_reference_datum (m)'
for station in observations.index:
    station_code = observations['station'][station]
    try:
        df = pyoos2df(collector, station_code, df_name=station)
        data.update({station_code: df[col]})
    except ExceptionReport as e:
        bad_station.append(station_code)
        log.warning("[{}] {}:\n{}".format(station_code, station, e))
obs_data = DataFrame.from_dict(data)

# %% [markdown]
# ### Split good and bad vertical datum stations.

# %%
pattern = '|'.join(bad_station)
if pattern:
    all_obs['bad_station'] = all_obs.station.str.contains(pattern)
    observations = observations[~observations.station.str.contains(pattern)]
else:
    all_obs['bad_station'] = ~all_obs.station.str.contains(pattern)

# Save updated `all_obs.csv`.
fname = '{}-all_obs.csv'.format(run_name)
fname = os.path.join(run_name, fname)
all_obs.to_csv(fname)

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         datum=datum,
                         url=url))

save_timeseries(obs_data, outfile=outfile,
                standard_name=sos_name, **kw)

to_html(obs_data.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th
td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:18:00</th>
#       <td>-0.068</td>
#       <td>0.009</td>
#       <td>0.092</td>
#       <td>0.051</td>
#       <td>-0.045</td>
#       <td>0.118</td>
#       <td>-0.278</td>
#       <td>-0.185</td>
#       <td>-0.293</td>
#       <td>NaN</td>
#       <td>0.063</td>
#       <td>0.109</td>
#       <td>0.221</td>
#       <td>-0.130</td>
#       <td>-0.067</td>
#       <td>-0.263</td>
#       <td>-0.112</td>
#       <td>-0.218</td>
#       <td>-0.161</td>
#       <td>0.001</td>
#       <td>-0.055</td>
#       <td>0.007</td>
#       <td>0.165</td>
#       <td>0.054</td>
#       <td>0.121</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:24:00</th>
#       <td>-0.013</td>
#       <td>0.014</td>
#       <td>0.091</td>
#       <td>0.085</td>
#       <td>-0.019</td>
#       <td>0.153</td>
#       <td>-0.243</td>
#       <td>-0.161</td>
#       <td>-0.281</td>
#       <td>NaN</td>
#       <td>0.066</td>
#       <td>0.108</td>
#       <td>0.213</td>
#       <td>-0.092</td>
#       <td>-0.048</td>
#       <td>-0.244</td>
#       <td>-0.115</td>
#       <td>-0.206</td>
#       <td>-0.167</td>
#       <td>0.002</td>
#       <td>-0.058</td>
#       <td>-0.010</td>
#       <td>0.165</td>
#       <td>0.053</td>
#       <td>0.123</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### SECOORA Observations

# %%
import numpy as np
from pandas import DataFrame

def extract_series(cube, station):
    time = cube.coord(axis='T')
    date_time = time.units.num2date(cube.coord(axis='T').points)
    data = cube.data
    return DataFrame(data, columns=[station], index=date_time)


if buoys:
    secoora_obs_data = []
    for station, cube in list(buoys.items()):
        df = extract_series(cube, station)
        secoora_obs_data.append(df)
    # Some series have duplicated times!
    kw = dict(subset='index', take_last=True)
    secoora_obs_data = [obs.reset_index().drop_duplicates(**kw).set_index('index') for
                        obs in secoora_obs_data]
    secoora_obs_data = concat(secoora_obs_data, axis=1)
else:
    secoora_obs_data = DataFrame()

# %% [markdown]
# ### These buoys need some QA/QC before saving

# %%
from utilities.qaqc import filter_spikes, threshold_series

if buoys:
    secoora_obs_data.apply(threshold_series, args=(0, 40))
    secoora_obs_data.apply(filter_spikes)

    # Interpolate to the same index as SOS.
    index = obs_data.index
    kw = dict(method='time', limit=30)
    secoora_obs_data = secoora_obs_data.reindex(index).interpolate(**kw).ix[index]

    log.info(fmt(' SECOORA Observations '))
    fname = '{}-SECOORA_OBS_DATA.nc'.format(run_name)
    fname = os.path.join(run_name, fname)

    log.info(fmt(' Downloading to file {} '.format(fname)))

    url = "http://129.252.139.124/thredds/catalog_platforms.html"
    comment = "Several stations {}".format(url)
    kw = dict(longitude=secoora_observations.lon,
              latitude=secoora_observations.lat,
              station_attr=dict(cf_role="timeseries_id"),
              cube_attr=dict(featureType='timeSeries',
                             Conventions='CF-1.6',
                             standard_name_vocabulary='CF-1.6',
                             cdm_data_type="Station",
                             comment=comment,
                             url=url))

    save_timeseries(secoora_obs_data, outfile=fname,
                    standard_name=sos_name, **kw)

    to_html(secoora_obs_data.head())

# %% [markdown]
# ### Loop discovered models and save the nearest time-series

# %%
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                             MergeError)

from utilities import time_limit, get_model_name, is_model, get_surface

log.info(fmt(' Models '))
cubes = dict()

with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # Suppress iris warnings.
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                cube = quick_load_cubes(url, name_list, callback=None, strict=True)
                if is_model(cube):
                    cube = proc_cube(cube, bbox=bbox, time=(start, stop), units=units)
                else:
                    log.warning("[Not model data]: {}".format(url))
                    continue
                cube = get_surface(cube)
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
        except (TimeoutException, RuntimeError, ValueError,
                ConstraintMismatchError, CoordinateNotFoundError,
                IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from iris.pandas import as_series

from utilities import (make_tree, get_nearest_water,
                       add_station, ensure_timeseries)

for mod_name, cube in cubes.items():
    fname = '{}-{}.nc'.format(run_name, mod_name)
    fname = os.path.join(run_name, fname)
    log.info(fmt(' Saving to file {} '.format(fname)))
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot create KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in all_obs.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            status = "No Data"
            log.info('[{}] {}'.format(status, obs.name))
            continue
        if not series:
            status = "Land   "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water  "

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = add_station(cube, station)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info('Finished processing [{}]: {}'.format(mod_name, url))

# %%
from utilities import nbviewer_link, make_qr

make_qr(nbviewer_link('00-fetch_data.ipynb'))

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

with open('{}/log.txt'.format(run_name)) as f:
    print(f.read())
# Out:
# 02:43:54 INFO: ************Saving data inside directory 2014-07-07*************
# 02:43:54 INFO: *********************** Run information ************************
# 02:43:54 INFO: Run date: 2015-10-05 17:43:54
# 02:43:54 INFO: Download start: 2014-07-01 12:00:00
# 02:43:54 INFO: Download stop: 2014-07-07 12:00:00
# 02:43:54 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 02:43:54 INFO: *********************** Software version ***********************
# 02:43:54 INFO: Iris version: 1.8.1
# 02:43:54 INFO: owslib version: 0.9.2
# 02:43:54 INFO: pyoos version: 0.6.2
# 02:44:02 INFO: ********************* Catalog information **********************
# 02:44:02 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 02:44:02 INFO: CSW version: 2.0.2
# 02:44:02 INFO: Number of datasets available: 23
# 02:44:02 INFO: ***************************** CSW ******************************
# 02:44:02 INFO: USF FVCOM - Nowcast Aggregation
# 02:44:02 INFO: ROMS/TOMS 3.0 - New Floria Shelf Application
WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fit.sispnj.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/fit.sispnj.met.nc.
# 02:45:53 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.imet.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c10.imet.nc.
# 02:46:05 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc.
# 02:46:30 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc.
# 02:47:14 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc.
# 02:47:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc.
# 02:47:53 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc.
# 02:48:16 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc.
# 02:48:21 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc.
# 02:48:27 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc.
# 02:48:33 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc.
# 02:48:39 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc.
# 02:48:45 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc.
# 02:48:52 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.sun2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/carocoops.sun2.buoy.nc.
# 02:48:59 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.frp2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/carocoops.frp2.buoy.nc.
# 02:49:09 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.cap2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/carocoops.cap2.buoy.nc.
# 02:49:27 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm3.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.ilm3.buoy.nc.
# 02:49:46 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm2.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.ilm2.buoy.nc.
# 02:49:49 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc.
# 02:50:09 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc.
# 02:50:16 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.gulfofmexico.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.gulfofmexico.wq.nc.
# 02:50:23 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.shellpoint.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.shellpoint.wq.nc.
# 02:50:30 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.redfishpass.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.redfishpass.wq.nc.
# 02:50:38 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.tarponbay.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.tarponbay.wq.nc.
# 02:50:44 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/sccf.fortmyers.wq.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/sccf.fortmyers.wq.nc.
# 02:51:44 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc
# istart must be different from istop! Got istart 43 and  istop 43
# 02:53:32 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.2ndave.pier.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/lbhmc.2ndave.pier.nc.
# 02:53:43 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.cherrygrove.pier.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/lbhmc.cherrygrove.pier.nc.
# 02:53:53 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.apachepier.pier.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/lbhmc.apachepier.pier.nc.
# 02:54:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wiwf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.wiwf1.met.nc.
# 02:54:09 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lbrf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lbrf1.met.nc.
# 02:54:16 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bobf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bobf1.met.nc.
# 02:54:23 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.trrf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.trrf1.met.nc.
# 02:54:31 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wwef1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.wwef1.met.nc.
# 02:54:38 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lrif1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lrif1.met.nc.
# 02:54:44 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bwsf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bwsf1.met.nc.
# 02:54:50 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.pkyf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.pkyf1.met.nc.
# 02:54:57 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lmdf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lmdf1.met.nc.
# 02:55:05 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.cnbf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.cnbf1.met.nc.
# 02:55:13 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.hcef1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.hcef1.met.nc.
# 02:55:19 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.jkyf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.jkyf1.met.nc.
# 02:55:26 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wrbf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.wrbf1.met.nc.
# 02:55:32 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.gbif1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.gbif1.met.nc.
# 02:55:41 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc.
# 02:55:47 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bdvf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bdvf1.met.nc.
# 02:55:53 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lrkf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lrkf1.met.nc.
# 02:56:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bnkf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.bnkf1.met.nc.
# 02:56:08 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.gbtf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.gbtf1.met.nc.
# 02:56:15 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.tcvf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.tcvf1.met.nc.
# 02:56:21 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.canf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.canf1.met.nc.
# 02:56:28 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lbsf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.lbsf1.met.nc.
# 02:56:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.mukf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.mukf1.met.nc.
# 02:56:41 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.dkkf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.dkkf1.met.nc.
# 02:56:48 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.cwaf1.met.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/enp.cwaf1.met.nc.
# 02:57:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fau.lobo.1.nc
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://129.252.139.124/thredds/dodsC/fau.lobo.1.nc.
# 02:57:23 INFO: ********************* Collector offerings **********************
# 02:57:23 INFO: NOAA.NOS.CO-OPS SOS: 1052 offerings
# 02:57:30 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-07-01T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AWaterLevelActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=water_surface_height_above_reference_datum
# 02:59:06 INFO: ************************* Observations *************************
# 02:59:06 INFO: **** Downloading to file 2014-07-07/2014-07-07-OBS_DATA.nc *****
# 02:59:09 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   warnings.warn(msg, FutureWarning)
#
# 02:59:12 WARNING: [8654467] USCG Station Hatteras, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 02:59:12 WARNING: [8656483] Beaufort, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 02:59:13 WARNING: [8658120] Wilmington, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:00:15 WARNING: [8726520] St Petersburg, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:00:16 WARNING: [8726607] Old Port Tampa, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:00:27 WARNING: [8729210] Panama City Beach, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:00:31 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/iris/fileformats/netcdf.py:1783: UserWarning: NetCDF default saving behaviour currently assigns the outermost dimensions to unlimited. This behaviour is to be deprecated, in favour of no automatic assignment. To switch to the new behaviour, set iris.FUTURE.netcdf_no_unlimited to True.
#   warnings.warn(msg)
#
# 03:00:31 INFO: ********************* SECOORA Observations *********************
# 03:00:31 INFO:  Downloading to file 2014-07-07/2014-07-07-SECOORA_OBS_DATA.nc *
# 03:00:31 INFO: **************************** Models ****************************
# 03:00:31 INFO:
# [Reading url 1/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:00:50 INFO:
# [Reading url 2/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 03:00:57 INFO:
# [Reading url 3/10]: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# 03:01:33 INFO:
# [Reading url 4/10]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 03:02:25 INFO:
# [Reading url 5/10]: http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 03:02:58 INFO:
# [Reading url 6/10]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# 03:03:02 INFO:
# [Reading url 7/10]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 03:03:06 INFO:
# [Reading url 8/10]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his/ESPRESSO_Real-Time_v2_History_Best
# 03:03:23 INFO:
# [Reading url 9/10]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 03:03:56 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 03:03:56 INFO:
# [Reading url 10/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:03:58 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cannot find ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid'] in http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd.
# 03:03:58 INFO: **** Saving to file 2014-07-07/2014-07-07-SABGOM_ARCHIVE.nc ****
# 03:04:03 INFO: [Water  ] Duck, NC
# 03:04:09 INFO: [Water  ] Oregon Inlet Marina, NC
# 03:04:12 INFO: [Water  ] USCG Station Hatteras, NC
# 03:04:14 INFO: [Land   ] Beaufort, NC
# 03:04:20 INFO: [Land   ] Wilmington, NC
# 03:04:23 INFO: [Water  ] Wrightsville Beach, NC
# 03:04:26 INFO: [Water  ] Springmaid Pier, SC
# 03:04:33 INFO: [Water  ] Oyster Landing (N Inlet Estuary), SC
# 03:04:40 INFO: [Land   ] Charleston, SC
# 03:04:47 INFO: [Land   ] Fernandina Beach, FL
# 03:04:54 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 03:05:02 INFO: [Land   ] Dames Point, FL
# 03:05:09 INFO: [Land   ] Southbank Riverwalk, St Johns River, FL
# 03:05:16 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 03:05:23 INFO: [Land   ] Red Bay Point, St Johns River, FL
# 03:05:30 INFO: [Land   ] Racy Point, St Johns River, FL
# 03:05:33 INFO: [Water  ] Trident Pier, FL
# 03:05:36 INFO: [Water  ] Lake Worth Pier, FL
# 03:05:40 INFO: [Water  ] Virginia Key, FL
# 03:05:44 INFO: [Water  ] Vaca Key, FL
# 03:05:47 INFO: [Water  ] Key West, FL
# 03:05:50 INFO: [Land   ] Naples, FL
# 03:05:55 INFO: [Land   ] Fort Myers, FL
# 03:05:59 INFO: [Water  ] Port Manatee, FL
# 03:06:03 INFO: [Water  ] St Petersburg, FL
# 03:06:06 INFO: [Water  ] Old Port Tampa, FL
# 03:06:09 INFO: [Water  ] Cedar Key, FL
# 03:06:12 INFO: [Land   ] Apalachicola, FL
# 03:06:19 INFO: [Land   ] Panama City, FL
# 03:06:23 INFO: [Water  ] Panama City Beach, FL
# 03:06:26 INFO: [Land   ] Pensacola, FL
# 03:06:29 INFO: [Land   ] Tolomato River station
# 03:06:34 INFO: [Water  ] Fred Howard Park
# 03:06:38 INFO: [Land   ] usf_tas_ngwlms
: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:10:17 INFO: ******** Saving to file 2014-07-07/2014-07-07-HYCOM.nc *********
# 03:10:25 INFO: [Land   ] Duck, NC
# 03:10:28 INFO: [Water  ] Oregon Inlet Marina, NC
# 03:10:31 INFO: [Land   ] USCG Station Hatteras, NC
# 03:10:40 INFO: [Land   ] Beaufort, NC
# 03:10:43 INFO: [Land   ] Wilmington, NC
# 03:10:46 INFO: [Water  ] Wrightsville Beach, NC
# 03:10:46 INFO: [No Data] Springmaid Pier, SC
# 03:10:51 INFO: [Land   ] Oyster Landing (N Inlet Estuary), SC
# 03:11:00 INFO: [Land   ] Charleston, SC
# 03:11:03 INFO: [Land   ] Fernandina Beach, FL
# 03:11:07 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 03:11:10 INFO: [Land   ] Dames Point, FL
# 03:11:13 INFO: [Land   ] Southbank Riverwalk, St Johns River, FL
# 03:11:16 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 03:11:19 INFO: [Land   ] Red Bay Point, St Johns River, FL
# 03:11:19 INFO: [No Data] Racy Point, St Johns River, FL
# 03:11:22 INFO: [Land   ] Trident Pier, FL
# 03:11:27 INFO: [Water  ] Lake Worth Pier, FL
# 03:11:32 INFO: [Land   ] Virginia Key, FL
# 03:11:36 INFO: [Land   ] Vaca Key, FL
# 03:11:40 INFO: [Land   ] Key West, FL
# 03:11:40 INFO: [No Data] Naples, FL
# 03:11:44 INFO: [Land   ] Fort Myers, FL
# 03:11:49 INFO: [Land   ] Port Manatee, FL
# 03:11:55 INFO: [Land   ] St Petersburg, FL
# 03:12:01 INFO: [Land   ] Old Port Tampa, FL
# 03:12:06 INFO: [Land   ] Cedar Key, FL
# 03:12:11 INFO: [Land   ] Apalachicola, FL
# 03:12:16 INFO: [Land   ] Panama City, FL
# 03:12:16 INFO: [No Data] Panama City Beach, FL
# 03:12:20 INFO: [Land   ] Pensacola, FL
# 03:12:24 INFO: [Land   ] Tolomato River station
# 03:12:27 INFO: [Land   ] Fred Howard Park
# 03:12:31 INFO: [Land   ] usf_tas_ngwlms
# 03:12:31 INFO: [No Data] Big Carlos Pass
# 03:12:36 INFO: [Land   ] Shell Point
# 03:12:40 INFO: [Land   ] St Lucie Inlet station
# 03:12:43 INFO: [Land   ] Naples Bay station
# 03:12:47 INFO: [Land   ] Vero Beach station
# 03:12:52 INFO: [Water  ] Ponce De Leon South station
# 03:12:56 INFO: [Land   ] Melbourne station
# 03:13:01 INFO: [Land   ] Aripeka
# 03:13:06 INFO: [Land   ] Bing's Landing station
# 03:13:10 INFO: [Land   ] Binney Dock station
# 03:13:14 INFO: [Land   ] Gordon River Inlet station
# 03:13:14 INFO: Finished processing [HYCOM]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:13:14 INFO: ******* Saving to file 2014-07-07/2014-07-07-USF_ROMS.nc *******
# 03:13:14 INFO: [No Data] Duck, NC
# 03:13:14 INFO: [No Data] Oregon Inlet Marina, NC
# 03:13:14 INFO: [No Data] USCG Station Hatteras, NC
# 03:13:14 INFO: [No Data] Beaufort, NC
# 03:13:14 INFO: [No Data] Wilmington, NC
# 03:13:14 INFO: [No Data] Wrightsville Beach, NC
# 03:13:14 INFO: [No Data] Springmaid Pier, SC
# 03:13:14 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 03:13:14 INFO: [No Data] Charleston, SC
# 03:13:14 INFO: [No Data] Fernandina Beach, FL
# 03:13:14 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 03:13:14 INFO: [No Data] Dames Point, FL
# 03:13:14 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:13:14 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 03:13:14 INFO: [No Data] Red Bay Point, St Johns River, FL
# 03:13:14 INFO: [No Data] Racy Point, St Johns River, FL
# 03:13:14 INFO: [No Data] Trident Pier, FL
# 03:13:14 INFO: [No Data] Lake Worth Pier, FL
# 03:13:14 INFO: [No Data] Virginia Key, FL
# 03:13:14 INFO: [No Data] Vaca Key, FL
# 03:13:14 INFO: [No Data] Key West, FL
# 03:13:16 INFO: [Water  ] Naples, FL
# 03:13:18 INFO: [Water  ] Fort Myers, FL
# 03:13:21 INFO: [Water  ] Port Manatee, FL
# 03:13:21 INFO: [No Data] St Petersburg, FL
# 03:13:23 INFO: [Water  ] Old Port Tampa, FL
# 03:13:25 INFO: [Water  ] Cedar Key, FL
# 03:13:27 INFO: [Water  ] Apalachicola, FL
# 03:13:30 INFO: [Water  ] Panama City, FL
# 03:13:32 INFO: [Water  ] Panama City Beach, FL
# 03:13:32 INFO: [No Data] Pensacola, FL
# 03:13:32 INFO: [No Data] Tolomato River station
# 03:13:34 INFO: [Water  ] Fred Howard Park
# 03:13:36 INFO: [Water  ] usf_tas_ngwlms
# 03:13:39 INFO: [Water  ] Big Carlos Pass
# 03:13:41 INFO: [Water  ] Shell Point
# 03:13:41 INFO: [No Data] St Lucie Inlet station
# 03:13:43 INFO: [Water  ] Naples Bay station
# 03:13:43 INFO: [No Data] Vero Beach station
# 03:13:43 INFO: [No Data] Ponce De Leon South station
# 03:13:43 INFO: [No Data] Melbourne station
# 03:13:46 INFO: [Water  ] Aripeka
# 03:13:46 INFO: [No Data] Bing's Landing station
# 03:13:46 INFO: [No Data] Binney Dock station
# 03:13:48 INFO: [Water  ] Gordon River Inlet station
# 03:14:40 INFO: Finished processing [USF_ROMS]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:14:40 INFO: ****** Saving to file 2014-07-07/2014-07-07-USF_FVCOM.nc *******
# 03:14:40 INFO: [No Data] Duck, NC
# 03:14:40 INFO: [No Data] Oregon Inlet Marina, NC
# 03:14:40 INFO: [No Data] USCG Station Hatteras, NC
# 03:14:40 INFO: [No Data] Beaufort, NC
# 03:14:40 INFO: [No Data] Wilmington, NC
# 03:14:40 INFO: [No Data] Wrightsville Beach, NC
# 03:14:40 INFO: [No Data] Springmaid Pier, SC
# 03:14:40 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 03:14:40 INFO: [No Data] Charleston, SC
# 03:14:40 INFO: [No Data] Fernandina Beach, FL
# 03:14:40 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 03:14:40 INFO: [No Data] Dames Point, FL
# 03:14:40 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:14:40 INFO: [No Data] I-295 Bridge, St Johns River, FL
#
# 03:19:40 INFO: [Water  ] Cedar Key, FL
# 03:19:45 INFO: [Water  ] Apalachicola, FL
# 03:19:52 INFO: [Water  ] Panama City, FL
# 03:20:00 INFO: [Water  ] Panama City Beach, FL
# 03:20:05 INFO: [Water  ] Pensacola, FL
# 03:20:10 INFO: [Land   ] Tolomato River station
# 03:20:15 INFO: [Land   ] Fred Howard Park
# 03:20:25 INFO: [Land   ] usf_tas_ngwlms
# 03:20:30 INFO: [Water  ] Big Carlos Pass
# 03:20:40 INFO: [Water  ] Shell Point
# 03:20:45 INFO: [Water  ] St Lucie Inlet station
# 03:20:55 INFO: [Land   ] Naples Bay station
# 03:21:01 INFO: [Water  ] Vero Beach station
# 03:21:06 INFO: [Water  ] Ponce De Leon South station
# 03:21:11 INFO: [Land   ] Melbourne station
# 03:21:21 INFO: [Water  ] Aripeka
# 03:21:26 INFO: [Land   ] Bing's Landing station
# 03:21:32 INFO: [Water  ] Binney Dock station
# 03:21:37 INFO: [Land   ] Gordon River Inlet station
# 03:24:16 INFO: Finished processing [COAWST_4]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:24:16 INFO: ******** Saving to file 2014-07-07/2014-07-07-BTMPB.nc *********
# 03:24:16 INFO: [No Data] Duck, NC
# 03:24:16 INFO: [No Data] Oregon Inlet Marina, NC
# 03:24:16 INFO: [No Data] USCG Station Hatteras, NC
# 03:24:16 INFO: [No Data] Beaufort, NC
# 03:24:16 INFO: [No Data] Wilmington, NC
# 03:24:16 INFO: [No Data] Wrightsville Beach, NC
# 03:24:16 INFO: [No Data] Springmaid Pier, SC
# 03:24:16 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 03:24:16 INFO: [No Data] Charleston, SC
# 03:24:16 INFO: [No Data] Fernandina Beach, FL
# 03:24:16 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 03:24:16 INFO: [No Data] Dames Point, FL
# 03:24:16 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:24:16 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 03:24:16 INFO: [No Data] Red Bay Point, St Johns River, FL
# 03:24:16 INFO: [No Data] Racy Point, St Johns River, FL
# 03:24:16 INFO: [No Data] Trident Pier, FL
# 03:24:16 INFO: [No Data] Lake Worth Pier, FL
# 03:24:16 INFO: [No Data] Virginia Key, FL
# 03:24:16 INFO: [No Data] Vaca Key, FL
# 03:24:16 INFO: [No Data] Key West, FL
# 03:24:16 INFO: [No Data] Naples, FL
# 03:24:16 INFO: [No Data] Fort Myers, FL
# 03:24:16 INFO: [No Data] Port Manatee, FL
# 03:24:16 INFO: [No Data] St Petersburg, FL
# 03:24:16 INFO: [No Data] Old Port Tampa, FL
# 03:24:16 INFO: [No Data] Cedar Key, FL
# 03:24:16 INFO: [No Data] Apalachicola, FL
# 03:24:16 INFO: [No Data] Panama City, FL
# 03:24:16 INFO: [No Data] Panama City Beach, FL
# 03:24:16 INFO: [No Data] Pensacola, FL
# 03:24:16 INFO: [No Data] Tolomato River station
# 03:24:16 INFO: [No Data] Fred Howard Park
# 03:24:16 INFO: [No Data] usf_tas_ngwlms
# 03:24:16 INFO: [No Data] Big Carlos Pass
# 03:24:16 INFO: [No Data] Shell Point
# 03:24:16 INFO: [No Data] St Lucie Inlet station
# 03:24:16 INFO: [No Data] Naples Bay station
# 03:24:16 INFO: [No Data] Vero Beach station
# 03:24:16 INFO: [No Data] Ponce De Leon South station
# 03:24:16 INFO: [No Data] Melbourne station
# 03:24:16 INFO: [No Data] Aripeka
# 03:24:16 INFO: [No Data] Bing's Landing station
# 03:24:16 INFO: [No Data] Binney Dock station
# 03:24:16 INFO: [No Data] Gordon River Inlet station
# 03:24:16 INFO: Finished processing [BTMPB]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:24:16 INFO: **** Saving to file 2014-07-07/2014-07-07-ROMS_ESPRESSO.nc *****
# 03:24:24 INFO: [Land   ] Duck, NC
# 03:24:28 INFO: [Water  ] Oregon Inlet Marina, NC
# 03:24:32 INFO: [Land   ] USCG Station Hatteras, NC
# 03:24:36 INFO: [Water  ] Beaufort, NC
# 03:24:36 INFO: [No Data] Wilmington, NC
# 03:24:36 INFO: [No Data] Wrightsville Beach, NC
# 03:24:36 INFO: [No Data] Springmaid Pier, SC
# 03:24:36 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 03:24:36 INFO: [No Data] Charleston, SC
# 03:24:36 INFO: [No Data] Fernandina Beach, FL
# 03:24:36 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 03:24:36 INFO: [No Data] Dames Point, FL
# 03:24:36 INFO: [No Data] Southbank Riverwalk, St Johns River, FL
# 03:24:36 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 03:24:36 INFO: [No Data] Red Bay Point, St Johns River, FL
# 03:24:36 INFO: [No Data] Racy Point, St Johns River, FL
# 03:24:36 INFO: [No Data] Trident Pier, FL
# 03:24:36 INFO: [No Data] Lake Worth Pier, FL
# 03:24:36 INFO: [No Data] Virginia Key, FL
# 03:24:36 INFO: [No Data] Vaca Key, FL
# 03:24:36 INFO: [No Data] Key West, FL
# 03:24:36 INFO: [No Data] Naples, FL
# 03:24:36 INFO: [No Data] Fort Myers, FL
# 03:24:36 INFO: [No Data] Port Manatee, FL
# 03:24:36 INFO: [No Data] St Petersburg, FL
# 03:24:36 INFO: [No Data] Old Port Tampa, FL
# 03:24:36 INFO: [No Data] Cedar Key, FL
# 03:24:36 INFO: [No Data] Apalachicola, FL
# 03:24:36 INFO: [No Data] Panama City, FL
# 03:24:36 INFO: [No Data] Panama City Beach, FL
# 03:24:36 INFO: [No Data] Pensacola, FL
# 03:24:36 INFO: [No Data] Tolomato River station
# 03:24:36 INFO: [No Data] Fred Howard Park
# 03:24:36 INFO: [No Data] usf_tas_ngwlms
# 03:24:36 INFO: [No Data] Big Carlos Pass
# 03:24:36 INFO: [No Data] Shell Point
# 03:24:36 INFO: [No Data] St Lucie Inlet station
# 03:24:36 INFO: [No Data] Naples Bay station
# 03:24:36 INFO: [No Data] Vero Beach station
# 03:24:36 INFO: [No Data] Ponce De Leon South station
# 03:24:36 INFO: [No Data] Melbourne station
# 03:24:36 INFO: [No Data] Aripeka
# 03:24:36 INFO: [No Data] Bing's Landing station
# 03:24:36 INFO: [No Data] Binney Dock station
# 03:24:36 INFO: [No Data] Gordon River Inlet station
# 03:24:43 INFO: Finished processing [ROMS_ESPRESSO]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:24:44 INFO: 40.85 minutes
# 03:24:44 INFO: EOF
