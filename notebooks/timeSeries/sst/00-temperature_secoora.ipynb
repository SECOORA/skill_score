# %% [markdown]
# ### SECOORA sea surface temperature time-series notebook
#
# Produce weekly maps and tables for the SECOORA.  Based on IOOS system-test [notebook](http://nbviewer.ipython.org/github/Bobfrat/system-test/blob/temp_nb/Theme_1_Baseline/Scenario_1F_Temperature/Temperature.ipynb).

# %%
import time
start_time = time.time()

# %%
import os
import sys

# %load_ext watermark
# %watermark --githash --machine --python --packages iris,pyoos,owslib

utilities_path = os.path.join(os.getcwd(), os.pardir, os.pardir)
root = os.path.abspath(utilities_path)
sys.path.append(root)

style = os.path.join(os.pardir, os.pardir, 'style.css')
# Out:
# CPython 2.7.9
# IPython 2.3.1
#
# iris 1.7.2-DEV
# pyoos 0.6.2
# owslib 0.8-dev
#
# compiler   : GCC 4.4.7 20120313 (Red Hat 4.4.7-1)
# system     : Linux
# release    : 3.16.7-7-desktop
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit
# Git hash   : be79c7758ef26f8081afbdc56c4bac89f72d779f

# %%
import pytz
from datetime import datetime, timedelta

from utilities import CF_names


# Choose the date range (e.g: stop = datetime(2014, 7, 7, 12)).
stop = datetime(2014, 7, 7, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = stop - timedelta(days=7)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names to look for:
name_list = CF_names['sea_water_temperature']

# %%
run_name = '{:%Y-%m-%d}'.format(stop)

if not os.path.exists(run_name):
    os.makedirs(run_name)

# %%
import iris
import pyoos
import owslib

import logging as log
reload(log)

fmt = '{:*^64}'.format
log.captureWarnings(True)
LOG_FILENAME = 'log.txt'
LOG_FILENAME = os.path.join(run_name, LOG_FILENAME)
log.basicConfig(filename=LOG_FILENAME,
                filemode='w',
                format='%(asctime)s %(levelname)s: %(message)s',
                datefmt='%I:%M:%S',
                level=log.INFO,
                stream=None)

log.info(fmt(' Run information '))
log.info('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
log.info('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
log.info('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
log.info('Bounding box: {0:3.2f}, {1:3.2f},'
         '{2:3.2f}, {3:3.2f}'.format(*bbox))
log.info(fmt(' Software version '))
log.info('Iris version: {}'.format(iris.__version__))
log.info('owslib version: {}'.format(owslib.__version__))
log.info('pyoos version: {}'.format(pyoos.__version__))

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exclude ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

# %% [markdown]
# ### Add SECOORA models and observations.

# %%
from utilities import titles

secoora_models = ['SABGOM', 'USEAST', 'USF_ROMS',
                  'USF_SWAN', 'USF_FVCOM']

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the NGDC csw'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# %%
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

from utilities import TimeoutException, secoora_buoys, get_cubes

urls = list(secoora_buoys())

buoys = dict()
for url in urls:
    try:
        cubes = get_cubes(url, name_list=name_list,
                          bbox=bbox, time=(start, stop),
                          units=iris.unit.Unit('celsius'))
        buoy = url.split('/')[-1].split('.nc')[0]
        buoys.update({buoy: cubes[0]})
    except (RuntimeError, ValueError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()
sos_name = 'sea_water_temperature'

collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:MetActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# #### Clean the dataframe (visualization purpose only)

# %%
from utilities import get_coops_longname, to_html

columns = {'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'sea_water_temperature (C)': 'sea_water_temperature'}

observations.rename(columns=columns, inplace=True)

observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td> 8651370</td>
#       <td> E1</td>
#       <td> 36.1833</td>
#       <td>-75.7467</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 25.5</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td> 8652587</td>
#       <td> E1</td>
#       <td> 35.7950</td>
#       <td>-75.5483</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 24.7</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td> 8654467</td>
#       <td> E1</td>
#       <td> 35.2086</td>
#       <td>-75.7042</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 26.2</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td> 8656483</td>
#       <td> E1</td>
#       <td> 34.7200</td>
#       <td>-76.6700</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 26.7</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td> 8658120</td>
#       <td> E1</td>
#       <td> 34.2267</td>
#       <td>-77.9533</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 28.6</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from utilities import secoora2df
secoora_observations = secoora2df(buoys, 'sea_water_temperature')
to_html(secoora_observations.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tolomato River station</th>
#       <td>   fldep.tolomatoriver.</td>
#       <td> NA</td>
#       <td> 29.994722</td>
#       <td>-81.329559</td>
#       <td> 2014-36-30T19:36:00Z</td>
#       <td> 29.244711</td>
#     </tr>
#     <tr>
#       <th>Duck Key, FL</th>
#       <td>          enp.dkkf1.met</td>
#       <td> NA</td>
#       <td> 25.180000</td>
#       <td>-80.489998</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 30.668215</td>
#     </tr>
#     <tr>
#       <th>Broad River Lower, FL</th>
#       <td>          enp.lbrf1.met</td>
#       <td> NA</td>
#       <td> 25.483999</td>
#       <td>-81.111000</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 29.773399</td>
#     </tr>
#     <tr>
#       <th>Cherry Grove Pier, N. Myrtle Beach, SC</th>
#       <td> lbhmc.cherrygrove.pier</td>
#       <td> NA</td>
#       <td> 33.827492</td>
#       <td>-78.632004</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td>  0.306635</td>
#     </tr>
#     <tr>
#       <th>Gulf of Mexico station</th>
#       <td>   sccf.gulfofmexico.wq</td>
#       <td> NA</td>
#       <td> 26.443029</td>
#       <td>-81.971191</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 30.756413</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from pandas import concat


all_obs = concat([observations, secoora_observations], axis=0)
to_html(concat([all_obs.head(2), all_obs.tail(2)]), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>       8651370</td>
#       <td> E1</td>
#       <td> 36.183300</td>
#       <td>-75.746700</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 25.500000</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>       8652587</td>
#       <td> E1</td>
#       <td> 35.795000</td>
#       <td>-75.548300</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 24.700000</td>
#     </tr>
#     <tr>
#       <th>Trout Cove, FL</th>
#       <td> enp.tcvf1.met</td>
#       <td> NA</td>
#       <td> 25.209000</td>
#       <td>-80.532997</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 30.862024</td>
#     </tr>
#     <tr>
#       <th>Johnson Key, FL</th>
#       <td> enp.jkyf1.met</td>
#       <td> NA</td>
#       <td> 25.049999</td>
#       <td>-80.903999</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 30.693077</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Generate a uniform 6-min time base for model/data comparison

# %%
import iris
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
fname = os.path.join(run_name, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))
data = dict()
bad_station = []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'sea_water_temperature (C)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_station.append(station)
        name = get_coops_longname(station)
        log.warning("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad stations.
pattern = '|'.join(bad_station)
if pattern:
    mask = observations.station.str.contains(pattern)
    bad_station = observations[mask]
    observations = observations[~mask]

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(obs_data.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8654467</th>
#       <th>8656483</th>
#       <th>8658120</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8665530</th>
#       <th>8670870</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720219</th>
#       <th>8720245</th>
#       <th>8720357</th>
#       <th>8720503</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8726520</th>
#       <th>8726607</th>
#       <th>8728690</th>
#       <th>8729108</th>
#       <th>8729210</th>
#       <th>8729840</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>
#       <td> 24.7</td>
#       <td> 26.1</td>
#       <td> 26.7</td>
#       <td> 28.6</td>
#       <td> 27.4</td>
#       <td> 28.1</td>
#       <td> 28.6</td>
#       <td> 25.5</td>
#       <td> 29.3</td>
#       <td> 28.6</td>
#       <td> 29.3</td>
#       <td> 29.3</td>
#       <td> 29.9</td>
#       <td> 30</td>
#       <td> 29.5</td>
#       <td> 29.2</td>
#       <td> 27.8</td>
#       <td> 30.6</td>
#       <td> 30.8</td>
#       <td> 31.800</td>
#       <td> 31.9</td>
#       <td> 30.4</td>
#       <td> 31.8</td>
#       <td> 31.1</td>
#       <td> 29.5</td>
#       <td> 29.2</td>
#       <td> 24.1</td>
#       <td> 28.6</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
import numpy as np
from pandas import DataFrame


def extract_series(cube, station):
    time = cube.coord(axis='T')
    date_time = time.units.num2date(cube.coord(axis='T').points)
    data = cube.data
    return DataFrame(data, columns=[station], index=date_time)


secoora_obs_data = []
for station, cube in list(buoys.items()):
    df = extract_series(cube, station)
    secoora_obs_data.append(df)

secoora_obs_data = concat(secoora_obs_data, axis=1)

# These buoys need some QA/QC!
mask = np.logical_or(secoora_obs_data < -5, secoora_obs_data > 40)
secoora_obs_data[mask] = np.NaN

# Interpolate to the same index as SOS temperatures.
index = obs_data.index
kw = dict(method='time', limit=30)
secoora_obs_data = secoora_obs_data.reindex(index).interpolate(**kw).ix[index]

log.info(fmt(' SECOORA Observations '))
fname = '{:%Y-%m-%d}-SECOORA_OBS_DATA.nc'.format(stop)
fname = os.path.join(run_name, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))

url = "http://129.252.139.124/thredds/catalog_platforms.html"
comment = "Several stations {}".format(url)
kw = dict(longitude=secoora_observations.lon,
          latitude=secoora_observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(secoora_obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(secoora_obs_data.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>enp.bnkf1.met</th>
#       <th>enp.bdvf1.met</th>
#       <th>enp.lbrf1.met</th>
#       <th>lbhmc.cherrygrove.pier</th>
#       <th>sccf.gulfofmexico.wq</th>
#       <th>usf.shp.ngwlms</th>
#       <th>enp.trrf1.met</th>
#       <th>sccf.redfishpass.wq</th>
#       <th>enp.lrkf1.met</th>
#       <th>enp.pkyf1.met</th>
#       <th>enp.hcef1.met</th>
#       <th>cormp.ilm2.buoy</th>
#       <th>fau.lobo.1</th>
#       <th>enp.cwaf1.met</th>
#       <th>sccf.tarponbay.wq</th>
#       <th>enp.gbif1.met</th>
#       <th>enp.cnbf1.met</th>
#       <th>enp.mukf1.met</th>
#       <th>enp.bwsf1.met</th>
#       <th>fldep.tolomatoriver.</th>
#       <th>sccf.shellpoint.wq</th>
#       <th>enp.wrbf1.met</th>
#       <th>lbhmc.apachepier.pier</th>
#       <th>enp.gbtf1.met</th>
#       <th>enp.lrif1.met</th>
#       <th>enp.lbsf1.met</th>
#       <th>enp.lmdf1.met</th>
#       <th>fldep.stlucieinlet.</th>
#       <th>enp.wwef1.met</th>
#       <th>enp.dkkf1.met</th>
#       <th>cormp.ilm3.buoy</th>
#       <th>sccf.fortmyers.wq</th>
#       <th>enp.wiwf1.met</th>
#       <th>enp.canf1.met</th>
#       <th>fit.sispnj.met</th>
#       <th>carocoops.sun2.buoy</th>
#       <th>fldep.bingslanding.</th>
#       <th>enp.bobf1.met</th>
#       <th>enp.tcvf1.met</th>
#       <th>enp.jkyf1.met</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                              MergeError)

from utilities import (TimeoutException, time_limit,
                        get_model_name, get_surface)


log.info(fmt(' Models '))
cubes = dict()

with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # Suppress iris warnings.
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                res = get_cubes(url, name_list=name_list,
                                bbox=bbox, time=(start, stop),
                                units=iris.unit.Unit('celsius'))
                if len(res) == 1:
                    cube = res[0]
                else:
                    msg = "Two cubes found.  Expected just one.\n {!r}".format
                    raise ValueError(msg(res))
                # FIXME: Surface data only!
                cube = get_surface(cube)
            # FIXME: We Need a better way to identify model data.
            if cube.ndim > 1:
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
            else:
                log.warning('url {} is probably a timeSeries!'.format(url))
        except (TimeoutException, RuntimeError, ValueError, MergeError,
                ConstraintMismatchError, CoordinateNotFoundError,
                IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from iris.pandas import as_series

from utilities import (standardize_fill_value,
                        make_tree, get_nearest_water,
                        add_station, ensure_timeseries, remove_ssh)


for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(run_name, fname)
    log.info(fmt(' Downloading to file {} '.format(fname)))
    # NOTE: 2D coords KDtree.  (Iris can only do 1D coords KDtree for now.)
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot make KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in all_obs.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            # log.warning(e)
            status = "No Data"
            log.info('[{}] {}'.format(status, obs.name))
            continue
        if not series:
            status = "Land   "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water  "

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = standardize_fill_value(cube)
            cube = add_station(cube, station)
            cube = remove_ssh(cube)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info('Finished processing [{}]: {}\n'.format(mod_name, url))

# %% [markdown]
# #### Load saved files and interpolate to the observations time interval

# %%
from utilities import load_secoora_ncs

dfs = load_secoora_ncs(run_name)

# %% [markdown]
# ### Model skill

# %%
from utilities import pearsonr_paired

# Reload the data to avoid contamination from the changes above!
dfs = load_secoora_ncs(run_name)

skills = dict()
for station, df in dfs.iteritems():
    skill = dict()
    try:
        obs = df.pop('OBS_DATA')
        for model, y in df.iteritems():
            r, p = pearsonr_paired(obs, y)
            if p > 0.01:
                r = np.NaN
            skill.update({model: r})
    except KeyError:  # All NaN data.
        for model, y in df.iteritems():
            skill.update({model: np.NaN})
            print(model)
    skills.update({station: skill})

df = DataFrame.from_dict(skills)


columns = dict()
for station in df.columns:
    sta_name = all_obs['station'][all_obs['station'] == station].index[0]
    columns.update({station: sta_name})

df.rename(columns=columns, inplace=True)

# %%
from utilities import to_html

fname = os.path.join(run_name, 'skill.html'.format(run_name))

df_skill = df.applymap('{:.2f}'.format).replace('nan', '--')

# FIXME: Abstract this out as a function.
with open(style, 'r') as f:
    css = """<style>{}</style>""".format(f.read())
    css_style = '{style}<div class="datagrid">{table}</div>'.format
    html_skill = dict(style=css, table=df_skill.T.to_html())
    html_skill = css_style(**html_skill)

with open(fname, 'w') as f:
    f.writelines(html_skill)


to_html(df_skill, style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>
th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>COAWST_4</th>
#       <td>    --</td>
#       <td> 0.60</td>
#       <td> 0.33</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> 0.75</td>
#       <td> 0.83</td>
#       <td> --</td>
#       <td>    --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> 0.25</td>
#       <td>   --</td>
#       <td> 0.59</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> 0.30</td>
#       <td>    --</td>
#       <td> 0.64</td>
#       <td>    --</td>
#       <td> 0.30</td>
#       <td> 0.83</td>
#       <td> 0.80</td>
#       <td>  0.42</td>
#       <td> --</td>
#       <td> 0.75</td>
#       <td> 0.61</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> 0.56</td>
#       <td> 0.77</td>
#       <td> --</td>
#       <td> -0.07</td>
#       <td> --</td>
#       <td> 0.59</td>
#       <td> --</td>
#       <td>   --</td>
#       <td> 0.67</td>
#       <td> --</td>
#       <td> 0.35</td>
#       <td> 0.33</td>
#       <td> 0.54</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> 0.64</td>
#       <td> 0.51</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> 0.67</td>
#       <td> --</td>
#       <td> --</td>
#       <td>    --</td>
#       <td> --</td>
#       <td> 0.76</td>
#       <td> 0.57</td>
#       <td> --</td>
#       <td> 0.53</td>
#       <td> --</td>
#     </tr>
#     <tr>
#       <th>ESPRESSO</th>
#       <td>    --</td>
#       <td> 0.68</td>
#       <td>   --</td>
#       <td> 0.57</td>
#       <td> --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> --</td>
#       <td>    --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td> --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> --</td>
#       <td>   --</td>

# %% [markdown]
# ### Map

# %%
from mpld3 import save_html
import matplotlib.pyplot as plt
from mpld3.plugins import LineLabelTooltip, connect

from utilities import inline_map, make_map

mapa = make_map(bbox, line=True, states=False)

# %% [markdown]
# ### ROMS stations files (SABGOM and USEAST)

# %%
roms_stations = [(-77.7866, 34.2133),
                 (-78.9183, 33.6550),
                 (-81.0000, 30.3966),
                 (-80.1600, 25.7300),
                 (-81.8116, 24.5550),
                 (-82.6137, 26.1300),
                 (-82.8320, 27.9770),
                 (-86.4987, 30.1520)]

for station in roms_stations:
    location = station[::-1]
    popup = '[SABGOM/USEAST]\nROMS station file'
    kw = dict(radius=700, fill_color='red', popup=popup,
              fill_opacity=0.75)
    mapa.circle_marker(location=location, **kw)

# %% [markdown]
# ### Clusters

# %%
from glob import glob
from operator import itemgetter


big_list = []
for fname in glob(os.path.join(run_name, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    cube = iris.load_cube(fname)
    model = fname.split('-')[-1].split('.')[0]
    lons = cube.coord(axis='X').points
    lats = cube.coord(axis='Y').points
    stations = cube.coord('station name').points
    models = [model]*lons.size
    lista = zip(models, lons.tolist(), lats.tolist(), stations.tolist())
    big_list.extend(lista)

big_list.sort(key=itemgetter(3))
df = DataFrame(big_list, columns=['name', 'lon', 'lat', 'station'])
df.set_index('station', drop=True, inplace=True)
groups = df.groupby(df.index)


for station, info in groups:
    sta_name = all_obs['station'][all_obs['station'] == station].index[0]
    for lat, lon, name in zip(info.lat, info.lon, info.name):
        location = lat, lon
        popup = '<b>{}</b>\n{}'.format(sta_name, name)
        mapa.simple_marker(location=location, popup=popup,
                           clustered_marker=True)

# %% [markdown]
# ### Model and observations plots

# %%
resolution, width, height = 75, 7, 3


def make_plot():
    fig, ax = plt.subplots(figsize=(width, height))
    ax.set_ylabel('Sea surface Temperature (celsius)')
    ax.grid(True)
    return fig, ax

for station in dfs:
    sta_name = all_obs['station'][all_obs['station'] == station].index[0]
    df = dfs[station].dropna(axis=1, how='all')
    if df.empty:
        continue
    fig, ax = make_plot()
    for col in df.columns:
        serie = df[col].dropna()
        lines = ax.plot(serie.index, serie, label=col,
                        linewidth=2.5, alpha=0.5)
    kw = dict(loc='upper center', bbox_to_anchor=(0.5, 1.05), numpoints=1,
              ncol=2, framealpha=0)
    l = ax.legend(**kw)
    l.set_title("")  # Workaround str(None).

    [connect(fig, LineLabelTooltip(line, name))
     for line, name in zip(ax.lines, df.columns)]

    html = 'station_{}.html'.format(station)
    save_html(fig, '{}/{}'.format(run_name, html))
    plt.close(fig)

    popup = "<div align='center'> {} <br><iframe src='{}' alt='image'"
    popup += "width='{}px' height='{}px' frameBorder='0'></div>"
    popup = popup.format('{}'.format(sta_name), html,
                         (width*resolution)+75, (height*resolution)+50)
    kw = dict(popup=popup, width=(width*resolution)+75)

    if (df.columns == 'OBS_DATA').all():
        kw.update(dict(marker_color="blue", marker_icon="ok"))
    else:
        conj = set(df.columns)
        conj.intersection_update(secoora_models)
        if conj:
            kw.update(dict(marker_color="green", marker_icon="ok-sign"))
        else:
            kw.update(dict(marker_color="green", marker_icon="ok"))
    obs = all_obs[all_obs['station'] == station].squeeze()
    mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %% [markdown]
# ### Bad stations

# %%
if isinstance(bad_station, DataFrame):
    for station, obs in bad_station.iterrows():
        popup = '<b>Station:</b> {}'
        popup = popup.format(station)
        kw = dict(popup=popup, marker_color="red", marker_icon="question-sign")
        mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %%
mapa.create_map(path=os.path.join(run_name, 'mapa.html'))
inline_map(os.path.join(run_name, 'mapa.html'))
# Out:
#         <iframe
#             width="750"
#             height=500"
#             src="2014-07-07/mapa.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %matplotlib inline

import qrcode

qr = qrcode.QRCode(version=1,
                   error_correction=qrcode.constants.ERROR_CORRECT_L,
                   box_size=10,
                   border=4)

nbviewer = "http://nbviewer.ipython.org/github"
github = "ioos/secoora/blob/master"
local = os.path.abspath('00-temperature_secoora.ipynb').split('SECOORA')[1]
qr.add_data('{}/{}{}'.format(nbviewer, github, local))
qr.make(fit=True)

img = qr.make_image()
fig, ax = plt.subplots()
ax.imshow(img)
ax.axis('off')
title = ax.set_title("Notebook nbviewer link")

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

# %%
with open('{}/log.txt'.format(run_name)) as f:
    print(f.read())
# Out:
# 01:00:05 INFO: *********************** Run information ************************
# 01:00:05 INFO: Run date: 2015-02-06 16:00:05
# 01:00:05 INFO: Download start: 2014-06-30 12:00:00
# 01:00:05 INFO: Download stop: 2014-07-07 12:00:00
# 01:00:05 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 01:00:05 INFO: *********************** Software version ***********************
# 01:00:05 INFO: Iris version: 1.7.2-DEV
# 01:00:05 INFO: owslib version: 0.8-dev
# 01:00:05 INFO: pyoos version: 0.6.2
# 01:00:09 INFO: ********************* Catalog information **********************
# 01:00:09 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 01:00:09 INFO: CSW version: 2.0.2
# 01:00:09 INFO: Number of datasets available: 43
# 01:00:09 INFO: ***************************** CSW ******************************
# 01:00:09 INFO: USF FVCOM - Nowcast Aggregation
# 01:00:09 INFO: ROMS/TOMS 3.0 - New Floria Shelf Application
# 01:00:09 INFO: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# 01:00:09 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY CANYON OUTER, CA from 2013/07/11 17:00:00 to 2014/07/01 20:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY BAY WEST, CA from 2013/06/19 18:00:00 to 2014/07/01 14:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY BAY WEST, CA from 2014/07/01 19:00:00 to 2014/10/04 23:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SAN FRANCISCO BAR, CA from 2013/06/19 22:00:00 to 2014/07/24 14:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near POINT REYES, CA from 2013/10/16 21:00:00 to 2014/09/05 11:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near HUMBOLDT BAY NORTH SPIT, CA from 2013/08/26 19:00:00 to 2014/07/24 03:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near DIABLO CANYON, CA from 2013/08/28 23:00:00 to 2014/10/29 16:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near CLATSOP SPIT, OR from 2013/07/18 20:00:00 to 2015/01/12 18:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near ASTORIA CANYON, OR from 2014/01/16 20:00:00 to 2014/09/29 22:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near GRAYS HARBOR, WA from 2013/10/13 19:00:00 to 2015/01/28 15:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near SAN FRANCISCO BAR, CA from 2007/07/25 to 2014/07/24.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SANTA CRUZ BASIN, CA from 2013/07/09 15:00:00 to 2014/07/14 16:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near OCEAN STATION PAPA from 2012/10/04 21:00:00 to 2015/01/01 00:59:59.
# 01:00:09 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located
lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1359: UserWarning: Failed to create 'time' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'time' auxiliary coordinate instead.
#   error=e_msg))
#
# 01:00:24 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:00:34 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.tas.ngwlms.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:00:46 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.apk.ngwlms.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:00:55 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:01:19 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.bcp.ngwlms.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:01:33 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.fhp.ngwlms.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:01:38 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc
# istart must be different from istop! Got istart 48233 and  istop 48233
# 01:01:41 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc
# istart must be different from istop! Got istart 18711 and  istop 18711
# 01:01:44 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc
# istart must be different from istop! Got istart 18099 and  istop 18099
# 01:01:47 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 01:01:49 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 01:01:52 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 01:02:04 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.frp2.buoy.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:02:11 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.cap2.buoy.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:02:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc
# istart must be different from istop! Got istart 1443 and  istop 1443
# 01:02:41 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc
# istart must be different from istop! Got istart 91490 and  istop 91490
# 01:02:45 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'dissolved_oxygen_saturation' invalid units 'mg_L-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:02:47 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'dissolved_oxygen' invalid units 'mg_L-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:02:47 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'cdom' invalid units 'QSDE'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:02:47 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'turbidity' invalid units 'ntu'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:02:47 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'conductivity' invalid units 'mS_cm-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:02:53 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nitrate' invalid units 'uM'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:03:19 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'conductivity_2' invalid units 'mS_cm-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:03:29 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.poncedeleonsouth..nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:03:41 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:04:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.naplesbay..nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:04:09 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.gordonriverinlet..nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:04:19 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.melbourne..nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:04:25 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.binneydock..nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:04:37 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.verobeach..nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:04:46 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.2ndave.pier.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:04:52 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'turbidity_2' invalid units 'ntu'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:04:53 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'dissolved_oxygen_2' invalid units 'mg_L-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:06:17 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:07:04 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'phosphate' invalid units 'uM'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:07:04 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'photosynthetically_available_radiation' invalid units 'micromoles_per_m^2'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 01:07:16 INFO: ********************* Collector offerings **********************
# 01:07:16 INFO: NOAA.NOS.CO-OPS SOS: 1030 offerings
# 01:07:17 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-06-30T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AMetActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=sea_water_temperature
# 01:09:26 INFO: ************************* Observations *************************
# 01:09:26 INFO: **** Downloading to file 2014-07-07/2014-07-07-OBS_DATA.nc *****
# 01:10:19 INFO: ********************* SECOORA Observations *********************
# 01:10:19 INFO:  Downloading to file 2014-07-07/2014-07-07-SECOORA_OBS_DATA.nc *
# 01:10:19 INFO: **************************** Models ****************************
# 01:10:19 INFO:
# [Reading url 1/43]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 01:15:14 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# Timed out!
# 01:15:14 INFO:
# [Reading url 2/43]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 01:15:19 INFO:
# [Reading url 3/43]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 01:16:43 INFO:
# [Reading url 4/43]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 01:17:11 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 01:17:11 INFO:
# [Reading url 5/43]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw
# 01:17:13 INFO:
# [Reading url 6/43]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 01:17:15 INFO:
# [Reading url 7/43]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# 01:17:23 INFO:
# [Reading url 8/43]: http://thredds.axiomalaska.com/thredds/dodsC/G1_SST_GLOBAL.nc
# 01:17:34 INFO:
# [Reading url 9/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc
# 01:17:36 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:17:36 INFO:
# [Reading url 10/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc
# 01:17:48 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:17:48 INFO:
# [Reading url 11/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/036p1/036p1_d40.nc
# 01:17:50 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/036p1/036p1_d40.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:17:50 INFO:
# [Reading url 12/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc
# 01:17:52 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:17:52 INFO:
# [Reading url 13/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d17.nc
# 01:17:54 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d17.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:17:54 INFO:
# [Reading url 14/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_historic.nc
# 01:18:06 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_historic.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:18:06 INFO:
# [Reading url 15/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc
# 01:18:08 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:18:08 INFO:
# [Reading url 16/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc
# 01:18:25 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:18:25 INFO:
# [Reading url 17/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d27.nc
# 01:18:27 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d27.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:18:27 INFO:
# [Reading url 18/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc
# 01:18:29 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:18:29 INFO:
# [Reading url 19/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc
# 01:18:41 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:18:41 INFO:
# [Reading url 20/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc
# 01:18:43 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:18:43 INFO:
# [Reading url 21/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc
# 01:19:26 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:19:26 INFO:
# [Reading url 22/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/132p1/132p1_d11.nc
# 01:19:28 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/132p1/132p1_d11.nc is probably a timeSeries!
# 01:19:28 INFO:
# [Reading url 23/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/132p1/132p1_historic.nc
# 01:19:36 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/132p1/132p1_historic.nc is probably a timeSeries!
# 01:19:36 INFO:
# [Reading url 24/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc
# 01:19:42 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:19:42 INFO:
# [Reading url 25/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc
# 01:19:48 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:19:48 INFO:
# [Reading url 26/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_d07.nc
# 01:19:50 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_d07.nc is probably a timeSeries!
# 01:19:50 INFO:
# [Reading url 27/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_historic.nc
# 01:19:56 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_historic.nc is probably a timeSeries!
# 01:19:56 INFO:
# [Reading url 28/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc
# 01:19:58 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:19:58 INFO:
# [Reading url 29/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d04.nc
# 01:20:04 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d04.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:04 INFO:
# [Reading url 30/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d02.nc
# 01:20:09 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d02.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:09 INFO:
# [Reading url 31/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc
# 01:20:11 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:11 INFO:
# [Reading url 32/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc
# 01:20:13 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:13 INFO:
# [Reading url 33/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc
# 01:20:16 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:16 INFO:
# [Reading url 34/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc
# 01:20:18 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:18 INFO:
# [Reading url 35/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc
# 01:20:20 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc is probably a timeSeries!
# 01:20:20 INFO:
# [Reading url 36/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc
# 01:20:27 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc is probably a timeSeries!
# 01:20:27 INFO:
# [Reading url 37/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc
# 01:20:29 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:29 INFO:
# [Reading url 38/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_d02.nc
# 01:20:36 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_d02.nc is probably a timeSeries!
# 01:20:36 INFO:
# [Reading url 39/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_historic.nc
# 01:20:40 WARNING: url http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_historic.nc is probably a timeSeries!
# 01:20:40 INFO:
# [Reading url 40/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d02.nc
# 01:20:47 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d02.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:47 INFO:
# [Reading url 41/43]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc
# 01:20:49 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc
# No cube using [-87.4, 24.25, -74.7, 36.7]
# 01:20:49 INFO:
# [Reading url 42/43]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 01:21:11 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 01:21:11 INFO:
# [Reading url 43/43]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 01:21:12 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 01:21:12 INFO: ****** Downloading to file 2014-07-07/2014-07-07-HYCOM.nc ******
# 01:21:14 INFO: [Land   ] Duck, NC
