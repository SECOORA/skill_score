# %% [markdown]
# <img style='float: left' width="150px" src="http://secoora.org/sites/default/files/secoora_logo.png">
# <br><br>
# ## [SECOORA Notebook 1](http://secoora.org/)
# ### Fetch Sea Surface Temperature time-series data
#
# This notebook fetches weekly time-series of all the SECOORA observations and
# models available in the **NGDC** and **SECOORA THREDDS** catalogs.

# %%
import time

start_time = time.time()

# %% [markdown]
# ### Save configuration

# %%
import os
try:
    import cPickle as pickle
except ImportError:
    import pickle

import iris
from datetime import datetime
from utilities import CF_names, fetch_range, start_log

# 1-week start of data.
kw = dict(start=datetime(2014, 7, 1, 12), days=6)
start, stop = fetch_range(**kw)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names.
sos_name = 'sea_water_temperature'
name_list = CF_names[sos_name]

# Units.
units = iris.unit.Unit('celsius')

# Logging.
run_name = '{:%Y-%m-%d}'.format(stop)
log = start_log(start, stop, bbox)

# SECOORA models.
secoora_models = ['SABGOM', 'USEAST',
                  'USF_ROMS', 'USF_SWAN', 'USF_FVCOM']

# Config.
fname = os.path.join(run_name, 'config.pkl')
config = dict(start=start,
              stop=stop,
              bbox=bbox,
              name_list=name_list,
              units=units,
              run_name=run_name,
              secoora_models=secoora_models)

with open(fname,'wb') as f:
    pickle.dump(config, f)

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exclude ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

fmt = '{:*^64}'.format
log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

# Work around https://github.com/ioos/secoora/issues/184:
dap_urls = [url for url in dap_urls if 'G1_SST_GLOBAL' not in url]

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %%
from utilities import is_station

# Filter out some station endpoints.
non_stations = []
for url in dap_urls:
    try:
        if not is_station(url):
            non_stations.append(url)
    except RuntimeError as e:
        log.warn("Could not access URL {}. {!r}".format(url, e))

dap_urls = non_stations

log.info(fmt(' Filtered DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %% [markdown]
# ### Add SECOORA models and observations

# %%
from utilities import titles, fix_url

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the NGDC csw'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# NOTE: USEAST is not archived at the moment!
# https://github.com/ioos/secoora/issues/173
dap_urls = [fix_url(start, url) if
            'SABGOM' in url else url for url in dap_urls]

# %%
import warnings
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

from utilities import (TimeoutException, secoora_buoys,
                       quick_load_cubes, proc_cube)

urls = list(secoora_buoys())
if not urls:
    raise ValueError("Did not find any SECOORA buoys!")

buoys = dict()
for url in urls:
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")  # Suppress iris warnings.
            kw = dict(bbox=bbox, time=(start, stop), units=units)
            cubes = quick_load_cubes(url, name_list)
            cubes = [proc_cube(cube, **kw) for cube in cubes]
        buoy = url.split('/')[-1].split('.nc')[0]
        if len(cubes) == 1:
            buoys.update({buoy: cubes[0]})
        else:
            #[buoys.update({'{}_{}'.format(buoy, k): cube}) for
            # k, cube in list(enumerate(cubes))]
            # FIXME: For now I am choosing the first sensor.
            buoys.update({buoy: cubes[0]})
    except (RuntimeError, ValueError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()

collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:MetActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# ### Clean the DataFrame

# %%
from utilities import get_coops_metadata, to_html

columns = {'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'sea_water_temperature (C)': sos_name}

observations.rename(columns=columns, inplace=True)

observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_metadata(s)[0] for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#       <th>quality_flags</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>8651370</td>
#       <td>E1</td>
#       <td>36.1833</td>
#       <td>-75.7467</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>25.1</td>
#       <td>0;0;0</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>8652587</td>
#       <td>E1</td>
#       <td>35.7950</td>
#       <td>-75.5483</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>27.3</td>
#       <td>0;0;0</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td>8654467</td>
#       <td>E1</td>
#       <td>35.2086</td>
#       <td>-75.7042</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>27.1</td>
#       <td>0;0;0</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td>8656483</td>
#       <td>E1</td>
#       <td>34.7200</td>
#       <td>-76.6700</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>27.5</td>
#       <td>0;0;0</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td>8658120</td>
#       <td>E1</td>
#       <td>34.2267</td>
#       <td>-77.9533</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>28.9</td>
#       <td>0;0;0</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from pandas import DataFrame
from utilities import secoora2df

if buoys:
    secoora_observations = secoora2df(buoys, sos_name)
    to_html(secoora_observations.head())
else:
    secoora_observations = DataFrame()

# %%
from pandas import concat

all_obs = concat([observations, secoora_observations], axis=0)
to_html(concat([all_obs.head(2), all_obs.tail(2)]))
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date_time</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>quality_flags</th>
#       <th>sea_water_temperature</th>
#       <th>sensor</th>
#       <th>station</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>36.183300</td>
#       <td>-75.746700</td>
#       <td>0;0;0</td>
#       <td>25.100000</td>
#       <td>E1</td>
#       <td>8651370</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>35.795000</td>
#       <td>-75.548300</td>
#       <td>0;0;0</td>
#       <td>27.300000</td>
#       <td>E1</td>
#       <td>8652587</td>
#     </tr>
#     <tr>
#       <th>Johnson Key, FL</th>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>25.049999</td>
#       <td>-80.903999</td>
#       <td>NaN</td>
#       <td>30.866940</td>
#       <td>NA</td>
#       <td>enp.jkyf1.met</td>
#     </tr>
#     <tr>
#       <th>Bob Allen, FL</th>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>25.024000</td>
#       <td>-80.681999</td>
#       <td>NaN</td>
#       <td>31.111263</td>
#       <td>NA</td>
#       <td>enp.bobf1.met</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Uniform 6-min time base for model/data comparison

# %%
from owslib.ows import ExceptionReport
from utilities import pyoos2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
outfile = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
outfile = os.path.join(run_name, outfile)

log.info(fmt(' Downloading to file {} '.format(outfile)))
data, bad_station = dict(), []
col = 'sea_water_temperature (C)'
for station in observations.index:
    station_code = observations['station'][station]
    try:
        df = pyoos2df(collector, station_code, df_name=station)
        data.update({station_code: df[col]})
    except ExceptionReport as e:
        bad_station.append(station_code)
        log.warning("[{}] {}:\n{}".format(station_code, station, e))
obs_data = DataFrame.from_dict(data)

# %% [markdown]
# ### Split good and bad stations

# %%
pattern = '|'.join(bad_station)
if pattern:
    all_obs['bad_station'] = all_obs.station.str.contains(pattern)
    observations = observations[~observations.station.str.contains(pattern)]
else:
    all_obs['bad_station'] = ~all_obs.station.str.contains(pattern)

# Save updated `all_obs.csv`.
fname = '{}-all_obs.csv'.format(run_name)
fname = os.path.join(run_name, fname)
all_obs.to_csv(fname)

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(obs_data, outfile=outfile,
                standard_name=sos_name, **kw)

to_html(obs_data.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8654467</th>
#       <th>8656483</th>
#       <th>8658120</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8665530</th>
#       <th>8670870</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720219</th>
#       <th>8720245</th>
#       <th>8720357</th>
#       <th>8720503</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723214</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8726520</th>
#       <th>8726607</th>
#       <th>8728690</th>
#       <th>8729108</th>
#       <th>8729210</th>
#       <th>8729840</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-07-01 12:00:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>28.0</td>
#       <td>28.6</td>
#       <td>28.6</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.1</td>
#       <td>31.1</td>
#       <td>30.8</td>
#       <td>31.9</td>
#       <td>31</td>
#       <td>29.9</td>
#       <td>28.6</td>
#       <td>22.8</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:06:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>28.0</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.1</td>
#       <td>31.1</td>
#       <td>30.8</td>
#       <td>31.9</td>
#       <td>31</td>
#       <td>29.9</td>
#       <td>28.6</td>
#       <td>22.8</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:12:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>27.9</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.4</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.1</td>
#       <td>31.1</td>
#       <td>30.9</td>
#       <td>31.9</td>
#       <td>31</td>
#       <td>29.9</td>
#       <td>29.1</td>
#       <td>22.8</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:18:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>27.9</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.1</td>
#       <td>31.1</td>
#       <td>30.8</td>
#       <td>32.0</td>
#       <td>31</td>
#       <td>29.8</td>
#       <td>29.0</td>
#       <td>22.9</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:24:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>27.9</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.1</td>
#       <td>31.2</td>
#       <td>30.8</td>
#       <td>32.0</td>
#       <td>31</td>
#       <td>29.8</td>
#       <td>29.0</td>
#       <td>22.9</td>
#       <td>29.5</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### SECOORA Observations

# %%
import numpy as np
from pandas import DataFrame


def extract_series(cube, station):
    time = cube.coord(axis='T')
    date_time = time.units.num2date(cube.coord(axis='T').points)
    data = cube.data
    return DataFrame(data, columns=[station], index=date_time)


if buoys:
    secoora_obs_data = []
    for station, cube in list(buoys.items()):
        df = extract_series(cube, station)
        secoora_obs_data.append(df)
    # Some series have duplicated times!
    kw = dict(subset='index', take_last=True)
    secoora_obs_data = [obs.reset_index().drop_duplicates(**kw).set_index('index') for
                        obs in secoora_obs_data]
    secoora_obs_data = concat(secoora_obs_data, axis=1)
else:
    secoora_obs_data = DataFrame()

# %% [markdown]
# ### These buoys need some QA/QC before saving

# %%
from utilities.qaqc import filter_spikes, threshold_series

if buoys:
    secoora_obs_data.apply(threshold_series, args=(-5, 40))
    secoora_obs_data.apply(filter_spikes)

    # Interpolate to the same index as SOS.
    index = obs_data.index
    kw = dict(method='time', limit=30)
    secoora_obs_data = secoora_obs_data.reindex(index).interpolate(**kw).ix[index]

    log.info(fmt(' SECOORA Observations '))
    fname = '{:%Y-%m-%d}-SECOORA_OBS_DATA.nc'.format(stop)
    fname = os.path.join(run_name, fname)

    log.info(fmt(' Downloading to file {} '.format(fname)))

    url = "http://129.252.139.124/thredds/catalog_platforms.html"
    comment = "Several stations {}".format(url)
    kw = dict(longitude=secoora_observations.lon,
              latitude=secoora_observations.lat,
              station_attr=dict(cf_role="timeseries_id"),
              cube_attr=dict(featureType='timeSeries',
                             Conventions='CF-1.6',
                             standard_name_vocabulary='CF-1.6',
                             cdm_data_type="Station",
                             comment=comment,
                             url=url))

    save_timeseries(secoora_obs_data, outfile=fname,
                    standard_name=sos_name, **kw)

    to_html(secoora_obs_data.head())

# %% [markdown]
# ### Loop discovered models and save the nearest time-series

# %%
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                              MergeError)

from utilities import time_limit, is_model, get_model_name, get_surface


log.info(fmt(' Models '))
cubes = dict()

with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # Suppress iris warnings.
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                cube = quick_load_cubes(url, name_list, callback=None, strict=True)
                if is_model(cube):
                    cube = proc_cube(cube, bbox=bbox, time=(start, stop), units=units)
                else:
                    log.warning("[Not model data]: {}".format(url))
                    continue
                cube = get_surface(cube)
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
        except (TimeoutException, RuntimeError, ValueError,
                ConstraintMismatchError, CoordinateNotFoundError,
                IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))
# Out:
# Exception AttributeError: "'CFReader' object has no attribute '_dataset'" in <bound method CFReader.__del__ of CFReader('http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd')> ignored

# %%
from iris.pandas import as_series

from utilities import (make_tree, get_nearest_water,
                        add_station, ensure_timeseries, remove_ssh)


for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(run_name, fname)
    log.info(fmt(' Downloading to file {} '.format(fname)))
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot make KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in all_obs.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            status = "No Data"
            log.info('[{}] {}'.format(status, obs.name))
            continue
        except RuntimeError as e:
            status = "Failed"
            log.info('[{}] {}. ({})'.format(status, obs.name, e.message))
            continue

        if not series:
            status = "Land   "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water  "

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = add_station(cube, station)
            cube = remove_ssh(cube)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info(fmt('Finished processing {}\n'.format(mod_name)))

# %%
from utilities import nbviewer_link, make_qr

make_qr(nbviewer_link('00-fetch_data.ipynb'))

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

with open('{}/log.txt'.format(run_name)) as f:
    print(f.read())
# Out:
# 06:23:08 INFO: ************Saving data inside directory 2014-07-07*************
# 06:23:08 INFO: *********************** Run information ************************
# 06:23:08 INFO: Run date: 2015-11-25 21:23:08
# 06:23:08 INFO: Download start: 2014-07-01 12:00:00
# 06:23:08 INFO: Download stop: 2014-07-07 12:00:00
# 06:23:08 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 06:23:08 INFO: *********************** Software version ***********************
# 06:23:08 INFO: Iris version: 1.8.1
# 06:23:08 INFO: owslib version: 0.10.0
# 06:23:08 INFO: pyoos version: 0.6.2
# 06:23:19 INFO: ********************* Catalog information **********************
# 06:23:19 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 06:23:19 INFO: CSW version: 2.0.2
# 06:23:19 INFO: Number of datasets available: 102
# 06:23:20 INFO: ***************************** CSW ******************************
# 06:23:20 INFO: USF FVCOM - Nowcast Aggregation
# 06:23:20 INFO: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# 06:23:20 INFO: AVHRR Sea Surface Temperature for MARACOOS (Mid-Atlantic Regional Association Coastal Ocean Observing System)
# 06:23:20 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY CANYON OUTER, CA from 2013/07/11 17:00:00 to 2014/07/01 20:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY BAY WEST, CA from 2013/06/19 18:00:00 to 2014/07/01 14:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY BAY WEST, CA from 2014/07/01 19:00:00 to 2014/10/04 23:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near CABRILLO POINT NEARSHORE, CA from 2014/05/08 21:00:00 to 2015/09/15 16:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SAN FRANCISCO BAR, CA from 2013/06/19 22:00:00 to 2014/07/24 14:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SAN FRANCISCO BAR, CA from 2014/07/24 19:00:00 to 2015/09/15 22:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near POINT REYES, CA from 2013/10/16 21:00:00 to 2014/09/05 11:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near HUMBOLDT BAY NORTH SPIT, CA from 2013/08/26 19:00:00 to 2014/07/24 03:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near UMPQUA OFFSHORE, OR from 2014/03/14 18:00:00 to 2015/05/21 16:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near DIABLO CANYON, CA from 2013/08/28 23:00:00 to 2014/10/29 16:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near CLATSOP SPIT, OR from 2013/07/18 20:00:00 to 2015/01/12 18:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located

# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near MASONBORO INLET, ILM2, NC from 2008/05/07 to 2015/09/04.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near ST. PETERSBURG OFFSHORE, FL from 2007/07/10 to 2015/09/23.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near OREGON INLET, NC from 2012/04/08 to 2015/02/01.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near FORT PIERCE, FL from 2006/09/29 to 2015/03/19.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near NEW RIVER INLET, NC from 2012/04/14 to 2014/07/11.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near NEW RIVER INLET, NC from 2014/03/09 19:00:00 to 2014/07/11 23:59:59.
# 06:23:20 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near WILMINGTON HARBOR, NC from 2013/02/06 to 2015/10/18.
# 06:23:20 INFO: carocoops.cap2.buoy
# 06:23:20 INFO: carocoops.cap2.buoy
# 06:23:20 INFO: carocoops.frp2.buoy
# 06:23:20 INFO: carocoops.frp2.buoy
# 06:23:20 INFO: carocoops.sun2.buoy
# 06:23:20 INFO: enp.bdvf1.met
# 06:23:20 INFO: enp.bnkf1.met
# 06:23:20 INFO: enp.bobf1.met
# 06:23:20 INFO: enp.bwsf1.met
# 06:23:20 INFO: enp.canf1.met
# 06:23:20 INFO: enp.cnbf1.met
# 06:23:20 INFO: enp.cwaf1.met
# 06:23:20 INFO: enp.dkkf1.met
# 06:23:20 INFO: enp.gbif1.met
# 06:23:20 INFO: enp.gbtf1.met
# 06:23:20 INFO: enp.hcef1.met
# 06:23:20 INFO: enp.jkyf1.met
# 06:23:20 INFO: enp.lbrf1.met
# 06:23:20 INFO: enp.lbsf1.met
# 06:23:20 INFO: enp.lmdf1.met
# 06:23:20 INFO: enp.lrif1.met
# 06:23:20 INFO: enp.lrkf1.met
# 06:23:20 INFO: enp.mukf1.met
# 06:23:20 INFO: enp.pkyf1.met
# 06:23:20 INFO: enp.tcvf1.met
# 06:23:20 INFO: enp.trrf1.met
# 06:23:20 INFO: enp.wiwf1.met
# 06:23:20 INFO: enp.wrbf1.met
# 06:23:20 INFO: enp.wwef1.met
# 06:23:20 INFO: fau.lobo.1
# 06:23:20 INFO: fldep.bingslanding.
# 06:23:20 INFO: fldep.stlucieinlet.
# 06:23:20 INFO: fldep.tolomatoriver.
# 06:23:20 INFO: lbhmc.2ndave.pier
# 06:23:20 INFO: lbhmc.apachepier.pier
# 06:23:20 INFO: lbhmc.cherrygrove.pier
# 06:23:20 INFO: sccf.fortmyers.wq
# 06:23:20 INFO: sccf.gulfofmexico.wq
# 06:23:20 INFO: sccf.redfishpass.wq
# 06:23:20 INFO: sccf.shellpoint.wq
# 06:23:20 INFO: sccf.tarponbay.wq
# 06:23:20 INFO: usf.c21.weatherpak
# 06:23:20 INFO: usf.shp.ngwlms
# 06:23:20 INFO: ***************************** SOS ******************************
# 06:23:20 INFO: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetCapabilities&acceptVersions=1.0.0
# 06:23:20 INFO: http://sdf.ndbc.noaa.gov/sos/server.php?service=SOS&request=GetCapabilities&acceptVersions=1.0.0
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/carocoops.cap2.buoy.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/carocoops.cap2.buoy_archive.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/carocoops.frp2.buoy.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/carocoops.frp2.buoy_archive.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/carocoops.sun2.buoy_archive.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/enp.bdvf1.met.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/enp.bnkf1.met.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/enp.bobf1.met.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/enp.bwsf1.met.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:23:20 INFO: http://tds.secoora.org/thredds/sos/enp
nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d04.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d02.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/186p1/186p1_d03.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_d02.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_historic.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/200p1/200p1_historic.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d02.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc.html
# 06:23:20 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/430p1/430p1_historic.nc.html
# 06:28:31 INFO: ************************* Filtered DAP *************************
# 06:28:31 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# 06:28:31 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 06:28:31 INFO: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# 06:28:31 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw.html
# 06:28:31 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 06:28:31 INFO: http://tds.maracoos.org/thredds/dodsC/SST-Three-Agg.nc.html
# 06:28:31 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his/ESPRESSO_Real-Time_v2_History_Best.html
# 06:28:31 WARNING: USEAST not in the NGDC csw
# 06:28:31 WARNING: USF_ROMS not in the NGDC csw
# 06:28:31 WARNING: USF_SWAN not in the NGDC csw
# 06:29:08 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc.
# 06:29:17 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.tas.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.tas.ngwlms.nc.
# 06:29:25 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.apk.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.apk.ngwlms.nc.
# 06:29:30 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc.
# 06:29:50 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.bcp.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.bcp.ngwlms.nc.
# 06:30:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.fhp.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.fhp.ngwlms.nc.
# 06:30:09 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc
# istart must be different from istop! Got istart 48233 and  istop 48233
# 06:30:37 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc.
# 06:31:02 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc.
# 06:31:16 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc.
# 06:31:22 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc
# istart must be different from istop! Got istart 18711 and  istop 18711
# 06:31:30 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc
# istart must be different from istop! Got istart 18099 and  istop 18099
# 06:31:37 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 06:31:45 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 06:31:51 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 06:32:54 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc
# istart must be different from istop! Got istart 1443 and  istop 1443
# 06:33:03 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc
# istart must be different from istop! Got istart 91490 and  istop 91490
# 06:33:58 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.poncedeleonsouth..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.poncedeleonsouth..nc.
# 06:34:09 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc.
# 06:34:40 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.naplesbay..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.naplesbay..nc.
# 06:34:50 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.gordonriverinlet..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.gordonriverinlet..nc.
# 06:35:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.melbourne..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.melbourne..nc.
# 06:35:17 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.binneydock..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.binneydock..nc.
# 06:35:30 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.verobeach..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.verobeach..nc.
# 06:38:51 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc.
# 06:40:46 INFO: ********************* Collector offerings **********************
# 06:40:46 INFO: NOAA.NOS.CO-OPS SOS: 1055 offerings
# 06:40:48 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-07-01T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AMetActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=sea_water_temperature
# 06:44:48 INFO: ************************* Observations *************************
# 06:44:48 INFO: **** Downloading to file 2014-07-07/2014-07-07-OBS_DATA.nc *****
# 06:44:50 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/utilities/secoora.py:694: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   df = df.drop_duplicates(cols='date_time').set_index('date_time')
#
# 06:45:45 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/iris/fileformats/netcdf.py:1783: UserWarning: NetCDF default saving behaviour currently assigns the outermost dimensions to unlimited. This behaviour is to be deprecated, in favour of no automatic assignment. To switch to the new behaviour, set iris.FUTURE.netcdf_no_unlimited to True.
#   warnings.warn(msg)
#
# 06:45:45 WARNING: /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/ipykernel/__main__.py:20: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#
# 06:45:45 INFO: ********************* SECOORA Observations *********************
# 06:45:45 INFO:  Downloading to file 2014-07-07/2014-07-07-SECOORA_OBS_DATA.nc *
# 06:45:45 INFO: **************************** Models ****************************
# 06:45:45 INFO:
# [Reading url 1/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 06:46:11 INFO:
# [Reading url 2/10]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 06:47:11 INFO:
# [Reading url 3/10]: http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 06:47:12 WARNING: Cannot get cube for: http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# NetCDF: file not found
# 06:47:12 INFO:
# [Reading url 4/10]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw
# 06:47:16 WARNING: [Not model data]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw
# 06:47:16 INFO:
# [Reading url 5/10]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 06:47:22 INFO:
# [Reading url 6/10]: http://tds.maracoos.org/thredds/dodsC/SST-Three-Agg.nc
# 06:47:36 WARNING: [Not model data]: http://tds.maracoos.org/thredds/dodsC/SST-Three-Agg.nc
# 06:47:36 INFO:
# [Reading url 7/10]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his/ESPRESSO_Real-Time_v2_History_Best
# 06:47:53 INFO:
# [Reading url 8/10]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 06:48:22 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 06:48:22 INFO:
# [Reading url 9/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 06:48:35 INFO:
# [Reading url 10/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 06:48:36 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd.
# 06:48:36 INFO: **** Downloading to file 2014-07-07/2014-07-07-USF_ROMS.nc *****
# 06:48:36 INFO: [No Data] Duck, NC
# 06:48:36 INFO: [No Data] Oregon Inlet Marina, NC
# 06:48:36 INFO: [No Data] USCG Station Hatteras, NC
# 06:48:36 INFO: [No Data] Beaufort, NC
# 06:48:36 INFO: [No Data] Wilmington, NC
# 06:48:36 INFO: [No Data] Wrightsville Beach, NC
# 06:48:36 INFO: [No Data] Springmaid Pier, SC
# 06:48:36 INFO: [No Data] Charleston, SC
# 06:48:36 INFO: [No Data] Fort Pulaski, GA
# 06:48:36 INFO: [No Data] Fernandina Beach, FL
# 06:48:36 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 06:48:36 INFO: [No Data] Dames Point, FL
# 06:48:36 INFO: [No Data] Jacksonville University, FL
# 06:48:36 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 06:48:36 INFO: [No Data] Red Bay Point, St Johns River, FL
# 06:48:36 INFO: [No Data] Racy Point, St Johns River, FL
# 06:48:36 INFO: [No Data] Trident Pier, FL
# 06:48:36 INFO: [No Data] Lake Worth Pier, FL
# 06:48:36 INFO: [No Data] Virginia Key, FL
# 06:48:36 INFO: [No Data] Vaca Key, FL
# 06:48:36 INFO: [No Data] Key West, FL
# 06:48:42 INFO: [Water  ] Naples, FL
# 06:48:48 INFO: [Water  ] Fort Myers, FL
# 06:48:56 INFO: [Water  ] Port Manatee, FL
# 06:48:56 INFO: [No Data] St Petersburg, FL
# 06:49:05 INFO: [Water  ] Old Port Tampa, FL
# 06:49:13 INFO: [Water  ] Apalachicola, FL
# 06:49:21 INFO: [Water  ] Panama City, FL
# 06:49:29 INFO: [Water  ] Panama City Beach, FL
# 06:49:29 INFO: [No Data] Pensacola, FL
# 06:49:36 INFO: [Water  ] Gulf of Mexico station
# 06:49:36 INFO: [No Data] Taylor River, FL
# 06:49:44 INFO: [Water  ] Redfish Pass station
# 06:49:44 INFO: [No Data] Little Rabbit Key, FL
# ...
# 06:50:10 INFO: [Water  ] Murray Key, FL
# 06:50:18 INFO: [Water  ] Blackwater Sound, FL
# 06:50:25 INFO: [Water  ] Butternut Key, FL
# 06:50:32 INFO: [Water  ] Shell Point station
# 06:50:32 INFO: [No Data] 2nd Ave North Pier, Myrtle Beach, SC
# 06:50:39 INFO: [Water  ] Little Blackwater, FL
# 06:50:39 INFO: [No Data] Trout Cove, FL
# 06:50:39 INFO: [No Data] White Water -West, FL
# 06:50:47 INFO: [Water  ] Cane Patch, FL
# 06:50:47 INFO: [No Data] Sebastian Inlet met station
# 06:50:53 INFO: [Water  ] usf_c10_imet
# 06:51:00 INFO: [Water  ] Shell Point
# 06:51:00 INFO: [No Data] Bing's Landing station
# 06:51:00 INFO: [No Data] CAROCOOPS CAP2, Capers Island Nearshore, SC
# 06:51:00 INFO: [No Data] CAROCOOPS SUN2, Sunset Nearshore, NC
# 06:51:08 INFO: [Water  ] Broad River Lower, FL
# 06:51:13 INFO: [Water  ] Clear Water Pass, FL
# 06:51:13 INFO: [No Data] Little Madeira, FL
# 06:51:20 INFO: [Water  ] Highway Creek, FL
# 06:51:20 INFO: [No Data] Gunboat Island, FL
# 06:51:20 INFO: [No Data] CAROCOOPS FRP2, Fripp Nearshore, SC
# 06:51:29 INFO: [Water  ] Cannon Bay, FL
# 06:51:29 INFO: [No Data] Apache Pier, Myrtle Beach, SC
CORMP ILM2, Wrightsville Beach Nearshore, NC
# 06:55:59 INFO: [No Data] fau_lobo_1
# 06:55:59 INFO: [No Data] Cherry Grove Pier, N. Myrtle Beach, SC
# 06:56:07 INFO: [Water  ] Tarpon Bay station
# 06:56:07 INFO: [No Data] Broad River, FL
# 06:56:15 INFO: [Water  ] Murray Key, FL
# 06:56:15 INFO: [No Data] Blackwater Sound, FL
# 06:56:15 INFO: [No Data] Butternut Key, FL
# 06:56:21 INFO: [Water  ] Shell Point station
# 06:56:21 INFO: [No Data] 2nd Ave North Pier, Myrtle Beach, SC
# 06:56:21 INFO: [No Data] Little Blackwater, FL
# 06:56:21 INFO: [No Data] Trout Cove, FL
# 06:56:21 INFO: [No Data] White Water -West, FL
# 06:56:21 INFO: [No Data] Cane Patch, FL
# 06:56:21 INFO: [No Data] Sebastian Inlet met station
# 06:56:34 INFO: [Water  ] usf_c10_imet
# 06:56:40 INFO: [Water  ] Shell Point
# 06:56:40 INFO: [No Data] Bing's Landing station
# 06:56:40 INFO: [No Data] CAROCOOPS CAP2, Capers Island Nearshore, SC
# 06:56:40 INFO: [No Data] CAROCOOPS SUN2, Sunset Nearshore, NC
# 06:56:40 INFO: [No Data] Broad River Lower, FL
# 06:56:40 INFO: [No Data] Clear Water Pass, FL
# 06:56:40 INFO: [No Data] Little Madeira, FL
# 06:56:40 INFO: [No Data] Highway Creek, FL
# 06:56:40 INFO: [No Data] Gunboat Island, FL
# 06:56:40 INFO: [No Data] CAROCOOPS FRP2, Fripp Nearshore, SC
# 06:56:40 INFO: [No Data] Cannon Bay, FL
# 06:56:40 INFO: [No Data] Apache Pier, Myrtle Beach, SC
# 06:56:40 INFO: [No Data] Tolomato River station
# 06:56:47 INFO: [Water  ] Whipray Basin, FL
# 06:56:54 INFO: [Water  ] Garfield Bight, FL
# 06:56:54 INFO: [No Data] Lane River, FL
# 06:56:54 INFO: [No Data] St Lucie Inlet station
# 06:56:54 INFO: [No Data] Duck Key, FL
# 06:56:54 INFO: [No Data] CORMP ILM3, Wrightsville Beach Offshore, NC
# 06:57:02 INFO: [Water  ] Fort Myers station
# 06:57:02 INFO: [No Data] Willy Willy, FL
# 06:57:09 INFO: [Water  ] Johnson Key, FL
# 06:57:15 INFO: [Water  ] Bob Allen, FL
# 06:57:15 INFO: *****************Finished processing USF_FVCOM
# *****************
# 06:57:15 INFO: **** Downloading to file 2014-07-07/2014-07-07-COAWST_4.nc *****
# 06:57:46 INFO: [Land   ] Duck, NC
# 06:58:00 INFO: [Water  ] Oregon Inlet Marina, NC
# 06:58:12 INFO: [Water  ] USCG Station Hatteras, NC
# 06:58:24 INFO: [Water  ] Beaufort, NC
# 06:58:37 INFO: [Land   ] Wilmington, NC
# 06:58:48 INFO: [Water  ] Wrightsville Beach, NC
# 06:58:58 INFO: [Water  ] Springmaid Pier, SC
# 06:59:28 INFO: [Water  ] Charleston, SC
# 06:59:39 INFO: [Land   ] Fort Pulaski, GA
# 07:00:03 INFO: [Land   ] Fernandina Beach, FL
# 07:00:34 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 07:00:59 INFO: [Land   ] Dames Point, FL
# 07:01:23 INFO: [Land   ] Jacksonville University, FL
# 07:01:48 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 07:02:11 INFO: [Land   ] Red Bay Point, St Johns River, FL
#
CAROCOOPS CAP2, Capers Island Nearshore, SC
# 07:28:03 INFO: [Water  ] CAROCOOPS SUN2, Sunset Nearshore, NC
# 07:28:07 INFO: [Land   ] Broad River Lower, FL
# 07:28:13 INFO: [Land   ] Clear Water Pass, FL
# 07:28:17 INFO: [Land   ] Little Madeira, FL
# 07:28:17 INFO: [No Data] Highway Creek, FL
# 07:28:21 INFO: [Land   ] Gunboat Island, FL
# 07:28:26 INFO: [Water  ] CAROCOOPS FRP2, Fripp Nearshore, SC
# 07:28:31 INFO: [Land   ] Cannon Bay, FL
# 07:28:36 INFO: [Land   ] Apache Pier, Myrtle Beach, SC
# 07:28:48 INFO: [Land   ] Tolomato River station
# 07:28:55 INFO: [Land   ] Whipray Basin, FL
# 07:29:00 INFO: [Land   ] Garfield Bight, FL
# 07:29:05 INFO: [Land   ] Lane River, FL
# 07:29:10 INFO: [Land   ] St Lucie Inlet station
# 07:29:14 INFO: [Land   ] Duck Key, FL
# 07:29:19 INFO: [Water  ] CORMP ILM3, Wrightsville Beach Offshore, NC
# 07:29:19 INFO: [No Data] Fort Myers station
# 07:29:28 INFO: [Land   ] Willy Willy, FL
# 07:29:33 INFO: [Land   ] Johnson Key, FL
# 07:29:33 INFO: [No Data] Bob Allen, FL
# 07:29:33 INFO: *******************Finished processing HYCOM
# *******************
# 07:29:33 INFO: ** Downloading to file 2014-07-07/2014-07-07-ROMS_ESPRESSO.nc **
# 07:29:52 INFO: [Land   ] Duck, NC
# 07:30:04 INFO: [Water  ] Oregon Inlet Marina, NC
# 07:30:12 INFO: [Land   ] USCG Station Hatteras, NC
# 07:30:22 INFO: [Water  ] Beaufort, NC
# 07:30:22 INFO: [No Data] Wilmington, NC
# 07:30:22 INFO: [No Data] Wrightsville Beach, NC
# 07:30:22 INFO: [No Data] Springmaid Pier, SC
# 07:30:22 INFO: [No Data] Charleston, SC
# 07:30:22 INFO: [No Data] Fort Pulaski, GA
# 07:30:22 INFO: [No Data] Fernandina Beach, FL
# 07:30:22 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 07:30:22 INFO: [No Data] Dames Point, FL
# 07:30:22 INFO: [No Data] Jacksonville University, FL
# 07:30:22 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 07:30:22 INFO: [No Data] Red Bay Point, St Johns River, FL
# 07:30:22 INFO: [No Data] Racy Point, St Johns River, FL
# 07:30:22 INFO: [No Data] Trident Pier, FL
# 07:30:22 INFO: [No Data] Lake Worth Pier, FL
# 07:30:22 INFO: [No Data] Virginia Key, FL
# 07:30:22 INFO: [No Data] Vaca Key, FL
# 07:30:22 INFO: [No Data] Key West, FL
# 07:30:22 INFO: [No Data] Naples, FL
# 07:30:22 INFO: [No Data] Fort Myers, FL
# 07:30:22 INFO: [No Data] Port Manatee, FL
# 07:30:22 INFO: [No Data] St Petersburg, FL
# 07:30:22 INFO: [No Data] Old Port Tampa, FL
# 07:30:22 INFO: [No Data] Apalachicola, FL
# 07:30:22 INFO: [No Data] Panama City, FL
# 07:30:22 INFO: [No Data] Panama City Beach, FL
# 07:30:22 INFO: [No Data] Pensacola, FL
# 07:30:22 INFO: [No Data] Gulf of Mexico station
# 07:30:22 INFO: [No Data] Taylor River, FL
# 07:30:22 INFO: [No Data] Redfish Pass station
# 07:30:22 INFO: [No Data] Little Rabbit Key, FL
# 07:30:22 INFO: [No Data] Peterson Key, FL
# 07:30:22 INFO: [No Data] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 07:30:22 INFO: [No Data] fau_lobo_1
# 07:30:22 INFO: [No Data] Cherry Grove Pier, N. Myrtle Beach, SC
# 07:30:22 INFO: [No Data] Tarpon Bay station
# 07:30:22 INFO: [No Data] Broad River, FL
# 07:30:22 INFO: [No Data] Murray Key, FL
# 07:30:22 INFO: [No Data] Blackwater Sound, FL
# 07:30:22 INFO: [No Data] Butternut Key, FL
# 07:30:22 INFO: [No Data] Shell Point station
# 07:30:22 INFO: [No Data] 2nd Ave North Pier, Myrtle Beach, SC
# 07:30:22 INFO: [No Data] Little Blackwater, FL
# 07:30:22 INFO: [No Data] Trout Cove, FL
# 07:30:22 INFO: [No Data] White Water -West, FL
# 07:30:22 INFO: [No Data] Cane Patch, FL
# 07:30:22 INFO: [No Data] Sebastian Inlet met station
# 07:30:22 INFO: [No Data] usf_c10_imet
# 07:30:22 INFO: [No Data] Shell Point
# 07:30:22 INFO: [No Data] Bing's Landing station
# 07:30:22 INFO: [No Data] CAROCOOPS CAP2, Capers Island Nearshore, SC
# 07:30:22 INFO: [No Data] CAROCOOPS SUN2, Sunset Nearshore, NC
# 07:30:22 INFO: [No Data] Broad River Lower, FL
# 07:30:22 INFO: [No Data] Clear Water Pass, FL
# 07:30:22 INFO: [No Data] Little Madeira, FL
# 07:30:22 INFO: [No Data] Highway Creek, FL
# 07:30:22 INFO: [No Data] Gunboat Island, FL
# 07:30:22 INFO: [No Data] CAROCOOPS FRP2, Fripp Nearshore, SC
# 07:30:22 INFO: [No Data] Cannon Bay, FL
# 07:30:22 INFO: [No Data] Apache Pier, Myrtle Beach, SC
# 07:30:22 INFO: [No Data] Tolomato River station
# 07:30:22 INFO: [No Data] Whipray Basin, FL
# 07:30:22 INFO: [No Data] Garfield Bight, FL
# 07:30:22 INFO: [No Data] Lane River, FL
# 07:30:22 INFO: [No Data] St Lucie Inlet station
# 07:30:22 INFO: [No Data] Duck Key, FL
# 07:30:22 INFO: [No Data] CORMP ILM3, Wrightsville Beach Offshore, NC
# 07:30:22 INFO: [No Data] Fort Myers station
# 07:30:22 INFO: [No Data] Willy Willy, FL
# 07:30:22 INFO: [No Data] Johnson Key, FL
# 07:30:22 INFO: [No Data] Bob Allen, FL
# 07:30:31 INFO: ***************Finished processing ROMS_ESPRESSO
# ***************
# 07:30:31 INFO: 67.41 minutes
# 07:30:31 INFO: EOF
