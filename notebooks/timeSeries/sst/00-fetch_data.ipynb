# %% [markdown]
# <img style='float: left' width="150px" src="http://secoora.org/sites/default/files/secoora_logo.png">
# <br><br>
# ## [SECOORA Notebook 1](http://secoora.org/)
# ### Fetch Sea Surface Temperature time-series data
#
# This notebook fetches weekly time-series of all the SECOORA observations and
# models available in the **NGDC** and **SECOORA THREDDS** catalogs.

# %%
import time

start_time = time.time()

# %%
# %load_ext watermark
# %watermark --githash --machine --python --packages iris,pyoos,owslib
# Out:
# CPython 2.7.10
# IPython 2.4.1
#
# iris 1.8.1
# pyoos 0.6.2
# owslib 0.9.0
#
# compiler   : GCC 4.4.7 20120313 (Red Hat 4.4.7-1)
# system     : Linux
# release    : 3.16.7-21-desktop
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 8
# interpreter: 64bit
# Git hash   : d3f52b7be67edd021a5057ed244b20d98972d93b

# %% [markdown]
# ### Save configuration

# %%
import os
try:
    import cPickle as pickle
except ImportError:
    import pickle

import iris
from datetime import datetime
from utilities import CF_names, fetch_range, start_log

# 1-week start of data.
kw = dict(start=datetime(2014, 7, 1, 12), days=6)
start, stop = fetch_range(**kw)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names.
sos_name = 'sea_water_temperature'
name_list = CF_names[sos_name]

# Units.
units = iris.unit.Unit('celsius')

# Logging.
run_name = '{:%Y-%m-%d}'.format(stop)
log = start_log(start, stop, bbox)

# SECOORA models.
secoora_models = ['SABGOM', 'USEAST',
                  'USF_ROMS', 'USF_SWAN', 'USF_FVCOM']

# Config.
fname = os.path.join(run_name, 'config.pkl')
config = dict(start=start,
              stop=stop,
              bbox=bbox,
              name_list=name_list,
              units=units,
              run_name=run_name,
              secoora_models=secoora_models)

with open(fname,'wb') as f:
    pickle.dump(config, f)

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exclude ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

fmt = '{:*^64}'.format
log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

# Work around https://github.com/ioos/secoora/issues/184:
dap_urls = [url for url in dap_urls if 'G1_SST_GLOBAL' not in url]

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %%
from utilities import is_station

# Filter out some station endpoints.
non_stations = []
for url in dap_urls:
    try:
        if not is_station(url):
            non_stations.append(url)
    except RuntimeError as e:
        log.warn("Could not access URL {}. {!r}".format(url, e))

dap_urls = non_stations

log.info(fmt(' Filtered DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

# %% [markdown]
# ### Add SECOORA models and observations

# %%
from utilities import titles, fix_url

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the NGDC csw'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# NOTE: USEAST is not archived at the moment!
# https://github.com/ioos/secoora/issues/173
dap_urls = [fix_url(start, url) if
            'SABGOM' in url else url for url in dap_urls]

# %%
import warnings
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

from utilities import (TimeoutException, secoora_buoys,
                       quick_load_cubes, proc_cube)

urls = list(secoora_buoys())
if not urls:
    raise ValueError("Did not find any SECOORA buoys!")

buoys = dict()
for url in urls:
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")  # Suppress iris warnings.
            kw = dict(bbox=bbox, time=(start, stop), units=units)
            cubes = quick_load_cubes(url, name_list)
            cubes = [proc_cube(cube, **kw) for cube in cubes]
        buoy = url.split('/')[-1].split('.nc')[0]
        if len(cubes) == 1:
            buoys.update({buoy: cubes[0]})
        else:
            #[buoys.update({'{}_{}'.format(buoy, k): cube}) for
            # k, cube in list(enumerate(cubes))]
            # FIXME: For now I am choosing the first sensor.
            buoys.update({buoy: cubes[0]})
    except (RuntimeError, ValueError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()

collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:MetActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# ### Clean the DataFrame

# %%
from utilities import get_coops_metadata, to_html

columns = {'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'sea_water_temperature (C)': sos_name}

observations.rename(columns=columns, inplace=True)

observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_metadata(s)[0] for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>8651370</td>
#       <td>E1</td>
#       <td>36.1833</td>
#       <td>-75.7467</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>25.1</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>8652587</td>
#       <td>E1</td>
#       <td>35.7950</td>
#       <td>-75.5483</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>27.3</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td>8654467</td>
#       <td>E1</td>
#       <td>35.2086</td>
#       <td>-75.7042</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>27.1</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td>8656483</td>
#       <td>E1</td>
#       <td>34.7200</td>
#       <td>-76.6700</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>27.5</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td>8658120</td>
#       <td>E1</td>
#       <td>34.2267</td>
#       <td>-77.9533</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>28.9</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from utilities import secoora2df

secoora_observations = secoora2df(buoys, sos_name)
to_html(secoora_observations.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Gulf of Mexico station</th>
#       <td>sccf.gulfofmexico.wq</td>
#       <td>NA</td>
#       <td>26.443029</td>
#       <td>-81.971191</td>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>30.806665</td>
#     </tr>
#     <tr>
#       <th>Taylor River, FL</th>
#       <td>enp.trrf1.met</td>
#       <td>NA</td>
#       <td>25.223000</td>
#       <td>-80.653000</td>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>31.917040</td>
#     </tr>
#     <tr>
#       <th>Redfish Pass station</th>
#       <td>sccf.redfishpass.wq</td>
#       <td>NA</td>
#       <td>26.561569</td>
#       <td>-82.175438</td>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>31.172716</td>
#     </tr>
#     <tr>
#       <th>Little Rabbit Key, FL</th>
#       <td>enp.lrkf1.met</td>
#       <td>NA</td>
#       <td>24.979000</td>
#       <td>-80.825996</td>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>30.869625</td>
#     </tr>
#     <tr>
#       <th>Peterson Key, FL</th>
#       <td>enp.pkyf1.met</td>
#       <td>NA</td>
#       <td>24.917000</td>
#       <td>-80.746002</td>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>30.920523</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from pandas import concat

all_obs = concat([observations, secoora_observations], axis=0)
to_html(concat([all_obs.head(2), all_obs.tail(2)]))
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>8651370</td>
#       <td>E1</td>
#       <td>36.183300</td>
#       <td>-75.746700</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>25.100000</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>8652587</td>
#       <td>E1</td>
#       <td>35.795000</td>
#       <td>-75.548300</td>
#       <td>2014-07-01T12:00:00Z</td>
#       <td>27.300000</td>
#     </tr>
#     <tr>
#       <th>CAROCOOPS SUN2, Sunset Nearshore, NC</th>
#       <td>carocoops.sun2.buoy</td>
#       <td>NA</td>
#       <td>33.830002</td>
#       <td>-78.480003</td>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>27.887022</td>
#     </tr>
#     <tr>
#       <th>Bob Allen, FL</th>
#       <td>enp.bobf1.met</td>
#       <td>NA</td>
#       <td>25.024000</td>
#       <td>-80.681999</td>
#       <td>2014-00-01T12:00:00Z</td>
#       <td>31.111263</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Uniform 6-min time base for model/data comparison

# %%
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
outfile = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
outfile = os.path.join(run_name, outfile)

log.info(fmt(' Downloading to file {} '.format(fname)))
data, bad_station = dict(), []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'sea_water_temperature (C)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_station.append(station)
        name = get_coops_metadata(station)[0]
        log.warning("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad stations.
pattern = '|'.join(bad_station)
if pattern:
    all_obs['bad_station'] = all_obs.station.str.contains(pattern)
    observations = observations[~observations.station.str.contains(pattern)]
else:
    all_obs['bad_station'] = ~all_obs.station.str.contains(pattern)

# Save updated `all_obs.csv`.
fname = '{}-all_obs.csv'.format(run_name)
fname = os.path.join(run_name, fname)
all_obs.to_csv(fname)

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(obs_data, outfile=outfile,
                standard_name=sos_name, **kw)

to_html(obs_data.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8654467</th>
#       <th>8656483</th>
#       <th>8658120</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8665530</th>
#       <th>8670870</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720219</th>
#       <th>8720245</th>
#       <th>8720357</th>
#       <th>8720503</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723214</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8726520</th>
#       <th>8726607</th>
#       <th>8728690</th>
#       <th>8729108</th>
#       <th>8729210</th>
#       <th>8729840</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-07-01 12:00:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>28.0</td>
#       <td>28.6</td>
#       <td>28.6</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.139</td>
#       <td>31.1</td>
#       <td>30.8</td>
#       <td>31.9</td>
#       <td>31</td>
#       <td>29.9</td>
#       <td>28.6</td>
#       <td>22.8</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:06:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>28.0</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.100</td>
#       <td>31.1</td>
#       <td>30.8</td>
#       <td>31.9</td>
#       <td>31</td>
#       <td>29.9</td>
#       <td>28.6</td>
#       <td>22.8</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:12:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>27.9</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.4</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.129</td>
#       <td>31.1</td>
#       <td>30.9</td>
#       <td>31.9</td>
#       <td>31</td>
#       <td>29.9</td>
#       <td>29.1</td>
#       <td>22.8</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:18:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>27.9</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.100</td>
#       <td>31.1</td>
#       <td>30.8</td>
#       <td>32.0</td>
#       <td>31</td>
#       <td>29.8</td>
#       <td>29.0</td>
#       <td>22.9</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2014-07-01 12:24:00</th>
#       <td>25.1</td>
#       <td>27.3</td>
#       <td>27.1</td>
#       <td>27.5</td>
#       <td>28.9</td>
#       <td>27.9</td>
#       <td>28.6</td>
#       <td>28.7</td>
#       <td>25.6</td>
#       <td>29.8</td>
#       <td>29.1</td>
#       <td>29.6</td>
#       <td>29.5</td>
#       <td>30.4</td>
#       <td>30.3</td>
#       <td>29.6</td>
#       <td>29.2</td>
#       <td>28.1</td>
#       <td>29.9</td>
#       <td>30.2</td>
#       <td>30.5</td>
#       <td>32.116</td>
#       <td>31.2</td>
#       <td>30.8</td>
#       <td>32.0</td>
#       <td>31</td>
#       <td>29.8</td>
#       <td>29.0</td>
#       <td>22.9</td>
#       <td>29.5</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
import numpy as np
from pandas import DataFrame


def extract_series(cube, station):
    time = cube.coord(axis='T')
    date_time = time.units.num2date(cube.coord(axis='T').points)
    data = cube.data
    return DataFrame(data, columns=[station], index=date_time)


secoora_obs_data = []
for station, cube in list(buoys.items()):
    df = extract_series(cube, station)
    secoora_obs_data.append(df)

secoora_obs_data = concat(secoora_obs_data, axis=1)

# These buoys need some QA/QC!
mask = np.logical_or(secoora_obs_data < -5, secoora_obs_data > 40)
secoora_obs_data[mask] = np.NaN

# Interpolate to the same index as SOS.
index = obs_data.index
kw = dict(method='time', limit=30)
secoora_obs_data = secoora_obs_data.reindex(index).interpolate(**kw).ix[index]

log.info(fmt(' SECOORA Observations '))
fname = '{:%Y-%m-%d}-SECOORA_OBS_DATA.nc'.format(stop)
fname = os.path.join(run_name, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))

url = "http://129.252.139.124/thredds/catalog_platforms.html"
comment = "Several stations {}".format(url)
kw = dict(longitude=secoora_observations.lon,
          latitude=secoora_observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(secoora_obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(secoora_obs_data.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sccf.gulfofmexico.wq</th>
#       <th>enp.trrf1.met</th>
#       <th>sccf.redfishpass.wq</th>
#       <th>enp.lrkf1.met</th>
#       <th>carocoops.frp2.buoy</th>
#       <th>cormp.ilm2.buoy</th>
#       <th>fau.lobo.1</th>
#       <th>enp.cwaf1.met</th>
#       <th>sccf.tarponbay.wq</th>
#       <th>sccf.fortmyers.wq</th>
#       <th>enp.mukf1.met</th>
#       <th>enp.bwsf1.met</th>
#       <th>enp.bnkf1.met</th>
#       <th>sccf.shellpoint.wq</th>
#       <th>lbhmc.2ndave.pier</th>
#       <th>enp.lbsf1.met</th>
#       <th>enp.lmdf1.met</th>
#       <th>enp.wwef1.met</th>
#       <th>enp.canf1.met</th>
#       <th>fit.sispnj.met</th>
#       <th>fldep.bingslanding.</th>
#       <th>carocoops.cap2.buoy</th>
#       <th>enp.tcvf1.met</th>
#       <th>enp.jkyf1.met</th>
#       <th>enp.lbrf1.met</th>
#       <th>lbhmc.cherrygrove.pier</th>
#       <th>usf.shp.ngwlms</th>
#       <th>enp.hcef1.met</th>
#       <th>enp.gbif1.met</th>
#       <th>enp.pkyf1.met</th>
#       <th>enp.cnbf1.met</th>
#       <th>lbhmc.apachepier.pier</th>
#       <th>fldep.tolomatoriver.</th>
#       <th>enp.wrbf1.met</th>
#       <th>enp.gbtf1.met</th>
#       <th>enp.lrif1.met</th>
#       <th>fldep.stlucieinlet.</th>
#       <th>enp.dkkf1.met</th>
#       <th>cormp.ilm3.buoy</th>
#       <th>enp.bdvf1.met</th>
#       <th>enp.wiwf1.met</th>
#       <th>carocoops.sun2.buoy</th>
#       <th>enp.bobf1.met</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                cube = quick_load_cubes(url, name_list, callback=None, strict=True)
                if is_model(cube):
                    cube = proc_cube(cube, bbox=bbox, time=(start, stop), units=units)
                else:
                    log.warning("[Not model data]: {}".format(url))
                    continue
                # FIXME: Surface data only!
                cube = get_surface(cube)
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
        except (TimeoutException, RuntimeError, ValueError,
                ConstraintMismatchError, CoordinateNotFoundError,
                IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from iris.pandas import as_series

from utilities import (make_tree, get_nearest_water,
                        add_station, ensure_timeseries, remove_ssh)


for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(run_name, fname)
    log.info(fmt(' Downloading to file {} '.format(fname)))
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot make KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in all_obs.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            status = "No Data"
            log.info('[{}] {}'.format(status, obs.name))
            continue
        if not series:
            status = "Land   "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water  "

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = add_station(cube, station)
            cube = remove_ssh(cube)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info('Finished processing [{}]: {}\n'.format(mod_name, url))

# %%
from utilities import nbviewer_link, make_qr

make_qr(nbviewer_link('00-fetch_data.ipynb'))

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

with open('{}/log.txt'.format(run_name)) as f:
    print(f.read())
# Out:
# 07:11:38 INFO: ************Saving data inside directory 2014-07-07*************
# 07:11:38 INFO: *********************** Run information ************************
# 07:11:38 INFO: Run date: 2015-08-03 22:11:38
# 07:11:38 INFO: Download start: 2014-07-01 12:00:00
# 07:11:38 INFO: Download stop: 2014-07-07 12:00:00
# 07:11:38 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 07:11:38 INFO: *********************** Software version ***********************
# 07:11:38 INFO: Iris version: 1.8.1
# 07:11:38 INFO: owslib version: 0.9.0
# 07:11:38 INFO: pyoos version: 0.6.2
# 07:11:48 INFO: ********************* Catalog information **********************
# 07:11:48 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 07:11:48 INFO: CSW version: 2.0.2
# 07:11:48 INFO: Number of datasets available: 93
# 07:11:48 INFO: ***************************** CSW ******************************
# 07:11:48 INFO: USF FVCOM - Nowcast Aggregation
# 07:11:48 INFO: ROMS/TOMS 3.0 - New Floria Shelf Application
# 07:11:48 INFO: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# 07:11:48 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near
59:59.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near FORT PIERCE, FL from 2013/12/05 17:00:00 to 2015/03/19 13:59:59.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near DUCK FRF 26m, NC from 2008/05/22 to 2015/05/06.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near CAPE CHARLES, VA from 2013/09/11 18:00:00 to 2015/02/18 11:59:59.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near CAPE CANAVERAL NEARSHORE, FL from 2006/09/07 to 2015/06/05.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near OREGON INLET, NC from 2013/07/17 17:00:00 to 2015/02/01 16:59:59.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near FERNANDINA BEACH, FL from 2006/02/09 to 2015/01/29.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near MASONBORO INLET, ILM2, NC from 2008/05/07 to 2015/01/06.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near ST. PETERSBURG OFFSHORE, FL from 2007/07/10 to 2015/02/24.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near OREGON INLET, NC from 2012/04/08 to 2015/02/01.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near FORT PIERCE, FL from 2006/09/29 to 2015/03/19.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near NEW RIVER INLET, NC from 2012/04/14 to 2014/07/11.
# 07:11:48 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near NEW RIVER INLET, NC from 2014/03/09 19:00:00 to 2014/07/11 23:59:59.
# 07:11:48 INFO: carocoops.cap2.buoy
# 07:11:48 INFO: carocoops.cap2.buoy
# 07:11:48 INFO: carocoops.frp2.buoy
# 07:11:48 INFO: carocoops.frp2.buoy
# 07:11:48 INFO: carocoops.sun2.buoy
# 07:11:48 INFO: enp.bdvf1.met
# 07:11:48 INFO: enp.bnkf1.met
# 07:11:48 INFO: enp.bobf1.met
# 07:11:48 INFO: enp.bwsf1.met
# 07:11:48 INFO: enp.canf1.met
# 07:11:48 INFO: enp.cnbf1.met
# 07:11:48 INFO: enp.cwaf1.met
# 07:11:48 INFO: enp.dkkf1.met
# 07:11:48 INFO: enp.gbif1.met
# 07:11:48 INFO: enp.gbtf1.met
# 07:11:48 INFO: enp.hcef1.met
# 07:11:48 INFO: enp.jkyf1.met
# 07:11:48 INFO: enp.lbrf1.met
# 07:11:48 INFO: enp.lbsf1.met
# 07:11:48 INFO: enp.lmdf1.met
# 07:11:48 INFO: enp.lrif1.met
# 07:11:48 INFO: enp.lrkf1.met
# 07:11:48 INFO: enp.mukf1.met
# 07:11:48 INFO: enp.pkyf1.met
# 07:11:48 INFO: enp.tcvf1.met
# 07:11:48 INFO: enp.trrf1.met
# 07:11:48 INFO: enp.wiwf1.met
# 07:11:48 INFO: enp.wrbf1.met
# 07:11:48 INFO: enp.wwef1.met
# 07:11:48 INFO: fau.lobo.1
# 07:11:48 INFO: fldep.bingslanding.
# 07:11:48 INFO: fldep.stlucieinlet.
# 07:11:48 INFO: fldep.tolomatoriver.
# 07:11:48 INFO: lbhmc.2ndave.pier
# 07:11:48 INFO: lbhmc.apachepier.pier
# 07:11:48 INFO: lbhmc.cherrygrove.pier
# 07:11:48 INFO: sccf.fortmyers.wq
# 07:11:48 INFO: sccf.gulfofmexico.wq
# 07:11:48 INFO: sccf.redfishpass.wq
# 07:11:48 INFO: sccf.shellpoint.wq
# 07:11:48 INFO: sccf.tarponbay.wq
# 07:11:48 INFO: usf.c21.weatherpak
# 07:11:48 INFO: usf.shp.ngwlms
# 07:11:48 INFO: ***************************** SOS ******************************
# 07:11:48 INFO: http://sdf.ndbc.noaa.gov/sos/server.php?service=SOS&request=GetCapabilities&acceptVersions=1.0.0
# 07:11:48 INFO: http://tds.secoora.org/thredds/sos
1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/036p1/036p1_d40.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d17.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d27.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/132p1/132p1_d11.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/132p1/132p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/134p1/134p1_d09.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/134p1/134p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/139p1/139p1_d08.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/139p1/139p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/143p1/143p1_d11.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/143p1/143p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/144p1/144p1_d07.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/144p1/144p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_d07.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d04.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d02.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/186p1/186p1_d03.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_d02.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/192p1/192p1_historic.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d02.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc.html
# 07:11:48 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/430p1/430p1_historic.nc.html
# 07:16:50 INFO: ************************* Filtered DAP *************************
# 07:16:50 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# 07:16:50 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd.html
# 07:16:50 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 07:16:50 INFO: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# 07:16:50 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw.html
# 07:16:50 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 07:16:50 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd.html
# 07:16:50 WARNING: USEAST not in the NGDC csw
# 07:16:50 WARNING: USF_SWAN not in the NGDC csw
# 07:17:18 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc.
# 07:17:28 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.tas.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.tas.ngwlms.nc.
# 07:17:52 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.apk.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.apk.ngwlms.nc.
# 07:18:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc.
# 07:18:14 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.bcp.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.bcp.ngwlms.nc.
# 07:18:21 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.fhp.ngwlms.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/usf.fhp.ngwlms.nc.
# 07:18:28 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc
# istart must be different from istop! Got istart 48233 and  istop 48233
# 07:18:40 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/c10_salinity_water_temp.nc.
# 07:18:55 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/QC_C10_Temp_full.nc.
# 07:19:06 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/QC_C10_Sal_full.nc.
# 07:19:11 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc
# istart must be different from istop! Got istart 18711 and  istop 18711
# 07:19:18 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc
# istart must be different from istop! Got istart 18099 and  istop 18099
# 07:19:23 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 07:19:29 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 07:19:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 07:20:27 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc
# istart must be different from istop! Got istart 1443 and  istop 1443
# 07:20:35 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc
# istart must be different from istop! Got istart 91490 and  istop 91490
# 07:21:20 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.poncedeleonsouth..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.poncedeleonsouth..nc.
# 07:21:31 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc.
# 07:21:54 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.naplesbay..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.naplesbay..nc.
# 07:22:04 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.gordonriverinlet..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.gordonriverinlet..nc.
# 07:22:12 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.melbourne..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.melbourne..nc.
# 07:22:36 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.binneydock..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.binneydock..nc.
# 07:22:55 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.verobeach..nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/fldep.verobeach..nc.
# 07:25:31 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc.
# 07:27:02 INFO: ********************* Collector offerings **********************
# 07:27:02 INFO: NOAA.NOS.CO-OPS SOS: 1048 offerings
# 07:27:05 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-07-01T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AMetActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=sea_water_temperature
# 07:31:31 INFO: ************************* Observations *************************
# 07:31:31 INFO: ********** Downloading to file 2014-07-07/config.pkl ***********
# 07:33:54 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/netcdf.py:1783: UserWarning: NetCDF default saving behaviour currently assigns the outermost dimensions to unlimited. This behaviour is to be deprecated, in favour of no automatic assignment. To switch to the new behaviour, set iris.FUTURE.netcdf_no_unlimited to True.
#   warnings.warn(msg)
#
# 07:33:54 INFO: ********************* SECOORA Observations *********************
# 07:33:54 INFO:  Downloading to file 2014-07-07/2014-07-07-SECOORA_OBS_DATA.nc *
# 07:33:54 INFO: **************************** Models ****************************
# 07:33:54 INFO:
# [Reading url 1/9]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 07:38:56 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# Timed out!
# 07:38:56 INFO:
# [Reading url 2/9]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 07:39:13 INFO:
# [Reading url 3/9]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 07:39:54 INFO:
# [Reading url 4/9]: http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 07:40:24 INFO:
# [Reading url 5/9]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw
# 07:40:28 WARNING: [Not model data]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw
# 07:40:28 INFO:
# [Reading url 6/9]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 07:40:34 INFO:
# [Reading url 7/9]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# 07:40:53 INFO:
# [Reading url 8/9]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 07:41:19 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 07:41:19 INFO:
# [Reading url 9/9]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 07:41:22 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cannot find ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature'] in http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.nc
INFO: [Land   ] Red Bay Point, St Johns River, FL
# 08:08:29 INFO: [Land   ] Racy Point, St Johns River, FL
# 08:08:41 INFO: [Land   ] Trident Pier, FL
# 08:09:06 INFO: [Water  ] Lake Worth Pier, FL
# 08:09:26 INFO: [Land   ] Virginia Key, FL
# 08:09:40 INFO: [Land   ] Vaca Key, FL
# 08:10:06 INFO: [Water  ] Key West, FL
# 08:10:19 INFO: [Land   ] Naples, FL
# 08:10:33 INFO: [Land   ] Fort Myers, FL
# 08:10:46 INFO: [Land   ] Port Manatee, FL
# 08:11:01 INFO: [Land   ] St Petersburg, FL
# 08:11:29 INFO: [Water  ] Old Port Tampa, FL
# 08:11:41 INFO: [Water  ] Apalachicola, FL
# 08:11:57 INFO: [Water  ] Panama City, FL
# 08:12:24 INFO: [Land   ] Panama City Beach, FL
# 08:12:39 INFO: [Water  ] Pensacola, FL
# 08:13:06 INFO: [Water  ] Gulf of Mexico station
# 08:13:20 INFO: [Land   ] Taylor River, FL
# 08:13:45 INFO: [Water  ] Redfish Pass station
# 08:13:59 INFO: [Water  ] Little Rabbit Key, FL
# 08:14:11 INFO: [Water  ] Peterson Key, FL
# 08:14:37 INFO: [Water  ] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 08:14:51 INFO: [Land   ] fau_lobo_1
# 08:15:03 INFO: [Land   ] Cherry Grove Pier, N. Myrtle Beach, SC
# 08:15:16 INFO: [Water  ] Tarpon Bay station
# 08:15:27 INFO: [Land   ] Broad River, FL
# 08:15:39 INFO: [Water  ] Murray Key, FL
# 08:15:50 INFO: [Land   ] Blackwater Sound, FL
# 08:16:17 INFO: [Water  ] Butternut Key, FL
# 08:16:47 INFO: [Land   ] Shell Point station
# 08:17:14 INFO: [Water  ] 2nd Ave North Pier, Myrtle Beach, SC
# 08:17:26 INFO: [Land   ] Little Blackwater, FL
# 08:17:37 INFO: [Land   ] Trout Cove, FL
# 08:17:50 INFO: [Water  ] White Water -West, FL
# 08:18:03 INFO: [Land   ] Cane Patch, FL
# 08:18:16 INFO: [Water  ] Sebastian Inlet met station
# 08:18:28 INFO: [Land   ] Shell Point
# 08:18:40 INFO: [Land   ] Bing's Landing station
# 08:19:05 INFO: [Water  ] CAROCOOPS CAP2, Capers Island Nearshore, SC
# 08:19:17 INFO: [Water  ] Johnson Key, FL
# 08:19:28 INFO: [Land   ] Broad River Lower, FL
# 08:19:40 INFO: [Water  ] Clear Water Pass, FL
# 08:19:53 INFO: [Water  ] Little Madeira, FL
# 08:20:05 INFO: [Land   ] Highway Creek, FL
# 08:20:20 INFO: [Land   ] Gunboat Island, FL
# 08:20:32 INFO: [Water  ] CAROCOOPS FRP2, Fripp Nearshore, SC
# 08:20:46 INFO: [Land   ] Cannon Bay, FL
# 08:20:58 INFO: [Land   ] Apache Pier, Myrtle Beach, SC
# 08:21:13 INFO: [Land   ] Tolomato River station
# 08:21:40 INFO: [Water  ] Whipray Basin, FL
# 08:21:54 INFO: [Water  ] Garfield Bight, FL
# 08:22:08 INFO: [Land   ] Lane River, FL
# 08:22:34 INFO: [Water  ] St Lucie Inlet station
# 08:22:47 INFO: [Water  ] Duck Key, FL
# 08:23:01 INFO: [Water  ] CORMP ILM3, Wrightsville Beach Offshore, NC
# 08:23:16 INFO: [Land   ] Fort Myers station
# 08:23:29 INFO: [Land   ] Willy Willy, FL
# 08:23:43 INFO: [Water  ] CAROCOOPS SUN2, Sunset Nearshore, NC
# 08:23:55 INFO: [Water  ] Bob Allen, FL
# 08:27:16 INFO: Finished processing [COAWST_4]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 08:27:16 INFO: **** Downloading to file 2014-07-07/2014-07-07-ESPRESSO.nc *****
# 08:27:28 INFO: [Land   ] Duck, NC
# 08:27:40 INFO: [Water  ] Oregon Inlet Marina, NC
# 08:27:50 INFO: [Land   ] USCG Station Hatteras, NC
# 08:28:01 INFO: [Water  ] Beaufort, NC
# 08:28:01 INFO: [No Data] Wilmington, NC
# 08:28:01 INFO: [No Data] Wrightsville Beach, NC
# 08:28:01 INFO: [No Data] Springmaid Pier, SC
# 08:28:01 INFO: [No Data] Charleston, SC
# 08:28:01 INFO: [No Data] Fort Pulaski, GA
# 08:28:01 INFO: [No Data] Fernandina Beach, FL
# 08:28:01 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 08:28:01 INFO: [No Data] Dames Point, FL
# 08:28:01 INFO: [No Data] Jacksonville University, FL
# 08:28:01 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 08:28:01 INFO: [No Data] Red Bay Point, St Johns River, FL
# 08:28:01 INFO: [No Data] Racy Point, St Johns River, FL
# 08:28:01 INFO: [No Data] Trident Pier, FL
# 08:28:01 INFO: [No Data] Lake Worth Pier, FL
# 08:28:01 INFO: [No Data] Virginia Key, FL
# 08:28:01 INFO: [No Data] Vaca Key, FL
# 08:28:01 INFO: [No Data] Key West, FL
# 08:28:01 INFO: [No Data] Naples, FL
# 08:28:01 INFO: [No Data] Fort Myers, FL
# 08:28:01 INFO: [No Data] Port Manatee, FL
# 08:28:01 INFO: [No Data] St Petersburg, FL
# 08:28:01 INFO: [No Data] Old Port Tampa, FL
# 08:28:01 INFO: [No Data] Apalachicola, FL
# 08:28:01 INFO: [No Data] Panama City, FL
# 08:28:01 INFO: [No Data] Panama City Beach, FL
# 08:28:01 INFO: [No Data] Pensacola, FL
# 08:28:01 INFO: [No Data] Gulf of Mexico station
# 08:28:01 INFO: [No Data] Taylor River, FL
# 08:28:01 INFO: [No Data] Redfish Pass station
# 08:28:01 INFO: [No Data] Little Rabbit Key, FL
# 08:28:01 INFO: [No Data] Peterson Key, FL
# 08:28:01 INFO: [No Data] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 08:28:01 INFO: [No Data] fau_lobo_1
# 08:28:01 INFO: [No Data] Cherry Grove Pier, N. Myrtle Beach, SC
# 08:28:01 INFO: [No Data] Tarpon Bay station
# 08:28:01 INFO: [No Data] Broad River, FL
# 08:28:01 INFO: [No Data] Murray Key, FL
# 08:28:01 INFO: [No Data] Blackwater Sound, FL
# 08:28:01 INFO: [No Data] Butternut Key, FL
# 08:28:01 INFO: [No Data] Shell Point station
# 08:28:01 INFO: [No Data] 2nd Ave North Pier, Myrtle Beach, SC
# 08:28:01 INFO: [No Data] Little Blackwater, FL
# 08:28:01 INFO: [No Data] Trout Cove, FL
# 08:28:01 INFO: [No Data] White Water -West, FL
# 08:28:01 INFO: [No Data] Cane Patch, FL
# 08:28:01 INFO: [No Data] Sebastian Inlet met station
# 08:28:01 INFO: [No Data] Shell Point
# 08:28:01 INFO: [No Data] Bing's Landing station
# 08:28:01 INFO: [No Data] CAROCOOPS CAP2, Capers Island Nearshore, SC
# 08:28:01 INFO: [No Data] Johnson Key, FL
# 08:28:01 INFO: [No Data] Broad River Lower, FL
# 08:28:01 INFO: [No Data] Clear Water Pass, FL
# 08:28:01 INFO: [No Data] Little Madeira, FL
# 08:28:01 INFO: [No Data] Highway Creek, FL
# 08:28:01 INFO: [No Data] Gunboat Island, FL
# 08:28:01 INFO: [No Data] CAROCOOPS FRP2, Fripp Nearshore, SC
# 08:28:01 INFO: [No Data] Cannon Bay, FL
# 08:28:01 INFO: [No Data] Apache Pier, Myrtle Beach, SC
# 08:28:01 INFO: [No Data] Tolomato River station
# 08:28:01 INFO: [No Data] Whipray Basin, FL
# 08:28:01 INFO: [No Data] Garfield Bight, FL
# 08:28:01 INFO: [No Data] Lane River, FL
# 08:28:01 INFO: [No Data] St Lucie Inlet station
# 08:28:01 INFO: [No Data] Duck Key, FL
# 08:28:01 INFO: [No Data] CORMP ILM3, Wrightsville Beach Offshore, NC
# 08:28:01 INFO: [No Data] Fort Myers station
# 08:28:01 INFO: [No Data] Willy Willy, FL
# 08:28:01 INFO: [No Data] CAROCOOPS SUN2, Sunset Nearshore, NC
# 08:28:01 INFO: [No Data] Bob Allen, FL
# 08:28:09 INFO: Finished processing [ESPRESSO]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 08:28:09 INFO: ****** Downloading to file 2014-07-07/2014-07-07-HYCOM.nc ******
# 08:28:14 INFO: [Land   ] Duck, NC
# 08:28:19 INFO: [Water  ] Oregon Inlet Marina, NC
# 08:28:25 INFO: [Land   ] USCG Station Hatteras, NC
# 08:28:33 INFO: [Land   ] Beaufort, NC
# 08:28:37 INFO: [Land   ] Wilmington, NC
# 08:28:41 INFO: [Water  ] Wrightsville Beach, NC
# 08:28:41 INFO: [No Data] Springmaid Pier, SC
# 08:28:46 INFO: [Land   ] Charleston, SC
# 08:28:50 INFO: [Land   ] Fort Pulaski, GA
# 08:28:56 INFO: [Land   ] Fernandina Beach, FL
# 08:29:04 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 08:29:12 INFO: [Land   ] Dames Point, FL
# 08:29:16 INFO: [Land   ] Jacksonville University, FL
# 08:29:21 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 08:29:25 INFO: [Land   ] Red Bay Point, St Johns River, FL
# 08:29:25 INFO: [No Data] Racy Point, St Johns River, FL
# 08:29:29 INFO: [Land   ] Trident Pier, FL
# 08:29:36 INFO: [Water  ] Lake Worth Pier, FL
# 08:29:44 INFO: [Land   ] Virginia Key, FL
# 08:29:51 INFO: [Land   ] Vaca Key, FL
# 08:29:55 INFO: [Land   ] Key West, FL
# 08:29:55 INFO: [No Data] Naples, FL
# 08:30:01 INFO: [Land   ] Fort Myers, FL
# 08:30:06 INFO: [Land   ] Port Manatee, FL
# 08:30:11 INFO: [Land   ] St Petersburg, FL
# 08:30:16 INFO: [Land   ] Old Port Tampa, FL
# 08:30:21 INFO: [Land   ] Apalachicola, FL
# 08:30:26 INFO: [Land   ] Panama City, FL
# 08:30:26 INFO: [No Data] Panama City Beach, FL
# 08:30:32 INFO: [Land   ] Pensacola, FL
# 08:30:37 INFO: [Land   ] Gulf of Mexico station
# 08:30:42 INFO: [Land   ] Taylor River, FL
# 08:30:48 INFO: [Land   ] Redfish Pass station
# 08:30:53 INFO: [Land   ] Little Rabbit Key, FL
# 08:31:03 INFO: [Land   ] Peterson Key, FL
# 08:31:03 INFO: [No Data] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 08:31:12 INFO: [Land   ] fau_lobo_1
# 08:31:19 INFO: [Land   ] Cherry Grove Pier, N. Myrtle Beach, SC
# 08:31:27 INFO: [Land   ] Tarpon Bay station
# 08:31:27 INFO: [No Data] Broad River, FL
# 08:31:35 INFO: [Land   ] Murray Key, FL
# 08:31:35 INFO: [No Data] Blackwater Sound, FL
# 08:31:41 INFO: [Land   ] Butternut Key, FL
# 08:31:50 INFO: [Land   ] Shell Point station
# 08:31:57 INFO: [Land   ] 2nd Ave North Pier, Myrtle Beach, SC
# 08:32:06 INFO: [Land   ] Little Blackwater, FL
# 08:32:12 INFO: [Land   ] Trout Cove, FL
# 08:32:18 INFO: [Land   ] White Water -West, FL
# 08:32:23 INFO: [Land   ] Cane Patch, FL
# 08:32:31 INFO: [Land   ] Sebastian Inlet met station
# 08:32:37 INFO: [Land   ] Shell Point
# 08:32:45 INFO: [Land   ] Bing's Landing station
# 08:32:54 INFO: [Water  ] CAROCOOPS CAP2, Capers Island Nearshore, SC
# 08:33:00 INFO: [Land   ] Johnson Key, FL
# 08:33:07 INFO: [Land   ] Broad River Lower, FL
# 08:33:18 INFO: [Land   ] Clear Water Pass, FL
# 08:33:25 INFO: [Land   ] Little Madeira, FL
# 08:33:25 INFO: [No Data] Highway Creek, FL
# 08:33:30 INFO: [Land   ] Gunboat Island, FL
# 08:33:42 INFO: [Water  ] CAROCOOPS FRP2, Fripp Nearshore, SC
# 08:33:49 INFO: [Land   ] Cannon Bay, FL
# 08:33:56 INFO: [Land   ] Apache Pier, Myrtle Beach, SC
# 08:34:08 INFO: [Land   ] Tolomato River station
# 08:34:14 INFO: [Land   ] Whipray Basin, FL
# 08:34:20 INFO: [Land   ] Garfield Bight, FL
# 08:34:25 INFO: [Land   ] Lane River, FL
# 08:34:35 INFO: [Land   ] St Lucie Inlet station
# 08:34:41 INFO: [Land   ] Duck Key, FL
# 08:34:47 INFO: [Water  ] CORMP ILM3, Wrightsville Beach Offshore, NC
# 08:34:47 INFO: [No Data] Fort Myers station
# 08:34:54 INFO: [Land   ] Willy Willy, FL
# 08:35:01 INFO: [Water  ] CAROCOOPS SUN2, Sunset Nearshore, NC
# 08:35:01 INFO: [No Data] Bob Allen, FL
# 08:35:01 INFO: Finished processing [HYCOM]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 08:35:02 INFO: 83.42 minutes
# 08:35:02 INFO: EOF
