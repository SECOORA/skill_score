# %% [markdown]
# ### SECOORA sea surface salinity time-series notebook
#
# Produce weekly maps and tables for the SECOORA.  Based on IOOS system-test [notebook](http://nbviewer.ipython.org/github/ioos/system-test/blob/master/Theme_1_Baseline/Scenario_1E_Salinity/Scenario_1E_Salinity.ipynb).

# %%
import time
start_time = time.time()

# %%
import os

# %load_ext watermark
# %watermark --githash --machine --python --packages iris,pyoos,owslib

style = os.path.join(os.pardir, os.pardir, 'style.css')
# Out:
# CPython 2.7.9
# IPython 2.3.1
#
# iris 1.7.2-DEV
# pyoos 0.6.2
# owslib 0.8-dev
#
# compiler   : GCC 4.4.7 20120313 (Red Hat 4.4.7-1)
# system     : Linux
# release    : 3.16.7-7-desktop
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit
# Git hash   : 912046c6ac1be9bf8e0a36b223eb2a5ec98ebe43

# %%
import pytz
from datetime import datetime, timedelta

from utilities import CF_names


# Choose the date range (e.g: stop = datetime(2014, 7, 7, 12)).
stop = datetime(2014, 7, 7, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = stop - timedelta(days=7)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names to look for:
name_list = CF_names['salinity']

# %%
run_name = '{:%Y-%m-%d}'.format(stop)

if not os.path.exists(run_name):
    os.makedirs(run_name)

# %%
import iris
import pyoos
import owslib

import logging as log
reload(log)

fmt = '{:*^64}'.format
log.captureWarnings(True)
LOG_FILENAME = 'log.txt'
LOG_FILENAME = os.path.join(run_name, LOG_FILENAME)
log.basicConfig(filename=LOG_FILENAME,
                filemode='w',
                format='%(asctime)s %(levelname)s: %(message)s',
                datefmt='%I:%M:%S',
                level=log.INFO,
                stream=None)

log.info(fmt(' Run information '))
log.info('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
log.info('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
log.info('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
log.info('Bounding box: {0:3.2f}, {1:3.2f},'
         '{2:3.2f}, {3:3.2f}'.format(*bbox))
log.info(fmt(' Software version '))
log.info('Iris version: {}'.format(iris.__version__))
log.info('owslib version: {}'.format(owslib.__version__))
log.info('pyoos version: {}'.format(pyoos.__version__))

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exclude ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

# %% [markdown]
# ### Add SECOORA models and observations.

# %%
from utilities import titles, fix_url

secoora_models = ['SABGOM', 'USEAST', 'USF_ROMS',
                  'USF_SWAN', 'USF_FVCOM']

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the NGDC csw'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# NOTE: USEAST is not archived at the moment!
dap_urls = [fix_url(start, url) if 'SABGOM' in url else url for url in dap_urls]

# %%
from iris.exceptions import CoordinateNotFoundError, ConstraintMismatchError

from utilities import TimeoutException, secoora_buoys, get_cubes

urls = list(secoora_buoys())

buoys = dict()
for url in urls:
    try:
        cubes = get_cubes(url, name_list=name_list,
                                  bbox=bbox, time=(start, stop),
                                  units=iris.unit.Unit('g/kg'))
        buoy = url.split('/')[-1].split('.nc')[0]
        buoys.update({buoy: cubes[0]})
    except (RuntimeError, ValueError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()
sos_name = 'salinity'

collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:MetActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# #### Clean the dataframe (visualization purpose only)

# %%
from utilities import get_coops_longname, to_html

columns = {'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'sea_water_salinity (psu)': 'salinity'}

observations.rename(columns=columns, inplace=True)

observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>salinity</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Mayport (Bar Pilots Dock), FL</th>
#       <td> 8720218</td>
#       <td> SALINITY</td>
#       <td> 30.3967</td>
#       <td>-81.4300</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 24.084</td>
#     </tr>
#     <tr>
#       <th>I-295 Bridge, St Johns River, FL</th>
#       <td> 8720357</td>
#       <td> SALINITY</td>
#       <td> 30.1917</td>
#       <td>-81.6917</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td>  3.517</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from utilities import secoora2df
secoora_observations = secoora2df(buoys, 'salinity')
to_html(secoora_observations.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>salinity</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tolomato River station</th>
#       <td>   fldep.tolomatoriver.</td>
#       <td> NA</td>
#       <td> 29.994722</td>
#       <td>-81.329559</td>
#       <td> 2014-36-30T19:36:00Z</td>
#       <td> 32.974892</td>
#     </tr>
#     <tr>
#       <th>Shell Point station</th>
#       <td>     sccf.shellpoint.wq</td>
#       <td> NA</td>
#       <td> 26.522564</td>
#       <td>-82.007988</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 27.764133</td>
#     </tr>
#     <tr>
#       <th>Cherry Grove Pier, N. Myrtle Beach, SC</th>
#       <td> lbhmc.cherrygrove.pier</td>
#       <td> NA</td>
#       <td> 33.827492</td>
#       <td>-78.632004</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td>  5.505477</td>
#     </tr>
#     <tr>
#       <th>Gulf of Mexico station</th>
#       <td>   sccf.gulfofmexico.wq</td>
#       <td> NA</td>
#       <td> 26.443029</td>
#       <td>-81.971191</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 34.430565</td>
#     </tr>
#     <tr>
#       <th>Shell Point</th>
#       <td>         usf.shp.ngwlms</td>
#       <td> NA</td>
#       <td> 30.058001</td>
#       <td>-84.290001</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td>-99.000000</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
from pandas import concat


all_obs = concat([observations, secoora_observations], axis=0)

to_html(concat([all_obs.head(2), all_obs.tail(2)]), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>salinity</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Mayport (Bar Pilots Dock), FL</th>
#       <td>               8720218</td>
#       <td> SALINITY</td>
#       <td> 30.396700</td>
#       <td>-81.430000</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 24.084000</td>
#     </tr>
#     <tr>
#       <th>I-295 Bridge, St Johns River, FL</th>
#       <td>               8720357</td>
#       <td> SALINITY</td>
#       <td> 30.191700</td>
#       <td>-81.691700</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td>  3.517000</td>
#     </tr>
#     <tr>
#       <th>Tarpon Bay station</th>
#       <td>     sccf.tarponbay.wq</td>
#       <td>       NA</td>
#       <td> 26.467907</td>
#       <td>-82.063103</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td> 33.126770</td>
#     </tr>
#     <tr>
#       <th>Apache Pier, Myrtle Beach, SC</th>
#       <td> lbhmc.apachepier.pier</td>
#       <td>       NA</td>
#       <td> 33.761520</td>
#       <td>-78.779877</td>
#       <td> 2014-00-30T12:00:00Z</td>
#       <td>-35.251507</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Generate a uniform 6-min time base for model/data comparison

# %%
import iris
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
fname = os.path.join(run_name, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))
data = dict()
bad_station = []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'sea_water_salinity (psu)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_station.append(station)
        name = get_coops_longname(station)
        log.warning("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad stations.
pattern = '|'.join(bad_station)
if pattern:
    mask = observations.station.str.contains(pattern)
    bad_station = observations[mask]
    observations = observations[~mask]

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(obs_data.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8720218</th>
#       <th>8720357</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-06-30 12:00:00</th>
#       <td> 24.084</td>
#       <td> 3.517</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:06:00</th>
#       <td> 24.019</td>
#       <td> 3.527</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:12:00</th>
#       <td> 23.953</td>
#       <td> 3.522</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:18:00</th>
#       <td> 23.838</td>
#       <td> 3.512</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:24:00</th>
#       <td> 23.887</td>
#       <td> 3.490</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
import numpy as np
from pandas import DataFrame


def extract_series(cube, station):
    time = cube.coord(axis='T')
    date_time = time.units.num2date(cube.coord(axis='T').points)
    data = cube.data
    return DataFrame(data, columns=[station], index=date_time)


secoora_obs_data = []
for station, cube in list(buoys.items()):
    df = extract_series(cube, station)
    secoora_obs_data.append(df)

secoora_obs_data = concat(secoora_obs_data, axis=1)

# These buoys need some QA/QC!
mask = np.logical_or(secoora_obs_data < 0, secoora_obs_data > 40)
secoora_obs_data[mask] = np.NaN

# Interpolate to the same index as SOS data.
index = obs_data.index
kw = dict(method='time', limit=30)
secoora_obs_data = secoora_obs_data.reindex(index).interpolate(**kw).ix[index]

log.info(fmt(' SECOORA Observations '))
fname = '{:%Y-%m-%d}-SECOORA_OBS_DATA.nc'.format(stop)
fname = os.path.join(run_name, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))

url = "http://129.252.139.124/thredds/catalog_platforms.html"
comment = "Several stations {}".format(url)
kw = dict(longitude=secoora_observations.lon,
          latitude=secoora_observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(secoora_obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(secoora_obs_data.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fldep.tolomatoriver.</th>
#       <th>sccf.shellpoint.wq</th>
#       <th>lbhmc.cherrygrove.pier</th>
#       <th>sccf.gulfofmexico.wq</th>
#       <th>usf.shp.ngwlms</th>
#       <th>fldep.stlucieinlet.</th>
#       <th>sccf.redfishpass.wq</th>
#       <th>fau.lobo.1</th>
#       <th>cormp.ilm3.buoy</th>
#       <th>sccf.fortmyers.wq</th>
#       <th>cormp.ilm2.buoy</th>
#       <th>lbhmc.apachepier.pier</th>
#       <th>fldep.bingslanding.</th>
#       <th>sccf.tarponbay.wq</th>
#       <th>carocoops.sun2.buoy</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-06-30 12:00:00</th>
#       <td>NaN</td>
#       <td> 30.330000</td>
#       <td> 34.959999</td>
#       <td> 34.090000</td>
#       <td>NaN</td>
#       <td> 30.400000</td>
#       <td> 35.919998</td>
#       <td> 29.309999</td>
#       <td> 36.029999</td>
#       <td> 11.730000</td>
#       <td> 35.509998</td>
#       <td> 35.180000</td>
#       <td> 34.520000</td>
#       <td> 32.189999</td>
#       <td> 34.919998</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:06:00</th>
#       <td>NaN</td>
#       <td> 30.200001</td>
#       <td> 34.955997</td>
#       <td> 34.063000</td>
#       <td>NaN</td>
#       <td> 30.160000</td>
#       <td> 35.925999</td>
#       <td> 29.313000</td>
#       <td> 36.030998</td>
#       <td> 11.698999</td>
#       <td> 35.509998</td>
#       <td> 35.180668</td>
#       <td> 34.669998</td>
#       <td> 32.207001</td>
#       <td> 34.920998</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:12:00</th>
#       <td>NaN</td>
#       <td> 30.070000</td>
#       <td> 34.952000</td>
#       <td> 34.035999</td>
#       <td>NaN</td>
#       <td> 30.690001</td>
#       <td> 35.931999</td>
#       <td> 29.316000</td>
#       <td> 36.031998</td>
#       <td> 11.667999</td>
#       <td> 35.509998</td>
#       <td> 35.181332</td>
#       <td> 34.490002</td>
#       <td> 32.223999</td>
#       <td> 34.921997</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:18:00</th>
#       <td>NaN</td>
#       <td> 29.940001</td>
#       <td> 34.947998</td>
#       <td> 34.008999</td>
#       <td>NaN</td>
#       <td> 31.639999</td>
#       <td> 35.938000</td>
#       <td> 29.319000</td>
#       <td> 36.033001</td>
#       <td> 11.637000</td>
#       <td> 35.509998</td>
#       <td> 35.181999</td>
#       <td> 34.840000</td>
#       <td> 32.240997</td>
#       <td> 34.923000</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:24:00</th>
#       <td>NaN</td>
#       <td> 29.809999</td>
#       <td> 34.944000</td>
#       <td> 33.981998</td>
#       <td>NaN</td>
#       <td> 32.049999</td>
#       <td> 35.944000</td>
#       <td> 29.322001</td>
#       <td> 36.034000</td>
#       <td> 11.606000</td>
#       <td> 35.509998</td>
#       <td> 35.182667</td>
#       <td> 34.630001</td>
#       <td> 32.257999</td>
#       <td> 34.924000</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Loop discovered models and save the nearest time-series

# %%
import warnings
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                             MergeError)

from utilities import (TimeoutException, time_limit,
                        get_model_name, get_surface)


log.info(fmt(' Models '))
cubes = dict()

with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # Suppress iris warnings.
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                res = get_cubes(url, name_list=name_list,
                                bbox=bbox, time=(start, stop),
                                units=iris.unit.Unit('g/kg'))
                if len(res) == 1:
                    cube = res[0]
                else:
                    msg = "Two cubes found.  Expected just one.\n {!r}".format
                    raise ValueError(msg(res))
                # FIXME: Surface data only!
                cube = get_surface(cube)
            # FIXME: We Need a better way to identify model data.
            if cube.ndim > 1:
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
            else:
                log.warning('url {} is probably a timeSeries!'.format(url))
        except (TimeoutException, RuntimeError, ValueError, MergeError,
                ConstraintMismatchError, CoordinateNotFoundError,
                IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))
# Out:
# USF_ROMS
# COAWST_4
# HYCOM
# ESPRESSO

# %%
from iris.pandas import as_series

from utilities import (standardize_fill_value,
                       make_tree, get_nearest_water,
                       add_station, ensure_timeseries, remove_ssh)

for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(run_name, fname)
    log.info(fmt(' Downloading to file {} '.format(fname)))
    # NOTE: 2D coords KDtree.  (Iris can only do 1D coords KDtree for now.)
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot make KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in all_obs.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            # log.warning(e)
            status = "No Data"
            log.info('[{}] {}'.format(status, obs.name))
            continue
        if not series:
            status = "Land   "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water  "

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = standardize_fill_value(cube)
            cube = add_station(cube, station)
            cube = remove_ssh(cube)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info('Finished processing [{}]: {}\n'.format(mod_name, url))

# %% [markdown]
# ### Model skill

# %%
from utilities import load_secoora_ncs

dfs = load_secoora_ncs(run_name)

# %%
from utilities import pearsonr_paired


skills = dict()
for station, df in dfs.iteritems():
    skill = dict()
    try:
        obs = df.pop('OBS_DATA')
        for model, y in df.iteritems():
            r, p = pearsonr_paired(obs, y)
            if p > 0.01:
                r = np.NaN
            skill.update({model: r})
    except KeyError:  # All NaN data.
        for model, y in df.iteritems():
            skill.update({model: np.NaN})
            print(model)
    skills.update({station: skill})

df = DataFrame.from_dict(skills)

columns = dict()
for station in df.columns:
    sta_name = all_obs['station'][all_obs['station'] == station].index[0]
    columns.update({station: sta_name})

df.rename(columns=columns, inplace=True)

# %%
from utilities import to_html

fname = os.path.join(run_name, 'skill.html'.format(run_name))

df_skill = df.applymap('{:.2f}'.format).replace('nan', '--')

# FIXME: Abstract this out as a function.
with open(style, 'r') as f:
    css = """<style>{}</style>""".format(f.read())
    css_style = '{style}<div class="datagrid">{table}</div>'.format
    html_skill = dict(style=css, table=df_skill.T.to_html())
    html_skill = css_style(**html_skill)

with open(fname, 'w') as f:
    f.writelines(html_skill)


to_html(df_skill, style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Mayport (Bar Pilots Dock), FL</th>
#       <th>I-295 Bridge, St Johns River, FL</th>
#       <th>CAROCOOPS SUN2, Sunset Nearshore, NC</th>
#       <th>CORMP ILM2, Wrightsville Beach Nearshore, NC</th>
#       <th>CORMP ILM3, Wrightsville Beach Offshore, NC</th>
#       <th>fau_lobo_1</th>
#       <th>Bing&amp;#39;s Landing station</th>
#       <th>St Lucie Inlet station</th>
#       <th>Tolomato River station</th>
#       <th>Apache Pier, Myrtle Beach, SC</th>
#       <th>Cherry Grove Pier, N. Myrtle Beach, SC</th>
#       <th>Fort Myers station</th>
#       <th>Gulf of Mexico station</th>
#       <th>Redfish Pass station</th>
#       <th>Shell Point station</th>
#       <th>Tarpon Bay station</th>
#       <th>Shell Point</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>COAWST_4</th>
#       <td> --</td>
#       <td> --</td>
#       <td> -0.08</td>
#       <td>    --</td>
#       <td> 0.51</td>
#       <td> --</td>
#       <td> --</td>
#       <td> 0.07</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td>  0.10</td>
#       <td> 0.21</td>
#       <td> --</td>
#       <td>  0.37</td>
#       <td> --</td>
#     </tr>
#     <tr>
#       <th>HYCOM</th>
#       <td> --</td>
#       <td> --</td>
#       <td>  0.59</td>
#       <td>    --</td>
#       <td> 0.77</td>
#       <td> --</td>
#       <td> --</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td> --</td>
#       <td>    --</td>
#       <td> --</td>
#     </tr>
#     <tr>
#       <th>ROMS_TOMS</th>
#       <td> --</td>
#       <td> --</td>
#       <td> -0.21</td>
#       <td> -0.44</td>
#       <td> 0.18</td>
#       <td> --</td>
#       <td> --</td>
#       <td> 0.09</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td>    --</td>
#       <td> 0.19</td>
#       <td> --</td>
#       <td>  0.58</td>
#       <td> --</td>
#     </tr>
#     <tr>
#       <th>USF_ROMS</th>
#       <td> --</td>
#       <td> --</td>
#       <td>    --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> --</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> --</td>
#       <td> -0.42</td>
#       <td>   --</td>
#       <td> --</td>
#       <td> -0.21</td>
#       <td> --</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Map

# %%
from mpld3 import save_html
import matplotlib.pyplot as plt
from mpld3.plugins import LineLabelTooltip, connect

from utilities import inline_map, make_map

mapa = make_map(bbox, line=True, states=False)

# %% [markdown]
# ### ROMS stations files (SABGOM and USEAST)

# %%
roms_stations = [(-77.7866, 34.2133),
                 (-78.9183, 33.6550),
                 (-81.0000, 30.3966),
                 (-80.1600, 25.7300),
                 (-81.8116, 24.5550),
                 (-82.6137, 26.1300),
                 (-82.8320, 27.9770),
                 (-86.4987, 30.1520)]

for station in roms_stations:
    location = station[::-1]
    popup = '[SABGOM/USEAST]\nROMS station file'
    kw = dict(radius=700, fill_color='red', popup=popup,
              fill_opacity=0.75)
    mapa.circle_marker(location=location, **kw)

# %% [markdown]
# ### Clusters

# %%
from glob import glob
from operator import itemgetter


big_list = []
for fname in glob(os.path.join(run_name, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    cube = iris.load_cube(fname)
    model = fname.split('-')[-1].split('.')[0]
    lons = cube.coord(axis='X').points
    lats = cube.coord(axis='Y').points
    stations = cube.coord('station name').points
    models = [model]*lons.size
    lista = zip(models, lons.tolist(), lats.tolist(), stations.tolist())
    big_list.extend(lista)

big_list.sort(key=itemgetter(3))
df = DataFrame(big_list, columns=['name', 'lon', 'lat', 'station'])
df.set_index('station', drop=True, inplace=True)
groups = df.groupby(df.index)


for station, info in groups:
    sta_name = all_obs['station'][all_obs['station'] == station].index[0]
    for lat, lon, name in zip(info.lat, info.lon, info.name):
        location = lat, lon
        popup = '<b>{}</b>\n{}'.format(sta_name, name)
        mapa.simple_marker(location=location, popup=popup,
                           clustered_marker=True)

# %% [markdown]
# ### Model and observations plots

# %%
resolution, width, height = 75, 7, 3


def make_plot():
    fig, ax = plt.subplots(figsize=(width, height))
    ax.set_ylabel('Sea surface salinity (g/kg)')
    ax.grid(True)
    return fig, ax


dfs = load_secoora_ncs(run_name)

for station in dfs:
    sta_name = all_obs['station'][all_obs['station'] == station].index[0]
    df = dfs[station].dropna(axis=1, how='all')
    if df.empty:
        continue

    labels = []
    fig, ax = make_plot()
    for col in df.columns:
        serie = df[col].dropna()
        lines = ax.plot(serie.index, serie, label=col,
                        linewidth=2.5, alpha=0.5)
        if 'OBS_DATA' not in col:
            text0 = col
            text1 = df_skill[sta_name][col]
            tooltip = '{}: \nskill: {}'.format
            labels.append(tooltip(text0, text1))
        else:
            labels.append('OBS_DATA')
    kw = dict(loc='upper center', bbox_to_anchor=(0.5, 1.05), numpoints=1,
              ncol=2, framealpha=0)
    l = ax.legend(**kw)
    l.set_title("")  # Workaround str(None).

    [connect(fig, LineLabelTooltip(line, name))
     for line, name in zip(ax.lines, labels)]

    html = 'station_{}.html'.format(station)
    save_html(fig, '{}/{}'.format(run_name, html))
    plt.close(fig)

    popup = "<div align='center'> {} <br><iframe src='{}' alt='image'"
    popup += "width='{}px' height='{}px' frameBorder='0'></div>"
    popup = popup.format('{}'.format(sta_name), html,
                         (width*resolution)+75, (height*resolution)+50)
    kw = dict(popup=popup, width=(width*resolution)+75)

    if (df.columns == 'OBS_DATA').all():
        kw.update(dict(marker_color="blue", marker_icon="ok"))
    else:
        conj = set(df.columns)
        conj.intersection_update(secoora_models)
        if conj:
            kw.update(dict(marker_color="green", marker_icon="ok-sign"))
        else:
            kw.update(dict(marker_color="green", marker_icon="ok"))
    obs = all_obs[all_obs['station'] == station].squeeze()
    mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %% [markdown]
# ### Bad stations

# %%
if isinstance(bad_station, DataFrame):
    for station, obs in bad_station.iterrows():
        popup = '<b>Station:</b> {}'
        popup = popup.format(station)
        kw = dict(popup=popup, marker_color="red", marker_icon="question-sign")
        mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %%
mapa.create_map(path=os.path.join(run_name, 'mapa.html'))
inline_map(os.path.join(run_name, 'mapa.html'))
# Out:
#         <iframe
#             width="750"
#             height=500"
#             src="2014-07-07/mapa.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %matplotlib inline

import qrcode

qr = qrcode.QRCode(version=1,
                   error_correction=qrcode.constants.ERROR_CORRECT_L,
                   box_size=10,
                   border=4)

nbviewer = "http://nbviewer.ipython.org/github"
github = "ioos/secoora/blob/master"
local = os.path.abspath('00-salinity_secoora.ipynb').split('SECOORA')[1]
qr.add_data('{}/{}{}'.format(nbviewer, github, local))
qr.make(fit=True)

img = qr.make_image()
fig, ax = plt.subplots()
ax.imshow(img)
ax.axis('off')
title = ax.set_title("Notebook nbviewer link")

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

# %%
with open('{}/log.txt'.format(run_name)) as f:
    print(f.read())
# Out:
# 05:55:52 INFO: *********************** Run information ************************
# 05:55:52 INFO: Run date: 2015-02-11 20:55:52
# 05:55:52 INFO: Download start: 2014-06-30 12:00:00
# 05:55:52 INFO: Download stop: 2014-07-07 12:00:00
# 05:55:52 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 05:55:52 INFO: *********************** Software version ***********************
# 05:55:52 INFO: Iris version: 1.7.2-DEV
# 05:55:52 INFO: owslib version: 0.8-dev
# 05:55:52 INFO: pyoos version: 0.6.2
# 05:55:56 INFO: ********************* Catalog information **********************
# 05:55:56 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 05:55:56 INFO: CSW version: 2.0.2
# 05:55:56 INFO: Number of datasets available: 10
# 05:55:56 INFO: ***************************** CSW ******************************
# 05:55:56 INFO: USF FVCOM - Nowcast Aggregation
# 05:55:56 INFO: ROMS/TOMS 3.0 - New Floria Shelf Application
# 05:55:56 INFO: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# 05:55:56 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 05:55:56 INFO: ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# 05:55:56 INFO: HYbrid Coordinate Ocean Model (HYCOM): Global
# 05:55:56 INFO: National Data Buoy Center SOS
# 05:55:56 INFO: Aquarius Level 3 Sea Surface Salinity Standard Mapped Image Daily Data V3.0
# 05:55:56 INFO: Aquarius Level 3 Sea Surface Salinity Standard Mapped Image Monthly Data V3.0
# 05:55:56 INFO: Aquarius Level 3 Sea Surface Salinity Standard Mapped Image Weekly Data V3.0
# 05:55:56 INFO: ***************************** DAP ******************************
# 05:55:56 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# 05:55:56 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd.html
# 05:55:56 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 05:55:56 INFO: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# 05:55:56 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 05:55:56 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd.html
# 05:55:56 INFO: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Daily.nc.html
# 05:55:56 INFO: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Monthly.nc.html
# 05:55:56 INFO: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Weekly.nc.html
# 05:55:56 INFO: ***************************** SOS ******************************
# 05:55:56 INFO: http://sdf.ndbc.noaa.gov/sos/server.php?service=SOS&request=GetCapabilities&acceptVersions=1.0.0
# 05:55:56 WARNING: USEAST not in the NGDC csw
# 05:55:56 WARNING: USF_SWAN not in the NGDC csw
# 05:56:01 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1359: UserWarning: Failed to create 'time' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'time' auxiliary coordinate instead.
#   error=e_msg))
#
# 05:56:01 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fit.sispnj.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:56:06 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.nfb.ngwlms.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:56:10 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.tas.ngwlms.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:56:14 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.apk.ngwlms.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:56:18 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c21.weatherpak.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:56:29 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.bcp.ngwlms.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:56:33 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.fhp.ngwlms.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:56:37 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat.nc
# istart must be different from istop! Got istart 48233 and  istop 48233
# 05:56:40 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat.nc
# istart must be different from istop! Got istart 18711 and  istop 18711
# 05:56:43 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat.nc
# istart must be different from istop! Got istart 18099 and  istop 18099
# 05:56:50 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c10.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 05:57:12 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c12.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 05:57:28 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/usf.c13.mcat_2011.nc
# istart must be different from istop! Got istart 26303 and  istop 26303
# 05:57:34 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.frp2.buoy.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:57:38 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/carocoops.cap2.buoy.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:57:52 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.ilm1.buoy.nc
# istart must be different from istop! Got istart 1443 and  istop 1443
# 05:57:56 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/cormp.lej3.buoy.nc
# istart must be different from istop! Got istart 91490 and  istop 91490
# 05:57:58 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'dissolved_oxygen_saturation' invalid units 'mg_L-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:57:59 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'dissolved_oxygen' invalid units 'mg_L-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:57:59 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'cdom' invalid units 'QSDE'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:57:59 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'turbidity' invalid units 'ntu'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:57:59 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'conductivity' invalid units 'mS_cm-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:58:03 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nitrate' invalid units 'uM'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:58:17 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'conductivity_2' invalid units 'mS_cm-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:58:22 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.poncedeleonsouth..nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:58:28 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.redbaypoint..nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:58:37 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.naplesbay..nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:58:42 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.gordonriverinlet..nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:58:46 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.melbourne..nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:58:50 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.binneydock..nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:58:54 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/fldep.verobeach..nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:58:59 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/lbhmc.2ndave.pier.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:03 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'turbidity_2' invalid units 'ntu'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:59:03 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'dissolved_oxygen_2' invalid units 'mg_L-1'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 05:59:10 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wiwf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:13 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lbrf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:16 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bobf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:19 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.trrf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:23 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wwef1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:27 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lrif1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:30 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bwsf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:33 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.pkyf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:36 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lmdf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:40 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.cnbf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:43 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.hcef1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:46 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.jkyf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:50 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.wrbf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:53 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.gbif1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 05:59:57 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.ppta1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:00 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bdvf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:03 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lrkf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:06 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.bnkf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:10 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.gbtf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:13 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.tcvf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:16 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.canf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:19 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.lbsf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:23 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.mukf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:27 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.dkkf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:31 WARNING: Cannot get cube for: http://129.252.139.124/thredds/dodsC/enp.cwaf1.met.nc
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:00:47 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'phosphate' invalid units 'uM'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 06:00:47 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'photosynthetically_available_radiation' invalid units 'micromoles_per_m^2'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 06:00:56 INFO: ********************* Collector offerings **********************
# 06:00:56 INFO: NOAA.NOS.CO-OPS SOS: 1027 offerings
# 06:01:00 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-06-30T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AMetActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=salinity
# 06:02:03 INFO: ************************* Observations *************************
# 06:02:03 INFO: **** Downloading to file 2014-07-07/2014-07-07-OBS_DATA.nc *****
# 06:02:08 INFO: ********************* SECOORA Observations *********************
# 06:02:08 INFO:  Downloading to file 2014-07-07/2014-07-07-SECOORA_OBS_DATA.nc *
# 06:02:08 INFO: **************************** Models ****************************
# 06:02:08 INFO:
# [Reading url 1/11]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 06:07:09 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# Timed out!
# 06:07:09 INFO:
# [Reading url 2/11]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 06:07:20 INFO:
# [Reading url 3/11]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 06:07:45 INFO:
# [Reading url 4/11]: http://omgarch1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 06:08:00 INFO:
# [Reading url 5/11]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 06:08:03 INFO:
# [Reading url 6/11]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# 06:08:12 INFO:
# [Reading url 7/11]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Daily.nc
# 06:08:14 WARNING: Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Daily.nc
# istart must be different from istop! Got istart 992 and  istop 992
# 06:08:14 INFO:
# [Reading url 8/11]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Monthly.nc
# 06:08:16 WARNING: Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Monthly.nc
# istart must be different from istop! Got istart 35 and  istop 35
# 06:08:16 INFO:
# [Reading url 9/11]: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Weekly.nc
# 06:08:19 WARNING: Cannot get cube for: http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_SSS_Weekly.nc
# istart must be different from istop! Got istart 149 and  istop 149
# 06:08:19 INFO:
# [Reading url 10/11]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 06:08:33 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 06:08:33 INFO:
# [Reading url 11/11]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 06:08:34 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cube does not contain ['sea_water_salinity', 'sea_surface_salinity', 'sea_water_absolute_salinity', 'sea_water_practical_salinity']
# 06:08:34 INFO: **** Downloading to file 2014-07-07/2014-07-07-USF_ROMS.nc *****
# 06:08:34 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 06:08:34 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 06:08:34 INFO: [No Data] Tolomato River station
# 06:08:36 INFO: [Water  ] Shell Point station
# 06:08:36 INFO: [No Data] Cherry Grove Pier, N. Myrtle Beach, SC
# 06:08:38 INFO: [Water  ] Gulf of Mexico station
# 06:08:43 INFO: [Water  ] Shell Point
# 06:08:43 INFO: [No Data] St Lucie Inlet station
# 06:08:45 INFO: [Water  ] Redfish Pass station
# 06:08:45 INFO: [No Data] fau_lobo_1
# 06:08:45 INFO: [No Data] CORMP ILM3, Wrightsville Beach Offshore, NC
# 06:08:45 INFO: [No Data] Fort Myers station
# 06:08:45 INFO: [No Data] CAROCOOPS SUN2, Sunset Nearshore, NC
# 06:08:45 INFO: [No Data] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 06:08:45 INFO: [No Data] Bing&#39;s Landing station
# 06:08:47 INFO: [Water  ] Tarpon Bay station
# 06:08:47 INFO: [No Data] Apache Pier, Myrtle Beach, SC
# 06:09:10 INFO: Finished processing [USF_ROMS]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 06:09:10 INFO: **** Downloading to file 2014-07-07/2014-07-07-COAWST_4.nc *****
# 06:09:16 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 06:09:23 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 06:09:28 INFO: [Land   ] Tolomato River station
# 06:09:40 INFO: [Land   ] Shell Point station
# 06:09:45 INFO: [Land   ] Cherry Grove Pier, N. Myrtle Beach, SC
# 06:09:57 INFO: [Water  ] Gulf of Mexico station
# 06:10:03 INFO: [Land   ] Shell Point
# 06:10:14 INFO: [Water  ] St Lucie Inlet station
# 06:10:25 INFO: [Water  ] Redfish Pass station
# 06:10:31 INFO: [Land   ] fau_lobo_1
# 06:10:37 INFO: [Water  ] CORMP ILM3, Wrightsville Beach Offshore, NC
# 06:10:43 INFO: [Land   ] Fort Myers station
# 06:10:48 INFO: [Water  ] CAROCOOPS SUN2, Sunset Nearshore, NC
# 06:10:59 INFO: [Water  ] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 06:11:05 INFO: [Land   ] Bing&#39;s Landing station
# 06:11:11 INFO: [Water  ] Tarpon Bay station
# 06:11:16 INFO: [Land   ] Apache Pier, Myrtle Beach, SC
# 06:12:53 INFO: Finished processing [COAWST_4]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 06:12:53 INFO: **** Downloading to file 2014-07-07/2014-07-07-ESPRESSO.nc *****
# 06:12:53 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 06:12:53 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 06:12:53 INFO: [No Data] Tolomato River station
# 06:12:53 INFO: [No Data] Shell Point station
# 06:12:53 INFO: [No Data] Cherry Grove Pier, N. Myrtle Beach, SC
# 06:12:53 INFO: [No Data] Gulf of Mexico station
# 06:12:53 INFO: [No Data] Shell Point
# 06:12:53 INFO: [No Data] St Lucie Inlet station
# 06:12:53 INFO: [No Data] Redfish Pass station
# 06:12:53 INFO: [No Data] fau_lobo_1
# 06:12:53 INFO: [No Data] CORMP ILM3, Wrightsville Beach Offshore, NC
# 06:12:53 INFO: [No Data] Fort Myers station
# 06:12:53 INFO: [No Data] CAROCOOPS SUN2, Sunset Nearshore, NC
# 06:12:53 INFO: [No Data] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 06:12:53 INFO: [No Data] Bing&#39;s Landing station
# 06:12:53 INFO: [No Data] Tarpon Bay station
# 06:12:53 INFO: [No Data] Apache Pier, Myrtle Beach, SC
# 06:12:53 INFO: Finished processing [ESPRESSO]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 06:12:53 INFO: **** Downloading to file 2014-07-07/2014-07-07-ROMS_TOMS.nc ****
# 06:12:55 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 06:12:58 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 06:13:00 INFO: [Land   ] Tolomato River station
# 06:13:03 INFO: [Land   ] Shell Point station
# 06:13:05 INFO: [Land   ] Cherry Grove Pier, N. Myrtle Beach, SC
# 06:13:11 INFO: [Land   ] Gulf of Mexico station
# 06:13:13 INFO: [Land   ] Shell Point
# 06:13:18 INFO: [Water  ] St Lucie Inlet station
# 06:13:23 INFO: [Water  ] Redfish Pass station
# 06:13:26 INFO: [Land   ] fau_lobo_1
# 06:13:31 INFO: [Water  ] CORMP ILM3, Wrightsville Beach Offshore, NC
# 06:13:34 INFO: [Land   ] Fort Myers station
# 06:13:39 INFO: [Water  ] CAROCOOPS SUN2, Sunset Nearshore, NC
# 06:13:41 INFO: [Water  ] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 06:13:44 INFO: [Land   ] Bing&#39;s Landing station
# 06:13:47 INFO: [Water  ] Tarpon Bay station
# 06:13:49 INFO: [Land   ] Apache Pier, Myrtle Beach, SC
# 06:14:34 INFO: Finished processing [ROMS_TOMS]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 06:14:34 INFO: ****** Downloading to file 2014-07-07/2014-07-07-HYCOM.nc ******
# 06:14:37 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 06:14:40 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 06:14:44 INFO: [Land   ] Tolomato River station
# 06:14:46 INFO: [Land   ] Shell Point station
# 06:14:49 INFO: [Land   ] Cherry Grove Pier, N. Myrtle Beach, SC
# 06:14:52 INFO: [Land   ] Gulf of Mexico station
# 06:14:56 INFO: [Land   ] Shell Point
# 06:14:59 INFO: [Land   ] St Lucie Inlet station
# 06:15:02 INFO: [Land   ] Redfish Pass station
# 06:15:05 INFO: [Land   ] fau_lobo_1
# 06:15:08 INFO: [Water  ] CORMP ILM3, Wrightsville Beach Offshore, NC
# 06:15:08 INFO: [No Data] Fort Myers station
# 06:15:10 INFO: [Water  ] CAROCOOPS SUN2, Sunset Nearshore, NC
# 06:15:10 INFO: [No Data] CORMP ILM2, Wrightsville Beach Nearshore, NC
# 06:15:13 INFO: [Land   ] Bing&#39;s Landing station
# 06:15:15 INFO: [Land   ] Tarpon Bay station
# 06:15:18 INFO: [Land   ] Apache Pier, Myrtle Beach, SC
# 06:15:18 INFO: Finished processing [HYCOM]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
#
# 06:15:19 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
#
# 06:15:29 INFO: 19.65 minutes
# 06:15:29 INFO: EOF
