# %%
import os
import sys

root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(root)

# %%
from datetime import datetime, timedelta

bbox = [-87.4, 24.25, -74.7, 36.70]  # SECOORA: NC, SC GA, FL

time = datetime.utcnow() - timedelta(hours=6)

# %% [markdown]
# ### HF radar

# %%
from iris.unit import Unit
from utilities import get_cube

url = 'http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/6km/hourly/RTV'

u_name_list = ['x_sea_water_velocity',
               'sea_water_x_velocity',
               'eastward_sea_water_velocity',
               'surface_eastward_sea_water_velocity']

v_name_list = ['y_sea_water_velocity',
               'sea_water_y_velocity',
               'northward_sea_water_velocity',
               'surface_northward_sea_water_velocity']

u_cube = get_cube(url, name_list=u_name_list,
                  time=time, bbox=bbox, units=Unit('m s-1'))

v_cube = get_cube(url, name_list=v_name_list,
                  time=time, bbox=bbox, units=Unit('m s-1'))

# %%
import numpy as np

def subsample_cubes(u_cube, v_cube, n=6):
    """This is just for plotting.  If using cartopy do not
    subsample.  Use cartopy's resample instead."""
    u = u_cube[::n, ::n]
    v = v_cube[::n, ::n]
    lon = u.coord(axis='X').points
    lat = u.coord(axis='Y').points
    if (lon.ndim == 1) and (lat.ndim == 1):
        lon, lat = np.meshgrid(lon, lat)
    time = u.coord('time')
    time.units.num2date(time.points)
    return dict(lon=lon, lat=lat, u=u.data, v=v.data, time=time)


hf_radar = subsample_cubes(u_cube, v_cube, n=6)

# %% [markdown]
# ### SABGOM model

# %%
from utilities import get_roms


model_url = ('http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/'
             'SABGOM_Forecast_Model_Run_Collection_best.ncd')

model = get_roms(model_url, time, n=6)

# %%
import mplleaflet
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
kw = dict(scale=20, headwidth=2, alpha=0.5)

mask = ~hf_radar['u'].mask  # mplleaflet does not support masked array.

Q = ax.quiver(hf_radar['lon'][mask], hf_radar['lat'][mask],
              hf_radar['u'][mask], hf_radar['v'][mask], color='black', **kw)

mask = ~model['u'].mask

Q = ax.quiver(model['lon'][mask], model['lat'][mask],
              model['u'][mask], model['v'][mask], color='red', **kw)

mplleaflet.display(fig=ax.figure)
# Out:
# <head>
#   <link rel="stylesheet" href="http://cdn.leafletjs.com/leaflet-0.7.1/leaflet.css" />
#   <script src="http://cdn.leafletjs.com/leaflet-0.7.1/leaflet.js"></script>
#   <style>
#     .leaflet-container .leaflet-tile {
#        margin: 0;
#     }
#     #map7fa4eb5aeea242a09d9263af25954c87 {
#       height:480.0px;
#     }
#   </style>
# </head>
# <body>
#   <div id="map7fa4eb5aeea242a09d9263af25954c87"></div>
# <script text="text/javascript">
# func7fa4eb5aeea242a09d9263af25954c87 = function() {
# var map = L.map('map7fa4eb5aeea242a09d9263af25954c87');
# L.tileLayer(
#   "http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#   {maxZoom:19, attribution: '<a href="https://github.com/jwass/mplleaflet">mplleaflet</a> | Map data (c) <a href="http://openstreetmap.org">OpenStreetMap</a> contributors'}).addTo(map);
# var gjData = {"type": "FeatureCollection", "features": [{"geometry": {"type": "Point", "coordinates": [-80.054763793945341, 25.565700531005859]}, "type": "Feature", "properties": {"anchor_x": 10.025600091678188, "html": "<svg width=\"14px\" height=\"17px\" viewBox=\"-10.0256000917 -13.6087999838 14.0 17.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M -1.19040000043 0.843200018423 L -2.03360001886 -0.347199982012 L -2.38080000087 1.68640003685 L -8.43200018423 -11.9040000043 L 2.38080000087 -1.68640003685 L 0.347199982012 -2.03360001886 L 1.19040000043 -0.843200018423 L -1.19040000043 0.843200018423\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 13.608799983751595}}, {"geometry": {"type": "Point", "coordinates": [-79.706314086914091, 25.565700531005859]}, "type": "Feature", "properties": {"anchor_x": 14.034399728567919, "html": "<svg width=\"18px\" height=\"15px\" viewBox=\"-14.0343997286 -10.8976006535 18.0 15.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M -0.917600124846 1.19039997068 L -2.10800009553 0.272799845837 L -1.83520024969 2.38079994137 L -11.9039997068 -9.17600124846 L 1.83520024969 -2.38079994137 L -0.272799845837 -2.10800009553 L 0.917600124846 -1.19039997068 L -0.917600124846 1.19039997068\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 10.897600653545291}}, {"geometry": {"type": "Point", "coordinates": [-80.054763793945341, 25.889339447021484]}, "type": "Feature", "properties": {"anchor_x": 4.4843050149214623, "html": "<svg width=\"9px\" height=\"23px\" viewBox=\"-4.48430501492 -20.4039844366 9.0 23.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M -1.72909789754 -0.0480304241233 L -1.66537248834 -2.34214864361 L -3.44250081 -0.66108117019 L 0.495999226311 -17.8559992973 L 3.47389078016 -0.468959473697 L 1.79282330674 -2.24608779536 L 1.72909789754 0.0480304241233 L -1.72909789754 -0.0480304241233\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 20.403984436603835}}, {"geometry": {"type": "Point", "coordinates": [-79.706314086914091, 25.889339447021484]}, "type": "Feature", "properties": {"anchor_x": 4.0907311582394765, "html": "<svg width=\"9px\" height=\"49px\" viewBox=\"-4.09073115824 -43.7032626804 9.0 49.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M -1.72944091796 -0.0334729988066 L -1.28669907739 -22.9085030968 L -3.04961299416 -21.2125351776 L 0.743998829827 -38.4399983596 L 3.86815067768 -21.0786431824 L 2.17218275853 -22.8415570991 L 1.72944091796 0.0334729988066 L -1.72944091796 -0.0334729988066\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 43.703262680391404}}, {"geometry": {"type": "Point", "coordinates": [-79.357864379882841, 25.889339447021484]}, "type": "Feature", "properties": {"anchor_x": 4.0, "html": "<svg width=\"8px\" height=\"20px\" viewBox=\"-4.0 -17.7871994022 8.0 20.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M -1.56239989159 -0.0248000557975 L -1.5375998358 -1.58719994739 L -3.12479978319 -0.0496001115951 L 0.248000557975 -15.6239989159 L 3.12479978319 0.0496001115951 L 1.58719994739 -1.5375998358 L 1.56239989159 0.0248000557975 L -1.56239989159 -0.0248000557975\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 17.787199402171549}}, {"geometry": {"type": "Point", "coordinates": [-83.190826416015653, 26.212980270385742]}, "type": "Feature", "properties": {"anchor_x": 2.5, "html": "<svg width=\"5px\" height=\"4px\" viewBox=\"-2.5 -2.0 5.0 4.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M -1.72976486451 1.51220847275e-07 L -0.864882301293 1.49802039085 L 0.864882563215 1.4980202 ...
