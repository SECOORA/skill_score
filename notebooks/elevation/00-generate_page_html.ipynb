# %% [markdown]
# ### This notebook generates the weekly map and table HTMLs for the SECOORA web-page.

# %%
import iris
import pyoos
import owslib

import time
start_time = time.time()

# %%
import os
import sys

utilities_path = os.path.join(os.getcwd(), os.pardir)
root = os.path.abspath(utilities_path)
sys.path.append(root)

style = '../style.css'

# %% [markdown]
# ### SECOORA inundation notebook
# Based on IOOS system-test [notebook](http://nbviewer.ipython.org/github/ioos/system-test/blob/master/Theme_2_Extreme_Events/Scenario_2A/ModelDataCompare_Inundation/Water_Level_Signell.ipynb).

# %%
import pytz
from datetime import datetime, timedelta

from utilities import CF_names


# Choose the date range.
stop = datetime(2015, 1, 2, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = stop - timedelta(days=7)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names to look for (Sea Surface Height).
name_list = CF_names['water level']

# %%
directory = '{:%Y-%m-%d}'.format(stop)

if not os.path.exists(directory):
    os.makedirs(directory)

# %%
import logging as log
reload(log)

fmt = '{:*^64}'.format
log.captureWarnings(True)
LOG_FILENAME = 'log.txt'
LOG_FILENAME = os.path.join(directory, LOG_FILENAME)
log.basicConfig(filename=LOG_FILENAME,
                filemode='w',
                format='%(asctime)s %(levelname)s: %(message)s',
                datefmt='%I:%M:%S',
                level=log.INFO,
                stream=None)

log.info(fmt(' Run information '))
log.info('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
log.info('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
log.info('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
log.info('Bounding box: {0:3.2f}, {1:3.2f},'
         '{2:3.2f}, {3:3.2f}'.format(*bbox))
log.info(fmt(' Software version '))
log.info('Iris version: {}'.format(iris.__version__))
log.info('owslib version: {}'.format(owslib.__version__))
log.info('pyoos version: {}'.format(pyoos.__version__))

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW URLs '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' DAP URLs '))
for url in dap_urls:
    log.info('{}.html'.format(url))

log.info(fmt(' SOS URLs '))
for url in sos_urls:
    log.info('{}'.format(url))

# %%
# Force SABGOM and USEAST into the URL list.
from utilities import titles

secoora_models = ['SABGOM', 'USEAST', 'USF_ROMS', 'USF_SWAN', 'USF_FVCOM']

for secoora_model in  secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the catalog'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()
sos_name = 'water_surface_height_above_reference_datum'

datum = 'NAVD'
collector.set_datum(datum)
collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# #### Clean the dataframe (visualization purpose only)

# %%
from utilities import get_coops_longname, to_html

columns = {'datum_id': 'datum',
           'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': 'ssh above datum'}

observations.rename(columns=columns, inplace=True)

observations['datum'] = [s.split(':')[-1] for s in observations['datum']]
observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>ssh above datum</th>
#       <th>datum</th>
#       <th>height</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td> 8651370</td>
#       <td> A1</td>
#       <td> 36.1833</td>
#       <td>-75.7467</td>
#       <td> 2014-12-26T12:00:00Z</td>
#       <td> 0.318</td>
#       <td> MLLW</td>
#       <td> 5.663</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td> 8652587</td>
#       <td> A1</td>
#       <td> 35.7950</td>
#       <td>-75.5483</td>
#       <td> 2014-12-26T12:00:00Z</td>
#       <td> 0.223</td>
#       <td> MLLW</td>
#       <td> 0.788</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td> 8654467</td>
#       <td> A1</td>
#       <td> 35.2086</td>
#       <td>-75.7042</td>
#       <td> 2014-12-26T12:00:00Z</td>
#       <td> 0.258</td>
#       <td> MLLW</td>
#       <td> 8.345</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td> 8656483</td>
#       <td> A1</td>
#       <td> 34.7200</td>
#       <td>-76.6700</td>
#       <td> 2014-12-26T12:00:00Z</td>
#       <td> 0.380</td>
#       <td> MLLW</td>
#       <td> 0.562</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td> 8658120</td>
#       <td> A1</td>
#       <td> 34.2267</td>
#       <td>-77.9533</td>
#       <td> 2014-12-26T12:00:00Z</td>
#       <td>-0.024</td>
#       <td> MLLW</td>
#       <td> 0.747</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Generate a uniform 6-min time base for model/data comparison

# %%
import iris
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations (station data) '))
fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
fname = os.path.join(directory, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))
data = dict()
bad_datum = []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'water_surface_height_above_reference_datum (m)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_datum.append(station)
        name = get_coops_longname(station)
        log.warning("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad vertical datum stations.
pattern = '|'.join(bad_datum)
if pattern:
    non_navd = observations.station.str.contains(pattern)
    bad_datum = observations[non_navd]
    observations = observations[~non_navd]

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         datum=datum,
                         url=url))

save_timeseries(obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(obs_data.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8662245</th>
#       <th>8665530</th>
#       <th>8670870</th>
#       <th>8720030</th>
#       <th>8720219</th>
#       <th>8720226</th>
#       <th>8720357</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723214</th>
#       <th>8723970</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8726667</th>
#       <th>8726724</th>
#       <th>8727520</th>
#       <th>8728690</th>
#       <th>8729108</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-12-26 12:00:00</th>
#       <td>-0.349</td>
#       <td> 0.008</td>
#       <td>-0.249</td>
#       <td>-0.395</td>
#       <td>-0.547</td>
#       <td>-0.445</td>
#       <td>-0.777</td>
#       <td>-0.939</td>
#       <td>-0.690</td>
#       <td>-0.353</td>
#       <td>-0.064</td>
#       <td> 0.186</td>
#       <td>-0.505</td>
#       <td>-0.510</td>
#       <td>-0.516</td>
#       <td>-0.167</td>
#       <td>-0.457</td>
#       <td>-0.017</td>
#       <td>-0.183</td>
#       <td>-0.019</td>
#       <td>-0.381</td>
#       <td> 0.008</td>
#       <td> 0.144</td>
#       <td>-0.092</td>
#     </tr>
#     <tr>
#       <th>2014-12-26 12:06:00</th>
#       <td>-0.345</td>
#       <td> 0.008</td>
#       <td>-0.224</td>
#       <td>-0.347</td>
#       <td>-0.521</td>
#       <td>-0.400</td>
#       <td>-0.717</td>
#       <td>-0.902</td>
#       <td>-0.680</td>
#       <td>-0.356</td>
#       <td>-0.068</td>
#       <td> 0.177</td>
#       <td>-0.503</td>
#       <td>-0.482</td>
#       <td>-0.507</td>
#       <td>-0.178</td>
#       <td>-0.463</td>
#       <td>-0.023</td>
#       <td>-0.195</td>
#       <td>-0.035</td>
#       <td>-0.401</td>
#       <td>-0.014</td>
#       <td> 0.141</td>
#       <td>-0.103</td>
#     </tr>
#     <tr>
#       <th>2014-12-26 12:12:00</th>
#       <td>-0.321</td>
#       <td> 0.009</td>
#       <td>-0.166</td>
#       <td>-0.302</td>
#       <td>-0.490</td>
#       <td>-0.356</td>
#       <td>-0.665</td>
#       <td>-0.864</td>
#       <td>-0.670</td>
#       <td>-0.359</td>
#       <td>-0.070</td>
#       <td> 0.169</td>
#       <td>-0.487</td>
#       <td>-0.464</td>
#       <td>-0.494</td>
#       <td>-0.184</td>
#       <td>-0.478</td>
#       <td>-0.029</td>
#       <td>-0.210</td>
#       <td>-0.049</td>
#       <td>-0.417</td>
#       <td>-0.036</td>
#       <td> 0.139</td>
#       <td>-0.103</td>
#     </tr>
#     <tr>
#       <th>2014-12-26 12:18:00</th>
#       <td>-0.288</td>
#       <td> 0.013</td>
#       <td>-0.132</td>
#       <td>-0.248</td>
#       <td>-0.456</td>
#       <td>-0.314</td>
#       <td>-0.611</td>
#       <td>-0.821</td>
#       <td>-0.640</td>
#       <td>-0.361</td>
#       <td>-0.070</td>
#       <td> 0.161</td>
#       <td>-0.478</td>
#       <td>-0.428</td>
#       <td>-0.485</td>
#       <td>-0.192</td>
#       <td>-0.490</td>
#       <td>-0.036</td>
#       <td>-0.226</td>
#       <td>-0.065</td>
#       <td>-0.429</td>
#       <td>-0.059</td>
#       <td> 0.134</td>
#       <td>-0.107</td>
#     </tr>
#     <tr>
#       <th>2014-12-26 12:24:00</th>
#       <td>-0.262</td>
#       <td> 0.016</td>
#       <td>-0.103</td>
#       <td>-0.191</td>
#       <td>-0.424</td>
#       <td>-0.272</td>
#       <td>-0.557</td>
#       <td>-0.785</td>
#       <td>-0.643</td>
#       <td>-0.361</td>
#       <td>-0.073</td>
#       <td> 0.154</td>
#       <td>-0.416</td>
#       <td>-0.405</td>
#       <td>-0.475</td>
#       <td>-0.199</td>
#       <td>-0.525</td>
#       <td>-0.042</td>
#       <td>-0.240</td>
#       <td>-0.081</td>
#       <td>-0.447</td>
#       <td>-0.084</td>
#       <td> 0.130</td>
#       <td>-0.112</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Loop discovered models and save the nearest time-series

# %%
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                             MergeError)

from utilities import TimeoutException, time_limit, get_cube, get_model_name

# FIXME: Filtering bad URLs.
dap_urls = [link for link in dap_urls
            if 'NECOFS' not in link]  # Cartesian coords are not implemented.

log.info(fmt(' Models (simulated data) '))
cubes = dict()
for k, url in enumerate(dap_urls):
    log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
    try:
        with time_limit(60*5):
            cube = get_cube(url, name_list=name_list,
                            bbox=bbox, time=(start, stop),
                            units=iris.unit.Unit('meters'))
        # TODO: Need a better way to identify model data and observed data.
        if cube.ndim > 1:
            mod_name, model_full_name = get_model_name(cube, url)
            cubes.update({mod_name: cube})
        else:
            log.warning('url {} is probably a timeSeries!'.format(url))
    except (RuntimeError, ValueError, MergeError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from iris.pandas import as_series

from utilities import (standardize_fill_value,
                       make_tree, get_nearest_water,
                       add_station, ensure_timeseries)


for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(directory, fname)
    log.info(fmt(' Saving to file {} '.format(fname)))
    # NOTE: 2D coords KDtree.  (Iris can only do 1D coords KDtree for now.)
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot make KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in observations.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            log.warning(e)
            continue
        if not series:
            status = "Found Land"
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Found Water"

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = standardize_fill_value(cube)
            cube = add_station(cube, station)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info('Finished processing [{}]: {}'.format(mod_name, url))

# %% [markdown]
# #### Load saved files and interpolate to the observations time interval

# %%
from glob import glob
from operator import itemgetter

from pandas import Panel
from utilities import nc2df

fname = '{}-OBS_DATA.nc'.format(directory)
fname = os.path.join(directory, fname)
OBS_DATA = nc2df(fname)
index = OBS_DATA.index

dfs = dict(OBS_DATA=OBS_DATA)
for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    else:
        model = fname.split('.')[0].split('-')[-1]
        df = nc2df(fname)
        if model == 'USF_FVCOM':
            # FIXME: Horrible work around duplicate times in USF FVCOM.
            df = df.reset_index().drop_duplicates(cols='index', take_last=True).set_index('index')
        kw = dict(method='time', limit=30)
        df = df.reindex(index).interpolate(**kw).ix[index]
        dfs.update({model: df})

dfs = Panel.fromDict(dfs).swapaxes(0, 2)

# Clusters.
big_list = []
for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    nc = iris.load_cube(fname)
    model = fname.split('-')[-1].split('.')[0]
    lons = nc.coord(axis='X').points
    lats = nc.coord(axis='Y').points
    stations = nc.coord('station name').points
    models = [model]*lons.size
    lista = zip(models, lons.tolist(), lats.tolist(), stations.tolist())
    big_list.extend(lista)

big_list.sort(key=itemgetter(3))
df = DataFrame(big_list, columns=['name', 'lon', 'lat', 'station'])
df.set_index('station', drop=True, inplace=True)
groups = df.groupby(df.index)

# %%
import vincent
from utilities import inline_map, make_map

ssh = make_map(bbox, line=True, states=False)

# ROMS stations files (SABGOM and USEAST?).
roms_stations = [(-77.7866, 34.2133),
                 (-78.9183, 33.6550),
                 (-81.0000, 30.3966),
                 (-80.1600, 25.7300),
                 (-81.8116, 24.5550),
                 (-82.6137, 26.1300),
                 (-82.8320, 27.9770),
                 (-86.4987, 30.1520)]

for station in roms_stations:
    location = station[::-1]
    popup = '[SABGOM/USEAST]\nROMS station file'
    kw = dict(radius=700, fill_color='red', popup=popup,
              fill_opacity=0.75)
    ssh.circle_marker(location=location, **kw)


# Clusters.
for station, info in groups:
    station = get_coops_longname(station)
    for lat, lon, name in zip(info.lat, info.lon, info.name):
        location = lat, lon
        popup = '<b>{}</b>\n{}'.format(station, name)
        ssh.simple_marker(location=location, popup=popup,
                          clustered_marker=True)

# Model and observations.
for station in dfs:
    sta_name = get_coops_longname(station)
    df = dfs[station].dropna(axis=1, how='all')
    # FIXME: This is bad!  But I cannot represent NaN with Vega!
    df.fillna(value='null', inplace=True)
    vis = vincent.Line(df, width=500, height=150)
    vis.axis_titles(x='Time', y='Sea surface height (m)')
    vis.legend(title=sta_name)
    vis.name = sta_name
    json = 'station_{}.json'.format(station)
    vis.to_json(os.path.join(directory, json))
    obs = observations[observations['station'] == station].squeeze()
    popup = (vis, json)
    if (df.columns == 'OBS_DATA').all():
        kw = dict(popup=popup, marker_color="blue", marker_icon="ok")
    else:
        conj = set(df.columns)
        conj.intersection_update(secoora_models)
        if conj:
            kw = dict(popup=popup, marker_color="green", marker_icon="ok-sign")
        else:
            kw = dict(popup=popup, marker_color="green", marker_icon="ok")
    ssh.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# Bad datum.
if isinstance(bad_datum, DataFrame):
    for station, obs in bad_datum.iterrows():
        popup = '<b>Station:</b> {}<br><b>Datum:</b> {}<br>'
        popup = popup.format(station, obs['datum'])
        kw = dict(popup=popup, marker_color="red", marker_icon="question-sign")
        ssh.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %%
ssh.create_map(path=os.path.join(directory, 'ssh.html'))
inline_map(os.path.join(directory, 'ssh.html'))
# Out:
#         <iframe
#             width="750"
#             height=500"
#             src="2015-01-02/ssh.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Compute bias

# %%
from utilities import nc2df

fname = '{}-OBS_DATA.nc'.format(directory)
fname = os.path.join(directory, fname)

OBS_DATA = nc2df(fname)
index = OBS_DATA.index

# %%
from glob import glob
from pandas import Panel

dfs = dict(OBS_DATA=OBS_DATA)
for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        pass
    else:
        model = fname.split('.')[0].split('-')[-1]
        df = nc2df(fname)
        if model == 'USF_FVCOM':
            # FIXME: Horrible work around duplicate times in USF FVCOM.
            df = df.reset_index().drop_duplicates(cols='index', take_last=True).set_index('index')
        if False:
            kw = dict(method='time')
            df = df.reindex(index).interpolate(**kw).ix[index]
        dfs.update({model: df})

dfs = Panel.fromDict(dfs).swapaxes(0, 2)

# %%
from pandas import DataFrame

means = dict()
for station, df in dfs.iteritems():
    df.dropna(axis=1, how='all', inplace=True)
    mean = df.mean()
    df = df - mean + mean['OBS_DATA']
    means.update({station: mean['OBS_DATA'] - mean.drop('OBS_DATA')})

bias = DataFrame.from_dict(means).dropna(axis=1, how='all')
bias = bias.applymap('{:.2f}'.format).replace('nan', '--')

columns = dict()
[columns.update({station: get_coops_longname(station)}) for
 station in bias.columns.values]

bias.rename(columns=columns, inplace=True)

# %%
fname = os.path.join(directory, 'bias.html'.format(directory))

with open(style, 'r') as f:
    css = """<style>{}</style>""".format(f.read())
    table = dict(style=css, table=bias.T.to_html())
    table = '{style}<div class="datagrid">{table}</div>'.format(**table)

with open(fname, 'w') as f:
    f.writelines(table)

to_html(bias.T, style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>COAWST_4</th>
#       <th>ESPRESSO</th>
#       <th>ESTOFS</th>
#       <th>USEAST</th>
#       <th>USF_FVCOM</th>
#       <th>USF_ROMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.03</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>  0.16</td>
#       <td> 0.34</td>
#       <td>  0.12</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Wrightsville Beach, NC</th>
#       <td> -0.03</td>
#       <td>   --</td>
#       <td> -0.04</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Springmaid Pier, SC</th>
#       <td>  0.01</td>
#       <td>   --</td>
#       <td>  0.02</td>
#       <td> 0.47</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oyster Landing (N Inlet Estuary), SC</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td>  0.11</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Fort Pulaski, GA</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.15</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Fernandina Beach, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.05</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Trident Pier, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.14</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Lake Worth Pier, FL</th>
#       <td> -0.24</td>
#       <td>   --</td>
#       <td> -0.14</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Virginia Key, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.17</td>
#       <td> 0.10</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Vaca Key, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.15</td>
#       <td>   --</td>
#       <td> 0.05</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Naples, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.14</td>
#       <td>   --</td>
#       <td> 0.03</td>
#       <td> 0.01</td>
#     </tr>
#     <tr>
#       <th>Fort Myers, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td> 0.06</td>
#       <td> 0.16</td>
#     </tr>
#     <tr>
#       <th>Port Manatee, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.08</td>
#       <td>   --</td>
#       <td> 0.07</td>
#       <td> 0.21</td>
#     </tr>
#     <tr>
#       <th>Mckay Bay Entrance, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.05</td>
#       <td>   --</td>
#       <td> 0.09</td>
#       <td> 0.18</td>
#     </tr>
#     <tr>
#       <th>Clearwater Beach, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.03</td>
#       <td>   --</td>
#       <td> 0.11</td>
#       <td> 0.18</td>
#     </tr>
#     <tr>
#       <th>Cedar Key, FL</th>
#       <td> -0.07</td>
#       <td>   --</td>
#       <td> -0.03</td>
#       <td> 0.31</td>
#       <td> 0.11</td>
#       <td> 0.21</td>
#     </tr>
#     <tr>
#       <th>Apalachicola, FL</th>
#       <td>  0.02</td>
#       <td>   --</td>
#       <td>  0.06</td>
#       <td>   --</td>
#       <td> 0.21</td>
#       <td> 0.26</td>
#     </tr>
#     <tr>
#       <th>Panama City, FL</th>
#       <td> -0.00</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.37</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

# %%
with open('2015-01-02/log.txt') as f:
    print(f.read())
# Out:
# 03:43:59 INFO: *********************** Run information ************************
# 03:43:59 INFO: Run date: 2015-01-08 18:43:59
# 03:43:59 INFO: Download start: 2014-12-26 12:00:00
# 03:43:59 INFO: Download stop: 2015-01-02 12:00:00
# 03:43:59 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 03:43:59 INFO: *********************** Software version ***********************
# 03:43:59 INFO: Iris version: 1.7.2-DEV
# 03:43:59 INFO: owslib version: 0.8.9
# 03:43:59 INFO: pyoos version: 0.6.1
# 03:44:02 INFO: ********************* Catalog information **********************
# 03:44:02 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 03:44:02 INFO: CSW version: 2.0.2
# 03:44:02 INFO: Number of datasets available: 8
# 03:44:02 INFO: *************************** CSW URLs ***************************
# 03:44:02 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 03:44:02 INFO: ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# 03:44:02 INFO: Barotropic Tide Model for the Pacific Basin
# 03:44:02 INFO: TBOFS - Tampa Bay Operational Forecast System - NOAA CO-OPS - POM
# 03:44:02 INFO: HYbrid Coordinate Ocean Model (HYCOM): Global
# 03:44:02 INFO: CBOFS - Chesapeake Bay Operational Forecast System - NOAA CO-OPS - POM
# 03:44:02 INFO: ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC
# 03:44:02 INFO: NECOFS GOM3 (FVCOM) - Northeast US - Latest Forecast
# 03:44:02 INFO: *************************** DAP URLs ***************************
# 03:44:02 INFO: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic.html
# 03:44:02 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 03:44:02 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac.html
# 03:44:02 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 03:44:02 INFO: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd.html
# 03:44:02 INFO: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd.html
# 03:44:02 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd.html
# 03:44:02 INFO: http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_GOM3_FORECAST.nc.html
# 03:44:02 INFO: *************************** SOS URLs ***************************
# 03:44:02 WARNING: SABGOM not in the catalog
# 03:44:02 WARNING: USEAST not in the catalog
# 03:44:02 WARNING: USF_ROMS not in the catalog
# 03:44:02 WARNING: USF_SWAN not in the catalog
# 03:44:02 WARNING: USF_FVCOM not in the catalog
# 03:44:07 INFO: ********************* Collector offerings **********************
# 03:44:07 INFO: NOAA.NOS.CO-OPS SOS: 1024 offerings
# 03:44:10 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-12-26T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AWaterLevelActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=water_surface_height_above_reference_datum
# 03:44:29 INFO: ***************** Observations (station data) ******************
# 03:44:29 INFO: **** Downloading to file 2015-01-02/2015-01-02-OBS_DATA.nc *****
# 03:44:36 WARNING: [8654467] USCG Station Hatteras, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:44:39 WARNING: [8656483] Beaufort, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:44:40 WARNING: [8658120] Wilmington, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:45:20 WARNING: [8726520] St Petersburg, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:45:21 WARNING: [8726607] Old Port Tampa, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:45:36 WARNING: [8729210] Panama City Beach, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 03:45:36 INFO: ******************* Models (simulated data) ********************
# 03:45:36 INFO:
# [Reading url 1/12]: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# 03:45:37 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nbdv' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:45:37 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'neta' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:45:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'ibtypee' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:45:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nvell' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:45:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'ibtype' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:45:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nbvv' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:45:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nvel' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:45:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'nvdll' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:46:05 INFO:
# [Reading url 2/12]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 03:46:08 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'v' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
#
# 03:46:08 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'v' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
#
# 03:46:09 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'u' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
#
# 03:46:09 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'u' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
#
# 03:46:11 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1291: UserWarning: Gracefully filling 'time' dimension coordinate masked points
#   warnings.warn(msg.format(str(cf_coord_var.cf_name)))
#
# 03:46:29 INFO:
# [Reading url 3/12]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# 03:46:33 WARNING: Cannot get cube for: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# The points array must be strictly monotonic.
# 03:46:33 INFO:
# [Reading url 4/12]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 03:46:36 WARNING: Cannot get cube for: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# The points array must be strictly monotonic.
# 03:46:36 INFO:
# [Reading url 5/12]: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd
# 03:46:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'Cs_w' via variable u's_w': Dimensions (u'eta_rho', u'xi_rho') do not span (u's_w',)
#   warnings.warn(msg)
#
# 03:46:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'Cs_w' via variable u's_w': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u's_w',)
#   warnings.warn(msg)
#
# 03:46:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'Cs_r' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u's_rho',)
#   warnings.warn(msg)
#
# 03:46:38 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1038: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'Cs_r' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u's_rho',)
#   warnings.warn(msg)
#
# 03:46:46 WARNING: Cannot get cube for: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/CBOFS/fmrc/Aggregated_7_day_CBOFS_Fields_Forecast_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 03:46:46 INFO:
# [Reading url 6/12]: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd
# 03:46:54 WARNING: Cannot get cube for: http://opendap.co-ops.nos.noaa.gov/thredds/dodsC/TBOFS/fmrc/Aggregated_7_day_TBOFS_Fields_Forecast_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 03:46:54 INFO:
# [Reading url 7/12]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# 03:47:02 INFO:
# [Reading url 8/12]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 03:47:04 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'chlorophyll' invalid units 'milligrams_chlorophyll meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:04 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'phytoplankton' invalid units 'millimole_nitrogen meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:04 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'NO3' invalid units 'millimole_N03 meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:04 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'zooplankton' invalid units 'millimole_nitrogen meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:04 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'NH4' invalid units 'millimole_NH4 meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:12 INFO:
# [Reading url 9/12]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 03:47:23 INFO:
# [Reading url 10/12]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 03:47:24 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'Cs_r' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:24 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 's_rho' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:24 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'Cs_w' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:24 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 's_w' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:24 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'salt' invalid units 'PSU'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:27 INFO:
# [Reading url 11/12]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 03:47:27 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'Itime2' invalid units 'msec since 00:00:00'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:27 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cube does not contain ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
# 03:47:27 INFO:
# [Reading url 12/12]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:47:28 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'lat' referenced by variable u'hc': Dimensions (u'node',) do not span (u'nele',)
#   warnings.warn(msg)
#
# 03:47:28 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'lon' referenced by variable u'hc': Dimensions (u'node',) do not span (u'nele',)
#   warnings.warn(msg)
#
# 03:47:28 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'siglay' referenced by variable u'u': Dimensions (u'siglay', u'node') do not span (u'time', u'siglay', u'nele')
#   warnings.warn(msg)
#
# 03:47:28 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/cf.py:1004: UserWarning: Ignoring variable u'siglay' referenced by variable u'v': Dimensions (u'siglay', u'node') do not span (u'time', u'siglay', u'nele')
#   warnings.warn(msg)
#
# 03:47:29 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1359: UserWarning: Failed to create 'time' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'time' auxiliary coordinate instead.
#   error=e_msg))
#
# 03:47:29 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'Itime2' invalid units 'msecs since 00:00:00'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 03:47:36 INFO: ******** Saving to file 2015-01-02/2015-01-02-ESTOFS.nc ********
# 03:47:41 INFO: [Found Water] Duck, NC
# 03:47:43 INFO: [Found Water] Oregon Inlet Marina, NC
# 03:47:50 INFO: [Found Water] Wrightsville Beach, NC
# 03:47:59 INFO: [Found Water] Springmaid Pier, SC
# 03:48:01 INFO: [Found Water] Oyster Landing (N Inlet Estuary), SC
# 03:48:01 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 03:48:04 INFO: [Found Water] Fort Pulaski, GA
# 03:48:05 INFO: [Found Water] Fernandina Beach, FL
# 03:48:05 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 03:48:05 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 03:48:05 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 03:48:05 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 03:48:09 INFO: [Found Water] Trident Pier, FL
# 03:48:13 INFO: [Found Water] Lake Worth Pier, FL
# 03:48:20 INFO: [Found Water] Virginia Key, FL
# 03:48:30 INFO: [Found Water] Vaca Key, FL
# 03:48:36 INFO: [Found Water] Naples, FL
# 03:48:36 WARNING: No data found for (-81.8712,26.6477) using max_dist=0.04.
# 03:48:46 INFO: [Found Water] Port Manatee, FL
# 03:48:50 INFO: [Found Water] Mckay Bay Entrance, FL
# 03:48:57 INFO: [Found Water] Clearwater Beach, FL
# 03:49:07 INFO: [Found Water] Cedar Key, FL
# 03:49:15 INFO: [Found Water] Apalachicola, FL
# 03:49:15 WARNING: No data found for (-85.6669,30.1523) using max_dist=0.04.
# 03:49:15 INFO: Finished processing [ESTOFS]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:49:15 INFO: ******** Saving to file 2015-01-02/2015-01-02-SABGOM.nc ********
# 03:49:17 INFO: [Found Land] Duck, NC
# 03:49:19 INFO: [Found Land] Oregon Inlet Marina, NC
# 03:49:21 INFO: [Found Land] Wrightsville Beach, NC
# 03:49:23 INFO: [Found Land] Springmaid Pier, SC
# 03:49:25 INFO: [Found Land] Oyster Landing (N Inlet Estuary), SC
# 03:49:27 INFO: [Found Land] Charleston, SC
# 03:49:29 INFO: [Found Land] Fort Pulaski, GA
# 03:49:31 INFO: [Found Land] Fernandina Beach, FL
# 03:49:33 INFO: [Found Land] Dames Point, FL
# 03:49:35 INFO: [Found Land] Southbank Riverwalk, St Johns River, FL
# 03:49:37 INFO: [Found Land] I-295 Bridge, St Johns River, FL
# 03:49:39 INFO: [Found Land] Racy Point, St Johns River, FL
# 03:49:41 INFO: [Found Land] Trident Pier, FL
# 03:49:43 INFO: [Found Land] Lake Worth Pier, FL
# 03:49:45 INFO: [Found Land] Virginia Key, FL
# 03:49:47 INFO: [Found Land] Vaca Key, FL
# 03:49:49 INFO: [Found Land] Naples, FL
# 03:49:51 INFO: [Found Land] Fort Myers, FL
# 03:49:53 INFO: [Found Land] Port Manatee, FL
# 03:49:55 INFO: [Found Land] Mckay Bay Entrance, FL
# 03:49:57 INFO: [Found Land] Clearwater Beach, FL
# 03:49:59 INFO: [Found Land] Cedar Key, FL
# 03:50:01 INFO: [Found Land] Apalachicola, FL
# 03:50:03 INFO: [Found Land] Panama City, FL
# 03:50:03 INFO: Finished processing [SABGOM]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:50:03 INFO: ******* Saving to file 2015-01-02/2015-01-02-USF_ROMS.nc *******
# 03:50:03 WARNING: No data found for (-75.7467,36.1833) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-75.5483,35.795) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-77.7867,34.2133) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-78.9183,33.655) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-79.1867,33.3517) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-80.9017,32.0333) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-81.465,30.6717) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-80.5931,28.4158) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-80.0333,26.6117) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-80.1618,25.7314) using max_dist=0.04.
# 03:50:03 WARNING: No data found for (-81.105,24.7117) using max_dist=0.04.
# 03:50:04 INFO: [Found Water] Naples, FL
# 03:50:05 INFO: [Found Water] Fort Myers, FL
# 03:50:07 INFO: [Found Water] Port Manatee, FL
# 03:50:08 INFO: [Found Water] Mckay Bay Entrance, FL
# 03:50:09 INFO: [Found Water] Clearwater Beach, FL
# 03:50:12 INFO: [Found Water] Cedar Key, FL
# 03:50:14 INFO: [Found Water] Apalachicola, FL
# 03:50:16 INFO: [Found Water] Panama City, FL
# 03:50:24 INFO: Finished processing [USF_ROMS]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:50:24 INFO: ****** Saving to file 2015-01-02/2015-01-02-USF_FVCOM.nc *******
# 03:50:24 WARNING: No data found for (-75.7467,36.1833) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-75.5483,35.795) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-77.7867,34.2133) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-78.9183,33.655) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-79.1867,33.3517) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-80.9017,32.0333) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-81.465,30.6717) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-80.5931,28.4158) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-80.0333,26.6117) using max_dist=0.04.
# 03:50:24 WARNING: No data found for (-80.1618,25.7314) using max_dist=0.04.
# 03:50:32 INFO: [Found Water] Vaca Key, FL
# 03:50:41 INFO: [Found Water] Naples, FL
# 03:50:49 INFO: [Found Water] Fort Myers, FL
# 03:50:57 INFO: [Found Water] Port Manatee, FL
# 03:51:05 INFO: [Found Water] Mckay Bay Entrance, FL
# 03:51:14 INFO: [Found Water] Clearwater Beach, FL
# 03:51:17 INFO: [Found Water] Cedar Key, FL
# 03:51:25 INFO: [Found Water] Apalachicola, FL
# 03:51:25 WARNING: No data found for (-85.6669,30.1523) using max_dist=0.04.
# 03:51:25 INFO: Finished processing [USF_FVCOM]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:51:25 INFO: ******* Saving to file 2015-01-02/2015-01-02-COAWST_4.nc *******
# 03:51:33 INFO: [Found Land] Duck, NC
# 03:51:45 INFO: [Found Water] Oregon Inlet Marina, NC
# 03:51:52 INFO: [Found Water] Wrightsville Beach, NC
# 03:52:02 INFO: [Found Water] Springmaid Pier, SC
# 03:52:07 INFO: [Found Land] Oyster Landing (N Inlet Estuary), SC
# 03:52:12 INFO: [Found Land] Charleston, SC
# 03:52:18 INFO: [Found Land] Fort Pulaski, GA
# 03:52:23 INFO: [Found Land] Fernandina Beach, FL
# 03:52:28 INFO: [Found Land] Dames Point, FL
# 03:52:33 INFO: [Found Land] Southbank Riverwalk, St Johns River, FL
# 03:52:38 INFO: [Found Land] I-295 Bridge, St Johns River, FL
# 03:52:43 INFO: [Found Land] Racy Point, St Johns River, FL
# 03:52:48 INFO: [Found Land] Trident Pier, FL
# 03:52:58 INFO: [Found Water] Lake Worth Pier, FL
# 03:53:04 INFO: [Found Land] Virginia Key, FL
# 03:53:09 INFO: [Found Land] Vaca Key, FL
# 03:53:14 INFO: [Found Land] Naples, FL
# 03:53:20 INFO: [Found Land] Fort Myers, FL
# 03:53:25 INFO: [Found Land] Port Manatee, FL
# 03:53:31 INFO: [Found Land] Mckay Bay Entrance, FL
# 03:53:36 INFO: [Found Land] Clearwater Beach, FL
# 03:53:46 INFO: [Found Water] Cedar Key, FL
# 03:53:51 INFO: [Found Water] Apalachicola, FL
# 03:53:56 INFO: [Found Water] Panama City, FL
# 03:54:36 INFO: Finished processing [COAWST_4]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:54:36 INFO: ******* Saving to file 2015-01-02/2015-01-02-ESPRESSO.nc *******
# 03:54:39 INFO: [Found Land] Duck, NC
# 03:54:41 INFO: [Found Water] Oregon Inlet Marina, NC
# 03:54:41 WARNING: No data found for (-77.7867,34.2133) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-78.9183,33.655) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-79.1867,33.3517) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-80.9017,32.0333) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.465,30.6717) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-80.5931,28.4158) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-80.0333,26.6117) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-80.1618,25.7314) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.105,24.7117) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.8075,26.1317) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-81.8712,26.6477) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-82.5621,27.6387) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-82.425,27.9133) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-82.8317,27.9783) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-83.0317,29.135) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-84.9817,29.7267) using max_dist=0.04.
# 03:54:41 WARNING: No data found for (-85.6669,30.1523) using max_dist=0.04.
# 03:54:43 INFO: Finished processing [ESPRESSO]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:54:43 INFO: ******** Saving to file 2015-01-02/2015-01-02-USEAST.nc ********
# 03:54:43 WARNING: No data found for (-75.7467,36.1833) using max_dist=0.04.
# 03:54:43 WARNING: No data found for (-75.5483,35.795) using max_dist=0.04.
# 03:54:43 WARNING: No data found for (-77.7867,34.2133) using max_dist=0.04.
# 03:54:45 INFO: [Found Water] Springmaid Pier, SC
# 03:54:47 INFO: [Found Land] Oyster Landing (N Inlet Estuary), SC
# 03:54:47 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 03:54:47 WARNING: No data found for (-80.9017,32.0333) using max_dist=0.04.
# 03:54:49 INFO: [Found Land] Fernandina Beach, FL
# 03:54:49 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 03:54:52 INFO: [Found Land] Southbank Riverwalk, St Johns River, FL
# 03:54:52 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 03:54:54 INFO: [Found Land] Racy Point, St Johns River, FL
# 03:54:54 WARNING: No data found for (-80.5931,28.4158) using max_dist=0.04.
# 03:54:54 WARNING: No data found for (-80.0333,26.6117) using max_dist=0.04.
# 03:54:57 INFO: [Found Water] Virginia Key, FL
# 03:54:57 WARNING: No data found for (-81.105,24.7117) using max_dist=0.04.
# 03:54:59 INFO: [Found Land] Naples, FL
# 03:54:59 WARNING: No data found for (-81.8712,26.6477) using max_dist=0.04.
# 03:54:59 WARNING: No data found for (-82.5621,27.6387) using max_dist=0.04.
# 03:55:02 INFO: [Found Land] Mckay Bay Entrance, FL
# 03:55:04 INFO: [Found Land] Clearwater Beach, FL
# 03:55:06 INFO: [Found Water] Cedar Key, FL
# 03:55:06 WARNING: No data found for (-84.9817,29.7267) using max_dist=0.04.
# 03:55:06 WARNING: No data found for (-85.6669,30.1523) using max_dist=0.04.
# 03:55:11 INFO: Finished processing [USEAST]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 03:55:12 WARNING: /home/filipe/miniconda/envs/ioos/lib/python2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   warnings.warn(msg, FutureWarning)
#
# 03:55:20 WARNING: -c:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# 03:55:54 INFO: 11.96 minutes
# 03:55:54 INFO: EOF
