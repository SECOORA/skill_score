# %% [markdown]
# ### SECOORA sea surface height notebook
#
# Produce weekly maps and tables for the SECOORA.  Based on IOOS system-test [notebook](http://nbviewer.ipython.org/github/ioos/system-test/blob/master/Theme_2_Extreme_Events/Scenario_2A/ModelDataCompare_Inundation/Water_Level_Signell.ipynb).

# %%
import iris
import pyoos
import owslib

import time
start_time = time.time()

# %%
import os
import sys

utilities_path = os.path.join(os.getcwd(), os.pardir)
root = os.path.abspath(utilities_path)
sys.path.append(root)

style = '../style.css'

# %%
import pytz
from datetime import datetime, timedelta

from utilities import CF_names


# Choose the date range.
stop = datetime(2014, 7, 7, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = stop - timedelta(days=7)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names to look for (Sea Surface Height).
name_list = CF_names['water level']

# %%
directory = '{:%Y-%m-%d}'.format(stop)

if not os.path.exists(directory):
    os.makedirs(directory)

# %%
import logging as log
reload(log)

fmt = '{:*^64}'.format
log.captureWarnings(True)
LOG_FILENAME = 'log.txt'
LOG_FILENAME = os.path.join(directory, LOG_FILENAME)
log.basicConfig(filename=LOG_FILENAME,
                filemode='w',
                format='%(asctime)s %(levelname)s: %(message)s',
                datefmt='%I:%M:%S',
                level=log.INFO,
                stream=None)

log.info(fmt(' Run information '))
log.info('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
log.info('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
log.info('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
log.info('Bounding box: {0:3.2f}, {1:3.2f},'
         '{2:3.2f}, {3:3.2f}'.format(*bbox))
log.info(fmt(' Software version '))
log.info('Iris version: {}'.format(iris.__version__))
log.info('owslib version: {}'.format(owslib.__version__))
log.info('pyoos version: {}'.format(pyoos.__version__))

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

# %%
# Force SECOORA models into the URL list.
from utilities import titles

secoora_models = ['SABGOM', 'USEAST', 'USF_ROMS',
                  'USF_SWAN', 'USF_FVCOM']

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the catalog'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()
sos_name = 'water_surface_height_above_reference_datum'

datum = 'NAVD'
collector.set_datum(datum)
collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# #### Clean the dataframe (visualization purpose only)

# %%
from utilities import get_coops_longname, to_html

columns = {'datum_id': 'datum',
           'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': 'ssh above datum'}

observations.rename(columns=columns, inplace=True)

observations['datum'] = [s.split(':')[-1] for s in observations['datum']]
observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>ssh above datum</th>
#       <th>datum</th>
#       <th>height</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td> 8651370</td>
#       <td> A1</td>
#       <td> 36.1833</td>
#       <td>-75.7467</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.761</td>
#       <td> MLLW</td>
#       <td> 5.663</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td> 8652587</td>
#       <td> A1</td>
#       <td> 35.7950</td>
#       <td>-75.5483</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.242</td>
#       <td> MLLW</td>
#       <td> 0.788</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td> 8654467</td>
#       <td> A1</td>
#       <td> 35.2086</td>
#       <td>-75.7042</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.216</td>
#       <td> MLLW</td>
#       <td> 8.345</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td> 8656483</td>
#       <td> A1</td>
#       <td> 34.7200</td>
#       <td>-76.6700</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.703</td>
#       <td> MLLW</td>
#       <td> 0.562</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td> 8658120</td>
#       <td> A1</td>
#       <td> 34.2267</td>
#       <td>-77.9533</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 0.391</td>
#       <td> MLLW</td>
#       <td> 0.747</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Generate a uniform 6-min time base for model/data comparison

# %%
import iris
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations (station data) '))
fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
fname = os.path.join(directory, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))
data = dict()
bad_datum = []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'water_surface_height_above_reference_datum (m)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_datum.append(station)
        name = get_coops_longname(station)
        log.warning("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad vertical datum stations.
pattern = '|'.join(bad_datum)
if pattern:
    non_navd = observations.station.str.contains(pattern)
    bad_datum = observations[non_navd]
    observations = observations[~non_navd]

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         datum=datum,
                         url=url))

save_timeseries(obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(obs_data.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8662245</th>
#       <th>8665530</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720219</th>
#       <th>8720226</th>
#       <th>8720357</th>
#       <th>8720503</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8727520</th>
#       <th>8728690</th>
#       <th>8729108</th>
#       <th>8729840</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-06-30 12:00:00</th>
#       <td> 0.094</td>
#       <td> 0.027</td>
#       <td> 0.186</td>
#       <td> 0.220</td>
#       <td> 0.104</td>
#       <td> 0.299</td>
#       <td>-0.044</td>
#       <td> 0.023</td>
#       <td>-0.145</td>
#       <td>-0.123</td>
#       <td> 0.079</td>
#       <td> 0.124</td>
#       <td> 0.240</td>
#       <td>-0.056</td>
#       <td>-0.142</td>
#       <td>-0.161</td>
#       <td>-0.221</td>
#       <td>-0.216</td>
#       <td>-0.028</td>
#       <td>-0.102</td>
#       <td>-0.097</td>
#       <td> 0.122</td>
#       <td> 0.064</td>
#       <td> 0.122</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:06:00</th>
#       <td> 0.133</td>
#       <td> 0.036</td>
#       <td> 0.219</td>
#       <td> 0.249</td>
#       <td> 0.125</td>
#       <td> 0.325</td>
#       <td>-0.002</td>
#       <td> 0.046</td>
#       <td>-0.124</td>
#       <td>-0.120</td>
#       <td> 0.078</td>
#       <td> 0.120</td>
#       <td> 0.232</td>
#       <td>-0.060</td>
#       <td>-0.124</td>
#       <td>-0.166</td>
#       <td>-0.213</td>
#       <td>-0.239</td>
#       <td>-0.029</td>
#       <td>-0.098</td>
#       <td>-0.116</td>
#       <td> 0.123</td>
#       <td> 0.069</td>
#       <td> 0.122</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:12:00</th>
#       <td> 0.150</td>
#       <td> 0.042</td>
#       <td> 0.224</td>
#       <td> 0.263</td>
#       <td> 0.145</td>
#       <td> 0.352</td>
#       <td> 0.028</td>
#       <td> 0.071</td>
#       <td>-0.105</td>
#       <td>-0.110</td>
#       <td> 0.077</td>
#       <td> 0.116</td>
#       <td> 0.225</td>
#       <td>-0.010</td>
#       <td>-0.107</td>
#       <td>-0.169</td>
#       <td>-0.204</td>
#       <td>-0.225</td>
#       <td>-0.030</td>
#       <td>-0.100</td>
#       <td>-0.137</td>
#       <td> 0.130</td>
#       <td> 0.073</td>
#       <td> 0.125</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:18:00</th>
#       <td> 0.161</td>
#       <td> 0.050</td>
#       <td> 0.249</td>
#       <td> 0.301</td>
#       <td> 0.165</td>
#       <td> 0.379</td>
#       <td> 0.063</td>
#       <td> 0.100</td>
#       <td>-0.083</td>
#       <td>-0.105</td>
#       <td> 0.077</td>
#       <td> 0.110</td>
#       <td> 0.217</td>
#       <td>-0.026</td>
#       <td>-0.087</td>
#       <td>-0.173</td>
#       <td>-0.192</td>
#       <td>-0.249</td>
#       <td>-0.031</td>
#       <td>-0.102</td>
#       <td>-0.157</td>
#       <td> 0.133</td>
#       <td> 0.070</td>
#       <td> 0.132</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:24:00</th>
#       <td> 0.206</td>
#       <td> 0.059</td>
#       <td> 0.273</td>
#       <td> 0.323</td>
#       <td> 0.182</td>
#       <td> 0.402</td>
#       <td> 0.096</td>
#       <td> 0.126</td>
#       <td>-0.058</td>
#       <td>-0.096</td>
#       <td> 0.077</td>
#       <td> 0.110</td>
#       <td> 0.209</td>
#       <td>-0.055</td>
#       <td>-0.077</td>
#       <td>-0.176</td>
#       <td>-0.183</td>
#       <td>-0.228</td>
#       <td>-0.033</td>
#       <td>-0.105</td>
#       <td>-0.170</td>
#       <td> 0.131</td>
#       <td> 0.077</td>
#       <td> 0.140</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Loop discovered models and save the nearest time-series

# %%
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                             MergeError)

from utilities import TimeoutException, time_limit, get_cube, get_model_name

# FIXME: Filtering bad URLs.
dap_urls = [link for link in dap_urls
            if 'NECOFS' not in link]  # Cartesian coords are not implemented.

log.info(fmt(' Models '))
cubes = dict()
for k, url in enumerate(dap_urls):
    log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
    try:
        with time_limit(60*5):
            cube = get_cube(url, name_list=name_list,
                            bbox=bbox, time=(start, stop),
                            units=iris.unit.Unit('meters'))
        # TODO: Need a better way to identify model data and observed data.
        if cube.ndim > 1:
            mod_name, model_full_name = get_model_name(cube, url)
            cubes.update({mod_name: cube})
        else:
            log.warning('url {} is probably a timeSeries!'.format(url))
    except (RuntimeError, ValueError, MergeError, TimeoutException,
            ConstraintMismatchError, CoordinateNotFoundError) as e:
        log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from iris.pandas import as_series

from utilities import (standardize_fill_value,
                       make_tree, get_nearest_water,
                       add_station, ensure_timeseries)


for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(directory, fname)
    log.info(fmt(' Saving to file {} '.format(fname)))
    # NOTE: 2D coords KDtree.  (Iris can only do 1D coords KDtree for now.)
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot create KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in observations.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            log.warning(e)
            continue
        if not series:
            status = "Land "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water"

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = standardize_fill_value(cube)
            cube = add_station(cube, station)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info('Finished processing [{}]: {}'.format(mod_name, url))

# %% [markdown]
# #### Load saved files and interpolate to the observations time interval

# %%
from glob import glob
from operator import itemgetter

from pandas import Panel
from utilities import nc2df

fname = '{}-OBS_DATA.nc'.format(directory)
fname = os.path.join(directory, fname)
OBS_DATA = nc2df(fname)
index = OBS_DATA.index

dfs = dict(OBS_DATA=OBS_DATA)
for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    else:
        model = fname.split('.')[0].split('-')[-1]
        df = nc2df(fname)
        if model == 'USF_FVCOM':
            # FIXME: Horrible work around duplicate times in USF FVCOM.
            opts = dict(cols='index', take_last=True)
            df = df.reset_index().drop_duplicates(**opts).set_index('index')
        kw = dict(method='time', limit=30)
        df = df.reindex(index).interpolate(**kw).ix[index]
        dfs.update({model: df})

dfs = Panel.fromDict(dfs).swapaxes(0, 2)

# Clusters.
big_list = []
for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    nc = iris.load_cube(fname)
    model = fname.split('-')[-1].split('.')[0]
    lons = nc.coord(axis='X').points
    lats = nc.coord(axis='Y').points
    stations = nc.coord('station name').points
    models = [model]*lons.size
    lista = zip(models, lons.tolist(), lats.tolist(), stations.tolist())
    big_list.extend(lista)

big_list.sort(key=itemgetter(3))
df = DataFrame(big_list, columns=['name', 'lon', 'lat', 'station'])
df.set_index('station', drop=True, inplace=True)
groups = df.groupby(df.index)

# %%
import matplotlib.pyplot as plt
from mpld3.plugins import LineLabelTooltip, connect

from utilities import inline_map, make_map, save_html


mapa = make_map(bbox, line=True, states=False)

# ROMS stations files (SABGOM and USEAST?).
roms_stations = [(-77.7866, 34.2133),
                 (-78.9183, 33.6550),
                 (-81.0000, 30.3966),
                 (-80.1600, 25.7300),
                 (-81.8116, 24.5550),
                 (-82.6137, 26.1300),
                 (-82.8320, 27.9770),
                 (-86.4987, 30.1520)]

for station in roms_stations:
    location = station[::-1]
    popup = '[SABGOM/USEAST]\nROMS station file'
    kw = dict(radius=700, fill_color='red', popup=popup,
              fill_opacity=0.75)
    mapa.circle_marker(location=location, **kw)


# Clusters.
for station, info in groups:
    station = get_coops_longname(station)
    for lat, lon, name in zip(info.lat, info.lon, info.name):
        location = lat, lon
        popup = '<b>{}</b>\n{}'.format(station, name)
        mapa.simple_marker(location=location, popup=popup,
                           clustered_marker=True)

# Model and observations.
resolution, width, height = 75, 7, 3
for station in dfs:
    sta_name = get_coops_longname(station)
    df = dfs[station].dropna(axis=1, how='all')

    fig, ax = plt.subplots(figsize=(width, height))
    for col in df.columns:
        ax.plot(df.index, df[col], linewidth=2.5, alpha=0.5,
                label=col)
    ax.set_ylabel('Sea surface height (m)')
    ax.set_ylim(-1.5, 1.5)
    ax.grid(False)
    kw = dict(loc='upper center', bbox_to_anchor=(0.5, 1.05), numpoints=1,
              ncol=2, framealpha=0)
    ax.legend(**kw)

    [connect(fig, LineLabelTooltip(line, name))
     for line, name in zip(ax.lines, df.columns)]

    html = 'station_{}.html'.format(station)
    save_html(fig, '{}/{}'.format(directory, html))

    popup = "<div align='center'> {} <br><iframe src='{}' alt='image'"
    popup += "width='{}px' height='{}px' frameBorder='0'></div>"
    popup = popup.format('{}'.format(sta_name), html,
                         (width*resolution)+75, (height*resolution)+50)
    kw = dict(popup=popup, width=(width*resolution)+75)

    if (df.columns == 'OBS_DATA').all():
        kw.update(dict(marker_color="blue", marker_icon="ok"))
    else:
        conj = set(df.columns)
        conj.intersection_update(secoora_models)
        if conj:
            kw.update(dict(marker_color="green", marker_icon="ok-sign"))
        else:
            kw.update(dict(marker_color="green", marker_icon="ok"))
    obs = observations[observations['station'] == station].squeeze()
    mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# Bad datum.
if isinstance(bad_datum, DataFrame):
    for station, obs in bad_datum.iterrows():
        popup = '<b>Station:</b> {}<br><b>Datum:</b> {}<br>'
        popup = popup.format(station, obs['datum'])
        kw = dict(popup=popup, marker_color="red", marker_icon="question-sign")
        mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %%
mapa.create_map(path=os.path.join(directory, 'mapa.html'))
inline_map(os.path.join(directory, 'mapa.html'))
# Out:
#         <iframe
#             width="750"
#             height=500"
#             src="2014-07-07/mapa.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Bias

# %%
from glob import glob
from pandas import Panel
from utilities import nc2df

fname = '{}-OBS_DATA.nc'.format(directory)
fname = os.path.join(directory, fname)

OBS_DATA = nc2df(fname)
index = OBS_DATA.index
dfs = dict(OBS_DATA=OBS_DATA)

for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        pass
    else:
        model = fname.split('.')[0].split('-')[-1]
        df = nc2df(fname)
        if model == 'USF_FVCOM':
            # FIXME: Horrible work around duplicate times in USF FVCOM.
            opts = dict(cols='index', take_last=True)
            df = df.reset_index().drop_duplicates(**opts).set_index('index')
        if False:  # I am not interpolating for now.
            kw = dict(method='time')
            df = df.reindex(index).interpolate(**kw).ix[index]
        dfs.update({model: df})

dfs = Panel.fromDict(dfs).swapaxes(0, 2)

# %%
from pandas import DataFrame

means = dict()
for station, df in dfs.iteritems():
    df.dropna(axis=1, how='all', inplace=True)
    mean = df.mean()
    df = df - mean + mean['OBS_DATA']
    means.update({station: mean['OBS_DATA'] - mean.drop('OBS_DATA')})

bias = DataFrame.from_dict(means).dropna(axis=1, how='all')
bias = bias.applymap('{:.2f}'.format).replace('nan', '--')

columns = dict()
[columns.update({station: get_coops_longname(station)}) for
 station in bias.columns.values]

bias.rename(columns=columns, inplace=True)

# %%
fname = os.path.join(directory, 'bias.html'.format(directory))

with open(style, 'r') as f:
    css = """<style>{}</style>""".format(f.read())
    table = dict(style=css, table=bias.T.to_html())
    table = '{style}<div class="datagrid">{table}</div>'.format(**table)

with open(fname, 'w') as f:
    f.writelines(table)

to_html(bias.T, style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>COAWST_4</th>
#       <th>ESPRESSO</th>
#       <th>ESTOFS</th>
#       <th>USF_FVCOM</th>
#       <th>USF_ROMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td>  0.02</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>  0.08</td>
#       <td> 0.44</td>
#       <td>  0.17</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Wrightsville Beach, NC</th>
#       <td> -0.07</td>
#       <td>   --</td>
#       <td> -0.01</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Springmaid Pier, SC</th>
#       <td> -0.10</td>
#       <td>   --</td>
#       <td> -0.00</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oyster Landing (N Inlet Estuary), SC</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td>  0.10</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Fernandina Beach, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.06</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Mayport (Bar Pilots Dock), FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.07</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Trident Pier, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.19</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Lake Worth Pier, FL</th>
#       <td> -0.32</td>
#       <td>   --</td>
#       <td> -0.17</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Vaca Key, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.16</td>
#       <td> 0.12</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Key West, FL</th>
#       <td> -0.34</td>
#       <td>   --</td>
#       <td> -0.17</td>
#       <td> 0.10</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Naples, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.09</td>
#       <td> 0.13</td>
#       <td> 0.14</td>
#     </tr>
#     <tr>
#       <th>Fort Myers, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td> 0.14</td>
#       <td> 0.18</td>
#     </tr>
#     <tr>
#       <th>Port Manatee, FL</th>
#       <td>    --</td>
#       <td>   --</td>
#       <td> -0.03</td>
#       <td> 0.18</td>
#       <td> 0.20</td>
#     </tr>
#     <tr>
#       <th>Cedar Key, FL</th>
#       <td> -0.11</td>
#       <td>   --</td>
#       <td>  0.06</td>
#       <td> 0.26</td>
#       <td> 0.28</td>
#     </tr>
#     <tr>
#       <th>Apalachicola, FL</th>
#       <td> -0.08</td>
#       <td>   --</td>
#       <td>  0.08</td>
#       <td> 0.26</td>
#       <td> 0.24</td>
#     </tr>
#     <tr>
#       <th>Panama City, FL</th>
#       <td> -0.05</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td> 0.32</td>
#     </tr>
#     <tr>
#       <th>Pensacola, FL</th>
#       <td> -0.00</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Model skill

# %%
from scipy.stats.stats import pearsonr

from utilities import both_valid


skill, skill_p = dict(), dict()
for station, df in dfs.iteritems():
    df.dropna(axis=0, how='all', inplace=True)
    df.dropna(axis=1, how='all', inplace=True)
    obs = df.pop('OBS_DATA')
    for model, y in df.iteritems():
        mask = both_valid(obs, y)
        r, p = pearsonr(obs[mask]-obs.mean(), y[mask]-y.mean())
        skill.update({station: {model: r}})
        skill_p.update({station: {model: p}})

df = DataFrame.from_dict(skill)

columns = dict()
[columns.update({station: get_coops_longname(station)}) for
 station in df.columns.values]

df.rename(columns=columns, inplace=True)

# %% [markdown]
# ### Annotated Heatmap (test)

# %%
# %matplotlib inline
import numpy as np
from matplotlib import patheffects

df = df.T
fig, ax = plt.subplots(figsize=(7, 21))
m, n = len(df.index), len(df.columns)
ax.imshow(df, interpolation='nearest', cmap='Oranges')
ax.set_xticks(np.linspace(0, n-1, n))
ax.set_xticklabels(df.columns)
ax.set_yticks(np.linspace(0, m-1, m))
ax.set_yticklabels(df.index)
ax.grid('off')
ax.xaxis.tick_top()

path_effects = [patheffects.withSimplePatchShadow(shadow_rgbFace=(1, 1, 1))]
for i in range(m):
    for j in range(n):
        ax.text(j, i, '{:.2f}'.format(df.iget_value(i, j)),
                size='medium', ha='center', va='center',
                path_effects=path_effects)

# %%
from utilities import to_html

html_skill = df.applymap('{:.2f}'.format).replace('nan', '--')

to_html(html_skill, css='../style.css')
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>COAWST_4</th>
#       <th>ESTOFS</th>
#       <th>USF_FVCOM</th>
#       <th>USF_ROMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>   --</td>
#       <td> 0.96</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>   --</td>
#       <td> 0.04</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Wrightsville Beach, NC</th>
#       <td>   --</td>
#       <td> 0.92</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Springmaid Pier, SC</th>
#       <td>   --</td>
#       <td> 0.90</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oyster Landing (N Inlet Estuary), SC</th>
#       <td>   --</td>
#       <td> 0.74</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Fernandina Beach, FL</th>
#       <td>   --</td>
#       <td> 0.92</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Mayport (Bar Pilots Dock), FL</th>
#       <td>   --</td>
#       <td> 0.95</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Trident Pier, FL</th>
#       <td>   --</td>
#       <td> 0.97</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Lake Worth Pier, FL</th>
#       <td>   --</td>
#       <td> 0.95</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Vaca Key, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.45</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Key West, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.94</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Naples, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.50</td>
#     </tr>
#     <tr>
#       <th>Fort Myers, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Port Manatee, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Cedar Key, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.93</td>
#     </tr>
#     <tr>
#       <th>Apalachicola, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.37</td>
#     </tr>
#     <tr>
#       <th>Panama City, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Pensacola, FL</th>
#       <td> 0.88</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

# %%
import qrcode

qr = qrcode.QRCode(version=1,
                   error_correction=qrcode.constants.ERROR_CORRECT_L,
                   box_size=10,
                   border=4)

nbviewer = "http://nbviewer.ipython.org/github"
github = "ioos/secoora/blob/master/notebooks/elevation"
qr.add_data('{}/{}/00-inundation_secoora'.format(nbviewer, github))
qr.make(fit=True)

img = qr.make_image()
fig, ax = plt.subplots()
ax.imshow(img)
ax.axis('off')
title = ax.set_title("Notebook nbviewer link")

# %%
with open('{}/log.txt'.format(directory)) as f:
    print(f.read())
# Out:
# 11:12:21 INFO: *********************** Run information ************************
# 11:12:21 INFO: Run date: 2015-01-12 14:12:21
# 11:12:21 INFO: Download start: 2014-06-30 12:00:00
# 11:12:21 INFO: Download stop: 2014-07-07 12:00:00
# 11:12:21 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 11:12:21 INFO: *********************** Software version ***********************
# 11:12:21 INFO: Iris version: 1.8.0-DEV
# 11:12:21 INFO: owslib version: 0.8-dev
# 11:12:21 INFO: pyoos version: 0.6.2
# 11:12:26 INFO: ********************* Catalog information **********************
# 11:12:26 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 11:12:26 INFO: CSW version: 2.0.2
# 11:12:26 INFO: Number of datasets available: 9
# 11:12:26 INFO: ***************************** CSW ******************************
# 11:12:26 INFO: USF FVCOM - Nowcast Aggregation
# 11:12:26 INFO: ROMS/TOMS 3.0 - New Floria Shelf Application
# 11:12:26 INFO: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# 11:12:26 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 11:12:26 INFO: ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# 11:12:26 INFO: Barotropic Tide Model for the Pacific Basin
# 11:12:26 INFO: HYbrid Coordinate Ocean Model (HYCOM): Global
# 11:12:26 INFO: ESTOFS Storm Surge Model - Atlantic - v1.0.0 - NOAA - NCEP - ADCIRC
# 11:12:26 INFO: NECOFS GOM3 Wave - Northeast US - Latest Forecast
# 11:12:26 INFO: ***************************** DAP ******************************
# 11:12:26 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# 11:12:26 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd.html
# 11:12:26 INFO: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic.html
# 11:12:26 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 11:12:26 INFO: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# 11:12:26 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac.html
# 11:12:26 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 11:12:26 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd.html
# 11:12:26 INFO: http://www.smast.umassd.edu:8080/thredds/dodsC/FVCOM/NECOFS/Forecasts/NECOFS_WAVE_FORECAST.nc.html
# 11:12:26 INFO: ***************************** SOS ******************************
# 11:12:26 WARNING: USEAST not in the catalog
# 11:12:26 WARNING: USF_SWAN not in the catalog
# 11:13:03 INFO: ********************* Collector offerings **********************
# 11:13:03 INFO: NOAA.NOS.CO-OPS SOS: 1024 offerings
# 11:13:05 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-06-30T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AWaterLevelActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=water_surface_height_above_reference_datum
# 11:13:28 INFO: ***************** Observations (station data) ******************
# 11:13:28 INFO: **** Downloading to file 2014-07-07/2014-07-07-OBS_DATA.nc *****
# 11:13:42 WARNING: [8654467] USCG Station Hatteras, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 11:13:44 WARNING: [8656483] Beaufort, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 11:13:46 WARNING: [8658120] Wilmington, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 11:15:30 WARNING: [8726520] St Petersburg, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 11:15:32 WARNING: [8726607] Old Port Tampa, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 11:15:52 WARNING: [8729210] Panama City Beach, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 11:15:56 INFO: **************************** Models ****************************
# 11:15:56 INFO:
# [Reading url 1/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 11:15:58 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1006: UserWarning: Ignoring variable u'lat' referenced by variable u'hc': Dimensions (u'node',) do not span (u'nele',)
#   warnings.warn(msg)
#
# 11:15:58 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1006: UserWarning: Ignoring variable u'lon' referenced by variable u'hc': Dimensions (u'node',) do not span (u'nele',)
#   warnings.warn(msg)
#
# 11:15:58 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1006: UserWarning: Ignoring variable u'siglay' referenced by variable u'u': Dimensions (u'siglay', u'node') do not span (u'time', u'siglay', u'nele')
#   warnings.warn(msg)
#
# 11:15:58 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1006: UserWarning: Ignoring variable u'siglay' referenced by variable u'v': Dimensions (u'siglay', u'node') do not span (u'time', u'siglay', u'nele')
#   warnings.warn(msg)
#
# 11:16:00 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1442: UserWarning: Failed to create 'time' dimension coordinate: The points array must be strictly monotonic.
# Gracefully creating 'time' auxiliary coordinate instead.
#   error=e_msg))
#
# 11:16:00 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'Itime2' invalid units 'msecs since 00:00:00'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:11 INFO:
# [Reading url 2/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1040: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'v' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1040: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'v' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_v', u'xi_v')
#   warnings.warn(msg)
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1040: UserWarning: Ignoring formula terms variable u'h' referenced by data variable u'u' via variable u's_rho': Dimensions (u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/cf.py:1040: UserWarning: Ignoring formula terms variable u'zeta' referenced by data variable u'u' via variable u's_rho': Dimensions (u'time', u'eta_rho', u'xi_rho') do not span (u'time', u's_rho', u'eta_u', u'xi_u')
#   warnings.warn(msg)
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1396: UserWarning: Gracefully filling 'time' dimension coordinate masked points
#   warnings.warn(msg.format(str(cf_coord_var.cf_name)))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'Cs_r' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 's_rho' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/netcdf.py:441: UserWarning: Unable to find coordinate for variable u'zeta'
#   '{!r}'.format(name))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/netcdf.py:441: UserWarning: Unable to find coordinate for variable u'h'
#   '{!r}'.format(name))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/netcdf.py:558: UserWarning: Unable to construct Ocean s-coordinate, generic form 1 factory due to insufficient source coordinates.
#   warnings.warn('{}'.format(e))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/netcdf.py:558: UserWarning: Invalid units: s coordinate u'ocean_s_coordinate_g1' must be dimensionless.
#   warnings.warn('{}'.format(e))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'Cs_w' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:12 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 's_w' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:13 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'salt' invalid units 'PSU'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:16 INFO:
# [Reading url 3/10]: http://geoport-dev.whoi.edu/thredds/dodsC/estofs/atlantic
# 11:16:18 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'nbdv' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:18 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'neta' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:19 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'ibtypee' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:19 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'nvell' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:19 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'ibtype' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:19 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'nbvv' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:19 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'nvel' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:16:19 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'nvdll' invalid units 'nondimensional'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:17:47 INFO:
# [Reading url 4/10]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 11:18:50 INFO:
# [Reading url 5/10]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 11:18:52 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'chlorophyll' invalid units 'milligrams_chlorophyll meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:18:52 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'phytoplankton' invalid units 'millimole_nitrogen meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:18:52 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'NO3' invalid units 'millimole_N03 meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:18:52 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'zooplankton' invalid units 'millimole_nitrogen meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:18:52 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'NH4' invalid units 'millimole_NH4 meter-3'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:18:59 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 11:18:59 INFO:
# [Reading url 6/10]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# 11:19:08 WARNING: Cannot get cube for: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# The points array must be strictly monotonic.
# 11:19:08 INFO:
# [Reading url 7/10]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 11:19:30 WARNING: Cannot get cube for: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# The points array must be strictly monotonic.
# 11:19:30 INFO:
# [Reading url 8/10]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# 11:19:43 INFO:
# [Reading url 9/10]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 11:19:45 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/netcdf.py:558: UserWarning: Unable to construct Ocean s-coordinate, generic form 2 factory due to insufficient source coordinates.
#   warnings.warn('{}'.format(e))
#
# 11:19:54 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 11:19:54 INFO:
# [Reading url 10/10]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 11:19:55 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1301: UserWarning: Ignoring netCDF variable 'Itime2' invalid units 'msec since 00:00:00'
#   warnings.warn(msg.format(msg_name, msg_units))
#
# 11:19:55 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cube does not contain ['sea_surface_height', 'sea_surface_elevation', 'sea_surface_height_above_geoid', 'sea_surface_height_above_sea_level', 'water_surface_height_above_reference_datum', 'sea_surface_height_above_reference_ellipsoid']
# 11:19:55 INFO: ******* Saving to file 2014-07-07/2014-07-07-USF_ROMS.nc *******
# 11:19:55 WARNING: No data found for (-75.7467,36.1833) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-75.5483,35.795) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-77.7867,34.2133) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-78.9183,33.655) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-79.1867,33.3517) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.465,30.6717) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.43,30.3967) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.6283,29.9783) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-80.5931,28.4158) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-80.0333,26.6117) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.105,24.7117) using max_dist=0.04.
# 11:19:55 WARNING: No data found for (-81.8079,24.5557) using max_dist=0.04.
# 11:19:57 INFO: [Water] Naples, FL
# 11:19:58 INFO: [Water] Fort Myers, FL
# 11:20:01 INFO: [Water] Port Manatee, FL
# 11:20:06 INFO: [Water] Cedar Key, FL
# 11:20:08 INFO: [Water] Apalachicola, FL
# 11:20:11 INFO: [Water] Panama City, FL
# 11:20:11 WARNING: No data found for (-87.2112,30.4044) using max_dist=0.04.
# 11:20:20 INFO: Finished processing [USF_ROMS]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 11:20:20 INFO: ****** Saving to file 2014-07-07/2014-07-07-USF_FVCOM.nc *******
# 11:20:21 WARNING: No data found for (-75.7467,36.1833) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-75.5483,35.795) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-77.7867,34.2133) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-78.9183,33.655) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-79.1867,33.3517) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-81.465,30.6717) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-81.43,30.3967) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-81.6283,29.9783) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-80.5931,28.4158) using max_dist=0.04.
# 11:20:21 WARNING: No data found for (-80.0333,26.6117) using max_dist=0.04.
# 11:20:33 INFO: [Water] Vaca Key, FL
# 11:20:45 INFO: [Water] Key West, FL
# 11:20:57 INFO: [Water] Naples, FL
# 11:21:09 INFO: [Water] Fort Myers, FL
# 11:21:21 INFO: [Water] Port Manatee, FL
# 11:21:26 INFO: [Water] Cedar Key, FL
# 11:21:38 INFO: [Water] Apalachicola, FL
# 11:21:38 WARNING: No data found for (-85.6669,30.1523) using max_dist=0.04.
# 11:21:38 WARNING: No data found for (-87.2112,30.4044) using max_dist=0.04.
# 11:21:38 INFO: Finished processing [USF_FVCOM]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 11:21:38 INFO: ******* Saving to file 2014-07-07/2014-07-07-COAWST_4.nc *******
# 11:21:45 INFO: [Land ] Duck, NC
# 11:21:57 INFO: [Water] Oregon Inlet Marina, NC
# 11:22:04 INFO: [Water] Wrightsville Beach, NC
# 11:22:17 INFO: [Water] Springmaid Pier, SC
# 11:22:24 INFO: [Land ] Oyster Landing (N Inlet Estuary), SC
# 11:22:31 INFO: [Land ] Charleston, SC
# 11:22:37 INFO: [Land ] Fernandina Beach, FL
# 11:22:43 INFO: [Land ] Mayport (Bar Pilots Dock), FL
# 11:22:51 INFO: [Land ] Dames Point, FL
# 11:22:58 INFO: [Land ] Southbank Riverwalk, St Johns River, FL
# 11:23:05 INFO: [Land ] I-295 Bridge, St Johns River, FL
# 11:23:12 INFO: [Land ] Red Bay Point, St Johns River, FL
# 11:23:18 INFO: [Land ] Racy Point, St Johns River, FL
# 11:23:25 INFO: [Land ] Trident Pier, FL
# 11:23:40 INFO: [Water] Lake Worth Pier, FL
# 11:23:47 INFO: [Land ] Vaca Key, FL
# 11:24:02 INFO: [Water] Key West, FL
# 11:24:09 INFO: [Land ] Naples, FL
# 11:24:15 INFO: [Land ] Fort Myers, FL
# 11:24:22 INFO: [Land ] Port Manatee, FL
# 11:24:36 INFO: [Water] Cedar Key, FL
# 11:24:43 INFO: [Water] Apalachicola, FL
# 11:24:50 INFO: [Water] Panama City, FL
# 11:24:56 INFO: [Water] Pensacola, FL
# 11:25:54 INFO: Finished processing [COAWST_4]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 11:25:54 INFO: ******** Saving to file 2014-07-07/2014-07-07-ESTOFS.nc ********
# 11:25:59 INFO: [Water] Duck, NC
# 11:26:01 INFO: [Water] Oregon Inlet Marina, NC
# 11:26:10 INFO: [Water] Wrightsville Beach, NC
# 11:26:20 INFO: [Water] Springmaid Pier, SC
# 11:26:22 INFO: [Water] Oyster Landing (N Inlet Estuary), SC
# 11:26:22 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 11:26:24 INFO: [Water] Fernandina Beach, FL
# 11:26:26 INFO: [Water] Mayport (Bar Pilots Dock), FL
# 11:26:26 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 11:26:26 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 11:26:26 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 11:26:26 WARNING: No data found for (-81.6283,29.9783) using max_dist=0.04.
# 11:26:26 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 11:26:31 INFO: [Water] Trident Pier, FL
# 11:26:36 INFO: [Water] Lake Worth Pier, FL
# 11:26:46 INFO: [Water] Vaca Key, FL
# 11:26:54 INFO: [Water] Key West, FL
# 11:27:02 INFO: [Water] Naples, FL
# 11:27:02 WARNING: No data found for (-81.8712,26.6477) using max_dist=0.04.
# 11:27:15 INFO: [Water] Port Manatee, FL
# 11:27:27 INFO: [Water] Cedar Key, FL
# 11:27:36 INFO: [Water] Apalachicola, FL
# 11:27:36 WARNING: No data found for (-85.6669,30.1523) using max_dist=0.04.
# 11:27:36 WARNING: No data found for (-87.2112,30.4044) using max_dist=0.04.
# 11:27:36 INFO: Finished processing [ESTOFS]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 11:27:36 INFO: ******* Saving to file 2014-07-07/2014-07-07-ESPRESSO.nc *******
# 11:27:39 INFO: [Land ] Duck, NC
# 11:27:43 INFO: [Water] Oregon Inlet Marina, NC
# 11:27:43 WARNING: No data found for (-77.7867,34.2133) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-78.9183,33.655) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-79.1867,33.3517) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-79.925,32.7817) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.465,30.6717) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.43,30.3967) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.5583,30.3867) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.6583,30.32) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.6917,30.1917) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.6283,29.9783) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.5483,29.8017) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-80.5931,28.4158) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-80.0333,26.6117) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.105,24.7117) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.8079,24.5557) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.8075,26.1317) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-81.8712,26.6477) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-82.5621,27.6387) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-83.0317,29.135) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-84.9817,29.7267) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-85.6669,30.1523) using max_dist=0.04.
# 11:27:43 WARNING: No data found for (-87.2112,30.4044) using max_dist=0.04.
# 11:27:46 INFO: Finished processing [ESPRESSO]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 11:27:46 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   warnings.warn(msg, FutureWarning)
#
# 11:28:23 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
#
# 11:28:55 INFO: 16.65 minutes
# 11:28:55 INFO: EOF
