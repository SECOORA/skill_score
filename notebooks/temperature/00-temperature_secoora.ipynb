# %% [markdown]
# ### SECOORA sea surface temperature time-series notebook
#
# Produce weekly maps and tables for the SECOORA.  Based on IOOS system-test [notebook](http://nbviewer.ipython.org/github/Bobfrat/system-test/blob/temp_nb/Theme_1_Baseline/Scenario_1F_Temperature/Temperature.ipynb).

# %%
import time
start_time = time.time()

# %%
import os
import sys

utilities_path = os.path.join(os.getcwd(), os.pardir)
root = os.path.abspath(utilities_path)
sys.path.append(root)

style = '../style.css'

# %%
import pytz
from datetime import datetime, timedelta

from utilities import CF_names


# Choose the date range (e.g: stop = datetime(2014, 7, 7, 12)).
stop = datetime(2014, 7, 7, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = stop - timedelta(days=7)

# SECOORA region (NC, SC GA, FL).
bbox = [-87.40, 24.25, -74.70, 36.70]

# CF-names to look for (Sea Surface Temperature).
name_list = CF_names['sea_water_temperature']

# %%
directory = '{:%Y-%m-%d}'.format(stop)

if not os.path.exists(directory):
    os.makedirs(directory)

# %%
import iris
import pyoos
import owslib

import logging as log
reload(log)

fmt = '{:*^64}'.format
log.captureWarnings(True)
LOG_FILENAME = 'log.txt'
LOG_FILENAME = os.path.join(directory, LOG_FILENAME)
log.basicConfig(filename=LOG_FILENAME,
                filemode='w',
                format='%(asctime)s %(levelname)s: %(message)s',
                datefmt='%I:%M:%S',
                level=log.INFO,
                stream=None)

log.info(fmt(' Run information '))
log.info('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
log.info('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
log.info('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
log.info('Bounding box: {0:3.2f}, {1:3.2f},'
         '{2:3.2f}, {3:3.2f}'.format(*bbox))
log.info(fmt(' Software version '))
log.info('Iris version: {}'.format(iris.__version__))
log.info('owslib version: {}'.format(owslib.__version__))
log.info('pyoos version: {}'.format(pyoos.__version__))

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exculde ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

# %%
# Force SECOORA models into the URL list.
from utilities import titles

secoora_models = ['SABGOM', 'USEAST', 'USF_ROMS',
                  'USF_SWAN', 'USF_FVCOM']

for secoora_model in secoora_models:
    if titles[secoora_model] not in dap_urls:
        log.warning('{} not in the NGDC csw'.format(secoora_model))
        dap_urls.append(titles[secoora_model])

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()
sos_name = 'sea_water_temperature'

collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:MetActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# #### Clean the dataframe (visualization purpose only)

# %%
from utilities import get_coops_longname, to_html

columns = {'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'sea_water_temperature (C)': 'sea_water_temperature'}

observations.rename(columns=columns, inplace=True)

observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>sea_water_temperature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td> 8651370</td>
#       <td> E1</td>
#       <td> 36.1833</td>
#       <td>-75.7467</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 25.5</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td> 8652587</td>
#       <td> E1</td>
#       <td> 35.7950</td>
#       <td>-75.5483</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 24.7</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td> 8654467</td>
#       <td> E1</td>
#       <td> 35.2086</td>
#       <td>-75.7042</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 26.2</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td> 8656483</td>
#       <td> E1</td>
#       <td> 34.7200</td>
#       <td>-76.6700</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 26.7</td>
#     </tr>
#     <tr>
#       <th>Wilmington, NC</th>
#       <td> 8658120</td>
#       <td> E1</td>
#       <td> 34.2267</td>
#       <td>-77.9533</td>
#       <td> 2014-06-30T12:00:00Z</td>
#       <td> 28.6</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Generate a uniform 6-min time base for model/data comparison

# %%
import iris
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
fname = os.path.join(directory, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))
data = dict()
bad_station = []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'sea_water_temperature (C)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_station.append(station)
        name = get_coops_longname(station)
        log.warning("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad stations.
pattern = '|'.join(bad_station)
if pattern:
    mask = observations.station.str.contains(pattern)
    bad_station = observations[mask]
    bservations = observations[~mask]

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         url=url))

save_timeseries(obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(obs_data.head(), style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8654467</th>
#       <th>8656483</th>
#       <th>8658120</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8665530</th>
#       <th>8670870</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720219</th>
#       <th>8720245</th>
#       <th>8720357</th>
#       <th>8720503</th>
#       <th>8720625</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8726520</th>
#       <th>8726607</th>
#       <th>8728690</th>
#       <th>8729108</th>
#       <th>8729210</th>
#       <th>8729840</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-06-30 12:00:00</th>
#       <td> 25.5</td>
#       <td> 24.7</td>
#       <td> 26.2</td>
#       <td> 26.7</td>
#       <td> 28.6</td>
#       <td> 27.5</td>
#       <td> 28.0</td>
#       <td> 28.6</td>
#       <td> 25.5</td>
#       <td> 29.3</td>
#       <td> 28.6</td>
#       <td> 29.3</td>
#       <td> 29.4</td>
#       <td> 29.9</td>
#       <td> 30</td>
#       <td> 29.4</td>
#       <td> 29.2</td>
#       <td> 27.9</td>
#       <td> 30.7</td>
#       <td> 30.8</td>
#       <td> 31.900</td>
#       <td> 31.9</td>
#       <td> 30.6</td>
#       <td> 31.8</td>
#       <td> 31.1</td>
#       <td> 29.5</td>
#       <td> 29.7</td>
#       <td> 24.2</td>
#       <td> 28.7</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:06:00</th>
#       <td> 25.4</td>
#       <td> 24.7</td>
#       <td> 26.2</td>
#       <td> 26.7</td>
#       <td> 28.6</td>
#       <td> 27.5</td>
#       <td> 28.0</td>
#       <td> 28.6</td>
#       <td> 25.5</td>
#       <td> 29.3</td>
#       <td> 28.6</td>
#       <td> 29.3</td>
#       <td> 29.4</td>
#       <td> 29.9</td>
#       <td> 30</td>
#       <td> 29.4</td>
#       <td> 29.2</td>
#       <td> 27.9</td>
#       <td> 30.7</td>
#       <td> 30.8</td>
#       <td> 31.816</td>
#       <td> 31.9</td>
#       <td> 30.6</td>
#       <td> 31.8</td>
#       <td> 31.1</td>
#       <td> 29.5</td>
#       <td> 29.6</td>
#       <td> 24.1</td>
#       <td> 28.6</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:12:00</th>
#       <td> 25.4</td>
#       <td> 24.7</td>
#       <td> 26.1</td>
#       <td> 26.7</td>
#       <td> 28.6</td>
#       <td> 27.4</td>
#       <td> 28.0</td>
#       <td> 28.6</td>
#       <td> 25.5</td>
#       <td> 29.3</td>
#       <td> 28.6</td>
#       <td> 29.3</td>
#       <td> 29.3</td>
#       <td> 29.9</td>
#       <td> 30</td>
#       <td> 29.5</td>
#       <td> 29.2</td>
#       <td> 27.8</td>
#       <td> 30.7</td>
#       <td> 30.8</td>
#       <td> 31.800</td>
#       <td> 31.9</td>
#       <td> 30.5</td>
#       <td> 31.8</td>
#       <td> 31.1</td>
#       <td> 29.5</td>
#       <td> 29.4</td>
#       <td> 24.1</td>
#       <td> 28.6</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:18:00</th>
#       <td> 25.4</td>
#       <td> 24.7</td>
#       <td> 26.1</td>
#       <td> 26.7</td>
#       <td> 28.6</td>
#       <td> 27.4</td>
#       <td> 28.1</td>
#       <td> 28.6</td>
#       <td> 25.5</td>
#       <td> 29.3</td>
#       <td> 28.7</td>
#       <td> 29.3</td>
#       <td> 29.3</td>
#       <td> 29.9</td>
#       <td> 30</td>
#       <td> 29.5</td>
#       <td> 29.2</td>
#       <td> 27.8</td>
#       <td> 30.7</td>
#       <td> 30.8</td>
#       <td> 31.765</td>
#       <td> 31.9</td>
#       <td> 30.5</td>
#       <td> 31.8</td>
#       <td> 31.1</td>
#       <td> 29.5</td>
#       <td> 29.4</td>
#       <td> 24.2</td>
#       <td> 28.6</td>
#     </tr>
#     <tr>
#       <th>2014-06-30 12:24:00</th>
#       <td> 25.4</td>
#       <td> 24.7</td>
#       <td> 26.1</td>
#       <td> 26.7</td>
#       <td> 28.6</td>
#       <td> 27.4</td>
#       <td> 28.1</td>
#       <td> 28.6</td>
#       <td> 25.5</td>
#       <td> 29.3</td>
#       <td> 28.6</td>
#       <td> 29.3</td>
#       <td> 29.3</td>
#       <td> 29.9</td>
#       <td> 30</td>
#       <td> 29.5</td>
#       <td> 29.2</td>
#       <td> 27.8</td>
#       <td> 30.6</td>
#       <td> 30.8</td>
#       <td> 31.800</td>
#       <td> 31.9</td>
#       <td> 30.4</td>
#       <td> 31.8</td>
#       <td> 31.1</td>
#       <td> 29.5</td>
#       <td> 29.2</td>
#       <td> 24.1</td>
#       <td> 28.6</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# #### Loop discovered models and save the nearest time-series

# %%
import warnings
from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                             MergeError)

from utilities import (TimeoutException, time_limit,
                       get_cube, get_model_name, get_surface)


# FIXME: Filtering bad URLs.
dap_urls = [link for link in dap_urls
            if 'NECOFS' not in link]  # Cartesian coords are not implemented.

log.info(fmt(' Models '))
cubes = dict()

with warnings.catch_warnings():
    # Suppress iris warnings :
    warnings.simplefilter("ignore")
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                cube = get_cube(url, name_list=name_list,
                                bbox=bbox, time=(start, stop),
                                units=iris.unit.Unit('celsius'))
                # FIXME: Surface data only!
                cube = get_surface(cube)
            # FIXME: We Need a better way to identify model data.
            if cube.ndim > 1:
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
            else:
                log.warning('url {} is probably a timeSeries!'.format(url))
        except (TimeoutException, RuntimeError, ValueError, MergeError,
                ConstraintMismatchError, CoordinateNotFoundError, IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from iris.pandas import as_series

from utilities import (standardize_fill_value,
                       make_tree, get_nearest_water,
                       add_station, ensure_timeseries, remove_ssh)

for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(directory, fname)
    log.info(fmt(' Downloading to file {} '.format(fname)))
    # NOTE: 2D coords KDtree.  (Iris can only do 1D coords KDtree for now.)
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot make KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in observations.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        # RuntimeError may occurs, but you should run it again!
        except ValueError as e:
            log.warning(e)
            continue
        if not series:
            status = "Land "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water"

        log.info('[{}] {}'.format(status, obs.name))

    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = standardize_fill_value(cube)
            cube = add_station(cube, station)
            cube = remove_ssh(cube)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube
        
    log.info('Finished processing [{}]: {}'.format(mod_name, url))

# %% [markdown]
# #### Load saved files and interpolate to the observations time interval

# %%
from glob import glob
from operator import itemgetter

from pandas import Panel
from utilities import nc2df

fname = '{}-OBS_DATA.nc'.format(directory)
fname = os.path.join(directory, fname)
OBS_DATA = nc2df(fname)
index = OBS_DATA.index

dfs = dict(OBS_DATA=OBS_DATA)
for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    else:
        model = fname.split('.')[0].split('-')[-1]
        df = nc2df(fname)
        if model == 'USF_FVCOM':
            # FIXME: Horrible work around duplicate times in USF FVCOM.
            opts = dict(cols='index', take_last=True)
            df = df.reset_index().drop_duplicates(**opts).set_index('index')
        kw = dict(method='time', limit=30)
        df = df.reindex(index).interpolate(**kw).ix[index]
        dfs.update({model: df})

dfs = Panel.fromDict(dfs).swapaxes(0, 2)

# Clusters.
big_list = []
for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    nc = iris.load_cube(fname)
    model = fname.split('-')[-1].split('.')[0]
    lons = nc.coord(axis='X').points
    lats = nc.coord(axis='Y').points
    stations = nc.coord('station name').points
    models = [model]*lons.size
    lista = zip(models, lons.tolist(), lats.tolist(), stations.tolist())
    big_list.extend(lista)

big_list.sort(key=itemgetter(3))
df = DataFrame(big_list, columns=['name', 'lon', 'lat', 'station'])
df.set_index('station', drop=True, inplace=True)
groups = df.groupby(df.index)

# %%
from mpld3 import save_html
import matplotlib.pyplot as plt
from mpld3.plugins import LineLabelTooltip, connect

from utilities import inline_map, make_map

mapa = make_map(bbox, line=True, states=False)

# ROMS stations files (SABGOM and USEAST?).
roms_stations = [(-77.7866, 34.2133),
                 (-78.9183, 33.6550),
                 (-81.0000, 30.3966),
                 (-80.1600, 25.7300),
                 (-81.8116, 24.5550),
                 (-82.6137, 26.1300),
                 (-82.8320, 27.9770),
                 (-86.4987, 30.1520)]

for station in roms_stations:
    location = station[::-1]
    popup = '[SABGOM/USEAST]\nROMS station file'
    kw = dict(radius=700, fill_color='red', popup=popup,
              fill_opacity=0.75)
    mapa.circle_marker(location=location, **kw)


# Clusters.
for station, info in groups:
    station = get_coops_longname(station)
    for lat, lon, name in zip(info.lat, info.lon, info.name):
        location = lat, lon
        popup = '<b>{}</b>\n{}'.format(station, name)
        mapa.simple_marker(location=location, popup=popup,
                           clustered_marker=True)

# Model and observations.
resolution, width, height = 75, 7, 3
for station in dfs:
    sta_name = get_coops_longname(station)
    df = dfs[station].dropna(axis=1, how='all')

    fig, ax = plt.subplots(figsize=(width, height))
    for col in df.columns:
        ax.plot(df.index, df[col], linewidth=2.5, alpha=0.5,
                label=col)
    ax.set_ylabel('Sea surface Temperature (celsius)')
    # ax.set_ylim(-1.5, 1.5)
    ax.grid(False)
    kw = dict(loc='upper center', bbox_to_anchor=(0.5, 1.05), numpoints=1,
              ncol=2, framealpha=0)
    l = ax.legend(**kw)
    # Workaround "None."
    l.set_title("")

    [connect(fig, LineLabelTooltip(line, name))
     for line, name in zip(ax.lines, df.columns)]

    html = 'station_{}.html'.format(station)
    save_html(fig, '{}/{}'.format(directory, html))

    popup = "<div align='center'> {} <br><iframe src='{}' alt='image'"
    popup += "width='{}px' height='{}px' frameBorder='0'></div>"
    popup = popup.format('{}'.format(sta_name), html,
                         (width*resolution)+75, (height*resolution)+50)
    kw = dict(popup=popup, width=(width*resolution)+75)

    if (df.columns == 'OBS_DATA').all():
        kw.update(dict(marker_color="blue", marker_icon="ok"))
    else:
        conj = set(df.columns)
        conj.intersection_update(secoora_models)
        if conj:
            kw.update(dict(marker_color="green", marker_icon="ok-sign"))
        else:
            kw.update(dict(marker_color="green", marker_icon="ok"))
    obs = observations[observations['station'] == station].squeeze()
    mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# Bad stations.
if isinstance(bad_station, DataFrame):
    for station, obs in bad_station.iterrows():
        popup = '<b>Station:</b> {}'
        popup = popup.format(station)
        kw = dict(popup=popup, marker_color="red", marker_icon="question-sign")
        mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %%
mapa.create_map(path=os.path.join(directory, 'mapa.html'))
inline_map(os.path.join(directory, 'mapa.html'))
# Out:
#         <iframe
#             width="750"
#             height=500"
#             src="2014-07-07/mapa.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Model skill

# %%
from glob import glob
from pandas import Panel
from utilities import nc2df

fname = '{}-OBS_DATA.nc'.format(directory)
fname = os.path.join(directory, fname)

OBS_DATA = nc2df(fname)
index = OBS_DATA.index
dfs = dict(OBS_DATA=OBS_DATA)

for fname in glob(os.path.join(directory, "*.nc")):
    if 'OBS_DATA' in fname:
        pass
    else:
        model = fname.split('.')[0].split('-')[-1]
        df = nc2df(fname)
        if model == 'USF_FVCOM':
            # FIXME: Horrible work around duplicate times in USF FVCOM.
            opts = dict(cols='index', take_last=True)
            df = df.reset_index().drop_duplicates(**opts).set_index('index')
        if False:  # I am not interpolating for now.
            kw = dict(method='time')
            df = df.reindex(index).interpolate(**kw).ix[index]
        dfs.update({model: df})

dfs = Panel.fromDict(dfs).swapaxes(0, 2)

# %%
from scipy.stats.stats import pearsonr

from utilities import both_valid


skill, skill_p = dict(), dict()
for station, df in dfs.iteritems():
    df.dropna(axis=0, how='all', inplace=True)
    df.dropna(axis=1, how='all', inplace=True)
    obs = df.pop('OBS_DATA')
    for model, y in df.iteritems():
        mask = both_valid(obs, y)
        r, p = pearsonr(obs[mask]-obs.mean(), y[mask]-y.mean())
        skill.update({station: {model: r}})
        skill_p.update({station: {model: p}})

df = DataFrame.from_dict(skill)

columns = dict()
[columns.update({station: get_coops_longname(station)}) for
 station in df.columns.values]

df.rename(columns=columns, inplace=True)

# %% [markdown]
# ### Annotated Heatmap (test)

# %%
# %matplotlib inline
import numpy as np
from matplotlib import patheffects

df = df.T
fig, ax = plt.subplots(figsize=(7, 21))
m, n = len(df.index), len(df.columns)
ax.imshow(df, interpolation='nearest', cmap='Oranges')
ax.set_xticks(np.linspace(0, n-1, n))
ax.set_xticklabels(df.columns)
ax.set_yticks(np.linspace(0, m-1, m))
ax.set_yticklabels(df.index)
ax.grid('off')
ax.xaxis.tick_top()

path_effects = [patheffects.withSimplePatchShadow(shadow_rgbFace=(1, 1, 1))]
for i in range(m):
    for j in range(n):
        ax.text(j, i, '{:.2f}'.format(df.iget_value(i, j)),
                size='medium', ha='center', va='center',
                path_effects=path_effects)

# %%
from utilities import to_html

fname = os.path.join(directory, 'skill.html'.format(directory))

df_skill = df.applymap('{:.2f}'.format).replace('nan', '--')

with open(style, 'r') as f:
    css = """<style>{}</style>""".format(f.read())
    html_skill = dict(style=css, table=df_skill.T.to_html())
    html_skill = '{style}<div class="datagrid">{table}</div>'.format(**html_skill)

with open(fname, 'w') as f:
    f.writelines(html_skill)


to_html(df_skill, style)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>COAWST_4</th>
#       <th>ESPRESSO</th>
#       <th>HYCOM</th>
#       <th>NECOFS_GOM3_WAVE</th>
#       <th>USF_ROMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Duck, NC</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td> -0.39</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>  0.81</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>USCG Station Hatteras, NC</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>  0.68</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Beaufort, NC</th>
#       <td>   --</td>
#       <td> 0.58</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Wrightsville Beach, NC</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.78</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Springmaid Pier, SC</th>
#       <td> 0.83</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Fort Pulaski, GA</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>  0.18</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Lake Worth Pier, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td> 0.28</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Vaca Key, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>  0.57</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Key West, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>  0.57</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Naples, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>  0.16</td>
#     </tr>
#     <tr>
#       <th>Fort Myers, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Port Manatee, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Old Port Tampa, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>  0.48</td>
#     </tr>
#     <tr>
#       <th>Apalachicola, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td> -0.33</td>
#     </tr>
#     <tr>
#       <th>Panama City, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Panama City Beach, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td> -0.14</td>
#     </tr>
#     <tr>
#       <th>Pensacola, FL</th>
#       <td> 0.30</td>
#       <td>   --</td>
#       <td>   --</td>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
import qrcode

qr = qrcode.QRCode(version=1,
                   error_correction=qrcode.constants.ERROR_CORRECT_L,
                   box_size=10,
                   border=4)

nbviewer = "http://nbviewer.ipython.org/github"
github = "ioos/secoora/blob/master/notebooks/temperature"
qr.add_data('{}/{}/00-temperature_secoora.ipynb'.format(nbviewer, github))
qr.make(fit=True)

img = qr.make_image()
fig, ax = plt.subplots()
ax.imshow(img)
ax.axis('off')
title = ax.set_title("Notebook nbviewer link")

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

# %%
with open('{}/log.txt'.format(directory)) as f:
    print(f.read())
# Out:
# 06:43:13 INFO: *********************** Run information ************************
# 06:43:13 INFO: Run date: 2015-01-19 21:43:13
# 06:43:13 INFO: Download start: 2014-06-30 12:00:00
# 06:43:13 INFO: Download stop: 2014-07-07 12:00:00
# 06:43:13 INFO: Bounding box: -87.40, 24.25,-74.70, 36.70
# 06:43:13 INFO: *********************** Software version ***********************
# 06:43:13 INFO: Iris version: 1.8.0-DEV
# 06:43:13 INFO: owslib version: 0.8-dev
# 06:43:13 INFO: pyoos version: 0.6.2
# 06:43:22 INFO: ********************* Catalog information **********************
# 06:43:22 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 06:43:22 INFO: CSW version: 2.0.2
# 06:43:22 INFO: Number of datasets available: 37
# 06:43:22 INFO: ***************************** CSW ******************************
# 06:43:22 INFO: USF FVCOM - Nowcast Aggregation
# 06:43:22 INFO: ROMS/TOMS 3.0 - New Floria Shelf Application
# 06:43:22 INFO: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
# 06:43:22 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY CANYON OUTER, CA from 2013/07/11 17:00:00 to 2014/07/01 20:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY BAY WEST, CA from 2013/06/19 18:00:00 to 2014/07/01 14:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MONTEREY BAY WEST, CA from 2014/07/01 19:00:00 to 2014/10/04 23:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SAN FRANCISCO BAR, CA from 2013/06/19 22:00:00 to 2014/07/24 14:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near POINT REYES, CA from 2013/10/16 21:00:00 to 2014/09/05 11:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near HUMBOLDT BAY NORTH SPIT, CA from 2013/08/26 19:00:00 to 2014/07/24 03:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near DIABLO CANYON, CA from 2013/08/28 23:00:00 to 2014/10/29 16:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near CLATSOP SPIT, OR from 2013/07/18 20:00:00 to 2015/01/12 18:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near ASTORIA CANYON, OR from 2014/01/16 20:00:00 to 2014/09/29 22:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near SAN FRANCISCO BAR, CA from 2007/07/25 to 2014/07/24.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SANTA CRUZ BASIN, CA from 2013/07/09 15:00:00 to 2014/07/14 16:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near OCEAN STATION PAPA from 2012/10/04 21:00:00 to 2015/01/01 00:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near CAMP PENDLETON NEARSHORE, CA from 2014/04/24 22:00:00 to 2014/06/06 16:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SAN NICOLAS ISLAND, CA from 2013/04/19 17:00:00 to 2014/06/08 21:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near TORREY PINES OUTER, CA from 2014/06/10 21:00:00 to 2014/06/12 15:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near SCRIPPS NEARSHORE, CA from 2013/07/12 20:00:00 to 2015/01/07 17:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MISSION BAY OFFSHORE, CA from 2014/04/28 21:00:00 to 2014/06/24 09:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near OCEANSIDE OFFSHORE, CA from 1997/05/19 to 2014/10/14.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near POINT LOMA SOUTH, CA from 2013/08/12 20:00:00 to 2014/09/10 07:59:59.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near MOKAPU POINT, HI from 2000/08/09 to 2014/09/10.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near TORREY PINES OUTER, CA from 2001/01/30 to 2014/06/06.
# 06:43:22 INFO: ROMS ESPRESSO Real-Time Operational IS4DVAR Forecast System Version 2 (NEW) 2013-present FMRC History (Best)
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near SAN NICOLAS ISLAND, CA from 1991/09/10 to 2014/06/08.
# 06:43:22 INFO: NDBC Standard Meteorological Buoy Data
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near POINT REYES, CA from 1996/12/06 to 2014/09/05.
# 06:43:22 INFO: HYbrid Coordinate Ocean Model (HYCOM): Global
# 06:43:22 INFO: National Data Buoy Center SOS
# 06:43:22 INFO: G1SST, 1km blended SST
# 06:43:22 INFO: NOAA Coral Reef Watch Operational Twice-Weekly Near-Real-Time Global 50km Satellite Coral Bleaching Monitoring Products
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near MASONBORO INLET, ILM2, NC from 2014/03/14 16:00:00 to 2015/01/06 13:59:59.where the water depth is approximately
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near MASONBORO INLET, ILM2, NC from 2008/05/07 to 2015/01/06.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Waverider buoys located near NEW RIVER INLET, NC from 2012/04/14 to 2014/07/11.
# 06:43:22 INFO: Directional wave and sea surface temperature measurements collected in situ by Datawell Mark 3 directional buoy located near NEW RIVER INLET, NC from 2014/03/09 19:00:00 to 2014/07/11 23:59:59.
# 06:43:22 INFO: ***************************** DAP ******************************
# 06:43:22 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc.html
# 06:43:22 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd.html
# 06:43:22 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 06:43:22 INFO: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd.html
# 06:43:22 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw.html
# 06:43:22 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 06:43:22 INFO: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd.html
# 06:43:22 INFO: http://thredds.axiomalaska.com/thredds/dodsC/G1_SST_GLOBAL.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d27.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_d07.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d04.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d02.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d02.nc.html
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc.html
# 06:43:22 INFO: ***************************** SOS ******************************
# 06:43:22 INFO: http://sdf.ndbc.noaa.gov/sos/server.php?service=SOS&request=GetCapabilities&acceptVersions=1.0.0
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d19.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d16.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d22.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/076p1/076p1_d27.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d40.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/098p1/098p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/150p1/150p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/150p1/150p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/156p1/156p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/162p1/162p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/166p1/166p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/168p1/168p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/179p1/179p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/185p1/185p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/185p1/185p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/190p1/190p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/190p1/190p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/201p1/201p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 INFO: http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/203p1/203p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# 06:43:22 WARNING: USEAST not in the NGDC csw
# 06:43:22 WARNING: USF_SWAN not in the NGDC csw
# 06:44:06 INFO: ********************* Collector offerings **********************
# 06:44:06 INFO: NOAA.NOS.CO-OPS SOS: 1030 offerings
# 06:44:10 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2014-06-30T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AMetActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87.4%2C24.25%2C-74.7%2C36.7&observedProperty=sea_water_temperature
# 06:44:52 INFO: ************************* Observations *************************
# 06:44:52 INFO: **** Downloading to file 2014-07-07/2014-07-07-OBS_DATA.nc *****
# 06:47:50 INFO: **************************** Models ****************************
# 06:47:50 INFO:
# [Reading url 1/37]: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# 06:52:50 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/FVCOM-Nowcast-Agg.nc
# Timed out!
# 06:52:50 INFO:
# [Reading url 2/37]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 06:52:56 INFO:
# [Reading url 3/37]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 06:56:41 INFO:
# [Reading url 4/37]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# 06:56:58 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/SABGOM_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 06:56:58 INFO:
# [Reading url 5/37]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/satellite/dhw
# 06:57:01 INFO:
# [Reading url 6/37]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 06:57:15 INFO:
# [Reading url 7/37]: http://tds.marine.rutgers.edu/thredds/dodsC/roms/espresso/2013_da/his_Best/ESPRESSO_Real-Time_v2_History_Best_Available_best.ncd
# 06:57:34 INFO:
# [Reading url 8/37]: http://thredds.axiomalaska.com/thredds/dodsC/G1_SST_GLOBAL.nc
# 06:58:07 INFO:
# [Reading url 9/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc
# 06:58:18 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc
# index 0 is out of bounds for axis 0 with size 0
# 06:58:18 INFO:
# [Reading url 10/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc
# 07:02:25 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:02:25 INFO:
# [Reading url 11/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc
# 07:02:38 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc
# need more than 0 values to unpack
# 07:02:38 INFO:
# [Reading url 12/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_historic.nc
# 07:07:14 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_historic.nc
# need more than 0 values to unpack
# 07:07:14 INFO:
# [Reading url 13/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc
# 07:07:41 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc
# need more than 0 values to unpack
# 07:07:41 INFO:
# [Reading url 14/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc
# 07:13:10 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc
# Timed out!
# 07:13:10 INFO:
# [Reading url 15/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d27.nc
# 07:13:47 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d27.nc
# need more than 0 values to unpack
# 07:13:47 INFO:
# [Reading url 16/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc
# 07:13:55 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc
# need more than 0 values to unpack
# 07:13:55 INFO:
# [Reading url 17/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc
# 07:16:11 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:16:11 INFO:
# [Reading url 18/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc
# 07:16:14 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc
# need more than 0 values to unpack
# 07:16:14 INFO:
# [Reading url 19/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc
# 07:21:15 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc
# Timed out!
# 07:21:15 INFO:
# [Reading url 20/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc
# 07:21:23 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:21:23 INFO:
# [Reading url 21/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc
# 07:27:33 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc
# Timed out!
# 07:27:33 INFO:
# [Reading url 22/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_d07.nc
# 07:29:54 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_d07.nc
# need more than 0 values to unpack
# 07:29:54 INFO:
# [Reading url 23/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_historic.nc
# 07:37:31 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/150p1/150p1_historic.nc
# Timed out!
# 07:37:31 INFO:
# [Reading url 24/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc
# 07:38:29 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:38:29 INFO:
# [Reading url 25/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d04.nc
# 07:39:33 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d04.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:39:33 INFO:
# [Reading url 26/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d02.nc
# 07:40:07 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d02.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:40:07 INFO:
# [Reading url 27/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc
# 07:40:25 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:40:25 INFO:
# [Reading url 28/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc
# 07:40:45 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:40:45 INFO:
# [Reading url 29/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc
# 07:41:07 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:41:07 INFO:
# [Reading url 30/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc
# 07:41:20 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc
# index 0 is out of bounds for axis 0 with size 0
# 07:41:20 INFO:
# [Reading url 31/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc
# 07:41:36 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_d02.nc
# need more than 0 values to unpack
# 07:41:36 INFO:
# [Reading url 32/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc
# 07:42:04 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/190p1/190p1_historic.nc
# need more than 0 values to unpack
# 07:42:04 INFO:
# [Reading url 33/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc
# 07:42:33 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc
# need more than 0 values to unpack
# 07:42:33 INFO:
# [Reading url 34/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d02.nc
# 07:43:06 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d02.nc
# need more than 0 values to unpack
# 07:43:06 INFO:
# [Reading url 35/37]: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc
# 07:43:22 WARNING: Cannot get cube for: http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc
# need more than 0 values to unpack
# 07:43:22 INFO:
# [Reading url 36/37]: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# 07:43:36 WARNING: Cannot get cube for: http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/us_east/US_East_Forecast_Model_Run_Collection_best.ncd
# istart must be different from istop! Got istart 0 and  istop 0
# 07:43:36 INFO:
# [Reading url 37/37]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 07:43:37 WARNING: Cannot get cube for: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# Cube does not contain ['sea_water_temperature', 'sea_surface_temperature', 'sea_water_potential_temperature', 'equivalent_potential_temperature', 'sea_water_conservative_temperature', 'pseudo_equivalent_potential_temperature']
# 07:43:37 INFO: ****** Downloading to file 2014-07-07/2014-07-07-HYCOM.nc ******
# 07:43:39 INFO: [Land ] Duck, NC
# 07:43:41 INFO: [Water] Oregon Inlet Marina, NC
# 07:43:43 INFO: [Land ] USCG Station Hatteras, NC
# 07:43:50 INFO: [Land ] Beaufort, NC
# 07:44:06 INFO: [Land ] Wilmington, NC
# 07:44:09 INFO: [Water] Wrightsville Beach, NC
# 07:44:09 WARNING: No data near (-78.9183, 33.655) max_dist=0.04.
# 07:44:12 INFO: [Land ] Charleston, SC
# 07:44:14 INFO: [Land ] Fort Pulaski, GA
# 07:44:16 INFO: [Land ] Fernandina Beach, FL
# 07:44:18 INFO: [Land ] Mayport (Bar Pilots Dock), FL
# 07:44:20 INFO: [Land ] Dames Point, FL
# 07:44:22 INFO: [Land ] Jacksonville University, FL
# 07:44:24 INFO: [Land ] I-295 Bridge, St Johns River, FL
# 07:44:26 INFO: [Land ] Red Bay Point, St Johns River, FL
# 07:44:26 WARNING: No data near (-81.5483, 29.8017) max_dist=0.04.
# 07:44:29 INFO: [Land ] Trident Pier, FL
# 07:44:37 INFO: [Water] Lake Worth Pier, FL
# 07:44:39 INFO: [Land ] Vaca Key, FL
# 07:44:41 INFO: [Land ] Key West, FL
# 07:44:41 WARNING: No data near (-81.8075, 26.1317) max_dist=0.04.
# 07:44:42 INFO: [Land ] Fort Myers, FL
# 07:44:44 INFO: [Land ] Port Manatee, FL
# 07:44:47 INFO: [Land ] St Petersburg, FL
# 07:44:49 INFO: [Land ] Old Port Tampa, FL
# 07:44:52 INFO: [Land ] Apalachicola, FL
# 07:44:54 INFO: [Land ] Panama City, FL
# 07:44:54 WARNING: No data near (-85.8783, 30.2133) max_dist=0.04.
# 07:44:56 INFO: [Land ] Pensacola, FL
# 07:44:56 INFO: Finished processing [HYCOM]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 07:44:56 INFO: **** Downloading to file 2014-07-07/2014-07-07-USF_ROMS.nc *****
# 07:44:56 WARNING: No data near (-75.7467, 36.1833) max_dist=0.04.
# 07:44:56 WARNING: No data near (-75.5483, 35.795) max_dist=0.04.
# 07:44:56 WARNING: No data near (-75.7042, 35.2086) max_dist=0.04.
# 07:44:56 WARNING: No data near (-76.67, 34.72) max_dist=0.04.
# 07:44:56 WARNING: No data near (-77.9533, 34.2267) max_dist=0.04.
# 07:44:56 WARNING: No data near (-77.7867, 34.2133) max_dist=0.04.
# 07:44:56 WARNING: No data near (-78.9183, 33.655) max_dist=0.04.
# 07:44:56 WARNING: No data near (-79.925, 32.7817) max_dist=0.04.
# 07:44:56 WARNING: No data near (-80.9017, 32.0333) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.465, 30.6717) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.43, 30.3967) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.5583, 30.3867) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.6118, 30.3541) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.6917, 30.1917) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.6283, 29.9783) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.5483, 29.8017) max_dist=0.04.
# 07:44:56 WARNING: No data near (-80.5931, 28.4158) max_dist=0.04.
# 07:44:56 WARNING: No data near (-80.0333, 26.6117) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.105, 24.7117) max_dist=0.04.
# 07:44:56 WARNING: No data near (-81.8079, 24.5557) max_dist=0.04.
# 07:44:57 INFO: [Water] Naples, FL
# 07:44:59 INFO: [Water] Fort Myers, FL
# 07:45:03 INFO: [Water] Port Manatee, FL
# 07:45:03 WARNING: No data near (-82.6269, 27.7606) max_dist=0.04.
# 07:45:04 INFO: [Water] Old Port Tampa, FL
# 07:45:07 INFO: [Water] Apalachicola, FL
# 07:45:11 INFO: [Water] Panama City, FL
# 07:45:15 INFO: [Water] Panama City Beach, FL
# 07:45:15 WARNING: No data near (-87.2112, 30.4044) max_dist=0.04.
# 07:46:11 INFO: Finished processing [USF_ROMS]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 07:46:11 INFO: **** Downloading to file 2014-07-07/2014-07-07-COAWST_4.nc *****
# 07:46:19 INFO: [Land ] Duck, NC
# 07:46:32 INFO: [Water] Oregon Inlet Marina, NC
# 07:46:38 INFO: [Water] USCG Station Hatteras, NC
# 07:46:52 INFO: [Land ] Beaufort, NC
# 07:46:58 INFO: [Land ] Wilmington, NC
# 07:47:06 INFO: [Water] Wrightsville Beach, NC
# 07:47:27 INFO: [Water] Springmaid Pier, SC
# 07:47:42 INFO: [Land ] Charleston, SC
# 07:47:56 INFO: [Land ] Fort Pulaski, GA
# 07:48:03 INFO: [Land ] Fernandina Beach, FL
# 07:48:10 INFO: [Land ] Mayport (Bar Pilots Dock), FL
# 07:48:18 INFO: [Land ] Dames Point, FL
# 07:48:24 INFO: [Land ] Jacksonville University, FL
# 07:48:32 INFO: [Land ] I-295 Bridge, St Johns River, FL
# 07:48:41 INFO: [Land ] Red Bay Point, St Johns River, FL
# 07:48:48 INFO: [Land ] Racy Point, St Johns River, FL
# 07:48:56 INFO: [Land ] Trident Pier, FL
# 07:49:10 INFO: [Water] Lake Worth Pier, FL
# 07:49:22 INFO: [Land ] Vaca Key, FL
# 07:49:45 INFO: [Water] Key West, FL
# 07:49:52 INFO: [Land ] Naples, FL
# 07:49:59 INFO: [Land ] Fort Myers, FL
# 07:50:07 INFO: [Land ] Port Manatee, FL
# 07:50:15 INFO: [Land ] St Petersburg, FL
# 07:50:29 INFO: [Water] Old Port Tampa, FL
# 07:50:37 INFO: [Water] Apalachicola, FL
# 07:50:45 INFO: [Water] Panama City, FL
# 07:51:00 INFO: [Land ] Panama City Beach, FL
# 07:51:09 INFO: [Water] Pensacola, FL
# 07:52:10 INFO: Finished processing [COAWST_4]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 07:52:10 INFO: **** Downloading to file 2014-07-07/2014-07-07-ESPRESSO.nc *****
# 07:52:16 INFO: [Land ] Duck, NC
# 07:52:23 INFO: [Water] Oregon Inlet Marina, NC
# 07:52:29 INFO: [Land ] USCG Station Hatteras, NC
# 07:52:34 INFO: [Water] Beaufort, NC
# 07:52:34 WARNING: No data near (-77.9533, 34.2267) max_dist=0.04.
# 07:52:34 WARNING: No data near (-77.7867, 34.2133) max_dist=0.04.
# 07:52:34 WARNING: No data near (-78.9183, 33.655) max_dist=0.04.
# 07:52:34 WARNING: No data near (-79.925, 32.7817) max_dist=0.04.
# 07:52:34 WARNING: No data near (-80.9017, 32.0333) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.465, 30.6717) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.43, 30.3967) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.5583, 30.3867) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.6118, 30.3541) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.6917, 30.1917) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.6283, 29.9783) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.5483, 29.8017) max_dist=0.04.
# 07:52:34 WARNING: No data near (-80.5931, 28.4158) max_dist=0.04.
# 07:52:34 WARNING: No data near (-80.0333, 26.6117) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.105, 24.7117) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.8079, 24.5557) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.8075, 26.1317) max_dist=0.04.
# 07:52:34 WARNING: No data near (-81.8712, 26.6477) max_dist=0.04.
# 07:52:34 WARNING: No data near (-82.5621, 27.6387) max_dist=0.04.
# 07:52:34 WARNING: No data near (-82.6269, 27.7606) max_dist=0.04.
# 07:52:34 WARNING: No data near (-82.5527, 27.8578) max_dist=0.04.
# 07:52:34 WARNING: No data near (-84.9817, 29.7267) max_dist=0.04.
# 07:52:34 WARNING: No data near (-85.6669, 30.1523) max_dist=0.04.
# 07:52:34 WARNING: No data near (-85.8783, 30.2133) max_dist=0.04.
# 07:52:34 WARNING: No data near (-87.2112, 30.4044) max_dist=0.04.
# 07:52:40 INFO: Finished processing [ESPRESSO]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 07:52:40 INFO:  Downloading to file 2014-07-07/2014-07-07-NECOFS_GOM3_WAVE.nc *
# 07:53:24 INFO: [Water] Duck, NC
# 07:53:41 INFO: [Water] Oregon Inlet Marina, NC
# 07:53:58 INFO: [Water] USCG Station Hatteras, NC
# 07:54:13 INFO: [Land ] Beaufort, NC
# 07:54:14 INFO: [Land ] Wilmington, NC
# 07:54:24 INFO: [Land ] Wrightsville Beach, NC
# 07:54:28 INFO: [Land ] Springmaid Pier, SC
# 07:54:32 INFO: [Land ] Charleston, SC
# 07:54:49 INFO: [Water] Fort Pulaski, GA
# 07:54:51 INFO: [Land ] Fernandina Beach, FL
# 07:54:53 INFO: [Land ] Mayport (Bar Pilots Dock), FL
# 07:54:54 INFO: [Land ] Dames Point, FL
# 07:54:56 INFO: [Land ] Jacksonville University, FL
# 07:54:58 INFO: [Land ] I-295 Bridge, St Johns River, FL
# 07:54:59 INFO: [Land ] Red Bay Point, St Johns River, FL
# 07:55:02 INFO: [Land ] Racy Point, St Johns River, FL
# 07:55:08 INFO: [Land ] Trident Pier, FL
# 07:55:09 INFO: [Land ] Lake Worth Pier, FL
# 07:55:26 INFO: [Water] Vaca Key, FL
# 07:55:42 INFO: [Water] Key West, FL
# 07:55:44 INFO: [Land ] Naples, FL
# 07:55:45 INFO: [Land ] Fort Myers, FL
# 07:55:47 INFO: [Land ] Port Manatee, FL
# 07:55:52 INFO: [Land ] St Petersburg, FL
# 07:55:57 INFO: [Land ] Old Port Tampa, FL
# 07:56:07 INFO: [Land ] Apalachicola, FL
# 07:56:10 INFO: [Land ] Panama City, FL
# 07:56:20 INFO: [Land ] Panama City Beach, FL
# 07:56:21 INFO: [Land ] Pensacola, FL
# 07:56:21 INFO: Finished processing [NECOFS_GOM3_WAVE]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_SWAN_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_SWAN_Nowcast_Forecast_Wave_Model_Data_best.ncd
# 07:56:55 WARNING: /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
#
# 07:57:19 INFO: 74.18 minutes
# 07:57:19 INFO: EOF
