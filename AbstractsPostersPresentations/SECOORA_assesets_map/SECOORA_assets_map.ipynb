# %% [markdown]
# ## Creating GeoJSONs for  HF-radar range

# %% [markdown]
# We are loading both the HF-radar and buoys data from the Excel files @vembus provided.
# (Note that we are not plotting the stations yet.)

# %%
import pandas as pd


stations = pd.read_excel('secoora_station_assets.xlsx', index_col=2)
stations
# Out:
#                                              Name ResponsibleParty  \
# DisplayTitle
# ILM2                               Onslow Bay 18M   UNC-Wilmington
# ILM3                               Onslow Bay 30M   UNC-Wilmington
# SUN2                          Sunset Beach Bouy 2   UNC-Wilmington
# CAP2                         Capers Island Buoy 2   UNC-Wilmington
# FRP2                          Fripp Island Bouy 2   UNC-Wilmington
# LEJ3                                Lejune Buoy 3   UNC-Wilmington
# OBL2                               Onslow Bay 27B   UNC-Wilmington
# LED2                     Onslow Bay 200-200 Ledge   UNC-Wilmington
# CBL2                         Carolina Beach Ledge   UNC-Wilmington
# FFL2                            Fort Fisher Ledge   UNC-Wilmington
# BCP                       Big Carlos Pass Station          USF-CMS
# EGK                                    Egmont Key          USF-CMS
# CLB                            Clam Bayou Station          USF-CMS
# FHP                      Fred Howard Park Station          USF-CMS
# NFB                 Northwest Florida Bay Station          USF-CMS
# SHP                Shellpoint Water Level Station          USF-CMS
# C10                           USF CMS C10 Mooring          USF-CMS
# C12                            USFCMS C12 Mooring          USF-CMS
# C13                            USFCMS C13 Mooring          USF-CMS
# C21                    USFCMS C21 Coastal Station          USF-CMS
# C11                       USFCMS C11 Bottom Mount          USF-CMS
# C15                      USF CMS C15 Bottom Mount          USF-CMS
# Gray's Reef           NOAA OA Gray's Reef Mooring              UGA
# UGApH                      UGA Seafloor pH sensor              UGA
# Charleston Harbor               Charleston Harbor            SCDNR
#
#                                  PlatformType   Latitude  Longitude  \
# DisplayTitle
# ILM2                       Fixed Surface Buoy  34.130000 -77.710000
# ILM3                       Fixed Surface Buoy  33.980000 -77.350000
# SUN2                       Fixed Surface Buoy  33.848000 -78.489000
# CAP2                       Fixed Surface Buoy  32.800000 -79.620000
# FRP2                       Fixed Surface Buoy  32.280000 -80.410000
# LEJ3                       Fixed Surface Buoy  34.210833 -76.952500
# OBL2               Fixed Bottom Mount Mooring  33.900000 -77.300000
# LED2               Fixed Bottom Mount Mooring  34.110000 -77.360000
# CBL2               Fixed Bottom Mount Mooring  34.000000 -77.760000
# FFL2               Fixed Bottom Mount Mooring  33.960000 -77.870000
# BCP                     Fixed Coastal Station  26.404483 -81.881000
# EGK                     Fixed Coastal Station  27.601000 -82.760000
# CLB                     Fixed Coastal Station  27.736083 -82.691733
# FHP                     Fixed Coastal Station  28.153250 -82.801150
# NFB                     Fixed Coastal Station  25.084350 -81.095733
# SHP                     Fixed Coastal Station  30.060117 -84.290500
# C10                        Fixed Surface Buoy  27.169167 -82.926167
# C12                        Fixed Surface Buoy  27.498333 -83.721667
# C13                        Fixed Surface Buoy  26.051917 -83.079917
# C21                     Fixed Coastal Station  27.677500 -82.769933
# C11                Fixed Bottom Mount Mooring  27.200000 -82.780000
# C15                Fixed Bottom Mount Mooring  27.300000 -82.640000
# Gray's Reef                Fixed Surface Buoy  31.400000 -80.860000
# UGApH                    Fixed Bottom Station  31.402700 -80.870200
# Charleston Harbor       Fixed Coastal Station  32.783000 -79.900000
#
#                          Status  \
# DisplayTitle
# ILM2                Operational
# ILM3                Operational
# SUN2                Operational
# CAP2                Operational
# FRP2                Operational
# LEJ3                Operational
# OBL2                    Planned
# LED2                    Planned
# CBL2                    Planned
# FFL2                    Planned
# BCP                 Operational
# EGK                Construction
# CLB                 Operational
# FHP                 Operational
# NFB                 Operational
# SHP                 Operational
# C10                 Operational
# C12                 Operational
# C13                 Operational
# C21                 Operational
# C11                 Operational
# C15                 Operational
# Gray's Reef         Operational
# UGApH               Operational
# Charleston Harbor       Planned
#
#                                                  LocationDescription
# DisplayTitle
# ILM2                                                            ILM2
# ILM3                                                            ILM3
# SUN2                                            Nearshore Sunset, NC
# CAP2                              Nearshore Charleston/Capers Island
# FRP2                             Nearshore Beaufort/Fripp Island, SC
# LEJ3                                        Offshore Camp Lejune, NC
# OBL2                                                        OB27B30M
# LED2                                                  OB200-200Ledge
# CBL2                                                         CBLedge
# FFL2                                                   FortFishLedge
# BCP                Big Carlos Pass Bridge between the cities of F...
# EGK                                                        Tampa Bay
# CLB                                        South Clam Bayou. Florida
# FHP                Fred Howard Park Coastal Station;Howard Park C...
# NFB                                       SSW of Cape Sable, Florida
# SHP                                           Shell Point Beach Park
# C10                Less than 30 miles west off the coast of Ospre...
# C12                About 70 miles west off the coast of Bradenton...
# C13                About 70 miles west off the coast of Naples Fl...
# C21                About 2 miles west off the coast of Pass A Gri...
# C11                Less than 20 miles west off the coast of Ospre...
# C15                About 4 miles west off the coast of South Lido...
# Gray's Reef                                  NDBC Grays Reef OA Buoy
# UGApH                                         UGA Seafloor pH sensor
# Charleston Harbor                                  Charleston Harbor

# %%
hfradar = pd.read_excel('secoora_hfradar_sites.xlsx', index_col=3)
hfradar
# Out:
#                                           ResponsibleParty   Type  \
# Abrreviated ID
# DUCK                          University of North Carolina  CODAR
# HATY                          University of North Carolina  CODAR
# GTN                           University of South Carolina   WERA
# CSW                           University of South Carolina   WERA
# CAT                     Skidaway Institute of Oceanography   WERA
# JEK                     Skidaway Institute of Oceanography   WERA
# STF                                    University of Miami   WERA
# VIR                                    University of Miami   WERA
# CDN                                    University of Miami   WERA
# BDK                                    University of Miami   WERA
# RDSR                           University of South Florida  CODAR
# VENI                           University of South Florida  CODAR
# NAPL                           University of South Florida  CODAR
# FDS                            University of South Florida  CODAR
# CORE            University of North Carolina - Chapel Hill  CODAR
# PCL                                University of Miami/FIT   WERA
# VBC                                University of Miami/FIT   WERA
#
#                     DisplayTitle  Latitude  Longitude   MHz       Status  \
# Abrreviated ID
# DUCK                        Duck     36.18     -75.75   5.0  Operational
# HATY               Cape Hatteras     35.26     -75.52   5.0  Operational
# GTN                   Georgetown     33.25     -79.15   8.3  Operational
# CSW                Caswell Beach     33.88     -78.11   8.3  Operational
# CAT                St. Catherine     31.69     -81.13   8.3  Operational
# JEK                Jekyll Island     31.06     -81.41   8.3  Operational
# STF                  Dania Beach     26.08     -80.12  12.6  Operational
# VIR                 Virginia Key     25.74     -80.15  12.6  Operational
# CDN                 Crandon Park     25.71     -80.15  16.0  Operational
# BDK                    Broad Key     25.35     -80.25  16.0   Permitting
# RDSR            Redington Shores     27.83     -82.83   5.0  Operational
# VENI                      Venice     27.08     -82.45   5.0  Operational
# NAPL                      Naples     26.16     -81.81   5.0  Operational
# FDS                  Fort deSoto     27.58     -82.73   5.0   Permitting
# CORE                  Core Banks     34.76     -76.41   5.0  Operational
# PCL               Port Canaveral     28.50     -80.53   8.3      Planned
# VBC                   Vero Beach     27.50     -80.35   8.3      Planned
#
#                 StartAngle  SpreadAngle
# Abrreviated ID
# DUCK                     5         -120
# HATY                    60         -170
# GTN                     20         -120
# CSW                    -15         -120
# CAT                     20         -120
# JEK                     55         -120
# STF                     55         -120
# VIR                     68         -120
# CDN                     31         -120
# BDK                    NaN          NaN
# RDSR                   -70         -120
# VENI                  -100         -120
# NAPL                  -120         -120
# FDS                    NaN          NaN
# CORE                    50         -120
# PCL                    NaN          NaN
# VBC                    NaN          NaN

# %% [markdown]
# The HF-radar spreadsheet did not have a radius column (radar range).
#
# The radii below is something put together from the GMT script @vembus sent.
# We are guessing that the number at the end of the location name is the frequency in (MHz).
#
# ```
# crandon16      100
# venice13       130
# dania12        130
# virginia12     130
# desoto13       130
# stcatherine8   160
# jekyll8        160
# georgetown8    160
# caswell8       160
# corebanks5     190
# duck5          190
# naples5        190
# redignton5     190
# venice5        190
# destin5        190
# orange5        190
# pascagoula5    190
# capehatteras5  190
# ```
#
# If that is correct the ranges are:
#
# - 16 MHz -> 100
# - 12.6 MHz -> 130
# - 8.3 MHz -> 160
# - 5 MHz -> 190

# %%
ranges = dict({'16': 100, '12': 130, '8': 160, '5': 190})

hfradar['Range'] = [ranges['{}'.format(int(key))] for key in  hfradar['MHz']]

hfradar
# Out:
#                                           ResponsibleParty   Type  \
# Abrreviated ID
# DUCK                          University of North Carolina  CODAR
# HATY                          University of North Carolina  CODAR
# GTN                           University of South Carolina   WERA
# CSW                           University of South Carolina   WERA
# CAT                     Skidaway Institute of Oceanography   WERA
# JEK                     Skidaway Institute of Oceanography   WERA
# STF                                    University of Miami   WERA
# VIR                                    University of Miami   WERA
# CDN                                    University of Miami   WERA
# BDK                                    University of Miami   WERA
# RDSR                           University of South Florida  CODAR
# VENI                           University of South Florida  CODAR
# NAPL                           University of South Florida  CODAR
# FDS                            University of South Florida  CODAR
# CORE            University of North Carolina - Chapel Hill  CODAR
# PCL                                University of Miami/FIT   WERA
# VBC                                University of Miami/FIT   WERA
#
#                     DisplayTitle  Latitude  Longitude   MHz       Status  \
# Abrreviated ID
# DUCK                        Duck     36.18     -75.75   5.0  Operational
# HATY               Cape Hatteras     35.26     -75.52   5.0  Operational
# GTN                   Georgetown     33.25     -79.15   8.3  Operational
# CSW                Caswell Beach     33.88     -78.11   8.3  Operational
# CAT                St. Catherine     31.69     -81.13   8.3  Operational
# JEK                Jekyll Island     31.06     -81.41   8.3  Operational
# STF                  Dania Beach     26.08     -80.12  12.6  Operational
# VIR                 Virginia Key     25.74     -80.15  12.6  Operational
# CDN                 Crandon Park     25.71     -80.15  16.0  Operational
# BDK                    Broad Key     25.35     -80.25  16.0   Permitting
# RDSR            Redington Shores     27.83     -82.83   5.0  Operational
# VENI                      Venice     27.08     -82.45   5.0  Operational
# NAPL                      Naples     26.16     -81.81   5.0  Operational
# FDS                  Fort deSoto     27.58     -82.73   5.0   Permitting
# CORE                  Core Banks     34.76     -76.41   5.0  Operational
# PCL               Port Canaveral     28.50     -80.53   8.3      Planned
# VBC                   Vero Beach     27.50     -80.35   8.3      Planned
#
#                 StartAngle  SpreadAngle  Range
# Abrreviated ID
# DUCK                     5         -120    190
# HATY                    60         -170    190
# GTN                     20         -120    160
# CSW                    -15         -120    160
# CAT                     20         -120    160
# JEK                     55         -120    160
# STF                     55         -120    130
# VIR                     68         -120    130
# CDN                     31         -120    100
# BDK                    NaN          NaN    100
# RDSR                   -70         -120    190
# VENI                  -100         -120    190
# NAPL                  -120         -120    190
# FDS                    NaN          NaN    190
# CORE                    50         -120    190
# PCL                    NaN          NaN    160
# VBC                    NaN          NaN    160

# %% [markdown]
# Here is our best interpretation of the data in the table as a map.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
from cartopy.io import shapereader
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER


def make_map(projection=ccrs.PlateCarree()):
    fig, ax = plt.subplots(figsize=(9, 13),
                           subplot_kw=dict(projection=projection))
    gl = ax.gridlines(draw_labels=True)
    gl.xlabels_top = gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    return fig, ax

# %%
from matplotlib.patches import Wedge


def make_wedge(radar):
    """
    Make a HF-radar "wedge" from a StartAngle, SpreadAngle, Center (Longitude, Latitude), and Radius (radar range).

    """
    r = radar['Range'] / 111.1  # deg2km
    theta1, theta2 = radar['StartAngle'], radar['SpreadAngle'],
    center = radar['Longitude'], radar['Latitude']
    kw = dict(alpha=0.3, color='lightgreen')
    return Wedge(center, r, theta1+theta2, theta1, **kw)

# %% [markdown]
# A simple static figure just to test this out.

# %%
dx = dy = 1.05
bbox = [-87.40-dx, -74.70+dx,
        24.25-dy, 36.70+dy]


fig, ax = make_map()
ax.set_extent(bbox)
ax.coastlines('10m')

kw = dict(marker='o', color='crimson')
for name, radar in hfradar.dropna().iterrows():
    p = ax.add_patch(make_wedge(radar))
    ax.plot(radar['Longitude'], radar['Latitude'], **kw)
    ax.text(radar['Longitude'], radar['Latitude'], radar['DisplayTitle'])
# Out:
# /home/filipe/miniconda/envs/secoora-skill/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Compare the image above against the original below.
#
# <img src="figure1_final.png" width="80%">

# %% [markdown]
# Now we can create polygons to plot on a map.
# At the and we save them as GeoJSONs to use in interactive maps (leaflet).

# %%
import json
from shapely.geometry import polygon, mapping

patch = make_wedge(radar)
p = patch.get_path()

shape = polygon.Polygon(p.vertices)
shape
# Out:
# WARNING:shapely.geos:Self-intersection at or near point -76.409999999999997 34.759999999999998

# %%
print(json.dumps(mapping(shape)))
# Out:
# {"type": "Polygon", "coordinates": [[[-75.82508706361946, 33.15296491494759], [-75.54301448802308, 33.255630936367474], [-75.29288200103353, 33.4307755893087], [-75.0999329955661, 33.660723259761994], [-74.90698399009867, 33.890670930215286], [-74.77793522852456, 34.16741689249417], [-74.72581032338145, 34.463031919381486], [-74.67368541823836, 34.758646946268804], [-74.7002988935277, 35.06284036078414], [-74.8029649149476, 35.34491293638053], [-74.90563093636747, 35.62698551197691], [-75.0807755893087, 35.87711799896646], [-75.31072325976199, 36.070067004433895], [-76.41, 34.76], [-75.82508706361946, 33.15296491494759], [-76.41, 34.76], [-75.82508706361946, 33.15296491494759]]]}

# %% [markdown]
# If that is OK we can start save all these JSON objects and move forward with the map.
