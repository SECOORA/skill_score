# %%
from datetime import datetime, timedelta

bbox = [-87.4, 24.25, -74.7, 36.70]  # SECOORA: NC, SC GA, FL

time = datetime.utcnow() - timedelta(hours=6)

# %% [markdown]
# ### HF radar

# %%
from iris.unit import Unit
from utilities import quick_load_cubes, proc_cube


url = 'http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/6km/hourly/RTV'

u_name_list = ['x_sea_water_velocity',
               'sea_water_x_velocity',
               'eastward_sea_water_velocity',
               'surface_eastward_sea_water_velocity']

v_name_list = ['y_sea_water_velocity',
               'sea_water_y_velocity',
               'northward_sea_water_velocity',
               'surface_northward_sea_water_velocity']

u_cube = quick_load_cubes(url, name_list=u_name_list, strict=True)
v_cube = quick_load_cubes(url, name_list=v_name_list, strict=True)

u_cube = proc_cube(u_cube, bbox=bbox, time=time, units=Unit('m s-1'))
v_cube = proc_cube(v_cube, bbox=bbox, time=time, units=Unit('m s-1'))

# %%
import numpy as np


def subsample_cubes(u_cube, v_cube, n=6):
    """This is just for plotting.  If using cartopy do not
    subsample.  Use cartopy's resample instead."""
    u = u_cube[::n, ::n]
    v = v_cube[::n, ::n]
    lon = u.coord(axis='X').points
    lat = u.coord(axis='Y').points
    if (lon.ndim == 1) and (lat.ndim == 1):
        lon, lat = np.meshgrid(lon, lat)
    time = u.coord('time')
    time.units.num2date(time.points)
    return dict(lon=lon, lat=lat, u=u.data, v=v.data, time=time)


hf_radar = subsample_cubes(u_cube, v_cube, n=1)

# %% [markdown]
# ### SABGOM model

# %%
from utilities import get_roms


model_url = ('http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/'
             'SABGOM_Forecast_Model_Run_Collection_best.ncd')

model = get_roms(model_url, time, n=1)

# %%
import mplleaflet
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
kw = dict(scale=20, headwidth=2, alpha=0.5)

# mplleaflet does not support masked array.
mask = ~hf_radar['u'].mask

Q = ax.quiver(hf_radar['lon'][mask], hf_radar['lat'][mask],
              hf_radar['u'][mask], hf_radar['v'][mask], color='black', **kw)

mask = ~model['u'].mask

Q = ax.quiver(model['lon'][mask], model['lat'][mask],
              model['u'][mask], model['v'][mask], color='red', **kw)

mplleaflet.display(fig=ax.figure)
# Out:
# <head>
#   <link rel="stylesheet" href="http://cdn.leafletjs.com/leaflet-0.7.1/leaflet.css" />
#   <script src="http://cdn.leafletjs.com/leaflet-0.7.1/leaflet.js"></script>
#   <style>
#     .leaflet-container .leaflet-tile {
#        margin: 0;
#     }
#     #map28a30fcaef0a4d1ba84775c8b4536cca {
#       height:480.0px;
#     }
#   </style>
# </head>
# <body>
#   <div id="map28a30fcaef0a4d1ba84775c8b4536cca"></div>
# <script text="text/javascript">
# func28a30fcaef0a4d1ba84775c8b4536cca = function() {
# var map = L.map('map28a30fcaef0a4d1ba84775c8b4536cca');
# L.tileLayer(
#   "http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#   {maxZoom:19, attribution: '<a href="https://github.com/jwass/mplleaflet">mplleaflet</a> | Map data (c) <a href="http://openstreetmap.org">OpenStreetMap</a> contributors'}).addTo(map);
# var gjData = {"type": "FeatureCollection", "features": [{"geometry": {"type": "Point", "coordinates": [-82.842369079589872, 25.889339447021484]}, "type": "Feature", "properties": {"anchor_x": 2.0695999535046035, "html": "<svg width=\"9px\" height=\"7px\" viewBox=\"-2.0695999535 -1.96240005341 9.0 7.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M 0.421599990809 -0.570400007461 L 0.99199999827 -0.148800016652 L 0.843199981619 -1.14080001492 L 5.70400007461 4.21599990809 L -0.843199981619 1.14080001492 L 0.148800016652 0.99199999827 L -0.421599990809 0.570400007461 L 0.421599990809 -0.570400007461\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 1.9624000534137684}}, {"geometry": {"type": "Point", "coordinates": [-83.539276123046903, 26.212980270385742]}, "type": "Feature", "properties": {"anchor_x": 1.128000117657757, "html": "<svg width=\"3px\" height=\"6px\" viewBox=\"-1.12800011766 -1.28879996808 3.0 6.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M 0.372000001747 -0.148799976818 L 0.520799978565 0.223200024929 L 0.744000003494 -0.297599953636 L 1.48799976818 3.72000001747 L -0.744000003494 0.297599953636 L -0.223200024929 0.520799978565 L -0.372000001747 0.148799976818 L 0.372000001747 -0.148799976818\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 1.2887999680823372}}, {"geometry": {"type": "Point", "coordinates": [-83.190826416015653, 26.212980270385742]}, "type": "Feature", "properties": {"anchor_x": 1.210399928480193, "html": "<svg width=\"5px\" height=\"4px\" viewBox=\"-1.21039992848 -1.30559992213 5.0 4.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M 0.198400019203 -0.297600018144 L 0.496000037347 -0.0991999989419 L 0.396800038405 -0.595200036289 L 2.97600018144 1.98400019203 L -0.396800038405 0.595200036289 L 0.0991999989419 0.496000037347 L -0.198400019203 0.297600018144 L 0.198400019203 -0.297600018144\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 1.3055999221314831}}, {"geometry": {"type": "Point", "coordinates": [-82.842369079589872, 26.212980270385742]}, "type": "Feature", "properties": {"anchor_x": 2.5, "html": "<svg width=\"5px\" height=\"4px\" viewBox=\"-2.5 -2.0 5.0 4.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M 1.64322110799 -0.0 L 0.821610553997 -1.42307122356 L -0.821610553997 -1.42307122356 L -1.64322110799 -2.0123654702e-16 L -0.821610553997 1.42307122356 L 0.821610553997 1.42307122356 L 1.64322110799 4.02473094039e-16 L 0.821610553997 -1.42307122356\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 1.9999999999999996}}, {"geometry": {"type": "Point", "coordinates": [-82.493919372558622, 26.212980270385742]}, "type": "Feature", "properties": {"anchor_x": 2.5, "html": "<svg width=\"5px\" height=\"4px\" viewBox=\"-2.5 -2.0 5.0 4.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M 1.63754498194 0.13646208999 L 0.936952127554 -1.3499245092 L -0.700592854384 -1.48638659919 L -1.63754498194 -0.13646208999 L -0.936952127554 1.3499245092 L 0.700592854384 1.48638659919 L 1.63754498194 0.13646208999 L 0.936952127554 -1.3499245092\" fill-opacity=\"0.5\" stroke=\"#000000\" stroke-width=\"0\" stroke-opacity=\"0.5\" fill=\"#000000\" /></svg>", "anchor_y": 1.9999999999999998}}, {"geometry": {"type": "Point", "coordinates": [-83.539276123046903, 26.536619186401367]}, "type": "Feature", "properties": {"anchor_x": 2.0, "html": "<svg width=\"4px\" height=\"5px\" viewBox=\"-2.0 -2.5 4.0 5.0\" xmlns=\"http://www.w3.org/2000/svg\" version=\"1.1\">  <path d=\"M -7.18274758925e-08 1.64322110799 L 1.42307118764 0.821610616201 L 1.42307125947 -0.821610491792 L 7.18274760937e-08 -1.64322110799 L -1.42307118764 -0.82161061 ...
